# %% [markdown]
# # Generate normal htfs

# %%
from perses.tests.test_topology_proposal import generate_atp, generate_dipeptide_top_pos_sys
from simtk.openmm import app, unit
from openmmforcefields.generators import SystemGenerator
import numpy as np
import os
import pickle

import logging
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
# Out:
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=6)
#            2	LOAD_GLOBAL(arg=0, lineno=6)
#            4	LOAD_METHOD(arg=1, lineno=6)
#            6	LOAD_CONST(arg=1, lineno=6)
#            8	CALL_METHOD(arg=1, lineno=6)
#           10	STORE_FAST(arg=2, lineno=6)
#           12	LOAD_FAST(arg=0, lineno=7)
#           14	LOAD_CONST(arg=2, lineno=7)
#           16	BINARY_SUBSCR(arg=None, lineno=7)
#           18	LOAD_FAST(arg=1, lineno=7)
#           20	LOAD_CONST(arg=3, lineno=7)
#           22	BINARY_SUBSCR(arg=None, lineno=7)
#           24	BINARY_MULTIPLY(arg=None, lineno=7)
#           26	LOAD_FAST(arg=0, lineno=7)
#           28	LOAD_CONST(arg=3, lineno=7)
#           30	BINARY_SUBSCR(arg=None, lineno=7)
#           32	LOAD_FAST(arg=1, lineno=7)
#           34	LOAD_CONST(arg=2, lineno=7)
#           36	BINARY_SUBSCR(arg=None, lineno=7)
#           38	BINARY_MULTIPLY(arg=None, lineno=7)
#           40	BINARY_SUBTRACT(arg=None, lineno=7)
#           42	LOAD_FAST(arg=2, lineno=7)
#           44	LOAD_CONST(arg=4, lineno=7)
#           46	STORE_SUBSCR(arg=None, lineno=7)
#           48	LOAD_FAST(arg=0, lineno=8)
#           50	LOAD_CONST(arg=3, lineno=8)
#           52	BINARY_SUBSCR(arg=None, lineno=8)
#           54	LOAD_FAST(arg=1, lineno=8)
#           56	LOAD_CONST(arg=4, lineno=8)
#           58	BINARY_SUBSCR(arg=None, lineno=8)
#           60	BINARY_MULTIPLY(arg=None, lineno=8)
#           62	LOAD_FAST(arg=0, lineno=8)
#           64	LOAD_CONST(arg=4, lineno=8)
#           66	BINARY_SUBSCR(arg=None, lineno=8)
#           68	LOAD_FAST(arg=1, lineno=8)
#           70	LOAD_CONST(arg=3, lineno=8)
#           72	BINARY_SUBSCR(arg=None, lineno=8)
#           74	BINARY_MULTIPLY(arg=None, lineno=8)
#           76	BINARY_SUBTRACT(arg=None, lineno=8)
#           78	LOAD_FAST(arg=2, lineno=8)
#           80	LOAD_CONST(arg=2, lineno=8)
#           82	STORE_SUBSCR(arg=None, lineno=8)
#           84	LOAD_FAST(arg=0, lineno=9)
#           86	LOAD_CONST(arg=4, lineno=9)
#           88	BINARY_SUBSCR(arg=None, lineno=9)
#           90	LOAD_FAST(arg=1, lineno=9)
#           92	LOAD_CONST(arg=2, lineno=9)
#           94	BINARY_SUBSCR(arg=None, lineno=9)
#           96	BINARY_MULTIPLY(arg=None, lineno=9)
#           98	LOAD_FAST(arg=0, lineno=9)
#          100	LOAD_CONST(arg=2, lineno=9)
#          102	BINARY_SUBSCR(arg=None, lineno=9)
#          104	LOAD_FAST(arg=1, lineno=9)
#          106	LOAD_CONST(arg=4, lineno=9)
#          108	BINARY_SUBSCR(arg=None, lineno=9)
#          110	BINARY_MULTIPLY(arg=None, lineno=9)
#          112	BINARY_SUBTRACT(arg=None, lineno=9)
#          114	LOAD_FAST(arg=2, lineno=9)
#          116	LOAD_CONST(arg=3, lineno=9)
#          118	STORE_SUBSCR(arg=None, lineno=9)
#          120	LOAD_FAST(arg=2, lineno=10)
#          122	RETURN_VALUE(arg=None, lineno=10)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=6)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_GLOBAL(arg=0, lineno=6)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_METHOD(arg=1, lineno=6)
# DEBUG:numba.core.byteflow:stack ['$2load_global.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=LOAD_CONST(arg=1, lineno=6)
# DEBUG:numba.core.byteflow:stack ['$4load_method.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=CALL_METHOD(arg=1, lineno=6)
# DEBUG:numba.core.byteflow:stack ['$4load_method.1', '$const6.2']
# DEBUG:numba.core.byteflow:dispatch pc=10, inst=STORE_FAST(arg=2, lineno=6)
# DEBUG:numba.core.byteflow:stack ['$8call_method.3']
# DEBUG:numba.core.byteflow:dispatch pc=12, inst=LOAD_FAST(arg=0, lineno=7)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=14, inst=LOAD_CONST(arg=2, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$a12.4']
# DEBUG:numba.core.byteflow:dispatch pc=16, inst=BINARY_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$a12.4', '$const14.5']
# DEBUG:numba.core.byteflow:dispatch pc=18, inst=LOAD_FAST(arg=1, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$16binary_subscr.6']
# DEBUG:numba.core.byteflow:dispatch pc=20, inst=LOAD_CONST(arg=3, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$16binary_subscr.6', '$b18.7']
# DEBUG:numba.core.byteflow:dispatch pc=22, inst=BINARY_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$16binary_subscr.6', '$b18.7', '$const20.8']
# DEBUG:numba.core.byteflow:dispatch pc=24, inst=BINARY_MULTIPLY(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$16binary_subscr.6', '$22binary_subscr.9']
# DEBUG:numba.core.byteflow:dispatch pc=26, inst=LOAD_FAST(arg=0, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10']
# DEBUG:numba.core.byteflow:dispatch pc=28, inst=LOAD_CONST(arg=3, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$a26.11']
# DEBUG:numba.core.byteflow:dispatch pc=30, inst=BINARY_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$a26.11', '$const28.12']
# DEBUG:numba.core.byteflow:dispatch pc=32, inst=LOAD_FAST(arg=1, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$30binary_subscr.13']
# DEBUG:numba.core.byteflow:dispatch pc=34, inst=LOAD_CONST(arg=2, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$30binary_subscr.13', '$b32.14']
# DEBUG:numba.core.byteflow:dispatch pc=36, inst=BINARY_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$30binary_subscr.13', '$b32.14', '$const34.15']
# DEBUG:numba.core.byteflow:dispatch pc=38, inst=BINARY_MULTIPLY(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$30binary_subscr.13', '$36binary_subscr.16']
# DEBUG:numba.core.byteflow:dispatch pc=40, inst=BINARY_SUBTRACT(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$38binary_multiply.17']
# DEBUG:numba.core.byteflow:dispatch pc=42, inst=LOAD_FAST(arg=2, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$40binary_subtract.18']
# DEBUG:numba.core.byteflow:dispatch pc=44, inst=LOAD_CONST(arg=4, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$40binary_subtract.18', '$c42.19']
# DEBUG:numba.core.byteflow:dispatch pc=46, inst=STORE_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$40binary_subtract.18', '$c42.19', '$const44.20']
# DEBUG:numba.core.byteflow:dispatch pc=48, inst=LOAD_FAST(arg=0, lineno=8)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=50, inst=LOAD_CONST(arg=3, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$a48.21']
# DEBUG:numba.core.byteflow:dispatch pc=52, inst=BINARY_SUBSCR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$a48.21', '$const50.22']
# DEBUG:numba.core.byteflow:dispatch pc=54, inst=LOAD_FAST(arg=1, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$52binary_subscr.23']
# DEBUG:numba.core.byteflow:dispatch pc=56, inst=LOAD_CONST(arg=4, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$52binary_subscr.23', '$b54.24']
# DEBUG:numba.core.byteflow:dispatch pc=58, inst=BINARY_SUBSCR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$52binary_subscr.23', '$b54.24', '$const56.25']
# DEBUG:numba.core.byteflow:dispatch pc=60, inst=BINARY_MULTIPLY(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$52binary_subscr.23', '$58binary_subscr.26']
# DEBUG:numba.core.byteflow:dispatch pc=62, inst=LOAD_FAST(arg=0, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27']
# DEBUG:numba.core.byteflow:dispatch pc=64, inst=LOAD_CONST(arg=4, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$a62.28']
# DEBUG:numba.core.byteflow:dispatch pc=66, inst=BINARY_SUBSCR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$a62.28', '$const64.29']
# DEBUG:numba.core.byteflow:dispatch pc=68, inst=LOAD_FAST(arg=1, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$66binary_subscr.30']
# DEBUG:numba.core.byteflow:dispatch pc=70, inst=LOAD_CONST(arg=3, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$66binary_subscr.30', '$b68.31']
# DEBUG:numba.core.byteflow:dispatch pc=72, inst=BINARY_SUBSCR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$66binary_subscr.30', '$b68.31', '$const70.32']
# DEBUG:numba.core.byteflow:dispatch pc=74, inst=BINARY_MULTIPLY(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$66binary_subscr.30', '$72binary_subscr.33']
# DEBUG:numba.core.byteflow:dispatch pc=76, inst=BINARY_SUBTRACT(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$74binary_multiply.34']
# DEBUG:numba.core.byteflow:dispatch pc=78, inst=LOAD_FAST(arg=2, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$76binary_subtract.35']
# DEBUG:numba.core.byteflow:dispatch pc=80, inst=LOAD_CONST(arg=2, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$76binary_subtract.35', '$c78.36']
# DEBUG:numba.core.byteflow:dispatch pc=82, inst=STORE_SUBSCR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$76binary_subtract.35', '$c78.36', '$const80.37']
# DEBUG:numba.core.byteflow:dispatch pc=84, inst=LOAD_FAST(arg=0, lineno=9)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=86, inst=LOAD_CONST(arg=4, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$a84.38']
# DEBUG:numba.core.byteflow:dispatch pc=88, inst=BINARY_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$a84.38', '$const86.39']
# DEBUG:numba.core.byteflow:dispatch pc=90, inst=LOAD_FAST(arg=1, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$88binary_subscr.40']
# DEBUG:numba.core.byteflow:dispatch pc=92, inst=LOAD_CONST(arg=2, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$88binary_subscr.40', '$b90.41']
# DEBUG:numba.core.byteflow:dispatch pc=94, inst=BINARY_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$88binary_subscr.40', '$b90.41', '$const92.42']
# DEBUG:numba.core.byteflow:dispatch pc=96, inst=BINARY_MULTIPLY(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$88binary_subscr.40', '$94binary_subscr.43']
# DEBUG:numba.core.byteflow:dispatch pc=98, inst=LOAD_FAST(arg=0, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44']
# DEBUG:numba.core.byteflow:dispatch pc=100, inst=LOAD_CONST(arg=2, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$a98.45']
# DEBUG:numba.core.byteflow:dispatch pc=102, inst=BINARY_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$a98.45', '$const100.46']
# DEBUG:numba.core.byteflow:dispatch pc=104, inst=LOAD_FAST(arg=1, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$102binary_subscr.47']
# DEBUG:numba.core.byteflow:dispatch pc=106, inst=LOAD_CONST(arg=4, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$102binary_subscr.47', '$b104.48']
# DEBUG:numba.core.byteflow:dispatch pc=108, inst=BINARY_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$102binary_subscr.47', '$b104.48', '$const106.49']
# DEBUG:numba.core.byteflow:dispatch pc=110, inst=BINARY_MULTIPLY(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$102binary_subscr.47', '$108binary_subscr.50']
# DEBUG:numba.core.byteflow:dispatch pc=112, inst=BINARY_SUBTRACT(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$110binary_multiply.51']
# DEBUG:numba.core.byteflow:dispatch pc=114, inst=LOAD_FAST(arg=2, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$112binary_subtract.52']
# DEBUG:numba.core.byteflow:dispatch pc=116, inst=LOAD_CONST(arg=3, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$112binary_subtract.52', '$c114.53']
# DEBUG:numba.core.byteflow:dispatch pc=118, inst=STORE_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$112binary_subtract.52', '$c114.53', '$const116.54']
# DEBUG:numba.core.byteflow:dispatch pc=120, inst=LOAD_FAST(arg=2, lineno=10)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=122, inst=RETURN_VALUE(arg=None, lineno=10)
# DEBUG:numba.core.byteflow:stack ['$c120.55']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$2load_global.0'}), (4, {'item': '$2load_global.0', 'res': '$4load_method.1'}), (6, {'res': '$const6.2'}), (8, {'func': '$4load_method.1', 'args': ['$const6.2'], 'res': '$8call_method.3'}), (10, {'value': '$8call_method.3'}), (12, {'res': '$a12.4'}), (14, {'res': '$const14.5'}), (16, {'index': '$const14.5', 'target': '$a12.4', 'res': '$16binary_subscr.6'}), (18, {'res': '$b18.7'}), (20, {'res': '$const20.8'}), (22, {'index': '$const20.8', 'target': '$b18.7', 'res': '$22binary_subscr.9'}), (24, {'lhs': '$16binary_subscr.6', 'rhs': '$22binary_subscr.9', 'res': '$24binary_multiply.10'}), (26, {'res': '$a26.11'}), (28, {'res': '$const28.12'}), (30, {'index': '$const28.12', 'target': '$a26.11', 'res': '$30binary_subscr.13'}), (32, {'res': '$b32.14'}), (34, {'res': '$const34.15'}), (36, {'index': '$const34.15', 'target': '$b32.14', 'res': '$36binary_subscr.16'}), (38, {'lhs': '$30binary_subscr.13', 'rhs': '$36binary_subscr.16', 'res': '$38binary_multiply.17'}), (40, {'lhs': '$24binary_multiply.10', 'rhs': '$38binary_multiply.17', 'res': '$40binary_subtract.18'}), (42, {'res': '$c42.19'}), (44, {'res': '$const44.20'}), (46, {'target': '$c42.19', 'index': '$const44.20', 'value': '$40binary_subtract.18'}), (48, {'res': '$a48.21'}), (50, {'res': '$const50.22'}), (52, {'index': '$const50.22', 'target': '$a48.21', 'res': '$52binary_subscr.23'}), (54, {'res': '$b54.24'}), (56, {'res': '$const56.25'}), (58, {'index': '$const56.25', 'target': '$b54.24', 'res': '$58binary_subscr.26'}), (60, {'lhs': '$52binary_subscr.23', 'rhs': '$58binary_subscr.26', 'res': '$60binary_multiply.27'}), (62, {'res': '$a62.28'}), (64, {'res': '$const64.29'}), (66, {'index': '$const64.29', 'target': '$a62.28', 'res': '$66binary_subscr.30'}), (68, {'res': '$b68.31'}), (70, {'res': '$const70.32'}), (72, {'index': '$const70.32', 'target': '$b68.31', 'res': '$72binary_subscr.33'}), (74, {'lhs': '$66binary_subscr.30', 'rhs': '$72binary_subscr.33', 'res': '$74binary_multiply.34'}), (76, {'lhs': '$60binary_multiply.27', 'rhs': '$74binary_multiply.34', 'res': '$76binary_subtract.35'}), (78, {'res': '$c78.36'}), (80, {'res': '$const80.37'}), (82, {'target': '$c78.36', 'index': '$const80.37', 'value': '$76binary_subtract.35'}), (84, {'res': '$a84.38'}), (86, {'res': '$const86.39'}), (88, {'index': '$const86.39', 'target': '$a84.38', 'res': '$88binary_subscr.40'}), (90, {'res': '$b90.41'}), (92, {'res': '$const92.42'}), (94, {'index': '$const92.42', 'target': '$b90.41', 'res': '$94binary_subscr.43'}), (96, {'lhs': '$88binary_subscr.40', 'rhs': '$94binary_subscr.43', 'res': '$96binary_multiply.44'}), (98, {'res': '$a98.45'}), (100, {'res': '$const100.46'}), (102, {'index': '$const100.46', 'target': '$a98.45', 'res': '$102binary_subscr.47'}), (104, {'res': '$b104.48'}), (106, {'res': '$const106.49'}), (108, {'index': '$const106.49', 'target': '$b104.48', 'res': '$108binary_subscr.50'}), (110, {'lhs': '$102binary_subscr.47', 'rhs': '$108binary_subscr.50', 'res': '$110binary_multiply.51'}), (112, {'lhs': '$96binary_multiply.44', 'rhs': '$110binary_multiply.51', 'res': '$112binary_subtract.52'}), (114, {'res': '$c114.53'}), (116, {'res': '$const116.54'}), (118, {'target': '$c114.53', 'index': '$const116.54', 'value': '$112binary_subtract.52'}), (120, {'res': '$c120.55'}), (122, {'retval': '$c120.55', 'castval': '$122return_value.56'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     a = arg(0, name=a)                       ['a']
#     b = arg(1, name=b)                       ['b']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=zeros) ['$2load_global.0', '$4load_method.1']
#     $const6.2 = const(int, 3)                ['$const6.2']
#     $8call_method.3 = call $4load_method.1($const6.2, func=$4load_method.1, args=[Var($const6.2, coordinate_numba.py:6)], kws=(), vararg=None) ['$4load_method.1', '$8call_method.3', '$const6.2']
#     c = $8call_method.3                      ['$8call_method.3', 'c']
#     $const14.5 = const(int, 1)               ['$const14.5']
#     $16binary_subscr.6 = getitem(value=a, index=$const14.5) ['$16binary_subscr.6', '$const14.5', 'a']
#     $const20.8 = const(int, 2)               ['$const20.8']
#     $22binary_subscr.9 = getitem(value=b, index=$const20.8) ['$22binary_subscr.9', '$const20.8', 'b']
#     $24binary_multiply.10 = $16binary_subscr.6 * $22binary_subscr.9 ['$16binary_subscr.6', '$22binary_subscr.9', '$24binary_multiply.10']
#     $const28.12 = const(int, 2)              ['$const28.12']
#     $30binary_subscr.13 = getitem(value=a, index=$const28.12) ['$30binary_subscr.13', '$const28.12', 'a']
#     $const34.15 = const(int, 1)              ['$const34.15']
#     $36binary_subscr.16 = getitem(value=b, index=$const34.15) ['$36binary_subscr.16', '$const34.15', 'b']
#     $38binary_multiply.17 = $30binary_subscr.13 * $36binary_subscr.16 ['$30binary_subscr.13', '$36binary_subscr.16', '$38binary_multiply.17']
#     $40binary_subtract.18 = $24binary_multiply.10 - $38binary_multiply.17 ['$24binary_multiply.10', '$38binary_multiply.17', '$40binary_subtract.18']
#     $const44.20 = const(int, 0)              ['$const44.20']
#     c[$const44.20] = $40binary_subtract.18   ['$40binary_subtract.18', '$const44.20', 'c']
#     $const50.22 = const(int, 2)              ['$const50.22']
#     $52binary_subscr.23 = getitem(value=a, index=$const50.22) ['$52binary_subscr.23', '$const50.22', 'a']
#     $const56.25 = const(int, 0)              ['$const56.25']
#     $58binary_subscr.26 = getitem(value=b, index=$const56.25) ['$58binary_subscr.26', '$const56.25', 'b']
#     $60binary_multiply.27 = $52binary_subscr.23 * $58binary_subscr.26 ['$52binary_subscr.23', '$58binary_subscr.26', '$60binary_multiply.27']
#     $const64.29 = const(int, 0)              ['$const64.29']
#     $66binary_subscr.30 = getitem(value=a, index=$const64.29) ['$66binary_subscr.30', '$const64.29', 'a']
#     $const70.32 = const(int, 2)              ['$const70.32']
#     $72binary_subscr.33 = getitem(value=b, index=$const70.32) ['$72binary_subscr.33', '$const70.32', 'b']
#     $74binary_multiply.34 = $66binary_subscr.30 * $72binary_subscr.33 ['$66binary_subscr.30', '$72binary_subscr.33', '$74binary_multiply.34']
#     $76binary_subtract.35 = $60binary_multiply.27 - $74binary_multiply.34 ['$60binary_multiply.27', '$74binary_multiply.34', '$76binary_subtract.35']
#     $const80.37 = const(int, 1)              ['$const80.37']
#     c[$const80.37] = $76binary_subtract.35   ['$76binary_subtract.35', '$const80.37', 'c']
#     $const86.39 = const(int, 0)              ['$const86.39']
#     $88binary_subscr.40 = getitem(value=a, index=$const86.39) ['$88binary_subscr.40', '$const86.39', 'a']
#     $const92.42 = const(int, 1)              ['$const92.42']
#     $94binary_subscr.43 = getitem(value=b, index=$const92.42) ['$94binary_subscr.43', '$const92.42', 'b']
#     $96binary_multiply.44 = $88binary_subscr.40 * $94binary_subscr.43 ['$88binary_subscr.40', '$94binary_subscr.43', '$96binary_multiply.44']
#     $const100.46 = const(int, 1)             ['$const100.46']
#     $102binary_subscr.47 = getitem(value=a, index=$const100.46) ['$102binary_subscr.47', '$const100.46', 'a']
#     $const106.49 = const(int, 0)             ['$const106.49']
#     $108binary_subscr.50 = getitem(value=b, index=$const106.49) ['$108binary_subscr.50', '$const106.49', 'b']
#     $110binary_multiply.51 = $102binary_subscr.47 * $108binary_subscr.50 ['$102binary_subscr.47', '$108binary_subscr.50', '$110binary_multiply.51']
#     $112binary_subtract.52 = $96binary_multiply.44 - $110binary_multiply.51 ['$110binary_multiply.51', '$112binary_subtract.52', '$96binary_multiply.44']
#     $const116.54 = const(int, 2)             ['$const116.54']
#     c[$const116.54] = $112binary_subtract.52 ['$112binary_subtract.52', '$const116.54', 'c']
#     $122return_value.56 = cast(value=c)      ['$122return_value.56', 'c']
#     return $122return_value.56               ['$122return_value.56']
# DEBUG:numba.core.ssa:-----------------------------------BEFORE SSA-----------------------------------
# DEBUG:numba.core.ssa:label 0:
#     a = arg(0, name=a)                       ['a']
#     b = arg(1, name=b)                       ['b']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=zeros) ['$2load_global.0', '$4load_method.1']
#     $const6.2 = const(int, 3)                ['$const6.2']
#     $8call_method.3 = call $4load_method.1($const6.2, func=$4load_method.1, args=[Var($const6.2, coordinate_numba.py:6)], kws=(), vararg=None) ['$4load_method.1', '$8call_method.3', '$const6.2']
#     c = $8call_method.3                      ['$8call_method.3', 'c']
#     $const14.5 = const(int, 1)               ['$const14.5']
#     $16binary_subscr.6 = static_getitem(value=a, index=1, index_var=$const14.5) ['$16binary_subscr.6', '$const14.5', 'a']
#     $const20.8 = const(int, 2)               ['$const20.8']
#     $22binary_subscr.9 = static_getitem(value=b, index=2, index_var=$const20.8) ['$22binary_subscr.9', '$const20.8', 'b']
#     $24binary_multiply.10 = $16binary_subscr.6 * $22binary_subscr.9 ['$16binary_subscr.6', '$22binary_subscr.9', '$24binary_multiply.10']
#     $const28.12 = const(int, 2)              ['$const28.12']
#     $30binary_subscr.13 = static_getitem(value=a, index=2, index_var=$const28.12) ['$30binary_subscr.13', '$const28.12', 'a']
#     $const34.15 = const(int, 1)              ['$const34.15']
#     $36binary_subscr.16 = static_getitem(value=b, index=1, index_var=$const34.15) ['$36binary_subscr.16', '$const34.15', 'b']
#     $38binary_multiply.17 = $30binary_subscr.13 * $36binary_subscr.16 ['$30binary_subscr.13', '$36binary_subscr.16', '$38binary_multiply.17']
#     $40binary_subtract.18 = $24binary_multiply.10 - $38binary_multiply.17 ['$24binary_multiply.10', '$38binary_multiply.17', '$40binary_subtract.18']
#     $const44.20 = const(int, 0)              ['$const44.20']
#     c[0] = $40binary_subtract.18             ['$40binary_subtract.18', '$const44.20', 'c']
#     $const50.22 = const(int, 2)              ['$const50.22']
#     $52binary_subscr.23 = static_getitem(value=a, index=2, index_var=$const50.22) ['$52binary_subscr.23', '$const50.22', 'a']
#     $const56.25 = const(int, 0)              ['$const56.25']
#     $58binary_subscr.26 = static_getitem(value=b, index=0, index_var=$const56.25) ['$58binary_subscr.26', '$const56.25', 'b']
#     $60binary_multiply.27 = $52binary_subscr.23 * $58binary_subscr.26 ['$52binary_subscr.23', '$58binary_subscr.26', '$60binary_multiply.27']
#     $const64.29 = const(int, 0)              ['$const64.29']
#     $66binary_subscr.30 = static_getitem(value=a, index=0, index_var=$const64.29) ['$66binary_subscr.30', '$const64.29', 'a']
#     $const70.32 = const(int, 2)              ['$const70.32']
#     $72binary_subscr.33 = static_getitem(value=b, index=2, index_var=$const70.32) ['$72binary_subscr.33', '$const70.32', 'b']
#     $74binary_multiply.34 = $66binary_subscr.30 * $72binary_subscr.33 ['$66binary_subscr.30', '$72binary_subscr.33', '$74binary_multiply.34']
#     $76binary_subtract.35 = $60binary_multiply.27 - $74binary_multiply.34 ['$60binary_multiply.27', '$74binary_multiply.34', '$76binary_subtract.35']
#     $const80.37 = const(int, 1)              ['$const80.37']
#     c[1] = $76binary_subtract.35             ['$76binary_subtract.35', '$const80.37', 'c']
#     $const86.39 = const(int, 0)              ['$const86.39']
#     $88binary_subscr.40 = static_getitem(value=a, index=0, index_var=$const86.39) ['$88binary_subscr.40', '$const86.39', 'a']
#     $const92.42 = const(int, 1)              ['$const92.42']
#     $94binary_subscr.43 = static_getitem(value=b, index=1, index_var=$const92.42) ['$94binary_subscr.43', '$const92.42', 'b']
#     $96binary_multiply.44 = $88binary_subscr.40 * $94binary_subscr.43 ['$88binary_subscr.40', '$94binary_subscr.43', '$96binary_multiply.44']
#     $const100.46 = const(int, 1)             ['$const100.46']
#     $102binary_subscr.47 = static_getitem(value=a, index=1, index_var=$const100.46) ['$102binary_subscr.47', '$const100.46', 'a']
#     $const106.49 = const(int, 0)             ['$const106.49']
#     $108binary_subscr.50 = static_getitem(value=b, index=0, index_var=$const106.49) ['$108binary_subscr.50', '$const106.49', 'b']
#     $110binary_multiply.51 = $102binary_subscr.47 * $108binary_subscr.50 ['$102binary_subscr.47', '$108binary_subscr.50', '$110binary_multiply.51']
#     $112binary_subtract.52 = $96binary_multiply.44 - $110binary_multiply.51 ['$110binary_multiply.51', '$112binary_subtract.52', '$96binary_multiply.44']
#     $const116.54 = const(int, 2)             ['$const116.54']
#     c[2] = $112binary_subtract.52            ['$112binary_subtract.52', '$const116.54', 'c']
#     $122return_value.56 = cast(value=c)      ['$122return_value.56', 'c']
#     return $122return_value.56               ['$122return_value.56']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b21affc5a20>
# DEBUG:numba.core.ssa:on stmt: a = arg(0, name=a)
# DEBUG:numba.core.ssa:on stmt: b = arg(1, name=b)
# DEBUG:numba.core.ssa:on stmt: $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $4load_method.1 = getattr(value=$2load_global.0, attr=zeros)
# DEBUG:numba.core.ssa:on stmt: $const6.2 = const(int, 3)
# DEBUG:numba.core.ssa:on stmt: $8call_method.3 = call $4load_method.1($const6.2, func=$4load_method.1, args=[Var($const6.2, coordinate_numba.py:6)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: c = $8call_method.3
# DEBUG:numba.core.ssa:on stmt: $const14.5 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $16binary_subscr.6 = static_getitem(value=a, index=1, index_var=$const14.5)
# DEBUG:numba.core.ssa:on stmt: $const20.8 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $22binary_subscr.9 = static_getitem(value=b, index=2, index_var=$const20.8)
# DEBUG:numba.core.ssa:on stmt: $24binary_multiply.10 = $16binary_subscr.6 * $22binary_subscr.9
# DEBUG:numba.core.ssa:on stmt: $const28.12 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $30binary_subscr.13 = static_getitem(value=a, index=2, index_var=$const28.12)
# DEBUG:numba.core.ssa:on stmt: $const34.15 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $36binary_subscr.16 = static_getitem(value=b, index=1, index_var=$const34.15)
# DEBUG:numba.core.ssa:on stmt: $38binary_multiply.17 = $30binary_subscr.13 * $36binary_subscr.16
# DEBUG:numba.core.ssa:on stmt: $40binary_subtract.18 = $24binary_multiply.10 - $38binary_multiply.17
# DEBUG:numba.core.ssa:on stmt: $const44.20 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: c[0] = $40binary_subtract.18
# DEBUG:numba.core.ssa:on stmt: $const50.22 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $52binary_subscr.23 = static_getitem(value=a, index=2, index_var=$const50.22)
# DEBUG:numba.core.ssa:on stmt: $const56.25 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $58binary_subscr.26 = static_getitem(value=b, index=0, index_var=$const56.25)
# DEBUG:numba.core.ssa:on stmt: $60binary_multiply.27 = $52binary_subscr.23 * $58binary_subscr.26
# DEBUG:numba.core.ssa:on stmt: $const64.29 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $66binary_subscr.30 = static_getitem(value=a, index=0, index_var=$const64.29)
# DEBUG:numba.core.ssa:on stmt: $const70.32 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $72binary_subscr.33 = static_getitem(value=b, index=2, index_var=$const70.32)
# DEBUG:numba.core.ssa:on stmt: $74binary_multiply.34 = $66binary_subscr.30 * $72binary_subscr.33
# DEBUG:numba.core.ssa:on stmt: $76binary_subtract.35 = $60binary_multiply.27 - $74binary_multiply.34
# DEBUG:numba.core.ssa:on stmt: $const80.37 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: c[1] = $76binary_subtract.35
# DEBUG:numba.core.ssa:on stmt: $const86.39 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $88binary_subscr.40 = static_getitem(value=a, index=0, index_var=$const86.39)
# DEBUG:numba.core.ssa:on stmt: $const92.42 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $94binary_subscr.43 = static_getitem(value=b, index=1, index_var=$const92.42)
# DEBUG:numba.core.ssa:on stmt: $96binary_multiply.44 = $88binary_subscr.40 * $94binary_subscr.43
# DEBUG:numba.core.ssa:on stmt: $const100.46 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $102binary_subscr.47 = static_getitem(value=a, index=1, index_var=$const100.46)
# DEBUG:numba.core.ssa:on stmt: $const106.49 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $108binary_subscr.50 = static_getitem(value=b, index=0, index_var=$const106.49)
# DEBUG:numba.core.ssa:on stmt: $110binary_multiply.51 = $102binary_subscr.47 * $108binary_subscr.50
# DEBUG:numba.core.ssa:on stmt: $112binary_subtract.52 = $96binary_multiply.44 - $110binary_multiply.51
# DEBUG:numba.core.ssa:on stmt: $const116.54 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: c[2] = $112binary_subtract.52
# DEBUG:numba.core.ssa:on stmt: $122return_value.56 = cast(value=c)
# DEBUG:numba.core.ssa:on stmt: return $122return_value.56
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$102binary_subscr.47': [<numba.core.ir.Assign object at 0x2b21cf952f28>],
#              '$108binary_subscr.50': [<numba.core.ir.Assign object at 0x2b21cf952f98>],
#              '$110binary_multiply.51': [<numba.core.ir.Assign object at 0x2b21cf9526a0>],
#              '$112binary_subtract.52': [<numba.core.ir.Assign object at 0x2b21cf952780>],
#              '$122return_value.56': [<numba.core.ir.Assign object at 0x2b21cf952b00>],
#              '$16binary_subscr.6': [<numba.core.ir.Assign object at 0x2b21cf952400>],
#              '$22binary_subscr.9': [<numba.core.ir.Assign object at 0x2b21cf952a20>],
#              '$24binary_multiply.10': [<numba.core.ir.Assign object at 0x2b21cf94a400>],
#              '$2load_global.0': [<numba.core.ir.Assign object at 0x2b21cf930b38>],
#              '$30binary_subscr.13': [<numba.core.ir.Assign object at 0x2b21cf952ba8>],
#              '$36binary_subscr.16': [<numba.core.ir.Assign object at 0x2b21cf952c18>],
#              '$38binary_multiply.17': [<numba.core.ir.Assign object at 0x2b21cf94a9b0>],
#              '$40binary_subtract.18': [<numba.core.ir.Assign object at 0x2b21cf94aa90>],
#              '$4load_method.1': [<numba.core.ir.Assign object at 0x2b21cf930be0>],
#              '$52binary_subscr.23': [<numba.core.ir.Assign object at 0x2b21cf952c88>],
#              '$58binary_subscr.26': [<numba.core.ir.Assign object at 0x2b21cf952cf8>],
#              '$60binary_multiply.27': [<numba.core.ir.Assign object at 0x2b21cf94f278>],
#              '$66binary_subscr.30': [<numba.core.ir.Assign object at 0x2b21cf952d68>],
#              '$72binary_subscr.33': [<numba.core.ir.Assign object at 0x2b21cf952dd8>],
#              '$74binary_multiply.34': [<numba.core.ir.Assign object at 0x2b21cf94f828>],
#              '$76binary_subtract.35': [<numba.core.ir.Assign object at 0x2b21cf94f908>],
#              '$88binary_subscr.40': [<numba.core.ir.Assign object at 0x2b21cf952e48>],
#              '$8call_method.3': [<numba.core.ir.Assign object at 0x2b21cf930d68>],
#              '$94binary_subscr.43': [<numba.core.ir.Assign object at 0x2b21cf952eb8>],
#              '$96binary_multiply.44': [<numba.core.ir.Assign object at 0x2b21cf9520f0>],
#              '$const100.46': [<numba.core.ir.Assign object at 0x2b21cf952278>],
#              '$const106.49': [<numba.core.ir.Assign object at 0x2b21cf9524e0>],
#              '$const116.54': [<numba.core.ir.Assign object at 0x2b21cf952908>],
#              '$const14.5': [<numba.core.ir.Assign object at 0x2b21cf930f98>],
#              '$const20.8': [<numba.core.ir.Assign object at 0x2b21cf94a240>],
#              '$const28.12': [<numba.core.ir.Assign object at 0x2b21cf94a588>],
#              '$const34.15': [<numba.core.ir.Assign object at 0x2b21cf94a7f0>],
#              '$const44.20': [<numba.core.ir.Assign object at 0x2b21cf94ac18>],
#              '$const50.22': [<numba.core.ir.Assign object at 0x2b21cf94ae10>],
#              '$const56.25': [<numba.core.ir.Assign object at 0x2b21cf94f0b8>],
#              '$const6.2': [<numba.core.ir.Assign object at 0x2b21cf930cc0>],
#              '$const64.29': [<numba.core.ir.Assign object at 0x2b21cf94f400>],
#              '$const70.32': [<numba.core.ir.Assign object at 0x2b21cf94f668>],
#              '$const80.37': [<numba.core.ir.Assign object at 0x2b21cf94fa90>],
#              '$const86.39': [<numba.core.ir.Assign object at 0x2b21cf94fc88>],
#              '$const92.42': [<numba.core.ir.Assign object at 0x2b21cf94fef0>],
#              'a': [<numba.core.ir.Assign object at 0x2b21cf9309b0>],
#              'b': [<numba.core.ir.Assign object at 0x2b21cf930a58>],
#              'c': [<numba.core.ir.Assign object at 0x2b21cf930e10>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     a = arg(0, name=a)                       ['a']
#     b = arg(1, name=b)                       ['b']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=zeros) ['$2load_global.0', '$4load_method.1']
#     $const6.2 = const(int, 3)                ['$const6.2']
#     $8call_method.3 = call $4load_method.1($const6.2, func=$4load_method.1, args=[Var($const6.2, coordinate_numba.py:6)], kws=(), vararg=None) ['$4load_method.1', '$8call_method.3', '$const6.2']
#     c = $8call_method.3                      ['$8call_method.3', 'c']
#     $const14.5 = const(int, 1)               ['$const14.5']
#     $16binary_subscr.6 = static_getitem(value=a, index=1, index_var=$const14.5) ['$16binary_subscr.6', '$const14.5', 'a']
#     $const20.8 = const(int, 2)               ['$const20.8']
#     $22binary_subscr.9 = static_getitem(value=b, index=2, index_var=$const20.8) ['$22binary_subscr.9', '$const20.8', 'b']
#     $24binary_multiply.10 = $16binary_subscr.6 * $22binary_subscr.9 ['$16binary_subscr.6', '$22binary_subscr.9', '$24binary_multiply.10']
#     $const28.12 = const(int, 2)              ['$const28.12']
#     $30binary_subscr.13 = static_getitem(value=a, index=2, index_var=$const28.12) ['$30binary_subscr.13', '$const28.12', 'a']
#     $const34.15 = const(int, 1)              ['$const34.15']
#     $36binary_subscr.16 = static_getitem(value=b, index=1, index_var=$const34.15) ['$36binary_subscr.16', '$const34.15', 'b']
#     $38binary_multiply.17 = $30binary_subscr.13 * $36binary_subscr.16 ['$30binary_subscr.13', '$36binary_subscr.16', '$38binary_multiply.17']
#     $40binary_subtract.18 = $24binary_multiply.10 - $38binary_multiply.17 ['$24binary_multiply.10', '$38binary_multiply.17', '$40binary_subtract.18']
#     $const44.20 = const(int, 0)              ['$const44.20']
#     c[0] = $40binary_subtract.18             ['$40binary_subtract.18', '$const44.20', 'c']
#     $const50.22 = const(int, 2)              ['$const50.22']
#     $52binary_subscr.23 = static_getitem(value=a, index=2, index_var=$const50.22) ['$52binary_subscr.23', '$const50.22', 'a']
#     $const56.25 = const(int, 0)              ['$const56.25']
#     $58binary_subscr.26 = static_getitem(value=b, index=0, index_var=$const56.25) ['$58binary_subscr.26', '$const56.25', 'b']
#     $60binary_multiply.27 = $52binary_subscr.23 * $58binary_subscr.26 ['$52binary_subscr.23', '$58binary_subscr.26', '$60binary_multiply.27']
#     $const64.29 = const(int, 0)              ['$const64.29']
#     $66binary_subscr.30 = static_getitem(value=a, index=0, index_var=$const64.29) ['$66binary_subscr.30', '$const64.29', 'a']
#     $const70.32 = const(int, 2)              ['$const70.32']
#     $72binary_subscr.33 = static_getitem(value=b, index=2, index_var=$const70.32) ['$72binary_subscr.33', '$const70.32', 'b']
#     $74binary_multiply.34 = $66binary_subscr.30 * $72binary_subscr.33 ['$66binary_subscr.30', '$72binary_subscr.33', '$74binary_multiply.34']
#     $76binary_subtract.35 = $60binary_multiply.27 - $74binary_multiply.34 ['$60binary_multiply.27', '$74binary_multiply.34', '$76binary_subtract.35']
#     $const80.37 = const(int, 1)              ['$const80.37']
#     c[1] = $76binary_subtract.35             ['$76binary_subtract.35', '$const80.37', 'c']
#     $const86.39 = const(int, 0)              ['$const86.39']
#     $88binary_subscr.40 = static_getitem(value=a, index=0, index_var=$const86.39) ['$88binary_subscr.40', '$const86.39', 'a']
#     $const92.42 = const(int, 1)              ['$const92.42']
#     $94binary_subscr.43 = static_getitem(value=b, index=1, index_var=$const92.42) ['$94binary_subscr.43', '$const92.42', 'b']
#     $96binary_multiply.44 = $88binary_subscr.40 * $94binary_subscr.43 ['$88binary_subscr.40', '$94binary_subscr.43', '$96binary_multiply.44']
#     $const100.46 = const(int, 1)             ['$const100.46']
#     $102binary_subscr.47 = static_getitem(value=a, index=1, index_var=$const100.46) ['$102binary_subscr.47', '$const100.46', 'a']
#     $const106.49 = const(int, 0)             ['$const106.49']
#     $108binary_subscr.50 = static_getitem(value=b, index=0, index_var=$const106.49) ['$108binary_subscr.50', '$const106.49', 'b']
#     $110binary_multiply.51 = $102binary_subscr.47 * $108binary_subscr.50 ['$102binary_subscr.47', '$108binary_subscr.50', '$110binary_multiply.51']
#     $112binary_subtract.52 = $96binary_multiply.44 - $110binary_multiply.51 ['$110binary_multiply.51', '$112binary_subtract.52', '$96binary_multiply.44']
#     $const116.54 = const(int, 2)             ['$const116.54']
#     c[2] = $112binary_subtract.52            ['$112binary_subtract.52', '$const116.54', 'c']
#     $122return_value.56 = cast(value=c)      ['$122return_value.56', 'c']
#     return $122return_value.56               ['$122return_value.56']
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=14)
#            2	LOAD_GLOBAL(arg=0, lineno=14)
#            4	LOAD_METHOD(arg=1, lineno=14)
#            6	LOAD_FAST(arg=0, lineno=14)
#            8	LOAD_FAST(arg=0, lineno=14)
#           10	CALL_METHOD(arg=2, lineno=14)
#           12	STORE_FAST(arg=1, lineno=14)
#           14	LOAD_GLOBAL(arg=0, lineno=15)
#           16	LOAD_METHOD(arg=2, lineno=15)
#           18	LOAD_FAST(arg=1, lineno=15)
#           20	CALL_METHOD(arg=1, lineno=15)
#           22	RETURN_VALUE(arg=None, lineno=15)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=14)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_GLOBAL(arg=0, lineno=14)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_METHOD(arg=1, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$2load_global.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=LOAD_FAST(arg=0, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$4load_method.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=LOAD_FAST(arg=0, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$4load_method.1', '$a6.2']
# DEBUG:numba.core.byteflow:dispatch pc=10, inst=CALL_METHOD(arg=2, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$4load_method.1', '$a6.2', '$a8.3']
# DEBUG:numba.core.byteflow:dispatch pc=12, inst=STORE_FAST(arg=1, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$10call_method.4']
# DEBUG:numba.core.byteflow:dispatch pc=14, inst=LOAD_GLOBAL(arg=0, lineno=15)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=16, inst=LOAD_METHOD(arg=2, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$14load_global.5']
# DEBUG:numba.core.byteflow:dispatch pc=18, inst=LOAD_FAST(arg=1, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$16load_method.6']
# DEBUG:numba.core.byteflow:dispatch pc=20, inst=CALL_METHOD(arg=1, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$16load_method.6', '$n_218.7']
# DEBUG:numba.core.byteflow:dispatch pc=22, inst=RETURN_VALUE(arg=None, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$20call_method.8']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$2load_global.0'}), (4, {'item': '$2load_global.0', 'res': '$4load_method.1'}), (6, {'res': '$a6.2'}), (8, {'res': '$a8.3'}), (10, {'func': '$4load_method.1', 'args': ['$a6.2', '$a8.3'], 'res': '$10call_method.4'}), (12, {'value': '$10call_method.4'}), (14, {'res': '$14load_global.5'}), (16, {'item': '$14load_global.5', 'res': '$16load_method.6'}), (18, {'res': '$n_218.7'}), (20, {'func': '$16load_method.6', 'args': ['$n_218.7'], 'res': '$20call_method.8'}), (22, {'retval': '$20call_method.8', 'castval': '$22return_value.9'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     a = arg(0, name=a)                       ['a']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=dot) ['$2load_global.0', '$4load_method.1']
#     $10call_method.4 = call $4load_method.1(a, a, func=$4load_method.1, args=[Var(a, coordinate_numba.py:14), Var(a, coordinate_numba.py:14)], kws=(), vararg=None) ['$10call_method.4', '$4load_method.1', 'a', 'a']
#     n_2 = $10call_method.4                   ['$10call_method.4', 'n_2']
#     $14load_global.5 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$14load_global.5']
#     $16load_method.6 = getattr(value=$14load_global.5, attr=sqrt) ['$14load_global.5', '$16load_method.6']
#     $20call_method.8 = call $16load_method.6(n_2, func=$16load_method.6, args=[Var(n_2, coordinate_numba.py:14)], kws=(), vararg=None) ['$16load_method.6', '$20call_method.8', 'n_2']
#     $22return_value.9 = cast(value=$20call_method.8) ['$20call_method.8', '$22return_value.9']
#     return $22return_value.9                 ['$22return_value.9']
#
# DEBUG:numba.core.ssa:-----------------------------------BEFORE SSA-----------------------------------
# DEBUG:numba.core.ssa:label 0:
#     a = arg(0, name=a)                       ['a']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=dot) ['$2load_global.0', '$4load_method.1']
#     $10call_method.4 = call $4load_method.1(a, a, func=$4load_method.1, args=[Var(a, coordinate_numba.py:14), Var(a, coordinate_numba.py:14)], kws=(), vararg=None) ['$10call_method.4', '$4load_method.1', 'a', 'a']
#     n_2 = $10call_method.4                   ['$10call_method.4', 'n_2']
#     $14load_global.5 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$14load_global.5']
#     $16load_method.6 = getattr(value=$14load_global.5, attr=sqrt) ['$14load_global.5', '$16load_method.6']
#     $20call_method.8 = call $16load_method.6(n_2, func=$16load_method.6, args=[Var(n_2, coordinate_numba.py:14)], kws=(), vararg=None) ['$16load_method.6', '$20call_method.8', 'n_2']
#     $22return_value.9 = cast(value=$20call_method.8) ['$20call_method.8', '$22return_value.9']
#     return $22return_value.9                 ['$22return_value.9']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b21cf94aef0>
# DEBUG:numba.core.ssa:on stmt: a = arg(0, name=a)
# DEBUG:numba.core.ssa:on stmt: $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $4load_method.1 = getattr(value=$2load_global.0, attr=dot)
# DEBUG:numba.core.ssa:on stmt: $10call_method.4 = call $4load_method.1(a, a, func=$4load_method.1, args=[Var(a, coordinate_numba.py:14), Var(a, coordinate_numba.py:14)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: n_2 = $10call_method.4
# DEBUG:numba.core.ssa:on stmt: $14load_global.5 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $16load_method.6 = getattr(value=$14load_global.5, attr=sqrt)
# DEBUG:numba.core.ssa:on stmt: $20call_method.8 = call $16load_method.6(n_2, func=$16load_method.6, args=[Var(n_2, coordinate_numba.py:14)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: $22return_value.9 = cast(value=$20call_method.8)
# DEBUG:numba.core.ssa:on stmt: return $22return_value.9
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$10call_method.4': [<numba.core.ir.Assign object at 0x2b21cf98dba8>],
#              '$14load_global.5': [<numba.core.ir.Assign object at 0x2b21cf98d320>],
#              '$16load_method.6': [<numba.core.ir.Assign object at 0x2b21cf98d438>],
#              '$20call_method.8': [<numba.core.ir.Assign object at 0x2b21cf98da20>],
#              '$22return_value.9': [<numba.core.ir.Assign object at 0x2b21cf98dc50>],
#              '$2load_global.0': [<numba.core.ir.Assign object at 0x2b21cf9c2dd8>],
#              '$4load_method.1': [<numba.core.ir.Assign object at 0x2b21cf9c2eb8>],
#              'a': [<numba.core.ir.Assign object at 0x2b21cf9c2cc0>],
#              'n_2': [<numba.core.ir.Assign object at 0x2b21cf98d1d0>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     a = arg(0, name=a)                       ['a']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=dot) ['$2load_global.0', '$4load_method.1']
#     $10call_method.4 = call $4load_method.1(a, a, func=$4load_method.1, args=[Var(a, coordinate_numba.py:14), Var(a, coordinate_numba.py:14)], kws=(), vararg=None) ['$10call_method.4', '$4load_method.1', 'a', 'a']
#     n_2 = $10call_method.4                   ['$10call_method.4', 'n_2']
# ...
# DEBUG:numba.core.ssa:on stmt: angle_position_2 = arg(0, name=angle_position_2)
# DEBUG:numba.core.ssa:on stmt: torsion_position_1 = arg(1, name=torsion_position_1)
# DEBUG:numba.core.ssa:on stmt: $6binary_subtract.2 = angle_position_2 - torsion_position_1
# DEBUG:numba.core.ssa:on stmt: $8return_value.3 = cast(value=$6binary_subtract.2)
# DEBUG:numba.core.ssa:on stmt: return $8return_value.3
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$6binary_subtract.2': [<numba.core.ir.Assign object at 0x2b21cfdf9940>],
#              '$8return_value.3': [<numba.core.ir.Assign object at 0x2b21cfdf9a20>],
#              'angle_position_2': [<numba.core.ir.Assign object at 0x2b21cfdf9668>],
#              'torsion_position_1': [<numba.core.ir.Assign object at 0x2b21cfdf9710>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     angle_position_2 = arg(0, name=angle_position_2) ['angle_position_2']
#     torsion_position_1 = arg(1, name=torsion_position_1) ['torsion_position_1']
#     $6binary_subtract.2 = angle_position_2 - torsion_position_1 ['$6binary_subtract.2', 'angle_position_2', 'torsion_position_1']
#     $8return_value.3 = cast(value=$6binary_subtract.2) ['$6binary_subtract.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=106)
#            2	LOAD_FAST(arg=1, lineno=106)
#            4	LOAD_FAST(arg=0, lineno=110)
#            6	BINARY_TRUE_DIVIDE(arg=None, lineno=110)
#            8	RETURN_VALUE(arg=None, lineno=110)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=106)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_FAST(arg=1, lineno=106)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_FAST(arg=0, lineno=110)
# DEBUG:numba.core.byteflow:stack ['$a_12.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=BINARY_TRUE_DIVIDE(arg=None, lineno=110)
# DEBUG:numba.core.byteflow:stack ['$a_12.0', '$_32call_function_12_14.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=RETURN_VALUE(arg=None, lineno=110)
# DEBUG:numba.core.byteflow:stack ['$6binary_true_divide.2']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$a_12.0'}), (4, {'res': '$_32call_function_12_14.1'}), (6, {'lhs': '$a_12.0', 'rhs': '$_32call_function_12_14.1', 'res': '$6binary_true_divide.2'}), (8, {'retval': '$6binary_true_divide.2', 'castval': '$8return_value.3'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     _32call_function_12_1 = arg(0, name=_32call_function_12_1) ['_32call_function_12_1']
#     a_1 = arg(1, name=a_1)                   ['a_1']
#     $6binary_true_divide.2 = a_1 / _32call_function_12_1 ['$6binary_true_divide.2', '_32call_function_12_1', 'a_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:-----------------------------------BEFORE SSA-----------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _32call_function_12_1 = arg(0, name=_32call_function_12_1) ['_32call_function_12_1']
#     a_1 = arg(1, name=a_1)                   ['a_1']
#     $6binary_true_divide.2 = a_1 / _32call_function_12_1 ['$6binary_true_divide.2', '_32call_function_12_1', 'a_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b21cfed0b70>
# DEBUG:numba.core.ssa:on stmt: _32call_function_12_1 = arg(0, name=_32call_function_12_1)
# DEBUG:numba.core.ssa:on stmt: a_1 = arg(1, name=a_1)
# DEBUG:numba.core.ssa:on stmt: $6binary_true_divide.2 = a_1 / _32call_function_12_1
# DEBUG:numba.core.ssa:on stmt: $8return_value.3 = cast(value=$6binary_true_divide.2)
# DEBUG:numba.core.ssa:on stmt: return $8return_value.3
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$6binary_true_divide.2': [<numba.core.ir.Assign object at 0x2b21cfed0f60>],
#              '$8return_value.3': [<numba.core.ir.Assign object at 0x2b21cfe58080>],
#              '_32call_function_12_1': [<numba.core.ir.Assign object at 0x2b21cfed0c88>],
#              'a_1': [<numba.core.ir.Assign object at 0x2b21cfed0d30>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _32call_function_12_1 = arg(0, name=_32call_function_12_1) ['_32call_function_12_1']
#     a_1 = arg(1, name=a_1)                   ['a_1']
#     $6binary_true_divide.2 = a_1 / _32call_function_12_1 ['$6binary_true_divide.2', '_32call_function_12_1', 'a_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=107)
#            2	LOAD_FAST(arg=1, lineno=107)
#            4	LOAD_FAST(arg=0, lineno=111)
#            6	BINARY_TRUE_DIVIDE(arg=None, lineno=111)
#            8	RETURN_VALUE(arg=None, lineno=111)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=107)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_FAST(arg=1, lineno=107)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_FAST(arg=0, lineno=111)
# DEBUG:numba.core.byteflow:stack ['$b_12.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=BINARY_TRUE_DIVIDE(arg=None, lineno=111)
# DEBUG:numba.core.byteflow:stack ['$b_12.0', '$_44call_function_17_14.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=RETURN_VALUE(arg=None, lineno=111)
# DEBUG:numba.core.byteflow:stack ['$6binary_true_divide.2']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$b_12.0'}), (4, {'res': '$_44call_function_17_14.1'}), (6, {'lhs': '$b_12.0', 'rhs': '$_44call_function_17_14.1', 'res': '$6binary_true_divide.2'}), (8, {'retval': '$6binary_true_divide.2', 'castval': '$8return_value.3'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     _44call_function_17_1 = arg(0, name=_44call_function_17_1) ['_44call_function_17_1']
#     b_1 = arg(1, name=b_1)                   ['b_1']
#     $6binary_true_divide.2 = b_1 / _44call_function_17_1 ['$6binary_true_divide.2', '_44call_function_17_1', 'b_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:-----------------------------------BEFORE SSA-----------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _44call_function_17_1 = arg(0, name=_44call_function_17_1) ['_44call_function_17_1']
#     b_1 = arg(1, name=b_1)                   ['b_1']
#     $6binary_true_divide.2 = b_1 / _44call_function_17_1 ['$6binary_true_divide.2', '_44call_function_17_1', 'b_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b21cfda5128>
# DEBUG:numba.core.ssa:on stmt: _44call_function_17_1 = arg(0, name=_44call_function_17_1)
# DEBUG:numba.core.ssa:on stmt: b_1 = arg(1, name=b_1)
# DEBUG:numba.core.ssa:on stmt: $6binary_true_divide.2 = b_1 / _44call_function_17_1
# DEBUG:numba.core.ssa:on stmt: $8return_value.3 = cast(value=$6binary_true_divide.2)
# DEBUG:numba.core.ssa:on stmt: return $8return_value.3
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$6binary_true_divide.2': [<numba.core.ir.Assign object at 0x2b21cfdaf400>],
#              '$8return_value.3': [<numba.core.ir.Assign object at 0x2b21cfdaf4e0>],
#              '_44call_function_17_1': [<numba.core.ir.Assign object at 0x2b21cfdaf128>],
#              'b_1': [<numba.core.ir.Assign object at 0x2b21cfdaf1d0>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _44call_function_17_1 = arg(0, name=_44call_function_17_1) ['_44call_function_17_1']
#     b_1 = arg(1, name=b_1)                   ['b_1']
#     $6binary_true_divide.2 = b_1 / _44call_function_17_1 ['$6binary_true_divide.2', '_44call_function_17_1', 'b_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=109)
#            2	LOAD_FAST(arg=1, lineno=109)
#            4	LOAD_FAST(arg=0, lineno=112)
#            6	BINARY_TRUE_DIVIDE(arg=None, lineno=112)
#            8	RETURN_VALUE(arg=None, lineno=112)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=109)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_FAST(arg=1, lineno=109)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_FAST(arg=0, lineno=112)
# DEBUG:numba.core.byteflow:stack ['$c_12.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=BINARY_TRUE_DIVIDE(arg=None, lineno=112)
# DEBUG:numba.core.byteflow:stack ['$c_12.0', '$_56call_function_22_14.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=RETURN_VALUE(arg=None, lineno=112)
# DEBUG:numba.core.byteflow:stack ['$6binary_true_divide.2']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$c_12.0'}), (4, {'res': '$_56call_function_22_14.1'}), (6, {'lhs': '$c_12.0', 'rhs': '$_56call_function_22_14.1', 'res': '$6binary_true_divide.2'}), (8, {'retval': '$6binary_true_divide.2', 'castval': '$8return_value.3'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     _56call_function_22_1 = arg(0, name=_56call_function_22_1) ['_56call_function_22_1']
#     c_1 = arg(1, name=c_1)                   ['c_1']
#     $6binary_true_divide.2 = c_1 / _56call_function_22_1 ['$6binary_true_divide.2', '_56call_function_22_1', 'c_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:-----------------------------------BEFORE SSA-----------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _56call_function_22_1 = arg(0, name=_56call_function_22_1) ['_56call_function_22_1']
#     c_1 = arg(1, name=c_1)                   ['c_1']
#     $6binary_true_divide.2 = c_1 / _56call_function_22_1 ['$6binary_true_divide.2', '_56call_function_22_1', 'c_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b21d047f7f0>
# DEBUG:numba.core.ssa:on stmt: _56call_function_22_1 = arg(0, name=_56call_function_22_1)
# DEBUG:numba.core.ssa:on stmt: c_1 = arg(1, name=c_1)
# DEBUG:numba.core.ssa:on stmt: $6binary_true_divide.2 = c_1 / _56call_function_22_1
# DEBUG:numba.core.ssa:on stmt: $8return_value.3 = cast(value=$6binary_true_divide.2)
# DEBUG:numba.core.ssa:on stmt: return $8return_value.3
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$6binary_true_divide.2': [<numba.core.ir.Assign object at 0x2b21d0493908>],
#              '$8return_value.3': [<numba.core.ir.Assign object at 0x2b21d04939e8>],
#              '_56call_function_22_1': [<numba.core.ir.Assign object at 0x2b21d0493278>],
#              'c_1': [<numba.core.ir.Assign object at 0x2b21d04936d8>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _56call_function_22_1 = arg(0, name=_56call_function_22_1) ['_56call_function_22_1']
#     c_1 = arg(1, name=c_1)                   ['c_1']
#     $6binary_true_divide.2 = c_1 / _56call_function_22_1 ['$6binary_true_divide.2', '_56call_function_22_1', 'c_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# RDKit WARNING: [12:16:54] Enabling RDKit 2019.09.3 jupyter extensions

# %%
# Generate htf for capped ALA->THR in vacuum
atp, sys_gen = generate_atp()

htf_at = generate_dipeptide_top_pos_sys(atp.topology, 
                                         new_res = 'THR', 
                                         system = atp.system, 
                                         positions = atp.positions,
                                         system_generator = sys_gen, 
                                         conduct_htf_prop=True,
                                         validate_endstate_energy=True)
# Out:
# DEBUG:perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{9: 7}, {10: 7}, {11: 7}, {12: 7}, {13: 7}, {9: 8}, {10: 8}, {11: 8}, {12: 8}, {13: 8}, {9: 9}, {10: 9}, {11: 9}, {12: 9}, {13: 9}]
# INFO:proposal_generator:{9: 7}
# INFO:proposal_generator:{10: 7}
# INFO:proposal_generator:{11: 7}
# INFO:proposal_generator:{12: 7}
# INFO:proposal_generator:{13: 7}
# INFO:proposal_generator:{9: 8}
# INFO:proposal_generator:{10: 8}
# INFO:proposal_generator:{11: 8}
# INFO:proposal_generator:{12: 8}
# making topology proposal
# INFO:proposal_generator:{13: 8}
# INFO:proposal_generator:{9: 9}
# INFO:proposal_generator:{10: 9}
# INFO:proposal_generator:{11: 9}
# INFO:proposal_generator:{12: 9}
# INFO:proposal_generator:{13: 9}
# INFO:proposal_generator:Returning map that best satisfies matching_criterion
# INFO:proposal_generator:Finding best map using matching_criterion name
# INFO:proposal_generator:{9: 7}
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 8
# INFO:geometry:Atom index proposal order is [10, 18, 14, 15, 19, 13, 16, 17]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 11 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 43 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 72 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 121 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (THR)> with neighbors [<Atom 9 (HA) of chain 0 residue 1 (THR)>, <Atom 10 (CB) of chain 0 residue 1 (THR)>, <Atom 11 (C) of chain 0 residue 1 (THR)>, <Atom 6 (N) of chain 0 residue 1 (THR)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# generating geometry engine
# making geometry proposal from ALA to THR
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {0: (18, 10, 8, 14, [1, Quantity(value=-1.0655064807976995, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 3])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -13.371595639480912
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context new positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 8 new atoms
# INFO:geometry:	reduced angle potential = 0.0003794643968550191.
# INFO:geometry:	reduced angle potential = 0.11241857925077162.
# INFO:geometry:	reduced angle potential = 0.22030632195505415.
# INFO:geometry:	reduced angle potential = 0.002252258644183288.
# INFO:geometry:	reduced angle potential = 0.2748519108095864.
# INFO:geometry:	reduced angle potential = 2.099567440697791.
# INFO:geometry:	reduced angle potential = 0.09496075906289868.
# INFO:geometry:	reduced angle potential = 0.17392460256602307.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 11 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 43 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 72 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.116470338224556
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: -59.50875127336281
# INFO:geometry:final reduced energy -50.39228220814085
# INFO:geometry:sum of energies: -50.39228093513826
# INFO:geometry:magnitude of difference in the energies: 1.2730025886753538e-06
# INFO:geometry:Final logp_proposal: 46.79490129169018
# added energy components: [('CustomBondForce', 0.3288267962001183), ('CustomAngleForce', 5.439319419012754), ('CustomTorsionForce', 19.399104653627436), ('CustomBondForce', -84.67600214220313)]
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 4
# INFO:geometry:Atom index proposal order is [10, 12, 13, 11]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 98 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (ALA)> with neighbors [<Atom 9 (HA) of chain 0 residue 1 (ALA)>, <Atom 10 (CB) of chain 0 residue 1 (ALA)>, <Atom 14 (C) of chain 0 residue 1 (ALA)>, <Atom 6 (N) of chain 0 residue 1 (ALA)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -5.78074351579233
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context old positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 4 new atoms
# INFO:geometry:	reduced angle potential = 0.08012155678424232.
# INFO:geometry:	reduced angle potential = 3.205828647416432e-13.
# INFO:geometry:	reduced angle potential = 7.390951941228323e-11.
# INFO:geometry:	reduced angle potential = 1.2915573155343707e-10.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.116470338224556
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: 20.67296217359934
# INFO:geometry:final reduced energy 29.789432654951565
# INFO:geometry:sum of energies: 29.789432511823897
# INFO:geometry:magnitude of difference in the energies: 1.431276679397797e-07
# INFO:geometry:Final logp_proposal: 24.879227300409582
# added energy components: [('CustomBondForce', 0.000520203310858755), ('CustomAngleForce', 0.4511192410252491), ('CustomTorsionForce', 7.250454736370486), ('CustomBondForce', 12.970867992892748)]
# INFO:relative:Beginning nonbonded method, total particle, barostat, and exceptions retrieval...
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 0
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:No MonteCarloBarostat added.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:Adding bond force terms...
# INFO:relative:Adding angle force terms...
# INFO:relative:Adding torsion force terms...
# INFO:relative:Adding nonbonded force terms...
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b21d32aaab0> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is NoCutoff
# INFO:relative:	_add_nonbonded_force_terms: 0 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 0 added to sterics_custom_nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.CustomNonbondedForce; proxy of <Swig Object of type 'OpenMM::CustomNonbondedForce *' at 0x2b21d32aaae0> > added to hybrid system
# INFO:relative:Handling harmonic bonds...
# INFO:relative:	handle_harmonic_bonds: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_bonds: looping through new_system to add relevant terms...
# INFO:relative:Handling harmonic angles...
# INFO:relative:	handle_harmonic_angles: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_angles: looping through new_system to add relevant terms...
# INFO:relative:Handling torsion forces...
# INFO:relative:	handle_periodic_torsion_forces: looping through old_system to add relevant terms...
# INFO:relative:	handle_periodic_torsion_forces: looping through new_system to add relevant terms...
# INFO:relative:Handling nonbonded forces...
# INFO:relative:	handle_nonbonded: looping through all particles in hybrid...
# INFO:relative:	handle_nonbonded: Handling Interaction Groups...
# INFO:relative:	handle_nonbonded: Handling Hybrid Exceptions...
# INFO:relative:	handle_nonbonded: Handling Original Exceptions...
# INFO:relative:Handling unique_new/old interaction exceptions...
# INFO:relative:There are old or new system exceptions...proceeding.
# conducting subsequent work with the following platform: Reference
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 0.0345517215958738
# 			HarmonicAngleForce: 0.60720164300622
# 			PeriodicTorsionForce: 16.176809797696
# 			NonbondedForce: -39.186882426927106
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			CustomBondForce: 0.03403151828501504
# 			HarmonicBondForce: 0.32934699951097696
# 			CustomAngleForce: 0.15608240198097084
# 			HarmonicAngleForce: 5.8904386600380025
# 			CustomTorsionForce: 0.0
# 			PeriodicTorsionForce: 35.575913190796705
# 			NonbondedForce: -128.57970491583865
# 			CustomNonbondedForce: 4.716820678715094
# 			CustomBondForce: 0.0
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			CustomBondForce: 0.03403151828501504
# 			HarmonicBondForce: 0.32934699951097696
# 			CustomAngleForce: 0.15608240198097084
# 			HarmonicAngleForce: 5.8904386600380025
# 			CustomTorsionForce: 0.0
# 			PeriodicTorsionForce: 35.575913190796705
# 			NonbondedForce: -58.530358900693564
# 			CustomNonbondedForce: 21.058342806312275
# 			CustomBondForce: 0.0
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 0.3628583144851332
# 			HarmonicAngleForce: 5.595401820993724
# 			PeriodicTorsionForce: 28.325459811059268
# 			NonbondedForce: -50.442885888323175
# 			AndersenThermostat: 0.0
# zero state error : 1.816886204153434e-06
# one state error : 3.35066588164068e-06

# %%
# Generate htf for capped THR->ALA in vacuum
pdb = app.PDBFile("../input/thr_vacuum.pdb")

forcefield_files = ['amber14/protein.ff14SB.xml', 'amber14/tip3p.xml']
barostat = None
system_generator = SystemGenerator(forcefields=forcefield_files,
                               barostat=barostat,
                               forcefield_kwargs={'removeCMMotion': False,
                                                    'ewaldErrorTolerance': 1e-4,
                                                    'constraints' : app.HBonds,
                                                    'hydrogenMass' : 4 * unit.amus},
                                periodic_forcefield_kwargs=None,
                                small_molecule_forcefield='gaff-2.11',
                                nonperiodic_forcefield_kwargs = {'nonbondedMethod': app.NoCutoff}, 
                                   molecules=None, 
                                   cache=None)
system = system_generator.create_system(pdb.topology) 
positions = unit.quantity.Quantity(value = np.array([list(atom_pos) for atom_pos in pdb.positions.value_in_unit_system(unit.md_unit_system)]), unit = unit.nanometers)

htf_ta = generate_dipeptide_top_pos_sys(pdb.topology, 
                                         new_res = 'ALA', 
                                         system = system, 
                                         positions = positions,
                                         system_generator = system_generator, 
                                         conduct_htf_prop=True, 
                                         validate_endstate_energy=True)
# Out:
# DEBUG:perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{7: 9}, {8: 9}, {9: 9}, {7: 10}, {8: 10}, {9: 10}, {7: 11}, {8: 11}, {9: 11}, {7: 12}, {8: 12}, {9: 12}, {7: 13}, {8: 13}, {9: 13}]
# INFO:proposal_generator:{7: 9}
# INFO:proposal_generator:{8: 9}
# INFO:proposal_generator:{9: 9}
# INFO:proposal_generator:{7: 10}
# making topology proposal
# INFO:proposal_generator:{8: 10}
# INFO:proposal_generator:{9: 10}
# INFO:proposal_generator:{7: 11}
# INFO:proposal_generator:{8: 11}
# INFO:proposal_generator:{9: 11}
# INFO:proposal_generator:{7: 12}
# INFO:proposal_generator:{8: 12}
# INFO:proposal_generator:{9: 12}
# INFO:proposal_generator:{7: 13}
# INFO:proposal_generator:{8: 13}
# INFO:proposal_generator:{9: 13}
# INFO:proposal_generator:Returning map that best satisfies matching_criterion
# INFO:proposal_generator:Finding best map using matching_criterion name
# INFO:proposal_generator:{7: 9}
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 4
# INFO:geometry:Atom index proposal order is [10, 13, 14, 15]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 98 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (ALA)> with neighbors [<Atom 11 (C) of chain 0 residue 1 (ALA)>, <Atom 10 (CB) of chain 0 residue 1 (ALA)>, <Atom 9 (HA) of chain 0 residue 1 (ALA)>, <Atom 6 (N) of chain 0 residue 1 (ALA)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# generating geometry engine
# making geometry proposal from THR to ALA
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -5.78074351579233
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context new positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 4 new atoms
# INFO:geometry:	reduced angle potential = 0.0004705744442371949.
# INFO:geometry:	reduced angle potential = 1.3355748110529153.
# INFO:geometry:	reduced angle potential = 0.6119008293665799.
# INFO:geometry:	reduced angle potential = 0.18120631227733855.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.117927746118994
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: 25.810985470459457
# INFO:geometry:final reduced energy 34.9289136482834
# INFO:geometry:sum of energies: 34.92891321657845
# INFO:geometry:magnitude of difference in the energies: 4.317049473456791e-07
# INFO:geometry:Final logp_proposal: 21.618874631506912
# added energy components: [('CustomBondForce', 0.9451266449817914), ('CustomAngleForce', 3.6450559496782846), ('CustomTorsionForce', 8.003970379386864), ('CustomBondForce', 13.216832496412515)]
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 8
# INFO:geometry:Atom index proposal order is [10, 18, 14, 13, 17, 19, 16, 15]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 11 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 43 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 72 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 121 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (THR)> with neighbors [<Atom 11 (C) of chain 0 residue 1 (THR)>, <Atom 10 (CB) of chain 0 residue 1 (THR)>, <Atom 9 (HA) of chain 0 residue 1 (THR)>, <Atom 6 (N) of chain 0 residue 1 (THR)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {0: (18, 10, 8, 14, [1, Quantity(value=-1.0655064807976995, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 3])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -13.553917196274867
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context old positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 8 new atoms
# INFO:geometry:	reduced angle potential = 4.533046222145519e-05.
# INFO:geometry:	reduced angle potential = 0.005165150791445113.
# INFO:geometry:	reduced angle potential = 0.4788702500646966.
# INFO:geometry:	reduced angle potential = 0.01392576095456174.
# INFO:geometry:	reduced angle potential = 0.2596979326900967.
# INFO:geometry:	reduced angle potential = 0.70608244841363.
# INFO:geometry:	reduced angle potential = 0.8672997245591195.
# INFO:geometry:	reduced angle potential = 0.2124939602020238.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 11 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 43 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 72 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.117927746118994
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: -62.96782058414476
# INFO:geometry:final reduced energy -53.84989368793476
# INFO:geometry:sum of energies: -53.84989283802577
# INFO:geometry:magnitude of difference in the energies: 8.499089929614456e-07
# INFO:geometry:Final logp_proposal: 40.74494621031465
# added energy components: [('CustomBondForce', 1.1114824464808768), ('CustomAngleForce', 9.449446410979123), ('CustomTorsionForce', 18.656515884333214), ('CustomBondForce', -92.18526532593798)]
# INFO:relative:Beginning nonbonded method, total particle, barostat, and exceptions retrieval...
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 0
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:No MonteCarloBarostat added.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:Adding bond force terms...
# INFO:relative:Adding angle force terms...
# INFO:relative:Adding torsion force terms...
# INFO:relative:Adding nonbonded force terms...
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b21d04fef00> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is NoCutoff
# INFO:relative:	_add_nonbonded_force_terms: 0 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 0 added to sterics_custom_nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.CustomNonbondedForce; proxy of <Swig Object of type 'OpenMM::CustomNonbondedForce *' at 0x2b21d04feb10> > added to hybrid system
# INFO:relative:Handling harmonic bonds...
# INFO:relative:	handle_harmonic_bonds: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_bonds: looping through new_system to add relevant terms...
# INFO:relative:Handling harmonic angles...
# INFO:relative:	handle_harmonic_angles: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_angles: looping through new_system to add relevant terms...
# INFO:relative:Handling torsion forces...
# INFO:relative:	handle_periodic_torsion_forces: looping through old_system to add relevant terms...
# INFO:relative:	handle_periodic_torsion_forces: looping through new_system to add relevant terms...
# INFO:relative:Handling nonbonded forces...
# INFO:relative:	handle_nonbonded: looping through all particles in hybrid...
# INFO:relative:	handle_nonbonded: Handling Interaction Groups...
# INFO:relative:	handle_nonbonded: Handling Hybrid Exceptions...
# INFO:relative:	handle_nonbonded: Handling Original Exceptions...
# INFO:relative:Handling unique_new/old interaction exceptions...
# INFO:relative:There are old or new system exceptions...proceeding.
# conducting subsequent work with the following platform: Reference
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 1.1441495623257518
# 			HarmonicAngleForce: 9.609430902542483
# 			PeriodicTorsionForce: 27.5817910696808
# 			NonbondedForce: -85.01390701922855
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			CustomBondForce: 0.032667115844874646
# 			HarmonicBondForce: 2.056609091462669
# 			CustomAngleForce: 0.15998449156336095
# 			HarmonicAngleForce: 13.094502360657406
# 			CustomTorsionForce: 0.0
# 			PeriodicTorsionForce: 35.58576035951334
# 			NonbondedForce: -83.10803619472516
# 			CustomNonbondedForce: 11.310963285085837
# 			CustomBondForce: 0.0
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			CustomBondForce: 0.032667115844874646
# 			HarmonicBondForce: 2.056609091462669
# 			CustomAngleForce: 0.15998449156336095
# 			HarmonicAngleForce: 13.094502360657406
# 			CustomTorsionForce: 0.0
# 			PeriodicTorsionForce: 35.58576035951334
# 			NonbondedForce: -135.576890276722
# 			CustomNonbondedForce: 14.160379585059076
# 			CustomBondForce: 0.0
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 0.9777937608266664
# 			HarmonicAngleForce: 3.8050404412416454
# 			PeriodicTorsionForce: 16.92924542854329
# 			NonbondedForce: -29.231246870998056
# 			AndersenThermostat: 0.0
# zero state error : 5.749617226769033e-06
# one state error : -3.671109006120332e-06

# %% [markdown]
# # Generate normal htfs with flattened torsions and exceptions: ALA -> THR

# %% [markdown]
# ## ALA -> THR lambda = 0

# %%
# Get topology and system capped ALA->THR in vacuum
atp, sys_gen = generate_atp()
# Out:
# DEBUG:perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11

# %%
# Generate topology proposal
from perses.rjmc.topology_proposal import PointMutationEngine
point_mutation_engine = PointMutationEngine(wildtype_topology=atp.topology,
                                            system_generator=sys_gen,
                                            chain_id='1', #denote the chain id allowed to mutate (it's always a string variable)
                                            max_point_mutants = 1,
                                            residues_allowed_to_mutate = ['2'], #the residue ids allowed to mutate
                                            allowed_mutations = [('2', 'THR')], #the residue ids allowed to mutate with the three-letter code allowed to change
                                            aggregate = True) #always allow aggregation
topology_proposal = point_mutation_engine.propose(current_system=atp.system, current_topology=atp.topology)
# Out:
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{9: 7}, {10: 7}, {11: 7}, {12: 7}, {13: 7}, {9: 8}, {10: 8}, {11: 8}, {12: 8}, {13: 8}, {9: 9}, {10: 9}, {11: 9}, {12: 9}, {13: 9}]
# INFO:proposal_generator:{9: 7}
# INFO:proposal_generator:{10: 7}
# INFO:proposal_generator:{11: 7}
# INFO:proposal_generator:{12: 7}
# INFO:proposal_generator:{13: 7}
# INFO:proposal_generator:{9: 8}
# INFO:proposal_generator:{10: 8}
# INFO:proposal_generator:{11: 8}
# INFO:proposal_generator:{12: 8}
# INFO:proposal_generator:{13: 8}
# INFO:proposal_generator:{9: 9}
# INFO:proposal_generator:{10: 9}
# INFO:proposal_generator:{11: 9}
# INFO:proposal_generator:{12: 9}
# INFO:proposal_generator:{13: 9}
# INFO:proposal_generator:Returning map that best satisfies matching_criterion
# INFO:proposal_generator:Finding best map using matching_criterion name
# INFO:proposal_generator:{9: 7}

# %%
unique_new = topology_proposal.unique_new_atoms

# %%
unique_old = topology_proposal.unique_old_atoms

# %%
# Flatten torsions involving unique new atoms in new system
periodic_torsion = topology_proposal.new_system.getForce(2)
for i in range(periodic_torsion.getNumTorsions()):
    p1, p2, p3, p4, periodicity, phase, k = periodic_torsion.getTorsionParameters(i)
    if p1 in unique_new or p2 in unique_new or p3 in unique_new or p4 in unique_new:
        periodic_torsion.setTorsionParameters(i, p1, p2, p3, p4, periodicity, phase, 0.*k)

# %%
# Flatten exceptions involving unique new atoms in new system
nb_force = topology_proposal.new_system.getForce(3)
for i in range(nb_force.getNumExceptions()):
    p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(i)
    if p1 in unique_new or p2 in unique_new:
        nb_force.setExceptionParameters(i, p1, p2, 0, sigma, 0)

# %%
# Generate geometry proposal

from perses.rjmc.geometry import FFAllAngleGeometryEngine
from openmmtools.constants import kB

temperature = 300*unit.kelvin
# Compute kT and inverse temperature.
kT = kB * temperature
beta = 1.0 / kT
ENERGY_THRESHOLD = 1e-6

geometry_engine = FFAllAngleGeometryEngine(metadata=None,
                                       use_sterics=False,
                                       n_bond_divisions=100,
                                       n_angle_divisions=180,
                                       n_torsion_divisions=360,
                                       verbose=True,
                                       storage=None,
                                       bond_softening_constant=1.0,
                                       angle_softening_constant=1.0,
                                       neglect_angles = False,
                                       use_14_nonbondeds = True)

forward_new_positions, logp_proposal = geometry_engine.propose(topology_proposal, atp.positions, beta, validate_energy_bookkeeping=True)
logp_reverse = geometry_engine.logp_reverse(topology_proposal, forward_new_positions, atp.positions, beta, validate_energy_bookkeeping=True)
# Out:
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 8
# INFO:geometry:Atom index proposal order is [10, 18, 14, 13, 17, 16, 15, 19]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 11 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 43 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 72 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 121 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (THR)> with neighbors [<Atom 9 (HA) of chain 0 residue 1 (THR)>, <Atom 10 (CB) of chain 0 residue 1 (THR)>, <Atom 11 (C) of chain 0 residue 1 (THR)>, <Atom 6 (N) of chain 0 residue 1 (THR)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {0: (18, 10, 8, 14, [1, Quantity(value=-1.0655064807976995, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 3])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -13.553917196274867
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context new positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 8 new atoms
# INFO:geometry:	reduced angle potential = 0.23727605268136268.
# INFO:geometry:	reduced angle potential = 0.017369261700799662.
# INFO:geometry:	reduced angle potential = 2.13839525473296.
# INFO:geometry:	reduced angle potential = 0.0032371749010191397.
# INFO:geometry:	reduced angle potential = 0.22758498300576724.
# INFO:geometry:	reduced angle potential = 0.018520171253710895.
# INFO:geometry:	reduced angle potential = 0.3008618338958671.
# INFO:geometry:	reduced angle potential = 0.18075516186423657.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 11 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 43 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 72 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.116470338224556
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: 12.99098985236917
# INFO:geometry:final reduced energy 22.107460190593724
# INFO:geometry:sum of energies: 22.107460190593727
# INFO:geometry:magnitude of difference in the energies: 1.7763568394002505e-15
# INFO:geometry:Final logp_proposal: 38.914448538162034
# added energy components: [('CustomBondForce', 4.833882397112167), ('CustomAngleForce', 8.157107455257004), ('CustomTorsionForce', 0.0), ('CustomBondForce', 0.0)]
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 4
# INFO:geometry:Atom index proposal order is [10, 11, 13, 12]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 98 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (ALA)> with neighbors [<Atom 9 (HA) of chain 0 residue 1 (ALA)>, <Atom 10 (CB) of chain 0 residue 1 (ALA)>, <Atom 14 (C) of chain 0 residue 1 (ALA)>, <Atom 6 (N) of chain 0 residue 1 (ALA)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -5.78074351579233
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context old positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 4 new atoms
# INFO:geometry:	reduced angle potential = 0.3517320112693091.
# INFO:geometry:	reduced angle potential = 1.2915573155343707e-10.
# INFO:geometry:	reduced angle potential = 7.390951941228323e-11.
# INFO:geometry:	reduced angle potential = 3.205828647416432e-13.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.116470338224556
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: 20.67296217359934
# INFO:geometry:final reduced energy 29.789432654951565
# INFO:geometry:sum of energies: 29.789432511823897
# INFO:geometry:magnitude of difference in the energies: 1.431276679397797e-07
# INFO:geometry:Final logp_proposal: 25.204492747177277
# added energy components: [('CustomBondForce', 0.000520203310858755), ('CustomAngleForce', 0.4511192410252491), ('CustomTorsionForce', 7.250454736370486), ('CustomBondForce', 12.970867992892748)]

# %%
# Build new htf and validate_endstate_energies
from perses.annihilation.relative import HybridTopologyFactory
from perses.tests.utils import validate_endstate_energies
from simtk import openmm
forward_htf = HybridTopologyFactory(topology_proposal=topology_proposal,
             current_positions=atp.positions,
             new_positions=forward_new_positions,
             use_dispersion_correction=False,
             functions=None,
             softcore_alpha=None,
             bond_softening_constant=1.0,
             angle_softening_constant=1.0,
             soften_only_new=False,
             neglected_new_angle_terms=[],
             neglected_old_angle_terms=[],
             softcore_LJ_v2=True,
             softcore_electrostatics=True,
             softcore_LJ_v2_alpha=0.85,
             softcore_electrostatics_alpha=0.3,
             softcore_sigma_Q=1.0,
             interpolate_old_and_new_14s=False,
             omitted_terms=None)

if not topology_proposal.unique_new_atoms:
    assert geometry_engine.forward_final_context_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.forward_final_context_reduced_potential})"
    assert geometry_engine.forward_atoms_with_positions_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's forward atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.forward_atoms_with_positions_reduced_potential})"
    vacuum_added_valence_energy = 0.0
else:
    added_valence_energy = geometry_engine.forward_final_context_reduced_potential - geometry_engine.forward_atoms_with_positions_reduced_potential

if not topology_proposal.unique_old_atoms:
    assert geometry_engine.reverse_final_context_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.reverse_final_context_reduced_potential})"
    assert geometry_engine.reverse_atoms_with_positions_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.reverse_atoms_with_positions_reduced_potential})"
    subtracted_valence_energy = 0.0
else:
    subtracted_valence_energy = geometry_engine.reverse_final_context_reduced_potential - geometry_engine.reverse_atoms_with_positions_reduced_potential

zero_state_error, one_state_error = validate_endstate_energies(forward_htf._topology_proposal, forward_htf, added_valence_energy, subtracted_valence_energy, beta = 1.0/(kB*temperature), ENERGY_THRESHOLD = ENERGY_THRESHOLD, platform = openmm.Platform.getPlatformByName('Reference'))
print(f"zero state error : {zero_state_error}")
print(f"one state error : {one_state_error}")
# Out:
# INFO:relative:Beginning nonbonded method, total particle, barostat, and exceptions retrieval...
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 0
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:No MonteCarloBarostat added.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:Adding bond force terms...
# INFO:relative:Adding angle force terms...
# INFO:relative:Adding torsion force terms...
# INFO:relative:Adding nonbonded force terms...
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b21d04fe2a0> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is NoCutoff
# INFO:relative:	_add_nonbonded_force_terms: 0 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 0 added to sterics_custom_nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.CustomNonbondedForce; proxy of <Swig Object of type 'OpenMM::CustomNonbondedForce *' at 0x2b21d04fede0> > added to hybrid system
# INFO:relative:Handling harmonic bonds...
# INFO:relative:	handle_harmonic_bonds: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_bonds: looping through new_system to add relevant terms...
# INFO:relative:Handling harmonic angles...
# INFO:relative:	handle_harmonic_angles: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_angles: looping through new_system to add relevant terms...
# INFO:relative:Handling torsion forces...
# INFO:relative:	handle_periodic_torsion_forces: looping through old_system to add relevant terms...
# INFO:relative:	handle_periodic_torsion_forces: looping through new_system to add relevant terms...
# INFO:relative:Handling nonbonded forces...
# INFO:relative:	handle_nonbonded: looping through all particles in hybrid...
# INFO:relative:	handle_nonbonded: Handling Interaction Groups...
# INFO:relative:	handle_nonbonded: Handling Hybrid Exceptions...
# INFO:relative:	handle_nonbonded: Handling Original Exceptions...
# INFO:relative:Handling unique_new/old interaction exceptions...
# INFO:relative:There are old or new system exceptions...proceeding.
# conducting subsequent work with the following platform: Reference
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 0.0345517215958738
# 			HarmonicAngleForce: 0.60720164300622
# 			PeriodicTorsionForce: 16.176809797696
# 			NonbondedForce: -39.186882426927106
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			CustomBondForce: 0.03403151828501504
# 			HarmonicBondForce: 4.834402600423026
# 			CustomAngleForce: 0.15608240198097084
# 			HarmonicAngleForce: 8.608226696282252
# 			CustomTorsionForce: 0.0
# 			PeriodicTorsionForce: 16.176809797695995
# 			NonbondedForce: -43.903702761159686
# 			CustomNonbondedForce: 4.716820678715094
# 			CustomBondForce: 0.0
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			CustomBondForce: 0.03403151828501504
# 			HarmonicBondForce: 4.834402600423026
# 			CustomAngleForce: 0.15608240198097084
# 			HarmonicAngleForce: 8.608226696282252
# 			CustomTorsionForce: 0.0
# 			PeriodicTorsionForce: 16.176809797695995
# 			NonbondedForce: -5.188312877849323
# 			CustomNonbondedForce: 3341719.1024067723
# 			CustomBondForce: 0.0
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 4.867913915397183
# 			HarmonicAngleForce: 8.313189857237973
# 			PeriodicTorsionForce: 8.92635641795857
# 			NonbondedForce: 3341700.7358328975
# 			AndersenThermostat: 0.0
# zero state error : -6.82082097291925e-06
# one state error : 3.3513137367435775e-06

# %% [markdown]
# ## ALA -> THR lambda = 1

# %%
# Get topology and system capped ALA->THR in vacuum
atp, sys_gen = generate_atp()
# Out:
# DEBUG:perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11

# %%
# Generate topology proposal
from perses.rjmc.topology_proposal import PointMutationEngine
point_mutation_engine = PointMutationEngine(wildtype_topology=atp.topology,
                                            system_generator=sys_gen,
                                            chain_id='1', #denote the chain id allowed to mutate (it's always a string variable)
                                            max_point_mutants = 1,
                                            residues_allowed_to_mutate = ['2'], #the residue ids allowed to mutate
                                            allowed_mutations = [('2', 'THR')], #the residue ids allowed to mutate with the three-letter code allowed to change
                                            aggregate = True) #always allow aggregation
topology_proposal = point_mutation_engine.propose(current_system=atp.system, current_topology=atp.topology)
# Out:
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{9: 7}, {10: 7}, {11: 7}, {12: 7}, {13: 7}, {9: 8}, {10: 8}, {11: 8}, {12: 8}, {13: 8}, {9: 9}, {10: 9}, {11: 9}, {12: 9}, {13: 9}]
# INFO:proposal_generator:{9: 7}
# INFO:proposal_generator:{10: 7}
# INFO:proposal_generator:{11: 7}
# INFO:proposal_generator:{12: 7}
# INFO:proposal_generator:{13: 7}
# INFO:proposal_generator:{9: 8}
# INFO:proposal_generator:{10: 8}
# INFO:proposal_generator:{11: 8}
# INFO:proposal_generator:{12: 8}
# INFO:proposal_generator:{13: 8}
# INFO:proposal_generator:{9: 9}
# INFO:proposal_generator:{10: 9}
# INFO:proposal_generator:{11: 9}
# INFO:proposal_generator:{12: 9}
# INFO:proposal_generator:{13: 9}
# INFO:proposal_generator:Returning map that best satisfies matching_criterion
# INFO:proposal_generator:Finding best map using matching_criterion name
# INFO:proposal_generator:{9: 7}

# %%
unique_new = topology_proposal.unique_new_atoms

# %%
unique_old = topology_proposal.unique_old_atoms

# %%
# Flatten torsions involving unique old atoms in old system
periodic_torsion = topology_proposal.old_system.getForce(2)
for i in range(periodic_torsion.getNumTorsions()):
    p1, p2, p3, p4, periodicity, phase, k = periodic_torsion.getTorsionParameters(i)
    if p1 in unique_old or p2 in unique_old or p3 in unique_old or p4 in unique_old:
        periodic_torsion.setTorsionParameters(i, p1, p2, p3, p4, periodicity, phase, 0.*k)

# %%
# Flatten exceptions involving unique old atoms in old system
nb_force = topology_proposal.old_system.getForce(3)
for i in range(nb_force.getNumExceptions()):
    p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(i)
    if p1 in unique_old or p2 in unique_old:
        nb_force.setExceptionParameters(i, p1, p2, 0, sigma, 0)

# %%
# Generate geometry proposal

from perses.rjmc.geometry import FFAllAngleGeometryEngine
from openmmtools.constants import kB

temperature = 300*unit.kelvin
# Compute kT and inverse temperature.
kT = kB * temperature
beta = 1.0 / kT
ENERGY_THRESHOLD = 1e-6

geometry_engine = FFAllAngleGeometryEngine(metadata=None,
                                       use_sterics=False,
                                       n_bond_divisions=100,
                                       n_angle_divisions=180,
                                       n_torsion_divisions=360,
                                       verbose=True,
                                       storage=None,
                                       bond_softening_constant=1.0,
                                       angle_softening_constant=1.0,
                                       neglect_angles = False,
                                       use_14_nonbondeds = True)

forward_new_positions, logp_proposal = geometry_engine.propose(topology_proposal, atp.positions, beta, validate_energy_bookkeeping=True)
logp_reverse = geometry_engine.logp_reverse(topology_proposal, forward_new_positions, atp.positions, beta, validate_energy_bookkeeping=True)
# Out:
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 8
# INFO:geometry:Atom index proposal order is [10, 18, 14, 17, 13, 16, 15, 19]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 11 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 43 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 72 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 121 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (THR)> with neighbors [<Atom 9 (HA) of chain 0 residue 1 (THR)>, <Atom 10 (CB) of chain 0 residue 1 (THR)>, <Atom 11 (C) of chain 0 residue 1 (THR)>, <Atom 6 (N) of chain 0 residue 1 (THR)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {0: (18, 10, 8, 14, [1, Quantity(value=-1.0655064807976995, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 3])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -13.371595639480912
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context new positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 8 new atoms
# INFO:geometry:	reduced angle potential = 0.013056187063151578.
# INFO:geometry:	reduced angle potential = 0.0007270981664233761.
# INFO:geometry:	reduced angle potential = 0.06274968542897891.
# INFO:geometry:	reduced angle potential = 0.07462424897159074.
# INFO:geometry:	reduced angle potential = 0.09531767892488545.
# INFO:geometry:	reduced angle potential = 0.016757235633823253.
# INFO:geometry:	reduced angle potential = 0.06917346004659981.
# INFO:geometry:	reduced angle potential = 0.0002570507897761874.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 11 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 43 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 72 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.116470338224556
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: -67.38131584938586
# INFO:geometry:final reduced energy -58.26484602935476
# INFO:geometry:sum of energies: -58.2648455111613
# INFO:geometry:magnitude of difference in the energies: 5.181934596976134e-07
# INFO:geometry:Final logp_proposal: 49.323857891455596
# added energy components: [('CustomBondForce', 0.17793851908038272), ('CustomAngleForce', 6.2378245976897375), ('CustomTorsionForce', 17.070713003358204), ('CustomBondForce', -90.86779196951422)]
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 4
# INFO:geometry:Atom index proposal order is [10, 11, 13, 12]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 98 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (ALA)> with neighbors [<Atom 9 (HA) of chain 0 residue 1 (ALA)>, <Atom 10 (CB) of chain 0 residue 1 (ALA)>, <Atom 14 (C) of chain 0 residue 1 (ALA)>, <Atom 6 (N) of chain 0 residue 1 (ALA)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -5.78074351579233
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context old positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 4 new atoms
# INFO:geometry:	reduced angle potential = 0.3517320112693091.
# INFO:geometry:	reduced angle potential = 1.2915573155343707e-10.
# INFO:geometry:	reduced angle potential = 7.390951941228323e-11.
# INFO:geometry:	reduced angle potential = 3.205828647416432e-13.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.116470338224556
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: 0.4516394443361078
# INFO:geometry:final reduced energy 9.568109782560661
# INFO:geometry:sum of energies: 9.568109782560663
# INFO:geometry:magnitude of difference in the energies: 1.9984014443252818e-15
# INFO:geometry:Final logp_proposal: 24.808499579531293
# added energy components: [('CustomBondForce', 0.000520203310858755), ('CustomAngleForce', 0.4511192410252491), ('CustomTorsionForce', 0.0), ('CustomBondForce', 0.0)]

# %%
# Build new htf and validate_endstate_energies
from perses.annihilation.relative import HybridTopologyFactory
from perses.tests.utils import validate_endstate_energies
from simtk import openmm
forward_htf = HybridTopologyFactory(topology_proposal=topology_proposal,
             current_positions=atp.positions,
             new_positions=forward_new_positions,
             use_dispersion_correction=False,
             functions=None,
             softcore_alpha=None,
             bond_softening_constant=1.0,
             angle_softening_constant=1.0,
             soften_only_new=False,
             neglected_new_angle_terms=[],
             neglected_old_angle_terms=[],
             softcore_LJ_v2=True,
             softcore_electrostatics=True,
             softcore_LJ_v2_alpha=0.85,
             softcore_electrostatics_alpha=0.3,
             softcore_sigma_Q=1.0,
             interpolate_old_and_new_14s=False,
             omitted_terms=None)

if not topology_proposal.unique_new_atoms:
    assert geometry_engine.forward_final_context_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.forward_final_context_reduced_potential})"
    assert geometry_engine.forward_atoms_with_positions_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's forward atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.forward_atoms_with_positions_reduced_potential})"
    vacuum_added_valence_energy = 0.0
else:
    added_valence_energy = geometry_engine.forward_final_context_reduced_potential - geometry_engine.forward_atoms_with_positions_reduced_potential

if not topology_proposal.unique_old_atoms:
    assert geometry_engine.reverse_final_context_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.reverse_final_context_reduced_potential})"
    assert geometry_engine.reverse_atoms_with_positions_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.reverse_atoms_with_positions_reduced_potential})"
    subtracted_valence_energy = 0.0
else:
    subtracted_valence_energy = geometry_engine.reverse_final_context_reduced_potential - geometry_engine.reverse_atoms_with_positions_reduced_potential

zero_state_error, one_state_error = validate_endstate_energies(forward_htf._topology_proposal, forward_htf, added_valence_energy, subtracted_valence_energy, beta = 1.0/(kB*temperature), ENERGY_THRESHOLD = ENERGY_THRESHOLD, platform = openmm.Platform.getPlatformByName('Reference'))
print(f"zero state error : {zero_state_error}")
print(f"one state error : {one_state_error}")
# Out:
# INFO:relative:Beginning nonbonded method, total particle, barostat, and exceptions retrieval...
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 0
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:No MonteCarloBarostat added.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:Adding bond force terms...
# INFO:relative:Adding angle force terms...
# INFO:relative:Adding torsion force terms...
# INFO:relative:Adding nonbonded force terms...
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b21d37acab0> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is NoCutoff
# INFO:relative:	_add_nonbonded_force_terms: 0 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 0 added to sterics_custom_nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.CustomNonbondedForce; proxy of <Swig Object of type 'OpenMM::CustomNonbondedForce *' at 0x2b21d37ac810> > added to hybrid system
# INFO:relative:Handling harmonic bonds...
# INFO:relative:	handle_harmonic_bonds: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_bonds: looping through new_system to add relevant terms...
# INFO:relative:Handling harmonic angles...
# INFO:relative:	handle_harmonic_angles: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_angles: looping through new_system to add relevant terms...
# INFO:relative:Handling torsion forces...
# INFO:relative:	handle_periodic_torsion_forces: looping through old_system to add relevant terms...
# INFO:relative:	handle_periodic_torsion_forces: looping through new_system to add relevant terms...
# INFO:relative:Handling nonbonded forces...
# INFO:relative:	handle_nonbonded: looping through all particles in hybrid...
# INFO:relative:	handle_nonbonded: Handling Interaction Groups...
# INFO:relative:	handle_nonbonded: Handling Hybrid Exceptions...
# INFO:relative:	handle_nonbonded: Handling Original Exceptions...
# INFO:relative:Handling unique_new/old interaction exceptions...
# INFO:relative:There are old or new system exceptions...proceeding.
# conducting subsequent work with the following platform: Reference
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 0.0345517215958738
# 			HarmonicAngleForce: 0.60720164300622
# 			PeriodicTorsionForce: 8.926356417958571
# 			NonbondedForce: -52.15775191958058
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			CustomBondForce: 0.03403151828501504
# 			HarmonicBondForce: 0.17845872239124153
# 			CustomAngleForce: 0.15608240198097084
# 			HarmonicAngleForce: 6.688943838714987
# 			CustomTorsionForce: 0.0
# 			PeriodicTorsionForce: 25.997068871465718
# 			NonbondedForce: -147.74236419166974
# 			CustomNonbondedForce: 4.716820678715094
# 			CustomBondForce: 0.0
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			CustomBondForce: 0.03403151828501504
# 			HarmonicBondForce: 0.17845872239124153
# 			CustomAngleForce: 0.15608240198097084
# 			HarmonicAngleForce: 6.688943838714987
# 			CustomTorsionForce: 0.0
# 			PeriodicTorsionForce: 25.997068871465718
# 			NonbondedForce: -94.06925052628038
# 			CustomNonbondedForce: 34.061099129096924
# 			CustomBondForce: 0.0
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 0.21197003736539782
# 			HarmonicAngleForce: 6.393906999670709
# 			PeriodicTorsionForce: 25.997068871465718
# 			NonbondedForce: -60.00815112893487
# 			AndersenThermostat: 0.0
# zero state error : 1.384985822028284e-06
# one state error : -9.935759948120904e-08

# %%
# Flatten torsions involving unique new atoms in old system
periodic_torsion = topology_proposal.old_system.getForce(2)
for i in range(periodic_torsion.getNumTorsions()):
    p1, p2, p3, p4, periodicity, phase, k = periodic_torsion.getTorsionParameters(i)
    if p1 in unique_old or p2 in unique_old or p3 in unique_old or p4 in unique_old:
        periodic_torsion.setTorsionParameters(i, p1, p2, p3, p4, periodicity, phase, 0.*k)

# %%
# Flatten torsions involving unique old atoms in new system
periodic_torsion = topology_proposal.new_system.getForce(2)
for i in range(periodic_torsion.getNumTorsions()):
    p1, p2, p3, p4, periodicity, phase, k = periodic_torsion.getTorsionParameters(i)
    if p1 in unique_new or p2 in unique_new or p3 in unique_new or p4 in unique_new:
        periodic_torsion.setTorsionParameters(i, p1, p2, p3, p4, periodicity, phase, 0.*k)

# %%
# Flatten exceptions involving unique new atoms in old system
nb_force = topology_proposal.old_system.getForce(3)
for i in range(nb_force.getNumExceptions()):
    p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(i)
    if p1 in unique_old or p2 in unique_old:
        nb_force.setExceptionParameters(i, p1, p2, 0, sigma, 0)

# %%
# Flatten exceptions involving unique old atoms in new system
nb_force = topology_proposal.new_system.getForce(3)
for i in range(nb_force.getNumExceptions()):
    p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(i)
    if p1 in unique_new or p2 in unique_new:
        nb_force.setExceptionParameters(i, p1, p2, 0, sigma, 0)

# %% [markdown]
# # Generate normal htfs with flattened torsions and exceptions: THR->ALA

# %% [markdown]
# ### THR->ALA lambda =  0

# %%
# Get pdb and system geneator for capped THR->ALA in vacuum
pdb = app.PDBFile("../input/thr_vacuum.pdb")

forcefield_files = ['amber14/protein.ff14SB.xml', 'amber14/tip3p.xml']
barostat = None
system_generator = SystemGenerator(forcefields=forcefield_files,
                               barostat=barostat,
                               forcefield_kwargs={'removeCMMotion': False,
                                                    'ewaldErrorTolerance': 1e-4,
                                                    'constraints' : app.HBonds,
                                                    'hydrogenMass' : 4 * unit.amus},
                                periodic_forcefield_kwargs=None,
                                small_molecule_forcefield='gaff-2.11',
                                nonperiodic_forcefield_kwargs = {'nonbondedMethod': app.NoCutoff}, 
                                   molecules=None, 
                                   cache=None)
system = system_generator.create_system(pdb.topology) 
positions = unit.quantity.Quantity(value = np.array([list(atom_pos) for atom_pos in pdb.positions.value_in_unit_system(unit.md_unit_system)]), unit = unit.nanometers)
# Out:
# DEBUG:perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11

# %%
# Generate topology proposal
from perses.rjmc.topology_proposal import PointMutationEngine
point_mutation_engine = PointMutationEngine(wildtype_topology=pdb.topology,
                                            system_generator=sys_gen,
                                            chain_id='1', #denote the chain id allowed to mutate (it's always a string variable)
                                            max_point_mutants = 1,
                                            residues_allowed_to_mutate = ['2'], #the residue ids allowed to mutate
                                            allowed_mutations = [('2', 'ALA')], #the residue ids allowed to mutate with the three-letter code allowed to change
                                            aggregate = True) #always allow aggregation
topology_proposal = point_mutation_engine.propose(current_system=system, current_topology=pdb.topology)
# Out:
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{7: 9}, {8: 9}, {9: 9}, {7: 10}, {8: 10}, {9: 10}, {7: 11}, {8: 11}, {9: 11}, {7: 12}, {8: 12}, {9: 12}, {7: 13}, {8: 13}, {9: 13}]
# INFO:proposal_generator:{7: 9}
# INFO:proposal_generator:{8: 9}
# INFO:proposal_generator:{9: 9}
# INFO:proposal_generator:{7: 10}
# INFO:proposal_generator:{8: 10}
# INFO:proposal_generator:{9: 10}
# INFO:proposal_generator:{7: 11}
# INFO:proposal_generator:{8: 11}
# INFO:proposal_generator:{9: 11}
# INFO:proposal_generator:{7: 12}
# INFO:proposal_generator:{8: 12}
# INFO:proposal_generator:{9: 12}
# INFO:proposal_generator:{7: 13}
# INFO:proposal_generator:{8: 13}
# INFO:proposal_generator:{9: 13}
# INFO:proposal_generator:Returning map that best satisfies matching_criterion
# INFO:proposal_generator:Finding best map using matching_criterion name
# INFO:proposal_generator:{7: 9}

# %%
unique_new = topology_proposal.unique_new_atoms

# %%
unique_old = topology_proposal.unique_old_atoms

# %%
# Flatten torsions involving unique new atoms in new system
periodic_torsion = topology_proposal.new_system.getForce(2)
for i in range(periodic_torsion.getNumTorsions()):
    p1, p2, p3, p4, periodicity, phase, k = periodic_torsion.getTorsionParameters(i)
    if p1 in unique_new or p2 in unique_new or p3 in unique_new or p4 in unique_new:
        periodic_torsion.setTorsionParameters(i, p1, p2, p3, p4, periodicity, phase, 0.*k)

# %%
# Flatten exceptions involving unique new_atoms in new system
nb_force = topology_proposal.new_system.getForce(3)
for i in range(nb_force.getNumExceptions()):
    p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(i)
    if p1 in unique_new or p2 in unique_new:
        nb_force.setExceptionParameters(i, p1, p2, 0, sigma, 0)

# %%
# Generate geometry proposal

from perses.rjmc.geometry import FFAllAngleGeometryEngine
from openmmtools.constants import kB

temperature = 300*unit.kelvin
# Compute kT and inverse temperature.
kT = kB * temperature
beta = 1.0 / kT
ENERGY_THRESHOLD = 1e-6

geometry_engine = FFAllAngleGeometryEngine(metadata=None,
                                       use_sterics=False,
                                       n_bond_divisions=100,
                                       n_angle_divisions=180,
                                       n_torsion_divisions=360,
                                       verbose=True,
                                       storage=None,
                                       bond_softening_constant=1.0,
                                       angle_softening_constant=1.0,
                                       neglect_angles = False,
                                       use_14_nonbondeds = True)

forward_new_positions, logp_proposal = geometry_engine.propose(topology_proposal, positions, beta, validate_energy_bookkeeping=True)
logp_reverse = geometry_engine.logp_reverse(topology_proposal, forward_new_positions, positions, beta, validate_energy_bookkeeping=True)
# Out:
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 4
# INFO:geometry:Atom index proposal order is [10, 13, 15, 14]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 98 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (ALA)> with neighbors [<Atom 11 (C) of chain 0 residue 1 (ALA)>, <Atom 10 (CB) of chain 0 residue 1 (ALA)>, <Atom 9 (HA) of chain 0 residue 1 (ALA)>, <Atom 6 (N) of chain 0 residue 1 (ALA)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -5.78074351579233
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context new positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 4 new atoms
# INFO:geometry:	reduced angle potential = 0.006388007452923387.
# INFO:geometry:	reduced angle potential = 0.4802206756888681.
# INFO:geometry:	reduced angle potential = 1.8656314017728863.
# INFO:geometry:	reduced angle potential = 1.2874395668159955.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.117927746118994
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: 7.085944308542392
# INFO:geometry:final reduced energy 16.203872054661385
# INFO:geometry:sum of energies: 16.203872054661385
# INFO:geometry:magnitude of difference in the energies: 8.881784197001252e-16
# INFO:geometry:Final logp_proposal: 20.192152698128165
# added energy components: [('CustomBondForce', 0.5872871708532142), ('CustomAngleForce', 6.498657137689179), ('CustomTorsionForce', 0.0), ('CustomBondForce', 0.0)]
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 8
# INFO:geometry:Atom index proposal order is [10, 18, 14, 15, 13, 16, 17, 19]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 11 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 43 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 72 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 121 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (THR)> with neighbors [<Atom 11 (C) of chain 0 residue 1 (THR)>, <Atom 10 (CB) of chain 0 residue 1 (THR)>, <Atom 9 (HA) of chain 0 residue 1 (THR)>, <Atom 6 (N) of chain 0 residue 1 (THR)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {0: (18, 10, 8, 14, [1, Quantity(value=-1.0655064807976995, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 3])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -13.371595639480912
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context old positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 8 new atoms
# INFO:geometry:	reduced angle potential = 0.5305209475348288.
# INFO:geometry:	reduced angle potential = 0.005165150791445113.
# INFO:geometry:	reduced angle potential = 0.4788702500646966.
# INFO:geometry:	reduced angle potential = 0.2124939602020238.
# INFO:geometry:	reduced angle potential = 0.01392576095456174.
# INFO:geometry:	reduced angle potential = 0.8672997245591195.
# INFO:geometry:	reduced angle potential = 0.2596979326900967.
# INFO:geometry:	reduced angle potential = 0.70608244841363.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 11 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 43 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 72 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.117927746118994
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: -62.96782058414476
# INFO:geometry:final reduced energy -53.84989368793476
# INFO:geometry:sum of energies: -53.84989283802577
# INFO:geometry:magnitude of difference in the energies: 8.499089929614456e-07
# INFO:geometry:Final logp_proposal: 42.82342071416458
# added energy components: [('CustomBondForce', 1.1114824464808768), ('CustomAngleForce', 9.449446410979123), ('CustomTorsionForce', 18.656515884333214), ('CustomBondForce', -92.18526532593798)]

# %%
# Build new htf and validate_endstate_energies
from perses.annihilation.relative import HybridTopologyFactory
from perses.tests.utils import validate_endstate_energies
from simtk import openmm
forward_htf = HybridTopologyFactory(topology_proposal=topology_proposal,
             current_positions=positions,
             new_positions=forward_new_positions,
             use_dispersion_correction=False,
             functions=None,
             softcore_alpha=None,
             bond_softening_constant=1.0,
             angle_softening_constant=1.0,
             soften_only_new=False,
             neglected_new_angle_terms=[],
             neglected_old_angle_terms=[],
             softcore_LJ_v2=True,
             softcore_electrostatics=True,
             softcore_LJ_v2_alpha=0.85,
             softcore_electrostatics_alpha=0.3,
             softcore_sigma_Q=1.0,
             interpolate_old_and_new_14s=False,
             omitted_terms=None)

if not topology_proposal.unique_new_atoms:
    assert geometry_engine.forward_final_context_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.forward_final_context_reduced_potential})"
    assert geometry_engine.forward_atoms_with_positions_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's forward atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.forward_atoms_with_positions_reduced_potential})"
    vacuum_added_valence_energy = 0.0
else:
    added_valence_energy = geometry_engine.forward_final_context_reduced_potential - geometry_engine.forward_atoms_with_positions_reduced_potential

if not topology_proposal.unique_old_atoms:
    assert geometry_engine.reverse_final_context_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.reverse_final_context_reduced_potential})"
    assert geometry_engine.reverse_atoms_with_positions_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.reverse_atoms_with_positions_reduced_potential})"
    subtracted_valence_energy = 0.0
else:
    subtracted_valence_energy = geometry_engine.reverse_final_context_reduced_potential - geometry_engine.reverse_atoms_with_positions_reduced_potential

zero_state_error, one_state_error = validate_endstate_energies(forward_htf._topology_proposal, forward_htf, added_valence_energy, subtracted_valence_energy, beta = 1.0/(kB*temperature), ENERGY_THRESHOLD = ENERGY_THRESHOLD, platform = openmm.Platform.getPlatformByName('Reference'))
print(f"zero state error : {zero_state_error}")
print(f"one state error : {one_state_error}")
# Out:
# INFO:relative:Beginning nonbonded method, total particle, barostat, and exceptions retrieval...
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 0
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:No MonteCarloBarostat added.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:Adding bond force terms...
# INFO:relative:Adding angle force terms...
# INFO:relative:Adding torsion force terms...
# INFO:relative:Adding nonbonded force terms...
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b21d04fea50> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is NoCutoff
# INFO:relative:	_add_nonbonded_force_terms: 0 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 0 added to sterics_custom_nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.CustomNonbondedForce; proxy of <Swig Object of type 'OpenMM::CustomNonbondedForce *' at 0x2b21d04feb40> > added to hybrid system
# INFO:relative:Handling harmonic bonds...
# INFO:relative:	handle_harmonic_bonds: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_bonds: looping through new_system to add relevant terms...
# INFO:relative:Handling harmonic angles...
# INFO:relative:	handle_harmonic_angles: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_angles: looping through new_system to add relevant terms...
# INFO:relative:Handling torsion forces...
# INFO:relative:	handle_periodic_torsion_forces: looping through old_system to add relevant terms...
# INFO:relative:	handle_periodic_torsion_forces: looping through new_system to add relevant terms...
# INFO:relative:Handling nonbonded forces...
# INFO:relative:	handle_nonbonded: looping through all particles in hybrid...
# INFO:relative:	handle_nonbonded: Handling Interaction Groups...
# INFO:relative:	handle_nonbonded: Handling Hybrid Exceptions...
# INFO:relative:	handle_nonbonded: Handling Original Exceptions...
# INFO:relative:Handling unique_new/old interaction exceptions...
# INFO:relative:There are old or new system exceptions...proceeding.
# conducting subsequent work with the following platform: Reference
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 1.1441495623257518
# 			HarmonicAngleForce: 9.609430902542483
# 			PeriodicTorsionForce: 27.5817910696808
# 			NonbondedForce: -85.01390701922855
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			CustomBondForce: 0.032667115844874646
# 			HarmonicBondForce: 1.6987696173340914
# 			CustomAngleForce: 0.15998449156336095
# 			HarmonicAngleForce: 15.948103548668298
# 			CustomTorsionForce: 0.0
# 			PeriodicTorsionForce: 27.581791069680804
# 			NonbondedForce: -96.32487021239696
# 			CustomNonbondedForce: 11.310963285085837
# 			CustomBondForce: 0.0
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			CustomBondForce: 0.032667115844874646
# 			HarmonicBondForce: 1.6987696173340914
# 			CustomAngleForce: 0.15998449156336095
# 			HarmonicAngleForce: 15.948103548668298
# 			CustomTorsionForce: 0.0
# 			PeriodicTorsionForce: 27.581791069680804
# 			NonbondedForce: -148.07873550289167
# 			CustomNonbondedForce: 5.32900261535617
# 			CustomBondForce: 0.0
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 0.619954286698089
# 			HarmonicAngleForce: 6.658641629252539
# 			PeriodicTorsionForce: 8.925276138710759
# 			NonbondedForce: -50.56446843323445
# 			AndersenThermostat: 0.0
# zero state error : -1.8839740612008882e-06
# one state error : -3.6711090487528963e-06

# %% [markdown]
# ### THR->ALA lambda = 1

# %%
# Get pdb and system geneator for capped THR->ALA in vacuum
pdb = app.PDBFile("../input/thr_vacuum.pdb")

forcefield_files = ['amber14/protein.ff14SB.xml', 'amber14/tip3p.xml']
barostat = None
system_generator = SystemGenerator(forcefields=forcefield_files,
                               barostat=barostat,
                               forcefield_kwargs={'removeCMMotion': False,
                                                    'ewaldErrorTolerance': 1e-4,
                                                    'constraints' : app.HBonds,
                                                    'hydrogenMass' : 4 * unit.amus},
                                periodic_forcefield_kwargs=None,
                                small_molecule_forcefield='gaff-2.11',
                                nonperiodic_forcefield_kwargs = {'nonbondedMethod': app.NoCutoff}, 
                                   molecules=None, 
                                   cache=None)
system = system_generator.create_system(pdb.topology) 
positions = unit.quantity.Quantity(value = np.array([list(atom_pos) for atom_pos in pdb.positions.value_in_unit_system(unit.md_unit_system)]), unit = unit.nanometers)
# Out:
# DEBUG:perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11

# %%
# Generate topology proposal
from perses.rjmc.topology_proposal import PointMutationEngine
point_mutation_engine = PointMutationEngine(wildtype_topology=pdb.topology,
                                            system_generator=sys_gen,
                                            chain_id='1', #denote the chain id allowed to mutate (it's always a string variable)
                                            max_point_mutants = 1,
                                            residues_allowed_to_mutate = ['2'], #the residue ids allowed to mutate
                                            allowed_mutations = [('2', 'ALA')], #the residue ids allowed to mutate with the three-letter code allowed to change
                                            aggregate = True) #always allow aggregation
topology_proposal = point_mutation_engine.propose(current_system=system, current_topology=pdb.topology)
# Out:
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{7: 9}, {8: 9}, {9: 9}, {7: 10}, {8: 10}, {9: 10}, {7: 11}, {8: 11}, {9: 11}, {7: 12}, {8: 12}, {9: 12}, {7: 13}, {8: 13}, {9: 13}]
# INFO:proposal_generator:{7: 9}
# INFO:proposal_generator:{8: 9}
# INFO:proposal_generator:{9: 9}
# INFO:proposal_generator:{7: 10}
# INFO:proposal_generator:{8: 10}
# INFO:proposal_generator:{9: 10}
# INFO:proposal_generator:{7: 11}
# INFO:proposal_generator:{8: 11}
# INFO:proposal_generator:{9: 11}
# INFO:proposal_generator:{7: 12}
# INFO:proposal_generator:{8: 12}
# INFO:proposal_generator:{9: 12}
# INFO:proposal_generator:{7: 13}
# INFO:proposal_generator:{8: 13}
# INFO:proposal_generator:{9: 13}
# INFO:proposal_generator:Returning map that best satisfies matching_criterion
# INFO:proposal_generator:Finding best map using matching_criterion name
# INFO:proposal_generator:{7: 9}

# %%
unique_new = topology_proposal.unique_new_atoms

# %%
unique_old = topology_proposal.unique_old_atoms

# %%
# Flatten torsions involving unique old atoms in old system
periodic_torsion = topology_proposal.old_system.getForce(2)
for i in range(periodic_torsion.getNumTorsions()):
    p1, p2, p3, p4, periodicity, phase, k = periodic_torsion.getTorsionParameters(i)
    if p1 in unique_old or p2 in unique_old or p3 in unique_old or p4 in unique_old:
        periodic_torsion.setTorsionParameters(i, p1, p2, p3, p4, periodicity, phase, 0.*k)

# %%
# Flatten exceptions involving unique old atoms in old system
nb_force = topology_proposal.old_system.getForce(3)
for i in range(nb_force.getNumExceptions()):
    p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(i)
    if p1 in unique_old or p2 in unique_old:
        nb_force.setExceptionParameters(i, p1, p2, 0, sigma, 0)

# %%
# Generate geometry proposal

from perses.rjmc.geometry import FFAllAngleGeometryEngine
from openmmtools.constants import kB

temperature = 300*unit.kelvin
# Compute kT and inverse temperature.
kT = kB * temperature
beta = 1.0 / kT
ENERGY_THRESHOLD = 1e-6

geometry_engine = FFAllAngleGeometryEngine(metadata=None,
                                       use_sterics=False,
                                       n_bond_divisions=100,
                                       n_angle_divisions=180,
                                       n_torsion_divisions=360,
                                       verbose=True,
                                       storage=None,
                                       bond_softening_constant=1.0,
                                       angle_softening_constant=1.0,
                                       neglect_angles = False,
                                       use_14_nonbondeds = True)

forward_new_positions, logp_proposal = geometry_engine.propose(topology_proposal, positions, beta, validate_energy_bookkeeping=True)
logp_reverse = geometry_engine.logp_reverse(topology_proposal, forward_new_positions, positions, beta, validate_energy_bookkeeping=True)
# Out:
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 4
# INFO:geometry:Atom index proposal order is [10, 15, 14, 13]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 98 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (ALA)> with neighbors [<Atom 11 (C) of chain 0 residue 1 (ALA)>, <Atom 10 (CB) of chain 0 residue 1 (ALA)>, <Atom 9 (HA) of chain 0 residue 1 (ALA)>, <Atom 6 (N) of chain 0 residue 1 (ALA)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -5.78074351579233
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context new positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 4 new atoms
# INFO:geometry:	reduced angle potential = 0.2196233721178903.
# INFO:geometry:	reduced angle potential = 0.09846547870644098.
# INFO:geometry:	reduced angle potential = 2.679950441570263.
# INFO:geometry:	reduced angle potential = 0.05092859871433057.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.117927746118994
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: 24.903691461471052
# INFO:geometry:final reduced energy 34.021620389356585
# INFO:geometry:sum of energies: 34.02161920759005
# INFO:geometry:magnitude of difference in the energies: 1.1817665388491605e-06
# INFO:geometry:Final logp_proposal: 22.440281500496933
# added energy components: [('CustomBondForce', 6.731933427696928e-06), ('CustomAngleForce', 4.703000202801505), ('CustomTorsionForce', 6.95393029893124), ('CustomBondForce', 13.24675422780488)]
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 8
# INFO:geometry:Atom index proposal order is [10, 14, 18, 15, 13, 17, 16, 19]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 11 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 43 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 72 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 121 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (THR)> with neighbors [<Atom 11 (C) of chain 0 residue 1 (THR)>, <Atom 10 (CB) of chain 0 residue 1 (THR)>, <Atom 9 (HA) of chain 0 residue 1 (THR)>, <Atom 6 (N) of chain 0 residue 1 (THR)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {0: (14, 10, 8, 18, [1, Quantity(value=1.0655064807976995, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 3])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -13.371595639480912
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context old positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 8 new atoms
# INFO:geometry:	reduced angle potential = 0.5305209475348288.
# INFO:geometry:	reduced angle potential = 0.4788702500646966.
# INFO:geometry:	reduced angle potential = 0.005165150791445113.
# INFO:geometry:	reduced angle potential = 0.2124939602020238.
# INFO:geometry:	reduced angle potential = 0.01392576095456174.
# INFO:geometry:	reduced angle potential = 0.2596979326900967.
# INFO:geometry:	reduced angle potential = 0.8672997245591195.
# INFO:geometry:	reduced angle potential = 0.70608244841363.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 11 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 43 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 72 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.117927746118994
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: 10.56092885746
# INFO:geometry:final reduced energy 19.678856603578996
# INFO:geometry:sum of energies: 19.678856603578993
# INFO:geometry:magnitude of difference in the energies: 1.7763568394002505e-15
# INFO:geometry:Final logp_proposal: 41.938837558534615
# added energy components: [('CustomBondForce', 1.1114824464808768), ('CustomAngleForce', 9.449446410979123), ('CustomTorsionForce', 0.0), ('CustomBondForce', 0.0)]

# %%
# Build new htf and validate_endstate_energies
from perses.annihilation.relative import HybridTopologyFactory
from perses.tests.utils import validate_endstate_energies
from simtk import openmm
forward_htf = HybridTopologyFactory(topology_proposal=topology_proposal,
             current_positions=positions,
             new_positions=forward_new_positions,
             use_dispersion_correction=False,
             functions=None,
             softcore_alpha=None,
             bond_softening_constant=1.0,
             angle_softening_constant=1.0,
             soften_only_new=False,
             neglected_new_angle_terms=[],
             neglected_old_angle_terms=[],
             softcore_LJ_v2=True,
             softcore_electrostatics=True,
             softcore_LJ_v2_alpha=0.85,
             softcore_electrostatics_alpha=0.3,
             softcore_sigma_Q=1.0,
             interpolate_old_and_new_14s=False,
             omitted_terms=None)

if not topology_proposal.unique_new_atoms:
    assert geometry_engine.forward_final_context_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.forward_final_context_reduced_potential})"
    assert geometry_engine.forward_atoms_with_positions_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's forward atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.forward_atoms_with_positions_reduced_potential})"
    vacuum_added_valence_energy = 0.0
else:
    added_valence_energy = geometry_engine.forward_final_context_reduced_potential - geometry_engine.forward_atoms_with_positions_reduced_potential

if not topology_proposal.unique_old_atoms:
    assert geometry_engine.reverse_final_context_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.reverse_final_context_reduced_potential})"
    assert geometry_engine.reverse_atoms_with_positions_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.reverse_atoms_with_positions_reduced_potential})"
    subtracted_valence_energy = 0.0
else:
    subtracted_valence_energy = geometry_engine.reverse_final_context_reduced_potential - geometry_engine.reverse_atoms_with_positions_reduced_potential

zero_state_error, one_state_error = validate_endstate_energies(forward_htf._topology_proposal, forward_htf, added_valence_energy, subtracted_valence_energy, beta = 1.0/(kB*temperature), ENERGY_THRESHOLD = ENERGY_THRESHOLD, platform = openmm.Platform.getPlatformByName('Reference'))
print(f"zero state error : {zero_state_error}")
print(f"one state error : {one_state_error}")
# Out:
# INFO:relative:Beginning nonbonded method, total particle, barostat, and exceptions retrieval...
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 0
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:No MonteCarloBarostat added.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:Adding bond force terms...
# INFO:relative:Adding angle force terms...
# INFO:relative:Adding torsion force terms...
# INFO:relative:Adding nonbonded force terms...
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b21d37accf0> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is NoCutoff
# INFO:relative:	_add_nonbonded_force_terms: 0 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 0 added to sterics_custom_nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.CustomNonbondedForce; proxy of <Swig Object of type 'OpenMM::CustomNonbondedForce *' at 0x2b21d37ac900> > added to hybrid system
# INFO:relative:Handling harmonic bonds...
# INFO:relative:	handle_harmonic_bonds: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_bonds: looping through new_system to add relevant terms...
# INFO:relative:Handling harmonic angles...
# INFO:relative:	handle_harmonic_angles: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_angles: looping through new_system to add relevant terms...
# INFO:relative:Handling torsion forces...
# INFO:relative:	handle_periodic_torsion_forces: looping through old_system to add relevant terms...
# INFO:relative:	handle_periodic_torsion_forces: looping through new_system to add relevant terms...
# INFO:relative:Handling nonbonded forces...
# INFO:relative:	handle_nonbonded: looping through all particles in hybrid...
# INFO:relative:	handle_nonbonded: Handling Interaction Groups...
# INFO:relative:	handle_nonbonded: Handling Hybrid Exceptions...
# INFO:relative:	handle_nonbonded: Handling Original Exceptions...
# INFO:relative:Handling unique_new/old interaction exceptions...
# INFO:relative:There are old or new system exceptions...proceeding.
# conducting subsequent work with the following platform: Reference
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 1.1441495623257518
# 			HarmonicAngleForce: 9.609430902542483
# 			PeriodicTorsionForce: 8.925276138710759
# 			NonbondedForce: 7.171358203255265
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			CustomBondForce: 0.032667115844874646
# 			HarmonicBondForce: 1.1114891784143048
# 			CustomAngleForce: 0.15998449156336095
# 			HarmonicAngleForce: 14.152446613780628
# 			CustomTorsionForce: 0.0
# 			PeriodicTorsionForce: 15.879206081635138
# 			NonbondedForce: 9.107150775665094
# 			CustomNonbondedForce: 11.310963285085837
# 			CustomBondForce: 0.0
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			CustomBondForce: 0.032667115844874646
# 			HarmonicBondForce: 1.1114891784143048
# 			CustomAngleForce: 0.15998449156336095
# 			HarmonicAngleForce: 14.152446613780628
# 			CustomTorsionForce: 0.0
# 			PeriodicTorsionForce: 15.879206081635138
# 			NonbondedForce: -43.09979223384687
# 			CustomNonbondedForce: 6.672545783156796
# 			CustomBondForce: 0.0
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 0.03267384777830234
# 			HarmonicAngleForce: 4.862984694364866
# 			PeriodicTorsionForce: 15.879206081635138
# 			NonbondedForce: -36.42724749709019
# 			AndersenThermostat: 0.0
# zero state error : 3.907047847917511e-06
# one state error : -1.64278071856927e-06

# %% [markdown]
# # Generate repartitioned htfs

# %%
# For ALA->THR at lambda 0 

atp, sys_gen = generate_atp()

rhtf_at_0 = generate_dipeptide_top_pos_sys(atp.topology, 
                                         new_res = 'THR', 
                                         system = atp.system, 
                                         positions = atp.positions,
                                         system_generator = sys_gen, 
                                         conduct_htf_prop=True,
                                         repartitioned=True, 
                                         endstate=0, 
                                         validate_endstate_energy=True)
# Out:
# DEBUG:perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{9: 7}, {10: 7}, {11: 7}, {12: 7}, {13: 7}, {9: 8}, {10: 8}, {11: 8}, {12: 8}, {13: 8}, {9: 9}, {10: 9}, {11: 9}, {12: 9}, {13: 9}]
# INFO:proposal_generator:{9: 7}
# INFO:proposal_generator:{10: 7}
# INFO:proposal_generator:{11: 7}
# INFO:proposal_generator:{12: 7}
# INFO:proposal_generator:{13: 7}
# INFO:proposal_generator:{9: 8}
# INFO:proposal_generator:{10: 8}
# INFO:proposal_generator:{11: 8}
# INFO:proposal_generator:{12: 8}
# INFO:proposal_generator:{13: 8}
# INFO:proposal_generator:{9: 9}
# INFO:proposal_generator:{10: 9}
# INFO:proposal_generator:{11: 9}
# INFO:proposal_generator:{12: 9}
# INFO:proposal_generator:{13: 9}
# INFO:proposal_generator:Returning map that best satisfies matching_criterion
# INFO:proposal_generator:Finding best map using matching_criterion name
# INFO:proposal_generator:{9: 7}
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 8
# INFO:geometry:Atom index proposal order is [10, 14, 18, 15, 16, 17, 13, 19]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 11 bonds in reference force.
# INFO:geometry:	creating angle force...
# making topology proposal
# generating geometry engine
# making geometry proposal from ALA to THR
# INFO:geometry:	there are 43 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 72 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 121 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (THR)> with neighbors [<Atom 9 (HA) of chain 0 residue 1 (THR)>, <Atom 10 (CB) of chain 0 residue 1 (THR)>, <Atom 11 (C) of chain 0 residue 1 (THR)>, <Atom 6 (N) of chain 0 residue 1 (THR)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {0: (14, 10, 8, 18, [1, Quantity(value=1.0655064807976995, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 3])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -13.659277711932692
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context new positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 8 new atoms
# INFO:geometry:	reduced angle potential = 0.03208236105414296.
# INFO:geometry:	reduced angle potential = 1.3218409577386985.
# INFO:geometry:	reduced angle potential = 0.7014295054505133.
# INFO:geometry:	reduced angle potential = 0.2916180577483287.
# INFO:geometry:	reduced angle potential = 0.621207610387497.
# INFO:geometry:	reduced angle potential = 0.0651530084304077.
# INFO:geometry:	reduced angle potential = 1.4801455342192602.
# INFO:geometry:	reduced angle potential = 0.4464917462916372.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 11 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 43 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 72 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.116470338224556
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: -46.46395783426735
# INFO:geometry:final reduced energy -37.347487984779406
# INFO:geometry:sum of energies: -37.34748749604279
# INFO:geometry:magnitude of difference in the energies: 4.887366173988994e-07
# INFO:geometry:Final logp_proposal: 46.2450400914509
# added energy components: [('CustomBondForce', 0.2559219395318536), ('CustomAngleForce', 7.278129929421563), ('CustomTorsionForce', 23.67996632602506), ('CustomBondForce', -77.67797602924583)]
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 4
# INFO:geometry:Atom index proposal order is [10, 12, 11, 13]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 98 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (ALA)> with neighbors [<Atom 9 (HA) of chain 0 residue 1 (ALA)>, <Atom 10 (CB) of chain 0 residue 1 (ALA)>, <Atom 14 (C) of chain 0 residue 1 (ALA)>, <Atom 6 (N) of chain 0 residue 1 (ALA)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -5.78074351579233
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context old positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 4 new atoms
# INFO:geometry:	reduced angle potential = 0.3517320112693091.
# INFO:geometry:	reduced angle potential = 3.205828647416432e-13.
# INFO:geometry:	reduced angle potential = 1.2915573155343707e-10.
# INFO:geometry:	reduced angle potential = 7.390951941228323e-11.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.116470338224556
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: 20.67296217359934
# INFO:geometry:final reduced energy 29.789432654951565
# INFO:geometry:sum of energies: 29.789432511823897
# INFO:geometry:magnitude of difference in the energies: 1.431276679397797e-07
# INFO:geometry:Final logp_proposal: 22.742517638070424
# added energy components: [('CustomBondForce', 0.000520203310858755), ('CustomAngleForce', 0.4511192410252491), ('CustomTorsionForce', 7.250454736370486), ('CustomBondForce', 12.970867992892748)]
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 0
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:No MonteCarloBarostat added.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b21d04fee40> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is NoCutoff
# INFO:relative:	_add_nonbonded_force_terms: 0 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 0 added to sterics_custom_nonbonded force
# conducting subsequent work with the following platform: Reference
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 0.0345517215958738
# 			HarmonicAngleForce: 0.60720164300622
# 			PeriodicTorsionForce: 16.176809797696
# 			NonbondedForce: -39.186882426927106
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 0.2904736611277273
# 			HarmonicAngleForce: 7.885331572427782
# 			PeriodicTorsionForce: 39.856775502112185
# 			NonbondedForce: -116.86485832330068
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 0.28995345781686865
# 			HarmonicAngleForce: 7.434212331402533
# 			PeriodicTorsionForce: 32.60632212237477
# 			NonbondedForce: 268.2794625842604
# 			AndersenThermostat: 0.0
# zero state error : -3.2467807571379126e-06
# one state error : None

# %%
# For ALA->THR at lambda 1 

atp, sys_gen = generate_atp()

rhtf_at_1 = generate_dipeptide_top_pos_sys(atp.topology, 
                                         new_res = 'THR', 
                                         system = atp.system, 
                                         positions = atp.positions,
                                         system_generator = sys_gen, 
                                         conduct_htf_prop=True,
                                         repartitioned=True, 
                                         endstate=1, 
                                         validate_endstate_energy=True)
# Out:
# DEBUG:perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{9: 7}, {10: 7}, {11: 7}, {12: 7}, {13: 7}, {9: 8}, {10: 8}, {11: 8}, {12: 8}, {13: 8}, {9: 9}, {10: 9}, {11: 9}, {12: 9}, {13: 9}]
# INFO:proposal_generator:{9: 7}
# INFO:proposal_generator:{10: 7}
# INFO:proposal_generator:{11: 7}
# INFO:proposal_generator:{12: 7}
# INFO:proposal_generator:{13: 7}
# INFO:proposal_generator:{9: 8}
# INFO:proposal_generator:{10: 8}
# INFO:proposal_generator:{11: 8}
# INFO:proposal_generator:{12: 8}
# INFO:proposal_generator:{13: 8}
# INFO:proposal_generator:{9: 9}
# INFO:proposal_generator:{10: 9}
# INFO:proposal_generator:{11: 9}
# INFO:proposal_generator:{12: 9}
# INFO:proposal_generator:{13: 9}
# INFO:proposal_generator:Returning map that best satisfies matching_criterion
# INFO:proposal_generator:Finding best map using matching_criterion name
# INFO:proposal_generator:{9: 7}
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 8
# INFO:geometry:Atom index proposal order is [10, 14, 18, 19, 15, 17, 13, 16]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 11 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 43 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 72 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 121 in the reference Nonbonded force
# making topology proposal
# generating geometry engine
# making geometry proposal from ALA to THR
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (THR)> with neighbors [<Atom 9 (HA) of chain 0 residue 1 (THR)>, <Atom 10 (CB) of chain 0 residue 1 (THR)>, <Atom 11 (C) of chain 0 residue 1 (THR)>, <Atom 6 (N) of chain 0 residue 1 (THR)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {0: (14, 10, 8, 18, [1, Quantity(value=1.0655064807976995, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 3])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -13.659277711932692
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context new positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 8 new atoms
# INFO:geometry:	reduced angle potential = 0.021534817475923427.
# INFO:geometry:	reduced angle potential = 0.10125416657105524.
# INFO:geometry:	reduced angle potential = 0.22552767592861783.
# INFO:geometry:	reduced angle potential = 4.581221622329511.
# INFO:geometry:	reduced angle potential = 0.10316116198775348.
# INFO:geometry:	reduced angle potential = 0.25456172944003036.
# INFO:geometry:	reduced angle potential = 0.26001370546515185.
# INFO:geometry:	reduced angle potential = 0.03699610857450816.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 11 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 43 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 72 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.116470338224556
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: -36.71201663055148
# INFO:geometry:final reduced energy -27.59554722422584
# INFO:geometry:sum of energies: -27.595546292326926
# INFO:geometry:magnitude of difference in the energies: 9.318989171447356e-07
# INFO:geometry:Final logp_proposal: 40.85672587602312
# added energy components: [('CustomBondForce', 1.5224927001266522), ('CustomAngleForce', 13.162253373311623), ('CustomTorsionForce', 18.333821728305885), ('CustomBondForce', -69.73058443229563)]
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 4
# INFO:geometry:Atom index proposal order is [10, 12, 11, 13]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 98 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (ALA)> with neighbors [<Atom 9 (HA) of chain 0 residue 1 (ALA)>, <Atom 10 (CB) of chain 0 residue 1 (ALA)>, <Atom 14 (C) of chain 0 residue 1 (ALA)>, <Atom 6 (N) of chain 0 residue 1 (ALA)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -5.78074351579233
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context old positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 4 new atoms
# INFO:geometry:	reduced angle potential = 0.3517320112693091.
# INFO:geometry:	reduced angle potential = 3.205828647416432e-13.
# INFO:geometry:	reduced angle potential = 1.2915573155343707e-10.
# INFO:geometry:	reduced angle potential = 7.390951941228323e-11.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.116470338224556
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: 20.67296217359934
# INFO:geometry:final reduced energy 29.789432654951565
# INFO:geometry:sum of energies: 29.789432511823897
# INFO:geometry:magnitude of difference in the energies: 1.431276679397797e-07
# INFO:geometry:Final logp_proposal: 22.75744400327806
# added energy components: [('CustomBondForce', 0.000520203310858755), ('CustomAngleForce', 0.4511192410252491), ('CustomTorsionForce', 7.250454736370486), ('CustomBondForce', 12.970867992892748)]
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 0
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:No MonteCarloBarostat added.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b21d04fef60> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is NoCutoff
# INFO:relative:	_add_nonbonded_force_terms: 0 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 0 added to sterics_custom_nonbonded force
# conducting subsequent work with the following platform: Reference
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 0.0345517215958738
# 			HarmonicAngleForce: 0.60720164300622
# 			PeriodicTorsionForce: 16.176809797696
# 			NonbondedForce: -39.186882426927106
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 1.5570444217225259
# 			HarmonicAngleForce: 13.769455016317842
# 			PeriodicTorsionForce: 34.51063063299985
# 			NonbondedForce: 736.599614843559
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 1.5565242184116672
# 			HarmonicAngleForce: 13.318335775292594
# 			PeriodicTorsionForce: 27.260177253262423
# 			NonbondedForce: 723.6287453509057
# 			AndersenThermostat: 0.0
# zero state error : None
# one state error : 3.350665835455402e-06

# %%
# For THR->ALA at lambda 0

pdb = app.PDBFile("../input/thr_vacuum.pdb")

forcefield_files = ['amber14/protein.ff14SB.xml', 'amber14/tip3p.xml']
barostat = None
system_generator = SystemGenerator(forcefields=forcefield_files,
                               barostat=barostat,
                               forcefield_kwargs={'removeCMMotion': False,
                                                    'ewaldErrorTolerance': 1e-4,
                                                    'constraints' : app.HBonds,
                                                    'hydrogenMass' : 4 * unit.amus},
                                periodic_forcefield_kwargs=None,
                                small_molecule_forcefield='gaff-2.11',
                                nonperiodic_forcefield_kwargs = {'nonbondedMethod': app.NoCutoff}, 
                                   molecules=None, 
                                   cache=None)
system = system_generator.create_system(pdb.topology) 
positions = unit.quantity.Quantity(value = np.array([list(atom_pos) for atom_pos in pdb.positions.value_in_unit_system(unit.md_unit_system)]), unit = unit.nanometers)

rhtf_ta_0 = generate_dipeptide_top_pos_sys(pdb.topology, 
                                         new_res = 'ALA', 
                                         system = system, 
                                         positions = positions,
                                         system_generator = system_generator, 
                                         conduct_htf_prop=True,
                                         repartitioned=True, 
                                         endstate=0, 
                                         validate_endstate_energy=True)
# Out:
# DEBUG:perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{7: 9}, {8: 9}, {9: 9}, {7: 10}, {8: 10}, {9: 10}, {7: 11}, {8: 11}, {9: 11}, {7: 12}, {8: 12}, {9: 12}, {7: 13}, {8: 13}, {9: 13}]
# INFO:proposal_generator:{7: 9}
# INFO:proposal_generator:{8: 9}
# INFO:proposal_generator:{9: 9}
# INFO:proposal_generator:{7: 10}
# INFO:proposal_generator:{8: 10}
# INFO:proposal_generator:{9: 10}
# INFO:proposal_generator:{7: 11}
# INFO:proposal_generator:{8: 11}
# INFO:proposal_generator:{9: 11}
# INFO:proposal_generator:{7: 12}
# INFO:proposal_generator:{8: 12}
# INFO:proposal_generator:{9: 12}
# INFO:proposal_generator:{7: 13}
# INFO:proposal_generator:{8: 13}
# INFO:proposal_generator:{9: 13}
# INFO:proposal_generator:Returning map that best satisfies matching_criterion
# INFO:proposal_generator:Finding best map using matching_criterion name
# INFO:proposal_generator:{7: 9}
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 4
# INFO:geometry:Atom index proposal order is [10, 15, 13, 14]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 98 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (ALA)> with neighbors [<Atom 11 (C) of chain 0 residue 1 (ALA)>, <Atom 10 (CB) of chain 0 residue 1 (ALA)>, <Atom 9 (HA) of chain 0 residue 1 (ALA)>, <Atom 6 (N) of chain 0 residue 1 (ALA)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -5.78074351579233
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# making topology proposal
# generating geometry engine
# making geometry proposal from THR to ALA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context new positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 4 new atoms
# INFO:geometry:	reduced angle potential = 0.46104604756474865.
# INFO:geometry:	reduced angle potential = 0.024701814622292623.
# INFO:geometry:	reduced angle potential = 0.8861413481102436.
# INFO:geometry:	reduced angle potential = 0.05004380860473719.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.117927746118994
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: 23.190104787028584
# INFO:geometry:final reduced energy 32.3080340111953
# INFO:geometry:sum of energies: 32.30803253314758
# INFO:geometry:magnitude of difference in the energies: 1.4780477251008506e-06
# INFO:geometry:Final logp_proposal: 24.889409224496873
# added energy components: [('CustomBondForce', 0.4898384970241201), ('CustomAngleForce', 3.4166955037471807), ('CustomTorsionForce', 7.263421267359967), ('CustomBondForce', 12.020149518897316)]
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 8
# INFO:geometry:Atom index proposal order is [10, 18, 14, 19, 13, 15, 16, 17]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 11 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 43 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 72 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 121 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (THR)> with neighbors [<Atom 11 (C) of chain 0 residue 1 (THR)>, <Atom 10 (CB) of chain 0 residue 1 (THR)>, <Atom 9 (HA) of chain 0 residue 1 (THR)>, <Atom 6 (N) of chain 0 residue 1 (THR)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {0: (18, 10, 8, 14, [1, Quantity(value=-1.0655064807976995, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 3])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -13.371595639480912
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context old positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 8 new atoms
# INFO:geometry:	reduced angle potential = 4.533046222145519e-05.
# INFO:geometry:	reduced angle potential = 0.005165150791445113.
# INFO:geometry:	reduced angle potential = 0.4788702500646966.
# INFO:geometry:	reduced angle potential = 0.70608244841363.
# INFO:geometry:	reduced angle potential = 0.01392576095456174.
# INFO:geometry:	reduced angle potential = 0.2124939602020238.
# INFO:geometry:	reduced angle potential = 0.8672997245591195.
# INFO:geometry:	reduced angle potential = 0.2596979326900967.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 11 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 43 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 72 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.117927746118994
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: -62.96782058414476
# INFO:geometry:final reduced energy -53.84989368793476
# INFO:geometry:sum of energies: -53.84989283802577
# INFO:geometry:magnitude of difference in the energies: 8.499089929614456e-07
# INFO:geometry:Final logp_proposal: 43.1526450507009
# added energy components: [('CustomBondForce', 1.1114824464808768), ('CustomAngleForce', 9.449446410979123), ('CustomTorsionForce', 18.656515884333214), ('CustomBondForce', -92.18526532593798)]
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 0
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:No MonteCarloBarostat added.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b21d37acd80> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is NoCutoff
# INFO:relative:	_add_nonbonded_force_terms: 0 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 0 added to sterics_custom_nonbonded force
# conducting subsequent work with the following platform: Reference
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 1.1441495623257518
# 			HarmonicAngleForce: 9.609430902542483
# 			PeriodicTorsionForce: 27.5817910696808
# 			NonbondedForce: -85.01390701922855
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 1.633988059349872
# 			HarmonicAngleForce: 13.026126406289665
# 			PeriodicTorsionForce: 34.84521231745523
# 			NonbondedForce: -72.99375600269796
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 0.5225056128689948
# 			HarmonicAngleForce: 3.5766799953105415
# 			PeriodicTorsionForce: 16.18869738648519
# 			NonbondedForce: -42.200188704751625
# 			AndersenThermostat: 0.0
# zero state error : 1.929908432174443e-06
# one state error : None

# %%
# For THR->ALA at lambda 1 

pdb = app.PDBFile("../input/thr_vacuum.pdb")

forcefield_files = ['amber14/protein.ff14SB.xml', 'amber14/tip3p.xml']
barostat = None
system_generator = SystemGenerator(forcefields=forcefield_files,
                               barostat=barostat,
                               forcefield_kwargs={'removeCMMotion': False,
                                                    'ewaldErrorTolerance': 1e-4,
                                                    'constraints' : app.HBonds,
                                                    'hydrogenMass' : 4 * unit.amus},
                                periodic_forcefield_kwargs=None,
                                small_molecule_forcefield='gaff-2.11',
                                nonperiodic_forcefield_kwargs = {'nonbondedMethod': app.NoCutoff}, 
                                   molecules=None, 
                                   cache=None)
system = system_generator.create_system(pdb.topology) 
positions = unit.quantity.Quantity(value = np.array([list(atom_pos) for atom_pos in pdb.positions.value_in_unit_system(unit.md_unit_system)]), unit = unit.nanometers)

rhtf_ta_1 = generate_dipeptide_top_pos_sys(pdb.topology, 
                                         new_res = 'ALA', 
                                         system = system, 
                                         positions = positions,
                                         system_generator = system_generator, 
                                         conduct_htf_prop=True,
                                         repartitioned=True, 
                                         endstate=1, 
                                         validate_endstate_energy=True)
# Out:
# DEBUG:perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{7: 9}, {8: 9}, {9: 9}, {7: 10}, {8: 10}, {9: 10}, {7: 11}, {8: 11}, {9: 11}, {7: 12}, {8: 12}, {9: 12}, {7: 13}, {8: 13}, {9: 13}]
# INFO:proposal_generator:{7: 9}
# INFO:proposal_generator:{8: 9}
# INFO:proposal_generator:{9: 9}
# INFO:proposal_generator:{7: 10}
# INFO:proposal_generator:{8: 10}
# INFO:proposal_generator:{9: 10}
# INFO:proposal_generator:{7: 11}
# INFO:proposal_generator:{8: 11}
# INFO:proposal_generator:{9: 11}
# INFO:proposal_generator:{7: 12}
# INFO:proposal_generator:{8: 12}
# INFO:proposal_generator:{9: 12}
# INFO:proposal_generator:{7: 13}
# INFO:proposal_generator:{8: 13}
# INFO:proposal_generator:{9: 13}
# INFO:proposal_generator:Returning map that best satisfies matching_criterion
# INFO:proposal_generator:Finding best map using matching_criterion name
# INFO:proposal_generator:{7: 9}
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 4
# INFO:geometry:Atom index proposal order is [10, 13, 15, 14]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 98 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (ALA)> with neighbors [<Atom 11 (C) of chain 0 residue 1 (ALA)>, <Atom 10 (CB) of chain 0 residue 1 (ALA)>, <Atom 9 (HA) of chain 0 residue 1 (ALA)>, <Atom 6 (N) of chain 0 residue 1 (ALA)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -5.78074351579233
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# making topology proposal
# generating geometry engine
# making geometry proposal from THR to ALA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context new positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 4 new atoms
# INFO:geometry:	reduced angle potential = 1.5784483857404576.
# INFO:geometry:	reduced angle potential = 0.09356174563075169.
# INFO:geometry:	reduced angle potential = 0.8483760415823733.
# INFO:geometry:	reduced angle potential = 1.4067405550906704.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.117927746118994
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: 30.68744718075335
# INFO:geometry:final reduced energy 39.80537617876266
# INFO:geometry:sum of energies: 39.80537492687235
# INFO:geometry:magnitude of difference in the energies: 1.2518903140801285e-06
# INFO:geometry:Final logp_proposal: 21.36082017074409
# added energy components: [('CustomBondForce', 0.019922617542685105), ('CustomAngleForce', 7.033185513184559), ('CustomTorsionForce', 8.185419263197094), ('CustomBondForce', 15.448919786829014)]
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 8
# INFO:geometry:Atom index proposal order is [10, 14, 18, 17, 13, 16, 15, 19]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 11 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 43 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 72 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 121 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (THR)> with neighbors [<Atom 11 (C) of chain 0 residue 1 (THR)>, <Atom 10 (CB) of chain 0 residue 1 (THR)>, <Atom 9 (HA) of chain 0 residue 1 (THR)>, <Atom 6 (N) of chain 0 residue 1 (THR)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {0: (14, 10, 8, 18, [1, Quantity(value=1.0655064807976995, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 3])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -13.371595639480912
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context old positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 8 new atoms
# INFO:geometry:	reduced angle potential = 0.5305209475348288.
# INFO:geometry:	reduced angle potential = 0.4788702500646966.
# INFO:geometry:	reduced angle potential = 0.005165150791445113.
# INFO:geometry:	reduced angle potential = 0.2596979326900967.
# INFO:geometry:	reduced angle potential = 0.01392576095456174.
# INFO:geometry:	reduced angle potential = 0.8672997245591195.
# INFO:geometry:	reduced angle potential = 0.2124939602020238.
# INFO:geometry:	reduced angle potential = 0.70608244841363.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 11 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 43 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 72 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.117927746118994
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: -62.96782058414476
# INFO:geometry:final reduced energy -53.84989368793476
# INFO:geometry:sum of energies: -53.84989283802577
# INFO:geometry:magnitude of difference in the energies: 8.499089929614456e-07
# INFO:geometry:Final logp_proposal: 34.5457769766889
# added energy components: [('CustomBondForce', 1.1114824464808768), ('CustomAngleForce', 9.449446410979123), ('CustomTorsionForce', 18.656515884333214), ('CustomBondForce', -92.18526532593798)]
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 0
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:No MonteCarloBarostat added.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b21d37acbd0> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is NoCutoff
# INFO:relative:	_add_nonbonded_force_terms: 0 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 0 added to sterics_custom_nonbonded force
# conducting subsequent work with the following platform: Reference
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 1.1441495623257518
# 			HarmonicAngleForce: 9.609430902542483
# 			PeriodicTorsionForce: 27.5817910696808
# 			NonbondedForce: -85.01390701922855
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 1.1640721798684368
# 			HarmonicAngleForce: 16.64261641572704
# 			PeriodicTorsionForce: 35.76721013017529
# 			NonbondedForce: -132.96348203143853
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 0.05258973338755975
# 			HarmonicAngleForce: 7.19317000474792
# 			PeriodicTorsionForce: 17.110695199205253
# 			NonbondedForce: -40.778216808954745
# 			AndersenThermostat: 0.0
# zero state error : None
# one state error : -3.671108942171486e-06

# %% [markdown]
# # Generate repartitioned htfs with flattened torsions and exceptions: ALA->THR

# %%
# Get topology and system capped ALA->THR in vacuum
atp, sys_gen = generate_atp()
# Out:
# DEBUG:perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11

# %%
# Generate topology proposal
from perses.rjmc.topology_proposal import PointMutationEngine
point_mutation_engine = PointMutationEngine(wildtype_topology=atp.topology,
                                            system_generator=sys_gen,
                                            chain_id='1', #denote the chain id allowed to mutate (it's always a string variable)
                                            max_point_mutants = 1,
                                            residues_allowed_to_mutate = ['2'], #the residue ids allowed to mutate
                                            allowed_mutations = [('2', 'THR')], #the residue ids allowed to mutate with the three-letter code allowed to change
                                            aggregate = True) #always allow aggregation
topology_proposal = point_mutation_engine.propose(current_system=atp.system, current_topology=atp.topology)
# Out:
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{9: 7}, {10: 7}, {11: 7}, {12: 7}, {13: 7}, {9: 8}, {10: 8}, {11: 8}, {12: 8}, {13: 8}, {9: 9}, {10: 9}, {11: 9}, {12: 9}, {13: 9}]
# INFO:proposal_generator:{9: 7}
# INFO:proposal_generator:{10: 7}
# INFO:proposal_generator:{11: 7}
# INFO:proposal_generator:{12: 7}
# INFO:proposal_generator:{13: 7}
# INFO:proposal_generator:{9: 8}
# INFO:proposal_generator:{10: 8}
# INFO:proposal_generator:{11: 8}
# INFO:proposal_generator:{12: 8}
# INFO:proposal_generator:{13: 8}
# INFO:proposal_generator:{9: 9}
# INFO:proposal_generator:{10: 9}
# INFO:proposal_generator:{11: 9}
# INFO:proposal_generator:{12: 9}
# INFO:proposal_generator:{13: 9}
# INFO:proposal_generator:Returning map that best satisfies matching_criterion
# INFO:proposal_generator:Finding best map using matching_criterion name
# INFO:proposal_generator:{9: 7}

# %%
unique_new = topology_proposal.unique_new_atoms

# %%
unique_old = topology_proposal.unique_old_atoms

# %%
# Flatten torsions involving unique new atoms in new system
periodic_torsion = topology_proposal.new_system.getForce(2)
for i in range(periodic_torsion.getNumTorsions()):
    p1, p2, p3, p4, periodicity, phase, k = periodic_torsion.getTorsionParameters(i)
    if p1 in unique_new or p2 in unique_new or p3 in unique_new or p4 in unique_new:
        periodic_torsion.setTorsionParameters(i, p1, p2, p3, p4, periodicity, phase, 0.*k)

# %%
# Flatten exceptions involving unique new atoms in new system
nb_force = topology_proposal.new_system.getForce(3)
for i in range(nb_force.getNumExceptions()):
    p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(i)
    if p1 in unique_new or p2 in unique_new:
        nb_force.setExceptionParameters(i, p1, p2, 0, sigma, 0)

# %%
# Generate geometry proposal

from perses.rjmc.geometry import FFAllAngleGeometryEngine
from openmmtools.constants import kB

temperature = 300*unit.kelvin
# Compute kT and inverse temperature.
kT = kB * temperature
beta = 1.0 / kT
ENERGY_THRESHOLD = 1e-6

geometry_engine = FFAllAngleGeometryEngine(metadata=None,
                                       use_sterics=False,
                                       n_bond_divisions=100,
                                       n_angle_divisions=180,
                                       n_torsion_divisions=360,
                                       verbose=True,
                                       storage=None,
                                       bond_softening_constant=1.0,
                                       angle_softening_constant=1.0,
                                       neglect_angles = False,
                                       use_14_nonbondeds = True)

forward_new_positions, logp_proposal = geometry_engine.propose(topology_proposal, atp.positions, beta, validate_energy_bookkeeping=True)
logp_reverse = geometry_engine.logp_reverse(topology_proposal, forward_new_positions, atp.positions, beta, validate_energy_bookkeeping=True)
# Out:
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 8
# INFO:geometry:Atom index proposal order is [10, 18, 14, 15, 17, 13, 16, 19]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 11 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 43 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 72 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 121 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (THR)> with neighbors [<Atom 9 (HA) of chain 0 residue 1 (THR)>, <Atom 10 (CB) of chain 0 residue 1 (THR)>, <Atom 11 (C) of chain 0 residue 1 (THR)>, <Atom 6 (N) of chain 0 residue 1 (THR)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {0: (18, 10, 8, 14, [1, Quantity(value=-1.0655064807976995, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 3])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -13.371595639480912
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context new positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 8 new atoms
# INFO:geometry:	reduced angle potential = 1.1032125853897035.
# INFO:geometry:	reduced angle potential = 1.8576254511778396.
# INFO:geometry:	reduced angle potential = 0.09153816823259248.
# INFO:geometry:	reduced angle potential = 0.02485711042997139.
# INFO:geometry:	reduced angle potential = 0.18423526712211014.
# INFO:geometry:	reduced angle potential = 0.0007328238393134305.
# INFO:geometry:	reduced angle potential = 0.1735175686551582.
# INFO:geometry:	reduced angle potential = 1.806112222635517.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 11 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 43 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 72 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.116470338224556
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: 11.083460160955418
# INFO:geometry:final reduced energy 20.199930499179978
# INFO:geometry:sum of energies: 20.199930499179974
# INFO:geometry:magnitude of difference in the energies: 3.552713678800501e-15
# INFO:geometry:Final logp_proposal: 41.43689681468251
# added energy components: [('CustomBondForce', 2.195520255510457), ('CustomAngleForce', 8.887939905444963), ('CustomTorsionForce', 0.0), ('CustomBondForce', 0.0)]
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 4
# INFO:geometry:Atom index proposal order is [10, 12, 11, 13]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 98 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (ALA)> with neighbors [<Atom 9 (HA) of chain 0 residue 1 (ALA)>, <Atom 10 (CB) of chain 0 residue 1 (ALA)>, <Atom 14 (C) of chain 0 residue 1 (ALA)>, <Atom 6 (N) of chain 0 residue 1 (ALA)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -5.78074351579233
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context old positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 4 new atoms
# INFO:geometry:	reduced angle potential = 0.3517320112693091.
# INFO:geometry:	reduced angle potential = 3.205828647416432e-13.
# INFO:geometry:	reduced angle potential = 1.2915573155343707e-10.
# INFO:geometry:	reduced angle potential = 7.390951941228323e-11.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.116470338224556
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: 20.67296217359934
# INFO:geometry:final reduced energy 29.789432654951565
# INFO:geometry:sum of energies: 29.789432511823897
# INFO:geometry:magnitude of difference in the energies: 1.431276679397797e-07
# INFO:geometry:Final logp_proposal: 22.737565598389114
# added energy components: [('CustomBondForce', 0.000520203310858755), ('CustomAngleForce', 0.4511192410252491), ('CustomTorsionForce', 7.250454736370486), ('CustomBondForce', 12.970867992892748)]

# %%
# Build new htf and validate_endstate_energies -- lambda = 0
from perses.annihilation.relative import RepartitionedHybridTopologyFactory
from perses.tests.utils import validate_endstate_energies
from simtk import openmm
forward_htf = RepartitionedHybridTopologyFactory(topology_proposal=topology_proposal,
             current_positions=atp.positions,
             new_positions=forward_new_positions,
             use_dispersion_correction=False,
             functions=None,
             softcore_alpha=None,
             bond_softening_constant=1.0,
             angle_softening_constant=1.0,
             soften_only_new=False,
             neglected_new_angle_terms=[],
             neglected_old_angle_terms=[],
             softcore_LJ_v2=True,
             softcore_electrostatics=True,
             softcore_LJ_v2_alpha=0.85,
             softcore_electrostatics_alpha=0.3,
             softcore_sigma_Q=1.0,
             interpolate_old_and_new_14s=False,
             omitted_terms=None,
             endstate=0,
             flatten_torsions=True,
             flatten_exceptions=True)

if not topology_proposal.unique_new_atoms:
    assert geometry_engine.forward_final_context_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.forward_final_context_reduced_potential})"
    assert geometry_engine.forward_atoms_with_positions_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's forward atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.forward_atoms_with_positions_reduced_potential})"
    vacuum_added_valence_energy = 0.0
else:
    added_valence_energy = geometry_engine.forward_final_context_reduced_potential - geometry_engine.forward_atoms_with_positions_reduced_potential

if not topology_proposal.unique_old_atoms:
    assert geometry_engine.reverse_final_context_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.reverse_final_context_reduced_potential})"
    assert geometry_engine.reverse_atoms_with_positions_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.reverse_atoms_with_positions_reduced_potential})"
    subtracted_valence_energy = 0.0
else:
    subtracted_valence_energy = geometry_engine.reverse_final_context_reduced_potential - geometry_engine.reverse_atoms_with_positions_reduced_potential

zero_state_error, one_state_error = validate_endstate_energies(forward_htf._topology_proposal, forward_htf, added_valence_energy, subtracted_valence_energy, beta = 1.0/(kB*temperature), ENERGY_THRESHOLD = ENERGY_THRESHOLD, platform = openmm.Platform.getPlatformByName('Reference'), repartitioned_endstate=0)
print(f"zero state error : {zero_state_error}")
print(f"one state error : {one_state_error}")
# Out:
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 0
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:No MonteCarloBarostat added.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b21d37ac240> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is NoCutoff
# INFO:relative:	_add_nonbonded_force_terms: 0 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 0 added to sterics_custom_nonbonded force
# conducting subsequent work with the following platform: Reference
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 0.0345517215958738
# 			HarmonicAngleForce: 0.60720164300622
# 			PeriodicTorsionForce: 16.176809797696
# 			NonbondedForce: -39.186882426927106
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 2.2300719771063306
# 			HarmonicAngleForce: 9.495141548451183
# 			PeriodicTorsionForce: 16.176809797696
# 			NonbondedForce: -39.186882426927106
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 2.2295517737954724
# 			HarmonicAngleForce: 9.044022307425934
# 			PeriodicTorsionForce: 8.92635641795857
# 			NonbondedForce: 26322.263167131176
# 			AndersenThermostat: 0.0
# zero state error : 3.6886851972894874e-06
# one state error : None

# %% [markdown]
# ### ALA->THR at lambda = 1

# %%
# Get topology and system capped ALA->THR in vacuum
atp, sys_gen = generate_atp()
# Out:
# DEBUG:perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11

# %%
# Generate topology proposal
from perses.rjmc.topology_proposal import PointMutationEngine
point_mutation_engine = PointMutationEngine(wildtype_topology=atp.topology,
                                            system_generator=sys_gen,
                                            chain_id='1', #denote the chain id allowed to mutate (it's always a string variable)
                                            max_point_mutants = 1,
                                            residues_allowed_to_mutate = ['2'], #the residue ids allowed to mutate
                                            allowed_mutations = [('2', 'THR')], #the residue ids allowed to mutate with the three-letter code allowed to change
                                            aggregate = True) #always allow aggregation
topology_proposal = point_mutation_engine.propose(current_system=atp.system, current_topology=atp.topology)
# Out:
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{9: 7}, {10: 7}, {11: 7}, {12: 7}, {13: 7}, {9: 8}, {10: 8}, {11: 8}, {12: 8}, {13: 8}, {9: 9}, {10: 9}, {11: 9}, {12: 9}, {13: 9}]
# INFO:proposal_generator:{9: 7}
# INFO:proposal_generator:{10: 7}
# INFO:proposal_generator:{11: 7}
# INFO:proposal_generator:{12: 7}
# INFO:proposal_generator:{13: 7}
# INFO:proposal_generator:{9: 8}
# INFO:proposal_generator:{10: 8}
# INFO:proposal_generator:{11: 8}
# INFO:proposal_generator:{12: 8}
# INFO:proposal_generator:{13: 8}
# INFO:proposal_generator:{9: 9}
# INFO:proposal_generator:{10: 9}
# INFO:proposal_generator:{11: 9}
# INFO:proposal_generator:{12: 9}
# INFO:proposal_generator:{13: 9}
# INFO:proposal_generator:Returning map that best satisfies matching_criterion
# INFO:proposal_generator:Finding best map using matching_criterion name
# INFO:proposal_generator:{9: 7}

# %%
unique_new = topology_proposal.unique_new_atoms

# %%
unique_old = topology_proposal.unique_old_atoms

# %%
# Flatten torsions involving unique old atoms in old system
periodic_torsion = topology_proposal.old_system.getForce(2)
for i in range(periodic_torsion.getNumTorsions()):
    p1, p2, p3, p4, periodicity, phase, k = periodic_torsion.getTorsionParameters(i)
    if p1 in unique_old or p2 in unique_old or p3 in unique_old or p4 in unique_old:
        periodic_torsion.setTorsionParameters(i, p1, p2, p3, p4, periodicity, phase, 0.*k)

# %%
# Flatten exceptions involving unique old atoms in old system
nb_force = topology_proposal.old_system.getForce(3)
for i in range(nb_force.getNumExceptions()):
    p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(i)
    if p1 in unique_old or p2 in unique_old:
        nb_force.setExceptionParameters(i, p1, p2, 0, sigma, 0)

# %%
# Generate geometry proposal

from perses.rjmc.geometry import FFAllAngleGeometryEngine
from openmmtools.constants import kB

temperature = 300*unit.kelvin
# Compute kT and inverse temperature.
kT = kB * temperature
beta = 1.0 / kT
ENERGY_THRESHOLD = 1e-6

geometry_engine = FFAllAngleGeometryEngine(metadata=None,
                                       use_sterics=False,
                                       n_bond_divisions=100,
                                       n_angle_divisions=180,
                                       n_torsion_divisions=360,
                                       verbose=True,
                                       storage=None,
                                       bond_softening_constant=1.0,
                                       angle_softening_constant=1.0,
                                       neglect_angles = False,
                                       use_14_nonbondeds = True)

forward_new_positions, logp_proposal = geometry_engine.propose(topology_proposal, atp.positions, beta, validate_energy_bookkeeping=True)
logp_reverse = geometry_engine.logp_reverse(topology_proposal, forward_new_positions, atp.positions, beta, validate_energy_bookkeeping=True)
# Out:
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 8
# INFO:geometry:Atom index proposal order is [10, 18, 14, 15, 13, 17, 16, 19]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 11 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 43 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 72 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 121 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (THR)> with neighbors [<Atom 9 (HA) of chain 0 residue 1 (THR)>, <Atom 10 (CB) of chain 0 residue 1 (THR)>, <Atom 11 (C) of chain 0 residue 1 (THR)>, <Atom 6 (N) of chain 0 residue 1 (THR)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {0: (18, 10, 8, 14, [1, Quantity(value=-1.0655064807976995, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 3])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -13.371595639480912
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context new positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 8 new atoms
# INFO:geometry:	reduced angle potential = 0.7510831873430404.
# INFO:geometry:	reduced angle potential = 0.8441930524752765.
# INFO:geometry:	reduced angle potential = 0.07565546415549719.
# INFO:geometry:	reduced angle potential = 0.0021653107115897157.
# INFO:geometry:	reduced angle potential = 0.0028437970584188534.
# INFO:geometry:	reduced angle potential = 0.35776646025155495.
# INFO:geometry:	reduced angle potential = 0.5014655592575674.
# INFO:geometry:	reduced angle potential = 0.00017561113595058079.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 11 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 43 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 72 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.116470338224556
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: -64.21919918047973
# INFO:geometry:final reduced energy -55.102729222246545
# INFO:geometry:sum of energies: -55.102728842255175
# INFO:geometry:magnitude of difference in the energies: 3.799913628199647e-07
# INFO:geometry:Final logp_proposal: 48.07945520559281
# added energy components: [('CustomBondForce', 1.433236707367092), ('CustomAngleForce', 10.70745420986337), ('CustomTorsionForce', 17.250424879772368), ('CustomBondForce', -93.61031497748259)]
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 4
# INFO:geometry:Atom index proposal order is [10, 13, 12, 11]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 98 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (ALA)> with neighbors [<Atom 9 (HA) of chain 0 residue 1 (ALA)>, <Atom 10 (CB) of chain 0 residue 1 (ALA)>, <Atom 14 (C) of chain 0 residue 1 (ALA)>, <Atom 6 (N) of chain 0 residue 1 (ALA)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -5.78074351579233
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context old positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 4 new atoms
# INFO:geometry:	reduced angle potential = 0.3517320112693091.
# INFO:geometry:	reduced angle potential = 7.390951941228323e-11.
# INFO:geometry:	reduced angle potential = 3.205828647416432e-13.
# INFO:geometry:	reduced angle potential = 1.2915573155343707e-10.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.116470338224556
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: 0.4516394443361078
# INFO:geometry:final reduced energy 9.568109782560661
# INFO:geometry:sum of energies: 9.568109782560663
# INFO:geometry:magnitude of difference in the energies: 1.9984014443252818e-15
# INFO:geometry:Final logp_proposal: 24.804854865240266
# added energy components: [('CustomBondForce', 0.000520203310858755), ('CustomAngleForce', 0.4511192410252491), ('CustomTorsionForce', 0.0), ('CustomBondForce', 0.0)]

# %%
# Build new htf and validate_endstate_energies -- lambda = 1
from perses.annihilation.relative import RepartitionedHybridTopologyFactory
from perses.tests.utils import validate_endstate_energies
from simtk import openmm
forward_htf = RepartitionedHybridTopologyFactory(topology_proposal=topology_proposal,
             current_positions=atp.positions,
             new_positions=forward_new_positions,
             use_dispersion_correction=False,
             functions=None,
             softcore_alpha=None,
             bond_softening_constant=1.0,
             angle_softening_constant=1.0,
             soften_only_new=False,
             neglected_new_angle_terms=[],
             neglected_old_angle_terms=[],
             softcore_LJ_v2=True,
             softcore_electrostatics=True,
             softcore_LJ_v2_alpha=0.85,
             softcore_electrostatics_alpha=0.3,
             softcore_sigma_Q=1.0,
             interpolate_old_and_new_14s=False,
             omitted_terms=None,
             endstate=1,
             flatten_torsions=True,
             flatten_exceptions=True)

if not topology_proposal.unique_new_atoms:
    assert geometry_engine.forward_final_context_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.forward_final_context_reduced_potential})"
    assert geometry_engine.forward_atoms_with_positions_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's forward atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.forward_atoms_with_positions_reduced_potential})"
    vacuum_added_valence_energy = 0.0
else:
    added_valence_energy = geometry_engine.forward_final_context_reduced_potential - geometry_engine.forward_atoms_with_positions_reduced_potential

if not topology_proposal.unique_old_atoms:
    assert geometry_engine.reverse_final_context_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.reverse_final_context_reduced_potential})"
    assert geometry_engine.reverse_atoms_with_positions_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.reverse_atoms_with_positions_reduced_potential})"
    subtracted_valence_energy = 0.0
else:
    subtracted_valence_energy = geometry_engine.reverse_final_context_reduced_potential - geometry_engine.reverse_atoms_with_positions_reduced_potential

zero_state_error, one_state_error = validate_endstate_energies(forward_htf._topology_proposal, forward_htf, added_valence_energy, subtracted_valence_energy, beta = 1.0/(kB*temperature), ENERGY_THRESHOLD = ENERGY_THRESHOLD, platform = openmm.Platform.getPlatformByName('Reference'), repartitioned_endstate=1)
print(f"zero state error : {zero_state_error}")
print(f"one state error : {one_state_error}")
# Out:
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 0
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:No MonteCarloBarostat added.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b21d37ac6f0> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is NoCutoff
# INFO:relative:	_add_nonbonded_force_terms: 0 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 0 added to sterics_custom_nonbonded force
# conducting subsequent work with the following platform: Reference
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 0.0345517215958738
# 			HarmonicAngleForce: 0.60720164300622
# 			PeriodicTorsionForce: 8.926356417958571
# 			NonbondedForce: -52.15775191958058
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 1.4677884289629655
# 			HarmonicAngleForce: 11.314655852869588
# 			PeriodicTorsionForce: 26.176780871100032
# 			NonbondedForce: -43.781476279204846
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 1.4672682256521066
# 			HarmonicAngleForce: 10.86353661184434
# 			PeriodicTorsionForce: 26.176780871100032
# 			NonbondedForce: -43.78147627920486
# 			AndersenThermostat: 0.0
# zero state error : None
# one state error : -9.93575710594996e-08

# %% [markdown]
# # Generate repartitioned htfs with flattened torsions and exceptions: THR->ALA

# %% [markdown]
# ### THR->ALA lambda = 0

# %%
# Get pdb and system geneator for capped THR->ALA in vacuum
pdb = app.PDBFile("../input/thr_vacuum.pdb")

forcefield_files = ['amber14/protein.ff14SB.xml', 'amber14/tip3p.xml']
barostat = None
system_generator = SystemGenerator(forcefields=forcefield_files,
                               barostat=barostat,
                               forcefield_kwargs={'removeCMMotion': False,
                                                    'ewaldErrorTolerance': 1e-4,
                                                    'constraints' : app.HBonds,
                                                    'hydrogenMass' : 4 * unit.amus},
                                periodic_forcefield_kwargs=None,
                                small_molecule_forcefield='gaff-2.11',
                                nonperiodic_forcefield_kwargs = {'nonbondedMethod': app.NoCutoff}, 
                                   molecules=None, 
                                   cache=None)
system = system_generator.create_system(pdb.topology) 
positions = unit.quantity.Quantity(value = np.array([list(atom_pos) for atom_pos in pdb.positions.value_in_unit_system(unit.md_unit_system)]), unit = unit.nanometers)
# Out:
# DEBUG:perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11

# %%
# Generate topology proposal
from perses.rjmc.topology_proposal import PointMutationEngine
point_mutation_engine = PointMutationEngine(wildtype_topology=pdb.topology,
                                            system_generator=sys_gen,
                                            chain_id='1', #denote the chain id allowed to mutate (it's always a string variable)
                                            max_point_mutants = 1,
                                            residues_allowed_to_mutate = ['2'], #the residue ids allowed to mutate
                                            allowed_mutations = [('2', 'ALA')], #the residue ids allowed to mutate with the three-letter code allowed to change
                                            aggregate = True) #always allow aggregation
topology_proposal = point_mutation_engine.propose(current_system=system, current_topology=pdb.topology)
# Out:
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{7: 9}, {8: 9}, {9: 9}, {7: 10}, {8: 10}, {9: 10}, {7: 11}, {8: 11}, {9: 11}, {7: 12}, {8: 12}, {9: 12}, {7: 13}, {8: 13}, {9: 13}]
# INFO:proposal_generator:{7: 9}
# INFO:proposal_generator:{8: 9}
# INFO:proposal_generator:{9: 9}
# INFO:proposal_generator:{7: 10}
# INFO:proposal_generator:{8: 10}
# INFO:proposal_generator:{9: 10}
# INFO:proposal_generator:{7: 11}
# INFO:proposal_generator:{8: 11}
# INFO:proposal_generator:{9: 11}
# INFO:proposal_generator:{7: 12}
# INFO:proposal_generator:{8: 12}
# INFO:proposal_generator:{9: 12}
# INFO:proposal_generator:{7: 13}
# INFO:proposal_generator:{8: 13}
# INFO:proposal_generator:{9: 13}
# INFO:proposal_generator:Returning map that best satisfies matching_criterion
# INFO:proposal_generator:Finding best map using matching_criterion name
# INFO:proposal_generator:{7: 9}

# %%
unique_new = topology_proposal.unique_new_atoms

# %%
unique_old = topology_proposal.unique_old_atoms

# %%
# # Flatten torsions involving unique old atoms in old system
# periodic_torsion = topology_proposal.old_system.getForce(2)
# for i in range(periodic_torsion.getNumTorsions()):
#     p1, p2, p3, p4, periodicity, phase, k = periodic_torsion.getTorsionParameters(i)
#     if p1 in unique_old or p2 in unique_old or p3 in unique_old or p4 in unique_old:
#         periodic_torsion.setTorsionParameters(i, p1, p2, p3, p4, periodicity, phase, 0.*k)

# %%
# Flatten torsions involving unique new atoms in new system
periodic_torsion = topology_proposal.new_system.getForce(2)
for i in range(periodic_torsion.getNumTorsions()):
    p1, p2, p3, p4, periodicity, phase, k = periodic_torsion.getTorsionParameters(i)
    if p1 in unique_new or p2 in unique_new or p3 in unique_new or p4 in unique_new:
        periodic_torsion.setTorsionParameters(i, p1, p2, p3, p4, periodicity, phase, 0.*k)

# %%
# # Flatten exceptions involving unique old atoms in old system
# nb_force = topology_proposal.old_system.getForce(3)
# for i in range(nb_force.getNumExceptions()):
#     p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(i)
#     if p1 in unique_old or p2 in unique_old:
#         nb_force.setExceptionParameters(i, p1, p2, 0, sigma, 0)

# %%
# Flatten exceptions involving unique new atoms in new system
nb_force = topology_proposal.new_system.getForce(3)
for i in range(nb_force.getNumExceptions()):
    p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(i)
    if p1 in unique_new or p2 in unique_new:
        nb_force.setExceptionParameters(i, p1, p2, 0, sigma, 0)

# %%
# Generate geometry proposal

from perses.rjmc.geometry import FFAllAngleGeometryEngine
from openmmtools.constants import kB

temperature = 300*unit.kelvin
# Compute kT and inverse temperature.
kT = kB * temperature
beta = 1.0 / kT
ENERGY_THRESHOLD = 1e-6

geometry_engine = FFAllAngleGeometryEngine(metadata=None,
                                       use_sterics=False,
                                       n_bond_divisions=100,
                                       n_angle_divisions=180,
                                       n_torsion_divisions=360,
                                       verbose=True,
                                       storage=None,
                                       bond_softening_constant=1.0,
                                       angle_softening_constant=1.0,
                                       neglect_angles = False,
                                       use_14_nonbondeds = True)

forward_new_positions, logp_proposal = geometry_engine.propose(topology_proposal, positions, beta, validate_energy_bookkeeping=True)
logp_reverse = geometry_engine.logp_reverse(topology_proposal, forward_new_positions, positions, beta, validate_energy_bookkeeping=True)
# Out:
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 4
# INFO:geometry:Atom index proposal order is [10, 14, 15, 13]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 98 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (ALA)> with neighbors [<Atom 11 (C) of chain 0 residue 1 (ALA)>, <Atom 10 (CB) of chain 0 residue 1 (ALA)>, <Atom 9 (HA) of chain 0 residue 1 (ALA)>, <Atom 6 (N) of chain 0 residue 1 (ALA)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -5.78074351579233
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context new positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 4 new atoms
# INFO:geometry:	reduced angle potential = 0.5911179830440737.
# INFO:geometry:	reduced angle potential = 0.014415868097007708.
# INFO:geometry:	reduced angle potential = 0.0660615737865995.
# INFO:geometry:	reduced angle potential = 0.13898567074652982.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.117927746118994
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: 7.263155037721021
# INFO:geometry:final reduced energy 16.381082783840014
# INFO:geometry:sum of energies: 16.381082783840014
# INFO:geometry:magnitude of difference in the energies: 8.881784197001252e-16
# INFO:geometry:Final logp_proposal: 20.148785938981995
# added energy components: [('CustomBondForce', 0.31293649761481507), ('CustomAngleForce', 6.9502185401062055), ('CustomTorsionForce', 0.0), ('CustomBondForce', 0.0)]
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 8
# INFO:geometry:Atom index proposal order is [10, 14, 18, 15, 17, 16, 13, 19]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 11 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 43 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 72 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 121 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (THR)> with neighbors [<Atom 11 (C) of chain 0 residue 1 (THR)>, <Atom 10 (CB) of chain 0 residue 1 (THR)>, <Atom 9 (HA) of chain 0 residue 1 (THR)>, <Atom 6 (N) of chain 0 residue 1 (THR)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {0: (14, 10, 8, 18, [1, Quantity(value=1.0655064807976995, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 3])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -13.659277711932692
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context old positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 8 new atoms
# INFO:geometry:	reduced angle potential = 0.5305209475348288.
# INFO:geometry:	reduced angle potential = 0.4788702500646966.
# INFO:geometry:	reduced angle potential = 0.005165150791445113.
# INFO:geometry:	reduced angle potential = 0.2124939602020238.
# INFO:geometry:	reduced angle potential = 0.2596979326900967.
# INFO:geometry:	reduced angle potential = 0.8672997245591195.
# INFO:geometry:	reduced angle potential = 1.053358409672891.
# INFO:geometry:	reduced angle potential = 0.70608244841363.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 11 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 43 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 72 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.117927746118994
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: -62.96782058414476
# INFO:geometry:final reduced energy -53.84989368793476
# INFO:geometry:sum of energies: -53.84989283802577
# INFO:geometry:magnitude of difference in the energies: 8.499089929614456e-07
# INFO:geometry:Final logp_proposal: 39.22786604089464
# added energy components: [('CustomBondForce', 1.1114824464808768), ('CustomAngleForce', 9.449446410979123), ('CustomTorsionForce', 18.656515884333214), ('CustomBondForce', -92.18526532593798)]

# %%
# Build new htf and validate_endstate_energies -- lambda = 0
from perses.annihilation.relative import RepartitionedHybridTopologyFactory
from perses.tests.utils import validate_endstate_energies
from simtk import openmm
forward_htf = RepartitionedHybridTopologyFactory(topology_proposal=topology_proposal,
             current_positions=positions,
             new_positions=forward_new_positions,
             use_dispersion_correction=False,
             functions=None,
             softcore_alpha=None,
             bond_softening_constant=1.0,
             angle_softening_constant=1.0,
             soften_only_new=False,
             neglected_new_angle_terms=[],
             neglected_old_angle_terms=[],
             softcore_LJ_v2=True,
             softcore_electrostatics=True,
             softcore_LJ_v2_alpha=0.85,
             softcore_electrostatics_alpha=0.3,
             softcore_sigma_Q=1.0,
             interpolate_old_and_new_14s=False,
             omitted_terms=None,
             endstate=0,
             flatten_torsions=True,
             flatten_exceptions=True)

if not topology_proposal.unique_new_atoms:
    assert geometry_engine.forward_final_context_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.forward_final_context_reduced_potential})"
    assert geometry_engine.forward_atoms_with_positions_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's forward atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.forward_atoms_with_positions_reduced_potential})"
    vacuum_added_valence_energy = 0.0
else:
    added_valence_energy = geometry_engine.forward_final_context_reduced_potential - geometry_engine.forward_atoms_with_positions_reduced_potential

if not topology_proposal.unique_old_atoms:
    assert geometry_engine.reverse_final_context_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.reverse_final_context_reduced_potential})"
    assert geometry_engine.reverse_atoms_with_positions_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.reverse_atoms_with_positions_reduced_potential})"
    subtracted_valence_energy = 0.0
else:
    subtracted_valence_energy = geometry_engine.reverse_final_context_reduced_potential - geometry_engine.reverse_atoms_with_positions_reduced_potential

zero_state_error, one_state_error = validate_endstate_energies(forward_htf._topology_proposal, forward_htf, added_valence_energy, subtracted_valence_energy, beta = 1.0/(kB*temperature), ENERGY_THRESHOLD = ENERGY_THRESHOLD, platform = openmm.Platform.getPlatformByName('Reference'), repartitioned_endstate=0)
print(f"zero state error : {zero_state_error}")
print(f"one state error : {one_state_error}")
# Out:
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 0
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:No MonteCarloBarostat added.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b21d37ac7b0> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is NoCutoff
# INFO:relative:	_add_nonbonded_force_terms: 0 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 0 added to sterics_custom_nonbonded force
# conducting subsequent work with the following platform: Reference
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 1.1441495623257518
# 			HarmonicAngleForce: 9.609430902542483
# 			PeriodicTorsionForce: 27.5817910696808
# 			NonbondedForce: -85.01390701922855
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 1.4570860599405668
# 			HarmonicAngleForce: 16.55964944264869
# 			PeriodicTorsionForce: 27.5817910696808
# 			NonbondedForce: -85.01390701922855
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 0.34560361345968965
# 			HarmonicAngleForce: 7.110203031669566
# 			PeriodicTorsionForce: 8.925276138710759
# 			NonbondedForce: -45.65313922962339
# 			AndersenThermostat: 0.0
# zero state error : 2.166376958712135e-06
# one state error : None

# %% [markdown]
# ### THR->ALA lambda = 1

# %%
# Get pdb and system geneator for capped THR->ALA in vacuum
pdb = app.PDBFile("../input/thr_vacuum.pdb")

forcefield_files = ['amber14/protein.ff14SB.xml', 'amber14/tip3p.xml']
barostat = None
system_generator = SystemGenerator(forcefields=forcefield_files,
                               barostat=barostat,
                               forcefield_kwargs={'removeCMMotion': False,
                                                    'ewaldErrorTolerance': 1e-4,
                                                    'constraints' : app.HBonds,
                                                    'hydrogenMass' : 4 * unit.amus},
                                periodic_forcefield_kwargs=None,
                                small_molecule_forcefield='gaff-2.11',
                                nonperiodic_forcefield_kwargs = {'nonbondedMethod': app.NoCutoff}, 
                                   molecules=None, 
                                   cache=None)
system = system_generator.create_system(pdb.topology) 
positions = unit.quantity.Quantity(value = np.array([list(atom_pos) for atom_pos in pdb.positions.value_in_unit_system(unit.md_unit_system)]), unit = unit.nanometers)
# Out:
# DEBUG:perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11

# %%
# Generate topology proposal
from perses.rjmc.topology_proposal import PointMutationEngine
point_mutation_engine = PointMutationEngine(wildtype_topology=pdb.topology,
                                            system_generator=sys_gen,
                                            chain_id='1', #denote the chain id allowed to mutate (it's always a string variable)
                                            max_point_mutants = 1,
                                            residues_allowed_to_mutate = ['2'], #the residue ids allowed to mutate
                                            allowed_mutations = [('2', 'ALA')], #the residue ids allowed to mutate with the three-letter code allowed to change
                                            aggregate = True) #always allow aggregation
topology_proposal = point_mutation_engine.propose(current_system=system, current_topology=pdb.topology)
# Out:
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{7: 9}, {8: 9}, {9: 9}, {7: 10}, {8: 10}, {9: 10}, {7: 11}, {8: 11}, {9: 11}, {7: 12}, {8: 12}, {9: 12}, {7: 13}, {8: 13}, {9: 13}]
# INFO:proposal_generator:{7: 9}
# INFO:proposal_generator:{8: 9}
# INFO:proposal_generator:{9: 9}
# INFO:proposal_generator:{7: 10}
# INFO:proposal_generator:{8: 10}
# INFO:proposal_generator:{9: 10}
# INFO:proposal_generator:{7: 11}
# INFO:proposal_generator:{8: 11}
# INFO:proposal_generator:{9: 11}
# INFO:proposal_generator:{7: 12}
# INFO:proposal_generator:{8: 12}
# INFO:proposal_generator:{9: 12}
# INFO:proposal_generator:{7: 13}
# INFO:proposal_generator:{8: 13}
# INFO:proposal_generator:{9: 13}
# INFO:proposal_generator:Returning map that best satisfies matching_criterion
# INFO:proposal_generator:Finding best map using matching_criterion name
# INFO:proposal_generator:{7: 9}

# %%
unique_new = topology_proposal.unique_new_atoms

# %%
unique_old = topology_proposal.unique_old_atoms

# %%
# Flatten torsions involving unique old atoms in old system
periodic_torsion = topology_proposal.old_system.getForce(2)
for i in range(periodic_torsion.getNumTorsions()):
    p1, p2, p3, p4, periodicity, phase, k = periodic_torsion.getTorsionParameters(i)
    if p1 in unique_old or p2 in unique_old or p3 in unique_old or p4 in unique_old:
        periodic_torsion.setTorsionParameters(i, p1, p2, p3, p4, periodicity, phase, 0.*k)

# %%
# # Flatten torsions involving unique new atoms in new system
# periodic_torsion = topology_proposal.new_system.getForce(2)
# for i in range(periodic_torsion.getNumTorsions()):
#     p1, p2, p3, p4, periodicity, phase, k = periodic_torsion.getTorsionParameters(i)
#     if p1 in unique_new or p2 in unique_new or p3 in unique_new or p4 in unique_new:
#         periodic_torsion.setTorsionParameters(i, p1, p2, p3, p4, periodicity, phase, 0.*k)

# %%
# Flatten exceptions involving unique old atoms in old system
nb_force = topology_proposal.old_system.getForce(3)
for i in range(nb_force.getNumExceptions()):
    p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(i)
    if p1 in unique_old or p2 in unique_old:
        nb_force.setExceptionParameters(i, p1, p2, 0, sigma, 0)

# %%
# # Flatten exceptions involving unique new atoms in new system
# nb_force = topology_proposal.new_system.getForce(3)
# for i in range(nb_force.getNumExceptions()):
#     p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(i)
#     if p1 in unique_new or p2 in unique_new:
#         nb_force.setExceptionParameters(i, p1, p2, 0, sigma, 0)

# %%
# Generate geometry proposal

from perses.rjmc.geometry import FFAllAngleGeometryEngine
from openmmtools.constants import kB

temperature = 300*unit.kelvin
# Compute kT and inverse temperature.
kT = kB * temperature
beta = 1.0 / kT
ENERGY_THRESHOLD = 1e-6

geometry_engine = FFAllAngleGeometryEngine(metadata=None,
                                       use_sterics=False,
                                       n_bond_divisions=100,
                                       n_angle_divisions=180,
                                       n_torsion_divisions=360,
                                       verbose=True,
                                       storage=None,
                                       bond_softening_constant=1.0,
                                       angle_softening_constant=1.0,
                                       neglect_angles = False,
                                       use_14_nonbondeds = True)

forward_new_positions, logp_proposal = geometry_engine.propose(topology_proposal, positions, beta, validate_energy_bookkeeping=True)
logp_reverse = geometry_engine.logp_reverse(topology_proposal, forward_new_positions, positions, beta, validate_energy_bookkeeping=True)
# Out:
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 4
# INFO:geometry:Atom index proposal order is [10, 15, 14, 13]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 98 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (ALA)> with neighbors [<Atom 11 (C) of chain 0 residue 1 (ALA)>, <Atom 10 (CB) of chain 0 residue 1 (ALA)>, <Atom 9 (HA) of chain 0 residue 1 (ALA)>, <Atom 6 (N) of chain 0 residue 1 (ALA)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -5.78074351579233
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context new positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 4 new atoms
# INFO:geometry:	reduced angle potential = 0.2500283125475755.
# INFO:geometry:	reduced angle potential = 0.01945791429598624.
# INFO:geometry:	reduced angle potential = 0.02851582584775563.
# INFO:geometry:	reduced angle potential = 1.743654083975638.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.117927746118994
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: 21.677838532037402
# INFO:geometry:final reduced energy 30.795766576730845
# INFO:geometry:sum of energies: 30.795766278156396
# INFO:geometry:magnitude of difference in the energies: 2.985744487205011e-07
# INFO:geometry:Final logp_proposal: 21.70365709191143
# added energy components: [('CustomBondForce', 1.546906241718489), ('CustomAngleForce', 2.6016552651167903), ('CustomTorsionForce', 7.838226315813601), ('CustomBondForce', 9.69105070938852)]
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 8
# INFO:geometry:Atom index proposal order is [10, 14, 18, 17, 19, 13, 16, 15]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 11 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 43 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 72 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 121 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (THR)> with neighbors [<Atom 11 (C) of chain 0 residue 1 (THR)>, <Atom 10 (CB) of chain 0 residue 1 (THR)>, <Atom 9 (HA) of chain 0 residue 1 (THR)>, <Atom 6 (N) of chain 0 residue 1 (THR)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {0: (14, 10, 8, 18, [1, Quantity(value=1.0655064807976995, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 3])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -13.371595639480912
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context old positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 8 new atoms
# INFO:geometry:	reduced angle potential = 0.5305209475348288.
# INFO:geometry:	reduced angle potential = 0.4788702500646966.
# INFO:geometry:	reduced angle potential = 0.005165150791445113.
# INFO:geometry:	reduced angle potential = 0.2596979326900967.
# INFO:geometry:	reduced angle potential = 0.70608244841363.
# INFO:geometry:	reduced angle potential = 0.01392576095456174.
# INFO:geometry:	reduced angle potential = 0.8672997245591195.
# INFO:geometry:	reduced angle potential = 0.2124939602020238.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 11 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 43 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 72 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.117927746118994
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: 10.56092885746
# INFO:geometry:final reduced energy 19.678856603578996
# INFO:geometry:sum of energies: 19.678856603578993
# INFO:geometry:magnitude of difference in the energies: 1.7763568394002505e-15
# INFO:geometry:Final logp_proposal: 41.020541590612304
# added energy components: [('CustomBondForce', 1.1114824464808768), ('CustomAngleForce', 9.449446410979123), ('CustomTorsionForce', 0.0), ('CustomBondForce', 0.0)]

# %%
# Build new htf and validate_endstate_energies -- lambda = 0
from perses.annihilation.relative import RepartitionedHybridTopologyFactory
from perses.tests.utils import validate_endstate_energies
from simtk import openmm
forward_htf = RepartitionedHybridTopologyFactory(topology_proposal=topology_proposal,
             current_positions=positions,
             new_positions=forward_new_positions,
             use_dispersion_correction=False,
             functions=None,
             softcore_alpha=None,
             bond_softening_constant=1.0,
             angle_softening_constant=1.0,
             soften_only_new=False,
             neglected_new_angle_terms=[],
             neglected_old_angle_terms=[],
             softcore_LJ_v2=True,
             softcore_electrostatics=True,
             softcore_LJ_v2_alpha=0.85,
             softcore_electrostatics_alpha=0.3,
             softcore_sigma_Q=1.0,
             interpolate_old_and_new_14s=False,
             omitted_terms=None,
             endstate=1,
             flatten_torsions=True,
             flatten_exceptions=True)

if not topology_proposal.unique_new_atoms:
    assert geometry_engine.forward_final_context_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.forward_final_context_reduced_potential})"
    assert geometry_engine.forward_atoms_with_positions_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's forward atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.forward_atoms_with_positions_reduced_potential})"
    vacuum_added_valence_energy = 0.0
else:
    added_valence_energy = geometry_engine.forward_final_context_reduced_potential - geometry_engine.forward_atoms_with_positions_reduced_potential

if not topology_proposal.unique_old_atoms:
    assert geometry_engine.reverse_final_context_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.reverse_final_context_reduced_potential})"
    assert geometry_engine.reverse_atoms_with_positions_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.reverse_atoms_with_positions_reduced_potential})"
    subtracted_valence_energy = 0.0
else:
    subtracted_valence_energy = geometry_engine.reverse_final_context_reduced_potential - geometry_engine.reverse_atoms_with_positions_reduced_potential

zero_state_error, one_state_error = validate_endstate_energies(forward_htf._topology_proposal, forward_htf, added_valence_energy, subtracted_valence_energy, beta = 1.0/(kB*temperature), ENERGY_THRESHOLD = ENERGY_THRESHOLD, platform = openmm.Platform.getPlatformByName('Reference'), repartitioned_endstate=1)
print(f"zero state error : {zero_state_error}")
print(f"one state error : {one_state_error}")
# Out:
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 0
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:No MonteCarloBarostat added.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b21d37ac510> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is NoCutoff
# INFO:relative:	_add_nonbonded_force_terms: 0 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 0 added to sterics_custom_nonbonded force
# conducting subsequent work with the following platform: Reference
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 1.1441495623257518
# 			HarmonicAngleForce: 9.609430902542483
# 			PeriodicTorsionForce: 8.925276138710759
# 			NonbondedForce: 7.171358203255265
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 2.6910558040442414
# 			HarmonicAngleForce: 12.211086167659271
# 			PeriodicTorsionForce: 16.763501256376614
# 			NonbondedForce: -32.32075284818795
# 			AndersenThermostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 1.579573357563364
# 			HarmonicAngleForce: 2.7616397566801516
# 			PeriodicTorsionForce: 16.763501256376614
# 			NonbondedForce: -32.32075284818795
# 			AndersenThermostat: 0.0
# ---------------------------------------------------
# AssertionError    Traceback (most recent call last)
# <ipython-input-72-fbca76ac0b7b> in <module>
#      39     subtracted_valence_energy = geometry_engine.reverse_final_context_reduced_potential - geometry_engine.reverse_atoms_with_positions_reduced_potential
#      40
# ---> 41 zero_state_error, one_state_error = validate_endstate_energies(forward_htf._topology_proposal, forward_htf, added_valence_energy, subtracted_valence_energy, beta = 1.0/(kB*temperature), ENERGY_THRESHOLD = ENERGY_THRESHOLD, platform = openmm.Platform.getPlatformByName('Reference'), repartitioned_endstate=1)
#      42 print(f"zero state error : {zero_state_error}")
#      43 print(f"one state error : {one_state_error}")
#
# ~/miniconda3/envs/perses-sims/lib/python3.7/site-packages/perses-0.8.2.dev0-py3.7.egg/perses/tests/utils.py in validate_endstate_energies(topology_proposal, htf, added_energy, subtracted_energy, beta, ENERGY_THRESHOLD, platform, trajectory_directory, repartitioned_endstate)
#     834         one_error = nonalch_one_rp - alch_one_rp + subtracted_energy
#     835         ratio = abs((one_error) / (nonalch_one_rp + alch_one_rp + subtracted_energy))
# --> 836         assert ratio < ENERGY_THRESHOLD, f"The ratio in energy difference for the ONE state is {ratio}.\n This is greater than the threshold of {ENERGY_THRESHOLD}.\n real-one: {nonalch_one_rp} \n alc-one: {alch_one_rp} \nsubtracted-valence: {subtracted_energy}"
#     837     else:
#     838         zero_error = nonalch_zero_rp - alch_zero_rp + added_energy
#
# AssertionError: The ratio in energy difference for the ONE state is 1.2537917418071042e-06.
#  This is greater than the threshold of 1e-06.
#  real-one: -11.21605474616723
#  alc-one: -0.6551242459264305
# subtracted-valence: 10.560928857460002
