# %%
###########################################
# IMPORTS
###########################################
from openmmtools.states import SamplerState, ThermodynamicState, CompoundThermodynamicState
from simtk import unit, openmm
from perses.tests.utils import compute_potential_components
from openmmtools.constants import kB
from perses.dispersed.utils import configure_platform
from perses.annihilation.rest import RESTTopologyFactory
from perses.annihilation.lambda_protocol import RESTState
import numpy as np
from perses.tests.test_topology_proposal import generate_atp, generate_dipeptide_top_pos_sys
from openmmtools.testsystems import AlanineDipeptideVacuum, AlanineDipeptideExplicit
import itertools

#############################################
# CONSTANTS
#############################################
temperature = 300.0 * unit.kelvin
kT = kB * temperature
beta = 1.0/kT
REFERENCE_PLATFORM = openmm.Platform.getPlatformByName("Reference")
# Out:
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
# INFO:rdkit:Enabling RDKit 2021.03.5 jupyter extensions
# conducting subsequent work with the following platform: CUDA

# %% [markdown]
# # Run the existing scaling test in test_rest.py

# %%
def compare_energies(REST_system, other_system, positions, rest_atoms, T_min, T):

    # Create thermodynamic state
    lambda_zero_alchemical_state = RESTState.from_system(REST_system)
    thermostate = ThermodynamicState(REST_system, temperature=T_min)
    compound_thermodynamic_state = CompoundThermodynamicState(thermostate,
                                                              composable_states=[lambda_zero_alchemical_state])

    # Set alchemical parameters
    beta_0 = 1 / (kB * T_min)
    beta_m = 1 / (kB * T)
    compound_thermodynamic_state.set_alchemical_parameters(beta_0, beta_m)

    # Minimize and save energy
    integrator = openmm.VerletIntegrator(1.0 * unit.femtosecond)
    context = compound_thermodynamic_state.create_context(integrator)
    context.setPositions(positions)
    sampler_state = SamplerState.from_context(context)
    REST_energy = compound_thermodynamic_state.reduced_potential(sampler_state)

    # Compute energy for non-RESTified system
    # Determine regions and scaling factors
    solute = rest_atoms
    solvent = [i for i in range(other_system.getNumParticles()) if i not in solute]
    solute_scaling = beta_m / beta_0
    inter_scaling = np.sqrt(beta_m / beta_0)

    # Scale the terms in the bond force appropriately
    bond_force = other_system.getForce(0)
    for bond in range(bond_force.getNumBonds()):
        p1, p2, length, k = bond_force.getBondParameters(bond)
        if p1 in solute and p2 in solute:
            bond_force.setBondParameters(bond, p1, p2, length, k * solute_scaling)
        elif (p1 in solute and p2 in solvent) or (p1 in solvent and p2 in solute):
            bond_force.setBondParameters(bond, p1, p2, length, k * inter_scaling)

    # Scale the terms in the angle force appropriately
    angle_force = other_system.getForce(1)
    for angle_index in range(angle_force.getNumAngles()):
        p1, p2, p3, angle, k = angle_force.getAngleParameters(angle_index)
        if p1 in solute and p2 in solute and p3 in solute:
            angle_force.setAngleParameters(angle_index, p1, p2, p3, angle, k * solute_scaling)
        elif set([p1, p2, p3]).intersection(set(solute)) != set() and set([p1, p2, p3]).intersection(
                set(solvent)) != set():
            angle_force.setAngleParameters(angle_index, p1, p2, p3, angle, k * inter_scaling)

    # Scale the terms in the torsion force appropriately
    torsion_force = other_system.getForce(2)
    for torsion_index in range(torsion_force.getNumTorsions()):
        p1, p2, p3, p4, periodicity, phase, k = torsion_force.getTorsionParameters(torsion_index)
        if p1 in solute and p2 in solute and p3 in solute and p4 in solute:
            torsion_force.setTorsionParameters(torsion_index, p1, p2, p3, p4, periodicity, phase, k * solute_scaling)
        elif set([p1, p2, p3, p4]).intersection(set(solute)) != set() and set([p1, p2, p3, p4]).intersection(
                set(solvent)) != set():
            torsion_force.setTorsionParameters(torsion_index, p1, p2, p3, p4, periodicity, phase, k * inter_scaling)

    # Scale the exceptions in the nonbonded force appropriately
    nb_force = other_system.getForce(3)
    for nb_index in range(nb_force.getNumExceptions()):
        p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(nb_index)
        if p1 in solute and p2 in solute:
            nb_force.setExceptionParameters(nb_index, p1, p2, solute_scaling * chargeProd, sigma, solute_scaling * epsilon)
        elif (p1 in solute and p2 in solvent) or (p1 in solvent and p2 in solute):
            nb_force.setExceptionParameters(nb_index, p1, p2, inter_scaling * chargeProd, sigma, inter_scaling * epsilon)

    # Scale nonbonded interactions for solute-solute region by adding exceptions for all pairs of atoms
    exception_pairs = [tuple(sorted([nb_force.getExceptionParameters(nb_index)[0], nb_force.getExceptionParameters(nb_index)[1]])) for nb_index in range(nb_force.getNumExceptions())]
    solute_pairs = set([tuple(sorted(pair)) for pair in list(itertools.product(solute, solute))])
    for pair in list(solute_pairs):
        p1 = pair[0]
        p2 = pair[1]
        p1_charge, p1_sigma, p1_epsilon = nb_force.getParticleParameters(p1)
        p2_charge, p2_sigma, p2_epsilon = nb_force.getParticleParameters(p2)
        if p1 != p2:
            if pair not in exception_pairs:
                nb_force.addException(p1, p2, p1_charge * p2_charge * solute_scaling, 0.5 * (p1_sigma + p2_sigma),
                                      np.sqrt(p1_epsilon * p2_epsilon) * solute_scaling)

    # Scale nonbonded interactions for inter region by adding exceptions for all pairs of atoms
    for pair in list(itertools.product(solute, solvent)):
        p1 = pair[0]
        p2 = int(pair[1])  # otherwise, will be a numpy int
        p1_charge, p1_sigma, p1_epsilon = nb_force.getParticleParameters(p1)
        p2_charge, p2_sigma, p2_epsilon = nb_force.getParticleParameters(p2)
        if tuple(sorted(pair)) not in exception_pairs:
            nb_force.addException(p1, p2, p1_charge * p2_charge * inter_scaling, 0.5 * (p1_sigma + p2_sigma), np.sqrt(p1_epsilon * p2_epsilon) * inter_scaling)

    # Get energy
    thermostate = ThermodynamicState(other_system, temperature=T_min)
    integrator = openmm.VerletIntegrator(1.0 * unit.femtosecond)
    context = thermostate.create_context(integrator)
    context.setPositions(positions)
    sampler_state = SamplerState.from_context(context)
    nonREST_energy = thermostate.reduced_potential(sampler_state)
    
    print(f"REST energy: {REST_energy}")
    print(f"nonREST energy: {nonREST_energy}")
    assert REST_energy - nonREST_energy < 1, f"The energy of the REST system ({REST_energy}) does not match " \
                                                        f"that of the non-REST system with terms manually scaled according to REST2({nonREST_energy})."

def test_energy_scaling():
    """
        Test whether the energy of a REST-ified system is equal to the energy of the system with terms manually scaled by
        the same factor as is used in REST.  T_min is 298 K and the thermodynamic state has temperature 600 K.
    """

    # Set temperatures
    T_min = 300.0 * unit.kelvin
    T = 600 * unit.kelvin

    ## CASE 1: alanine dipeptide in vacuum
    # Create vanilla system
    print("alanine dipeptide in vacuum")
    ala = AlanineDipeptideVacuum()
    system = ala.system
    positions = ala.positions

    # Create REST system
    system.removeForce(4)
    res1 = list(ala.topology.residues())[1]
    rest_atoms = [atom.index for atom in res1.atoms()]
    factory = RESTTopologyFactory(system, solute_region=rest_atoms)
    REST_system = factory.REST_system
    
    # Check energy scaling
    compare_energies(REST_system, system, positions, rest_atoms, T_min, T)

    ## CASE 2: alanine dipeptide in solvent (with Nonbonded Method as NoCutoff)
    # Create vanilla system
    print("alanine dipeptide in solvent")
    ala = AlanineDipeptideExplicit()
    system = ala.system
#     system.getForce(3).setNonbondedMethod(0)
    positions = ala.positions

    # Create REST system
    system.removeForce(4)
    res1 = list(ala.topology.residues())[1]
    rest_atoms = [atom.index for atom in res1.atoms()]
    factory = RESTTopologyFactory(system, solute_region=rest_atoms, use_dispersion_correction=True)
    REST_system = factory.REST_system
    
#     system.getForce(3).setUseDispersionCorrection(False)
#     REST_system.getForce(3).setUseDispersionCorrection(False)

    # Check energy scaling
    compare_energies(REST_system, system, positions, rest_atoms, T_min, T)

    ## CASE 3: alanine dipeptide in solvent with repartitioned hybrid system (with Nonbonded Method as NoCutoff)
    # Create repartitioned hybrid system for lambda 0 endstate
    print("alanine dipepetide with repartitioned hybrid system")
    atp, system_generator = generate_atp(phase='solvent')
    htf = generate_dipeptide_top_pos_sys(atp.topology,
                                         new_res='THR',
                                         system=atp.system,
                                         positions=atp.positions,
                                         system_generator=system_generator,
                                         conduct_htf_prop=True,
                                         repartitioned=True,
                                         endstate=0,
                                         validate_endstate_energy=False)
    system = htf.hybrid_system
    system.removeForce(0) # Remove barostat
#     system.getForce(3).setNonbondedMethod(0)

    # Create REST-ified hybrid system
    res1 = list(htf.hybrid_topology.residues)[1]
    rest_atoms = [atom.index for atom in list(res1.atoms)]
    factory = RESTTopologyFactory(system, solute_region=rest_atoms, use_dispersion_correction=True)
    REST_system = factory.REST_system

    # Check energy scaling
    compare_energies(REST_system, system, htf.hybrid_positions, rest_atoms, T_min, T)

# %%
test_energy_scaling()
# Out:
# INFO:REST:No MonteCarloBarostat added.
# INFO:REST:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# INFO:REST:No unknown forces.
# alanine dipeptide in vacuum
# INFO:REST:No MonteCarloBarostat added.
# INFO:REST:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=3.2852863, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=3.2861648000000003, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=3.1855098), unit=nanometer)]
# REST energy: -38.356522004048074
# nonREST energy: -38.35653377001734
# alanine dipeptide in solvent
# INFO:REST:No unknown forces.
# REST energy: -9883.66816482165
# nonREST energy: -9884.410368966905

# %% [markdown]
# # Adapt this test to avoid adding exceptions (which don't use PME)

# %%
import copy
from tqdm import tqdm_notebook

# %%
# Set temperatures
T_min = 300.0 * unit.kelvin
T = 600 * unit.kelvin

# ## CASE 1: alanine dipeptide in vacuum
# # Create vanilla system
# print("alanine dipeptide in vacuum")
# ala = AlanineDipeptideVacuum()
# system = ala.system
# positions = ala.positions

# # Create REST system
# system.removeForce(4)
# res1 = list(ala.topology.residues())[1]
# rest_atoms = [atom.index for atom in res1.atoms()]
# factory = RESTTopologyFactory(system, solute_region=rest_atoms)
# REST_system = factory.REST_system

## CASE 2: alanine dipeptide in solvent
# Create vanilla system
print("alanine dipeptide in solvent")
ala = AlanineDipeptideExplicit()
system = ala.system
positions = ala.positions

# Create REST system
system.removeForce(4)
# system.getForce(3).setNonbondedMethod(0)
res1 = list(ala.topology.residues())[1]
rest_atoms = [atom.index for atom in res1.atoms()]
factory = RESTTopologyFactory(system, solute_region=rest_atoms, use_dispersion_correction=True)
REST_system = factory.REST_system
# REST_system.getForce(3).setNonbondedMethod(0)
# Out:
# alanine dipeptide in solvent
# INFO:REST:No MonteCarloBarostat added.
# INFO:REST:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=3.2852863, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=3.2861648000000003, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=3.1855098), unit=nanometer)]
# INFO:REST:No unknown forces.

# %%
# system.getForce(3).setUseDispersionCorrection(False)
# REST_system.getForce(3).setUseDispersionCorrection(False)

# %%
# solute = rest_atoms
# solvent = [i for i in range(REST_system.getNumParticles()) if i not in rest_atoms]

# nb_force = REST_system.getForce(3)
# # for i in range(nb_force.getNumParticles()):
# #     charge, sigma, epsilon = nb_force.getParticleParameters(i)
# #     if i in rest_atoms:
# #         continue
# #     else:
# #         nb_force.setParticleParameters(i, charge*0, sigma, epsilon*0)
# # #     nb_force.setParticleParameters(i, charge*0, sigma, epsilon*0)
        

# # for i in range(nb_force.getNumParticleParameterOffsets()):
# #     param, particle_idx, chargeScale, sigmaScale, epsilonScale = nb_force.getParticleParameterOffset(i)
# #     if particle_idx in rest_atoms:
# #         continue
# #     else:
# #         nb_force.setParticleParameterOffset(i, 'electrostatic_scale', particle_idx, 0.0, 0.0, 0.0)
# #         nb_force.setParticleParameterOffset(i, 'steric_scale', particle_idx, 0.0, 0.0, 0.0)

# zeroed_exceptions = []
# for i in range(nb_force.getNumExceptions()):
#     p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(i)
#     particles = [p1, p2]
#     if all(x in rest_atoms for x in particles):
# #         nb_force.setExceptionParameters(i, p1, p2, chargeProd*0, sigma, epsilon*0)
# #         zeroed_exceptions.append(i)
#         continue
#     elif all(x in solvent for x in particles):
#         nb_force.setExceptionParameters(i, p1, p2, chargeProd*0, sigma, epsilon*0)
#         zeroed_exceptions.append(i)
#     else:
#         nb_force.setExceptionParameters(i, p1, p2, chargeProd*0, sigma, epsilon*0)
#         zeroed_exceptions.append(i)
# #     nb_force.setExceptionParameters(i, p1, p2, charge*0, sigma, epsilon*0)
        
# for i in range(nb_force.getNumExceptionParameterOffsets()):
#     param, exception_idx, chargeScale, sigmaScale, epsilonScale = nb_force.getExceptionParameterOffset(i)
#     if exception_idx in zeroed_exceptions:
#         nb_force.setExceptionParameterOffset(i, 'electrostatic_scale', exception_idx, 0.0, 0.0, 0.0)
#         nb_force.setExceptionParameterOffset(i, 'steric_scale', exception_idx, 0.0, 0.0, 0.0)


# print("adding exceptions for solute-solvent pairs")
# exception_pairs = [tuple(sorted([nb_force.getExceptionParameters(nb_index)[0], nb_force.getExceptionParameters(nb_index)[1]])) for nb_index in range(nb_force.getNumExceptions())]
# solute_solvent_pairs = set([tuple(sorted(pair)) for pair in list(itertools.product(solute, solvent))])
# solvent_pairs = set([tuple(sorted(pair)) for pair in list(itertools.product(solvent, solvent))])
# for pair in list(solute_solvent_pairs):
#     p1 = pair[0]
#     p2 = pair[1]
# #     p1_charge, p1_sigma, p1_epsilon = nb_force.getParticleParameters(p1)
# #     p2_charge, p2_sigma, p2_epsilon = nb_force.getParticleParameters(p2)
#     if p1 != p2:
#         if pair not in exception_pairs:
#             nb_force.addException(p1, p2, 0, 0.5, 0)
# print("adding exceptions for solvent pairs")
# for pair in tqdm_notebook(list(solvent_pairs)):
#     p1 = pair[0]
#     p2 = pair[1]
# #     p1_charge, p1_sigma, p1_epsilon = nb_force.getParticleParameters(p1)
# #     p2_charge, p2_sigma, p2_epsilon = nb_force.getParticleParameters(p2)
#     if p1 != p2:
#         if pair not in exception_pairs:
#             nb_force.addException(p1, p2, 0, 0.5, 0)
# Out:
# adding exceptions for solute-solvent pairs
# adding exceptions for solvent pairs
# <ipython-input-17-0036cfe680f0>:58: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for pair in tqdm_notebook(list(solvent_pairs)):
#   0%|          | 0/2552670 [00:00<?, ?it/s]

# %%
# bond_force = REST_system.getForce(0)
# for i in range(bond_force.getNumBonds()):
#     p1, p2, params = bond_force.getBondParameters(i)
#     length, k, identifier = params
#     if p1 in rest_atoms and p2 in rest_atoms:
#         continue
# #         bond_force.setBondParameters(i, p1, p2, [length, k*0, identifier])
#     elif (p1 in rest_atoms and p2 not in rest_atoms) or (p1 not in rest_atoms and p2 in rest_atoms):
#         bond_force.setBondParameters(i, p1, p2, [length, k*0, identifier])
#     else:
#         bond_force.setBondParameters(i, p1, p2, [length, k*0, identifier])

# %%
# Create thermodynamic state
lambda_zero_alchemical_state = RESTState.from_system(REST_system)
thermostate = ThermodynamicState(REST_system, temperature=T_min)
compound_thermodynamic_state = CompoundThermodynamicState(thermostate,
                                                          composable_states=[lambda_zero_alchemical_state])

# Set alchemical parameters
beta_0 = 1 / (kB * T_min)
beta_m = 1 / (kB * T)
compound_thermodynamic_state.set_alchemical_parameters(beta_0, beta_m)

# Get energy
integrator = openmm.VerletIntegrator(1.0 * unit.femtosecond)
context = compound_thermodynamic_state.create_context(integrator)
context.setPositions(positions)
sampler_state = SamplerState.from_context(context)
REST_energy = compound_thermodynamic_state.reduced_potential(sampler_state)
components_rest = [component[1] for component in compute_potential_components(context, beta=beta)]
# Out:
# conducting subsequent work with the following platform: CUDA

# %%
# Zero inter and solvent energies and get REST energy
system_A = copy.deepcopy(system)

# Determine regions and scaling factors
solute = rest_atoms
solvent = [i for i in range(system_A.getNumParticles()) if i not in solute]
solute_scaling = beta_m / beta_0
inter_scaling = np.sqrt(beta_m / beta_0)

bond_force = system_A.getForce(0)
for bond_index in range(bond_force.getNumBonds()):
    p1, p2, length, k = bond_force.getBondParameters(bond_index)
    particles = [p1, p2]
    if all(x in solute for x in particles):
        continue
    elif all(x in solvent for x in particles):
        bond_force.setBondParameters(bond_index, p1, p2, length, k*0)
    else:
        bond_force.setBondParameters(bond_index, p1, p2, length, k*0)
#     bond_force.setBondParameters(bond_index, p1, p2, length, k*0)

angle_force = system_A.getForce(1)
for angle_index in range(angle_force.getNumAngles()):
    p1, p2, p3, angle, k = angle_force.getAngleParameters(angle_index)
    particles = [p1, p2, p3]
    if all(x in solute for x in particles):
        continue
    elif all(x in solvent for x in particles):
        angle_force.setAngleParameters(angle_index, p1, p2, p3, angle, k*0)
    else:
        angle_force.setAngleParameters(angle_index, p1, p2, p3, angle, k*0)
#     angle_force.setAngleParameters(angle_index, p1, p2, p3, angle, k*0)

torsion_force = system_A.getForce(2)
for torsion_index in range(torsion_force.getNumTorsions()):
    p1, p2, p3, p4, periodicity, phase, k = torsion_force.getTorsionParameters(torsion_index)
    particles = [p1, p2, p3, p4]
    if all(x in solute for x in particles):
        continue
    elif all(x in solvent for x in particles):
        torsion_force.setTorsionParameters(torsion_index, p1, p2, p3, p4, periodicity, phase, k*0)
    else:
        torsion_force.setTorsionParameters(torsion_index, p1, p2, p3, p4, periodicity, phase, k*0)
#     torsion_force.setTorsionParameters(torsion_index, p1, p2, p3, p4, periodicity, phase, k*0)


nb_force = system_A.getForce(3)
for i in range(nb_force.getNumParticles()):
    charge, sigma, epsilon = nb_force.getParticleParameters(i)
    if i in solute:
        continue
    else:
        nb_force.setParticleParameters(i, charge*0, sigma, epsilon*0)
    nb_force.setParticleParameters(i, charge*0, sigma, epsilon*0)
        
for i in range(nb_force.getNumExceptions()):
    p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(i)
    particles = [p1, p2]
    if all(x in solute for x in particles):
        continue
    elif all(x in solvent for x in particles):
        nb_force.setExceptionParameters(i, p1, p2, charge*0, sigma, epsilon*0)
    else:
        nb_force.setExceptionParameters(i, p1, p2, charge*0, sigma, epsilon*0)
#     if p1 in solute and p2 in solute:
#         continue
#     elif (p1 in solute and p2 in solvent) or (p1 in solvent and p2 in solute):
#         nb_force.setExceptionParameters(i, p1, p2, charge*0, sigma, epsilon*0)
#     else:
#         nb_force.setExceptionParameters(i, p1, p2, charge*0, sigma, epsilon*0)
#     nb_force.setExceptionParameters(i, p1, p2, charge*0, sigma, epsilon*0)
        
        
# Get energy
thermostate = ThermodynamicState(system_A, temperature=T_min)
integrator = openmm.VerletIntegrator(1.0 * unit.femtosecond)
context = thermostate.create_context(integrator)
context.setPositions(positions)
sampler_state = SamplerState.from_context(context)
system_A_energy = thermostate.reduced_potential(sampler_state)
system_A_energy_scaled = system_A_energy * solute_scaling

# %%
# Zero inter and REST energies and get solvent energy
system_B = copy.deepcopy(system)

# Determine regions and scaling factors
solute = rest_atoms
solvent = [i for i in range(system_B.getNumParticles()) if i not in solute]
solute_scaling = beta_m / beta_0
inter_scaling = np.sqrt(beta_m / beta_0)

bond_force = system_B.getForce(0)
for bond_index in range(bond_force.getNumBonds()):
    p1, p2, length, k = bond_force.getBondParameters(bond_index)
    particles = [p1, p2]
    if all(x in solute for x in particles):
        bond_force.setBondParameters(bond_index, p1, p2, length, k*0)
    elif all(x in solvent for x in particles):
        continue
    else:
        bond_force.setBondParameters(bond_index, p1, p2, length, k*0)
#     if p1 in solute and p2 in solute:
#         bond_force.setBondParameters(bond_index, p1, p2, length, k*0)
#     elif (p1 in solute and p2 in solvent) or (p1 in solvent and p2 in solute):
#         bond_force.setBondParameters(bond_index, p1, p2, length, k*0)
#     else:
#         continue
#     bond_force.setBondParameters(bond_index, p1, p2, length, k*0)

angle_force = system_B.getForce(1)
for angle_index in range(angle_force.getNumAngles()):
    p1, p2, p3, angle, k = angle_force.getAngleParameters(angle_index)
    particles = [p1, p2, p3]
    if all(x in solute for x in particles):
        angle_force.setAngleParameters(angle_index, p1, p2, p3, angle, k*0)
    elif all(x in solvent for x in particles):
        continue
    else:
        angle_force.setAngleParameters(angle_index, p1, p2, p3, angle, k*0)
    
#     if p1 in solute and p2 in solute and p3 in solute:
#         angle_force.setAngleParameters(angle_index, p1, p2, p3, angle, k*0)
#     elif set([p1, p2, p3]).intersection(set(solute)) != set() and set([p1, p2, p3]).intersection(set(solvent)) != set():
#         angle_force.setAngleParameters(angle_index, p1, p2, p3, angle, k*0)
#     else:
#         continue
#     angle_force.setAngleParameters(angle_index, p1, p2, p3, angle, k*0)

torsion_force = system_B.getForce(2)
for torsion_index in range(torsion_force.getNumTorsions()):
    p1, p2, p3, p4, periodicity, phase, k = torsion_force.getTorsionParameters(torsion_index)
    particles = [p1, p2, p3, p4]
    if all(x in solute for x in particles):
        torsion_force.setTorsionParameters(torsion_index, p1, p2, p3, p4, periodicity, phase, k*0)
    elif all(x in solvent for x in particles):
        continue
    else:
        torsion_force.setTorsionParameters(torsion_index, p1, p2, p3, p4, periodicity, phase, k*0)
#     if p1 in solute and p2 in solute and p3 in solute and p4 in solute:
#         torsion_force.setTorsionParameters(torsion_index, p1, p2, p3, p4, periodicity, phase, k*0)
#     elif set([p1, p2, p3, p4]).intersection(set(solute)) != set() and set([p1, p2, p3, p4]).intersection(
#             set(solvent)) != set():
#         torsion_force.setTorsionParameters(torsion_index, p1, p2, p3, p4, periodicity, phase, k*0)
#     else:
#         continue
#     torsion_force.setTorsionParameters(torsion_index, p1, p2, p3, p4, periodicity, phase, k*0)

nb_force = system_B.getForce(3)
for i in range(nb_force.getNumParticles()):
    charge, sigma, epsilon = nb_force.getParticleParameters(i)
    if i in solute:
        nb_force.setParticleParameters(i, charge*0, sigma, epsilon*0)
    else:
        continue
#     nb_force.setParticleParameters(i, charge*0, sigma, epsilon*0)
        
nb_force = system_B.getForce(3)
for i in range(nb_force.getNumExceptions()):
    p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(i)
    particles = [p1, p2]
    if all(x in solute for x in particles):
        nb_force.setExceptionParameters(i, p1, p2, charge*0, sigma, epsilon*0)
    elif all(x in solvent for x in particles):
        continue
    else:
        nb_force.setExceptionParameters(i, p1, p2, charge*0, sigma, epsilon*0)
#     if p1 in solute and p2 in solute:
#         nb_force.setExceptionParameters(i, p1, p2, charge*0, sigma, epsilon*0)
#     elif (p1 in solute and p2 in solvent) or (p1 in solvent and p2 in solute):
#         nb_force.setExceptionParameters(i, p1, p2, charge*0, sigma, epsilon*0)
#     else:
#         continue
#     nb_force.setExceptionParameters(i, p1, p2, charge*0, sigma, epsilon*0)
        
# Get energy
thermostate = ThermodynamicState(system_B, temperature=T_min)
integrator = openmm.VerletIntegrator(1.0 * unit.femtosecond)
context = thermostate.create_context(integrator)
context.setPositions(positions)
sampler_state = SamplerState.from_context(context)
system_B_energy = thermostate.reduced_potential(sampler_state)
system_B_energy_scaled = system_B_energy

# %%
# # Zero REST and solvent energies and get inter energy
# system_C = copy.deepcopy(system)

# # Determine regions and scaling factors
# solute = rest_atoms
# solvent = [i for i in range(system_C.getNumParticles()) if i not in solute]
# solute_scaling = beta_m / beta_0
# inter_scaling = np.sqrt(beta_m / beta_0)

# bond_force = system_C.getForce(0)
# for bond_index in range(bond_force.getNumBonds()):
#     p1, p2, length, k = bond_force.getBondParameters(bond_index)
#     particles = [p1, p2]
# #     if all(x in solute for x in particles):
# #         bond_force.setBondParameters(bond_index, p1, p2, length, k*0)
# #     elif all(x in solvent for x in particles):
# #         bond_force.setBondParameters(bond_index, p1, p2, length, k*0)
# #     else:
# #         continue
# #     if p1 in solute and p2 in solute:
# #         bond_force.setBondParameters(bond_index, p1, p2, length, k*0)
# #     elif (p1 in solute and p2 in solvent) or (p1 in solvent and p2 in solute):
# #         continue
# #     else:
# #         bond_force.setBondParameters(bond_index, p1, p2, length, k*0)
#     bond_force.setBondParameters(bond_index, p1, p2, length, k*0)
        
# angle_force = system_C.getForce(1)
# for angle_index in range(angle_force.getNumAngles()):
#     p1, p2, p3, angle, k = angle_force.getAngleParameters(angle_index)
#     particles = [p1, p2, p3]
# #     if all(x in solute for x in particles):
# #         angle_force.setAngleParameters(angle_index, p1, p2, p3, angle, k*0)
# #     elif all(x in solvent for x in particles):
# #         angle_force.setAngleParameters(angle_index, p1, p2, p3, angle, k*0)
# #     else:
# #         continue
# #     if p1 in solute and p2 in solute and p3 in solute:
# #         angle_force.setAngleParameters(angle_index, p1, p2, p3, angle, k*0)
# #     elif set([p1, p2, p3]).intersection(set(solute)) != set() and set([p1, p2, p3]).intersection(set(solvent)) != set():
# #         continue
# #     else:
# #         angle_force.setAngleParameters(angle_index, p1, p2, p3, angle, k*0)
#     angle_force.setAngleParameters(angle_index, p1, p2, p3, angle, k*0)
    
# torsion_force = system_C.getForce(2)
# for torsion_index in range(torsion_force.getNumTorsions()):
#     p1, p2, p3, p4, periodicity, phase, k = torsion_force.getTorsionParameters(torsion_index)
#     particles = [p1, p2, p3, p4]
# #     if all(x in solute for x in particles):
# #         torsion_force.setTorsionParameters(torsion_index, p1, p2, p3, p4, periodicity, phase, k*0)
# #     elif all(x in solvent for x in particles):
# #         torsion_force.setTorsionParameters(torsion_index, p1, p2, p3, p4, periodicity, phase, k*0)
# #     else:
# #         continue
# #     if p1 in solute and p2 in solute and p3 in solute and p4 in solute:
# #         torsion_force.setTorsionParameters(torsion_index, p1, p2, p3, p4, periodicity, phase, k*0)
# #     elif set([p1, p2, p3, p4]).intersection(set(solute)) != set() and set([p1, p2, p3, p4]).intersection(
# #             set(solvent)) != set():
# #         continue
# #     else:
# #         torsion_force.setTorsionParameters(torsion_index, p1, p2, p3, p4, periodicity, phase, k*0)
#     torsion_force.setTorsionParameters(torsion_index, p1, p2, p3, p4, periodicity, phase, k*0)
    
# nb_force = system_C.getForce(3)
# # for i in range(nb_force.getNumParticles()):
# #     charge, sigma, epsilon = nb_force.getParticleParameters(i)
# #     nb_force.setParticleParameters(i, charge*0, sigma, epsilon*0)

# print("zeroing exceptions")
# for i in range(nb_force.getNumExceptions()):
#     p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(i)
#     particles = [p1, p2]
#     if all(x in solute for x in particles):
#         print("solute exception: ", particles, chargeProd, sigma, epsilon)
#         nb_force.setExceptionParameters(i, p1, p2, chargeProd*0, sigma, epsilon*0)
#     elif all(x in solvent for x in particles):
#         print("solvent exception: ", particles, chargeProd, sigma, epsilon)
#         nb_force.setExceptionParameters(i, p1, p2, chargeProd*0, sigma, epsilon*0)
#     else:
#         continue
# #     if p1 in solute and p2 in solute:
# #         nb_force.setExceptionParameters(i, p1, p2, charge*0, sigma, epsilon*0)
# #     elif (p1 in solute and p2 in solvent) or (p1 in solvent and p2 in solute):
# #         nb_force.setExceptionParameters(i, p1, p2, charge*0, sigma, epsilon*0)
# #     else:
# #         continue
# #     nb_force.setExceptionParameters(i, p1, p2, charge*0, sigma, epsilon*0)

# print("adding exceptions for solute pairs")
# exception_pairs = [tuple(sorted([nb_force.getExceptionParameters(nb_index)[0], nb_force.getExceptionParameters(nb_index)[1]])) for nb_index in range(nb_force.getNumExceptions())]
# solute_pairs = set([tuple(sorted(pair)) for pair in list(itertools.product(solute, solute))])
# solvent_pairs = set([tuple(sorted(pair)) for pair in list(itertools.product(solvent, solvent))])
# for pair in list(solute_pairs):
#     p1 = pair[0]
#     p2 = pair[1]
# #     p1_charge, p1_sigma, p1_epsilon = nb_force.getParticleParameters(p1)
# #     p2_charge, p2_sigma, p2_epsilon = nb_force.getParticleParameters(p2)
#     if p1 != p2:
#         if pair not in exception_pairs:
#             nb_force.addException(p1, p2, 0, 0.5, 0)
# print("adding exceptions for solvent pairs")
# for pair in tqdm_notebook(list(solvent_pairs)):
#     p1 = pair[0]
#     p2 = pair[1]
# #     p1_charge, p1_sigma, p1_epsilon = nb_force.getParticleParameters(p1)
# #     p2_charge, p2_sigma, p2_epsilon = nb_force.getParticleParameters(p2)
#     if p1 != p2:
#         if pair not in exception_pairs:
#             nb_force.addException(p1, p2, 0, 0.5, 0)


            
# # Get energy
# thermostate = ThermodynamicState(system_C, temperature=T_min)
# integrator = openmm.VerletIntegrator(1.0 * unit.femtosecond)
# context = thermostate.create_context(integrator)
# context.setPositions(positions)
# sampler_state = SamplerState.from_context(context)
# system_C_energy = thermostate.reduced_potential(sampler_state)
# system_C_energy_scaled = system_C_energy * inter_scaling
# Out:
# zeroing exceptions
# solvent exception:  [3, 5] -0.053145975154069464 e**2 0.28047273444524545 nm 0.12012161263171671 kJ/mol
# solvent exception:  [2, 5] -0.053145975154069464 e**2 0.28047273444524545 nm 0.12012161263171671 kJ/mol
# solvent exception:  [0, 5] -0.053145975154069464 e**2 0.28047273444524545 nm 0.12012161263171671 kJ/mol
# solute exception:  [13, 14] 0.030014325027576096 e**2 0.3024601147602527 nm 0.07687068174209402 kJ/mol
# solute exception:  [12, 14] 0.030014325027576096 e**2 0.3024601147602527 nm 0.07687068174209402 kJ/mol
# solute exception:  [11, 14] 0.030014325027576096 e**2 0.3024601147602527 nm 0.07687068174209402 kJ/mol
# solute exception:  [9, 11] 0.004135575 e**2 0.2560442914951194 nm 0.03284440013043381 kJ/mol
# solute exception:  [9, 12] 0.004135575 e**2 0.2560442914951194 nm 0.03284440013043381 kJ/mol
# solute exception:  [9, 13] 0.004135575 e**2 0.2560442914951194 nm 0.03284440013043381 kJ/mol
# solute exception:  [9, 15] -0.0389484751129111 e**2 0.2715637472143426 nm 0.12012161290801605 kJ/mol
# solute exception:  [7, 9] 0.018647808333333335 e**2 0.1770215752181344 nm 0.032844400107403984 kJ/mol
# solute exception:  [7, 10] -0.04135145833333334 e**2 0.22343739850856315 nm 0.08670021357153467 kJ/mol
# solute exception:  [7, 14] 0.13533822512434399 e**2 0.2234373984832677 nm 0.07687068168819385 kJ/mol
# solute exception:  [6, 11] -0.020888925 e**2 0.2949765655645629 nm 0.10807766850678557 kJ/mol
# solute exception:  [6, 12] -0.020888925 e**2 0.2949765655645629 nm 0.10807766850678557 kJ/mol
# solute exception:  [6, 13] -0.020888925 e**2 0.2949765655645629 nm 0.10807766850678557 kJ/mol
# solvent exception:  [17, 19] 0.02211453333333334 e**2 0.1770215752181344 nm 0.032844400107403984 kJ/mol
# solvent exception:  [17, 20] 0.02211453333333334 e**2 0.1770215752181344 nm 0.032844400107403984 kJ/mol
# solvent exception:  [17, 21] 0.02211453333333334 e**2 0.1770215752181344 nm 0.032844400107403984 kJ/mol
# solute exception:  [10, 15] 0.08636812525038001 e**2 0.3179795705047714 nm 0.31708813251652274 kJ/mol
# solute exception:  [6, 15] 0.19673002557031768 e**2 0.3104960212837861 nm 0.3952717604467176 kJ/mol
# solvent exception:  [0, 1] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [0, 2] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [0, 3] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [0, 4] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [1, 2] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [1, 3] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [1, 4] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [1, 5] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2, 3] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2, 4] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [3, 4] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [4, 5] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [6, 7] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [6, 8] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [6, 9] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [6, 10] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [6, 14] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [7, 8] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [8, 9] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [8, 10] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [8, 11] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [8, 12] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [8, 13] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [8, 14] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [8, 15] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [9, 10] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [9, 14] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [10, 11] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [10, 12] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [10, 13] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [10, 14] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [11, 12] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [11, 13] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [12, 13] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solute exception:  [14, 15] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [16, 17] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [16, 18] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [16, 19] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [16, 20] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [16, 21] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [17, 18] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [18, 19] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [18, 20] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [18, 21] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [19, 20] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [19, 21] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [20, 21] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [22, 23] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [22, 24] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [23, 24] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [25, 26] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [25, 27] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [26, 27] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [28, 29] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [28, 30] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [29, 30] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [31, 32] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [31, 33] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [32, 33] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [34, 35] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [34, 36] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [35, 36] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [37, 38] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [37, 39] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [38, 39] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [40, 41] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [40, 42] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [41, 42] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [43, 44] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [43, 45] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [44, 45] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [46, 47] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [46, 48] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [47, 48] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [49, 50] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [49, 51] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [50, 51] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [52, 53] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [52, 54] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [53, 54] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [55, 56] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [55, 57] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [56, 57] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [58, 59] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [58, 60] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [59, 60] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [61, 62] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [61, 63] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [62, 63] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [64, 65] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [64, 66] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [65, 66] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [67, 68] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [67, 69] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [68, 69] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [70, 71] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [70, 72] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [71, 72] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [73, 74] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [73, 75] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [74, 75] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [76, 77] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [76, 78] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [77, 78] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [79, 80] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [79, 81] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [80, 81] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [82, 83] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [82, 84] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [83, 84] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [85, 86] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [85, 87] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [86, 87] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [88, 89] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [88, 90] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [89, 90] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [91, 92] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [91, 93] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [92, 93] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [94, 95] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [94, 96] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [95, 96] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [97, 98] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [97, 99] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [98, 99] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [100, 101] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [100, 102] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [101, 102] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [103, 104] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [103, 105] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [104, 105] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [106, 107] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [106, 108] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [107, 108] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [109, 110] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [109, 111] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [110, 111] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [112, 113] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [112, 114] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [113, 114] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [115, 116] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [115, 117] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [116, 117] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [118, 119] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [118, 120] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [119, 120] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [121, 122] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [121, 123] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [122, 123] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [124, 125] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [124, 126] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [125, 126] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [127, 128] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [127, 129] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [128, 129] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [130, 131] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [130, 132] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [131, 132] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [133, 134] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [133, 135] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [134, 135] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [136, 137] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [136, 138] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [137, 138] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [139, 140] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [139, 141] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [140, 141] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [142, 143] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [142, 144] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [143, 144] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [145, 146] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [145, 147] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [146, 147] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [148, 149] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [148, 150] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [149, 150] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [151, 152] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [151, 153] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [152, 153] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [154, 155] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [154, 156] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [155, 156] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [157, 158] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [157, 159] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [158, 159] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [160, 161] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [160, 162] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [161, 162] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [163, 164] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [163, 165] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [164, 165] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [166, 167] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [166, 168] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [167, 168] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [169, 170] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [169, 171] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [170, 171] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [172, 173] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [172, 174] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [173, 174] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [175, 176] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [175, 177] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [176, 177] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [178, 179] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [178, 180] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [179, 180] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [181, 182] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [181, 183] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [182, 183] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [184, 185] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [184, 186] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [185, 186] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [187, 188] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [187, 189] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [188, 189] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [190, 191] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [190, 192] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [191, 192] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [193, 194] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [193, 195] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [194, 195] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [196, 197] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [196, 198] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [197, 198] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [199, 200] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [199, 201] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [200, 201] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [202, 203] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [202, 204] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [203, 204] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [205, 206] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [205, 207] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [206, 207] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [208, 209] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [208, 210] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [209, 210] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [211, 212] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [211, 213] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [212, 213] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [214, 215] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [214, 216] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [215, 216] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [217, 218] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [217, 219] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [218, 219] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [220, 221] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [220, 222] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [221, 222] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [223, 224] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [223, 225] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [224, 225] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [226, 227] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [226, 228] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [227, 228] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [229, 230] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [229, 231] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [230, 231] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [232, 233] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [232, 234] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [233, 234] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [235, 236] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [235, 237] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [236, 237] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [238, 239] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [238, 240] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [239, 240] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [241, 242] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [241, 243] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [242, 243] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [244, 245] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [244, 246] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [245, 246] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [247, 248] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [247, 249] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [248, 249] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [250, 251] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [250, 252] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [251, 252] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [253, 254] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [253, 255] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [254, 255] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [256, 257] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [256, 258] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [257, 258] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [259, 260] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [259, 261] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [260, 261] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [262, 263] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [262, 264] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [263, 264] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [265, 266] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [265, 267] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [266, 267] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [268, 269] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [268, 270] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [269, 270] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [271, 272] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [271, 273] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [272, 273] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [274, 275] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [274, 276] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [275, 276] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [277, 278] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [277, 279] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [278, 279] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [280, 281] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [280, 282] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [281, 282] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [283, 284] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [283, 285] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [284, 285] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [286, 287] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [286, 288] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [287, 288] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [289, 290] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [289, 291] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [290, 291] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [292, 293] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [292, 294] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [293, 294] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [295, 296] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [295, 297] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [296, 297] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [298, 299] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [298, 300] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [299, 300] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [301, 302] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [301, 303] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [302, 303] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [304, 305] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [304, 306] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [305, 306] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [307, 308] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [307, 309] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [308, 309] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [310, 311] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [310, 312] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [311, 312] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [313, 314] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [313, 315] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [314, 315] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [316, 317] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [316, 318] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [317, 318] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [319, 320] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [319, 321] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [320, 321] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [322, 323] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [322, 324] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [323, 324] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [325, 326] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [325, 327] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [326, 327] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [328, 329] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [328, 330] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [329, 330] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [331, 332] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [331, 333] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [332, 333] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [334, 335] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [334, 336] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [335, 336] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [337, 338] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [337, 339] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [338, 339] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [340, 341] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [340, 342] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [341, 342] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [343, 344] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [343, 345] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [344, 345] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [346, 347] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [346, 348] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [347, 348] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [349, 350] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [349, 351] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [350, 351] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [352, 353] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [352, 354] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [353, 354] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [355, 356] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [355, 357] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [356, 357] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [358, 359] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [358, 360] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [359, 360] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [361, 362] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [361, 363] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [362, 363] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [364, 365] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [364, 366] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [365, 366] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [367, 368] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [367, 369] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [368, 369] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [370, 371] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [370, 372] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [371, 372] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [373, 374] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [373, 375] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [374, 375] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [376, 377] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [376, 378] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [377, 378] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [379, 380] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [379, 381] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [380, 381] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [382, 383] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [382, 384] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [383, 384] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [385, 386] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [385, 387] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [386, 387] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [388, 389] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [388, 390] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [389, 390] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [391, 392] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [391, 393] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [392, 393] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [394, 395] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [394, 396] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [395, 396] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [397, 398] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [397, 399] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [398, 399] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [400, 401] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [400, 402] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [401, 402] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [403, 404] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [403, 405] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [404, 405] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [406, 407] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [406, 408] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [407, 408] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [409, 410] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [409, 411] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [410, 411] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [412, 413] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [412, 414] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [413, 414] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [415, 416] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [415, 417] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [416, 417] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [418, 419] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [418, 420] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [419, 420] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [421, 422] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [421, 423] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [422, 423] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [424, 425] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [424, 426] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [425, 426] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [427, 428] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [427, 429] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [428, 429] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [430, 431] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [430, 432] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [431, 432] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [433, 434] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [433, 435] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [434, 435] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [436, 437] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [436, 438] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [437, 438] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [439, 440] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [439, 441] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [440, 441] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [442, 443] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [442, 444] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [443, 444] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [445, 446] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [445, 447] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [446, 447] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [448, 449] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [448, 450] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [449, 450] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [451, 452] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [451, 453] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [452, 453] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [454, 455] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [454, 456] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [455, 456] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [457, 458] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [457, 459] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [458, 459] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [460, 461] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [460, 462] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [461, 462] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [463, 464] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [463, 465] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [464, 465] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [466, 467] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [466, 468] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [467, 468] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [469, 470] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [469, 471] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [470, 471] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [472, 473] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [472, 474] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [473, 474] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [475, 476] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [475, 477] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [476, 477] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [478, 479] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [478, 480] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [479, 480] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [481, 482] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [481, 483] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [482, 483] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [484, 485] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [484, 486] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [485, 486] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [487, 488] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [487, 489] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [488, 489] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [490, 491] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [490, 492] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [491, 492] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [493, 494] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [493, 495] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [494, 495] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [496, 497] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [496, 498] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [497, 498] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [499, 500] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [499, 501] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [500, 501] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [502, 503] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [502, 504] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [503, 504] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [505, 506] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [505, 507] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [506, 507] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [508, 509] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [508, 510] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [509, 510] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [511, 512] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [511, 513] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [512, 513] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [514, 515] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [514, 516] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [515, 516] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [517, 518] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [517, 519] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [518, 519] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [520, 521] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [520, 522] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [521, 522] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [523, 524] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [523, 525] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [524, 525] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [526, 527] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [526, 528] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [527, 528] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [529, 530] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [529, 531] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [530, 531] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [532, 533] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [532, 534] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [533, 534] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [535, 536] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [535, 537] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [536, 537] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [538, 539] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [538, 540] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [539, 540] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [541, 542] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [541, 543] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [542, 543] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [544, 545] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [544, 546] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [545, 546] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [547, 548] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [547, 549] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [548, 549] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [550, 551] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [550, 552] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [551, 552] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [553, 554] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [553, 555] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [554, 555] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [556, 557] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [556, 558] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [557, 558] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [559, 560] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [559, 561] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [560, 561] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [562, 563] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [562, 564] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [563, 564] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [565, 566] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [565, 567] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [566, 567] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [568, 569] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [568, 570] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [569, 570] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [571, 572] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [571, 573] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [572, 573] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [574, 575] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [574, 576] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [575, 576] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [577, 578] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [577, 579] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [578, 579] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [580, 581] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [580, 582] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [581, 582] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [583, 584] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [583, 585] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [584, 585] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [586, 587] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [586, 588] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [587, 588] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [589, 590] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [589, 591] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [590, 591] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [592, 593] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [592, 594] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [593, 594] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [595, 596] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [595, 597] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [596, 597] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [598, 599] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [598, 600] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [599, 600] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [601, 602] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [601, 603] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [602, 603] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [604, 605] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [604, 606] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [605, 606] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [607, 608] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [607, 609] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [608, 609] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [610, 611] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [610, 612] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [611, 612] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [613, 614] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [613, 615] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [614, 615] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [616, 617] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [616, 618] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [617, 618] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [619, 620] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [619, 621] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [620, 621] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [622, 623] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [622, 624] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [623, 624] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [625, 626] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [625, 627] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [626, 627] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [628, 629] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [628, 630] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [629, 630] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [631, 632] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [631, 633] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [632, 633] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [634, 635] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [634, 636] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [635, 636] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [637, 638] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [637, 639] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [638, 639] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [640, 641] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [640, 642] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [641, 642] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [643, 644] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [643, 645] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [644, 645] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [646, 647] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [646, 648] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [647, 648] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [649, 650] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [649, 651] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [650, 651] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [652, 653] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [652, 654] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [653, 654] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [655, 656] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [655, 657] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [656, 657] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [658, 659] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [658, 660] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [659, 660] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [661, 662] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [661, 663] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [662, 663] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [664, 665] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [664, 666] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [665, 666] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [667, 668] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [667, 669] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [668, 669] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [670, 671] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [670, 672] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [671, 672] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [673, 674] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [673, 675] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [674, 675] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [676, 677] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [676, 678] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [677, 678] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [679, 680] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [679, 681] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [680, 681] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [682, 683] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [682, 684] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [683, 684] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [685, 686] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [685, 687] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [686, 687] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [688, 689] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [688, 690] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [689, 690] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [691, 692] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [691, 693] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [692, 693] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [694, 695] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [694, 696] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [695, 696] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [697, 698] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [697, 699] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [698, 699] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [700, 701] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [700, 702] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [701, 702] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [703, 704] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [703, 705] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [704, 705] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [706, 707] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [706, 708] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [707, 708] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [709, 710] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [709, 711] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [710, 711] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [712, 713] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [712, 714] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [713, 714] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [715, 716] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [715, 717] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [716, 717] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [718, 719] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [718, 720] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [719, 720] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [721, 722] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [721, 723] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [722, 723] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [724, 725] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [724, 726] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [725, 726] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [727, 728] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [727, 729] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [728, 729] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [730, 731] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [730, 732] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [731, 732] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [733, 734] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [733, 735] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [734, 735] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [736, 737] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [736, 738] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [737, 738] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [739, 740] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [739, 741] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [740, 741] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [742, 743] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [742, 744] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [743, 744] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [745, 746] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [745, 747] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [746, 747] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [748, 749] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [748, 750] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [749, 750] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [751, 752] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [751, 753] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [752, 753] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [754, 755] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [754, 756] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [755, 756] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [757, 758] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [757, 759] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [758, 759] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [760, 761] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [760, 762] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [761, 762] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [763, 764] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [763, 765] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [764, 765] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [766, 767] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [766, 768] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [767, 768] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [769, 770] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [769, 771] 0.0 e**2 0.1 nm 0.0 kJ/mol
# ...
# solvent exception:  [2008, 2009] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2008, 2010] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2009, 2010] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2011, 2012] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2011, 2013] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2012, 2013] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2014, 2015] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2014, 2016] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2015, 2016] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2017, 2018] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2017, 2019] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2018, 2019] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2020, 2021] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2020, 2022] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2021, 2022] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2023, 2024] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2023, 2025] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2024, 2025] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2026, 2027] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2026, 2028] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2027, 2028] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2029, 2030] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2029, 2031] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2030, 2031] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2032, 2033] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2032, 2034] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2033, 2034] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2035, 2036] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2035, 2037] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2036, 2037] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2038, 2039] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2038, 2040] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2039, 2040] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2041, 2042] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2041, 2043] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2042, 2043] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2044, 2045] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2044, 2046] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2045, 2046] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2047, 2048] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2047, 2049] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2048, 2049] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2050, 2051] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2050, 2052] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2051, 2052] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2053, 2054] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2053, 2055] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2054, 2055] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2056, 2057] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2056, 2058] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2057, 2058] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2059, 2060] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2059, 2061] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2060, 2061] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2062, 2063] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2062, 2064] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2063, 2064] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2065, 2066] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2065, 2067] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2066, 2067] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2068, 2069] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2068, 2070] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2069, 2070] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2071, 2072] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2071, 2073] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2072, 2073] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2074, 2075] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2074, 2076] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2075, 2076] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2077, 2078] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2077, 2079] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2078, 2079] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2080, 2081] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2080, 2082] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2081, 2082] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2083, 2084] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2083, 2085] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2084, 2085] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2086, 2087] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2086, 2088] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2087, 2088] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2089, 2090] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2089, 2091] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2090, 2091] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2092, 2093] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2092, 2094] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2093, 2094] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2095, 2096] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2095, 2097] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2096, 2097] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2098, 2099] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2098, 2100] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2099, 2100] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2101, 2102] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2101, 2103] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2102, 2103] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2104, 2105] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2104, 2106] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2105, 2106] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2107, 2108] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2107, 2109] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2108, 2109] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2110, 2111] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2110, 2112] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2111, 2112] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2113, 2114] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2113, 2115] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2114, 2115] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2116, 2117] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2116, 2118] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2117, 2118] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2119, 2120] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2119, 2121] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2120, 2121] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2122, 2123] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2122, 2124] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2123, 2124] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2125, 2126] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2125, 2127] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2126, 2127] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2128, 2129] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2128, 2130] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2129, 2130] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2131, 2132] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2131, 2133] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2132, 2133] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2134, 2135] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2134, 2136] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2135, 2136] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2137, 2138] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2137, 2139] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2138, 2139] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2140, 2141] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2140, 2142] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2141, 2142] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2143, 2144] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2143, 2145] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2144, 2145] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2146, 2147] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2146, 2148] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2147, 2148] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2149, 2150] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2149, 2151] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2150, 2151] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2152, 2153] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2152, 2154] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2153, 2154] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2155, 2156] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2155, 2157] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2156, 2157] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2158, 2159] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2158, 2160] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2159, 2160] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2161, 2162] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2161, 2163] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2162, 2163] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2164, 2165] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2164, 2166] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2165, 2166] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2167, 2168] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2167, 2169] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2168, 2169] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2170, 2171] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2170, 2172] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2171, 2172] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2173, 2174] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2173, 2175] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2174, 2175] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2176, 2177] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2176, 2178] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2177, 2178] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2179, 2180] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2179, 2181] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2180, 2181] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2182, 2183] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2182, 2184] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2183, 2184] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2185, 2186] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2185, 2187] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2186, 2187] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2188, 2189] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2188, 2190] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2189, 2190] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2191, 2192] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2191, 2193] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2192, 2193] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2194, 2195] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2194, 2196] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2195, 2196] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2197, 2198] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2197, 2199] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2198, 2199] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2200, 2201] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2200, 2202] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2201, 2202] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2203, 2204] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2203, 2205] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2204, 2205] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2206, 2207] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2206, 2208] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2207, 2208] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2209, 2210] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2209, 2211] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2210, 2211] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2212, 2213] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2212, 2214] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2213, 2214] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2215, 2216] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2215, 2217] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2216, 2217] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2218, 2219] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2218, 2220] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2219, 2220] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2221, 2222] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2221, 2223] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2222, 2223] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2224, 2225] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2224, 2226] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2225, 2226] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2227, 2228] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2227, 2229] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2228, 2229] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2230, 2231] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2230, 2232] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2231, 2232] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2233, 2234] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2233, 2235] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2234, 2235] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2236, 2237] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2236, 2238] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2237, 2238] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2239, 2240] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2239, 2241] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2240, 2241] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2242, 2243] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2242, 2244] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2243, 2244] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2245, 2246] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2245, 2247] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2246, 2247] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2248, 2249] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2248, 2250] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2249, 2250] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2251, 2252] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2251, 2253] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2252, 2253] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2254, 2255] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2254, 2256] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2255, 2256] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2257, 2258] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2257, 2259] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2258, 2259] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2260, 2261] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2260, 2262] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2261, 2262] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2263, 2264] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2263, 2265] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2264, 2265] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2266, 2267] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2266, 2268] 0.0 e**2 0.1 nm 0.0 kJ/mol
# solvent exception:  [2267, 2268] 0.0 e**2 0.1 nm 0.0 kJ/mol
# adding exceptions for solute pairs
# adding exceptions for solvent pairs
# <ipython-input-10-644630d2e936>:103: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for pair in tqdm_notebook(list(solvent_pairs)):
#   0%|          | 0/2552670 [00:00<?, ?it/s]

# %%
# Get total energy
system_C = copy.deepcopy(system)
         
# Get energy
thermostate = ThermodynamicState(system_C, temperature=T_min)
integrator = openmm.VerletIntegrator(1.0 * unit.femtosecond)
context = thermostate.create_context(integrator)
context.setPositions(positions)
sampler_state = SamplerState.from_context(context)
system_C_energy = thermostate.reduced_potential(sampler_state)

# %%
len(solvent_pairs)
# Out:
# 2552670

# %%
system_D_energy_scaled = (system_C_energy - system_A_energy - system_B_energy)*inter_scaling

# %%
REST_energy
# Out:
# -9883.658890418434

# %%
components_rest
# Out:
# [0.03429166476612171,
#  0.3557026496311803,
#  2.282951099724897,
#  -9886.341110588197,
#  0.0]

# %%
0.03429166476612171 + 0.3557026496311803 + 2.282951099724897
# Out:
# 2.672945414122199

# %%
np.sum(components_rest)
# Out:
# -9883.668165174075

# %%
system_A_energy_scaled + system_B_energy_scaled + system_D_energy_scaled
# Out:
# -9883.668095370325

# %%
np.isclose(np.sum(components_rest), system_A_energy_scaled + system_B_energy_scaled + system_D_energy_scaled
)
# Out:
# True

# %% [markdown]
# # Write new test scaling function and run on vanilla rest

# %%
import copy
from tqdm import tqdm_notebook

# %%
def compare_energies(REST_system, other_system, positions, rest_atoms, T_min, T):

    # Zero nb forces
    nb_force = REST_system.getForce(3)
    for i in range(nb_force.getNumParticles()):
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        nb_force.setParticleParameters(i, charge*0, sigma, epsilon*0)
    
    # Zero exceptions force
    for i in range(nb_force.getNumExceptions()):
        p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(i)
        nb_force.setExceptionParameters(i, p1, p2, chargeProd*0, sigma, epsilon*0)
    
    for i in range(nb_force.getNumParticleParameterOffsets()):
        param, particle_idx, chargeScale, sigmaScale, epsilonScale = nb_force.getParticleParameterOffset(i)
        nb_force.setParticleParameterOffset(i, 'electrostatic_scale', particle_idx, 0.0, 0.0, 0.0)
        nb_force.setParticleParameterOffset(i, 'steric_scale', particle_idx, 0.0, 0.0, 0.0)

    for i in range(nb_force.getNumExceptionParameterOffsets()):
        param, exception_idx, chargeScale, sigmaScale, epsilonScale = nb_force.getExceptionParameterOffset(i)
        nb_force.setExceptionParameterOffset(i, 'electrostatic_scale', exception_idx, 0.0, 0.0, 0.0)
        nb_force.setExceptionParameterOffset(i, 'steric_scale', exception_idx, 0.0, 0.0, 0.0)

    nb_force = other_system.getForce(3)
    for i in range(nb_force.getNumExceptions()):
        p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(i)
        nb_force.setExceptionParameters(i, p1, p2, chargeProd*0, sigma, epsilon*0)

    for i in range(nb_force.getNumParticles()):
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        nb_force.setParticleParameters(i, charge*0, sigma, epsilon*0)
    
    # Create thermodynamic state
    lambda_zero_alchemical_state = RESTState.from_system(REST_system)
    thermostate = ThermodynamicState(REST_system, temperature=T_min)
    compound_thermodynamic_state = CompoundThermodynamicState(thermostate,
                                                              composable_states=[lambda_zero_alchemical_state])

    # Set alchemical parameters
    beta_0 = 1 / (kB * T_min)
    beta_m = 1 / (kB * T)
    compound_thermodynamic_state.set_alchemical_parameters(beta_0, beta_m)

    # Get energy
    integrator = openmm.VerletIntegrator(1.0 * unit.femtosecond)
    context = compound_thermodynamic_state.create_context(integrator)
    context.setPositions(positions)
#     sampler_state = SamplerState.from_context(context)
#     REST_energy = compound_thermodynamic_state.reduced_potential(sampler_state)
    REST_energy = context.getState(getEnergy=True).getPotentialEnergy().value_in_unit_system(unit.md_unit_system)

    # Compute energy for non-RESTified system
    # Determine regions and scaling factors
    nonrest_atoms = [i for i in range(other_system.getNumParticles()) if i not in rest_atoms]
    rest_scaling = beta_m / beta_0
    inter_scaling = np.sqrt(beta_m / beta_0)
    
    # Compute 3 energies: 
    ## Test case 1: rest-rest energy
    ## Test case 2: nonrest-nonrest energy
    ## Test case 3: total energy
    unmodified_energies = []
    for test_case in range(3):
        system_copy = copy.deepcopy(other_system)
        
        if test_case != 2:
            bond_force = system_copy.getForce(0)
            for bond_index in range(bond_force.getNumBonds()):
                p1, p2, length, k = bond_force.getBondParameters(bond_index)
                particles = [p1, p2]
                if all(x in rest_atoms for x in particles):
                    if test_case == 1:
                        bond_force.setBondParameters(bond_index, p1, p2, length, k*0)
                    else:
                        continue
                elif all(x in nonrest_atoms for x in particles):
                    if test_case == 0:
                        bond_force.setBondParameters(bond_index, p1, p2, length, k*0)
                    else:
                        continue
                else:
                    bond_force.setBondParameters(bond_index, p1, p2, length, k*0)

            angle_force = system_copy.getForce(1)
            for angle_index in range(angle_force.getNumAngles()):
                p1, p2, p3, angle, k = angle_force.getAngleParameters(angle_index)
                particles = [p1, p2, p3]
                if all(x in rest_atoms for x in particles):
                    if test_case == 1:
                        angle_force.setAngleParameters(angle_index, p1, p2, p3, angle, k*0) 
                    else:
                        continue
                elif all(x in nonrest_atoms for x in particles):
                    if test_case == 0:
                        angle_force.setAngleParameters(angle_index, p1, p2, p3, angle, k*0) 
                    else:
                        continue
                else:
                    angle_force.setAngleParameters(angle_index, p1, p2, p3, angle, k*0) 

            torsion_force = system_copy.getForce(2)
            for torsion_index in range(torsion_force.getNumTorsions()):
                p1, p2, p3, p4, periodicity, phase, k = torsion_force.getTorsionParameters(torsion_index)
                particles = [p1, p2, p3, p4]
                if all(x in rest_atoms for x in particles):
                    if test_case == 1:
                        torsion_force.setTorsionParameters(torsion_index, p1, p2, p3, p4, periodicity, phase, k*0)
                    else:
                        continue
                elif all(x in nonrest_atoms for x in particles):
                    if test_case == 0:
                        torsion_force.setTorsionParameters(torsion_index, p1, p2, p3, p4, periodicity, phase, k*0)
                    else:
                        continue
                else:
                    torsion_force.setTorsionParameters(torsion_index, p1, p2, p3, p4, periodicity, phase, k*0)

            nb_force = system_copy.getForce(3)
            for i in range(nb_force.getNumExceptions()):
                p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(i)
                particles = [p1, p2]
                if all(x in rest_atoms for x in particles):
                    if test_case == 1:
                        nb_force.setExceptionParameters(i, p1, p2, chargeProd*0, sigma, epsilon*0)
                    else:
                        continue
                elif all(x in nonrest_atoms for x in particles):
                    if test_case == 0:
                        nb_force.setExceptionParameters(i, p1, p2, chargeProd*0, sigma, epsilon*0)
                    else:
                        continue
                else:
                    nb_force.setExceptionParameters(i, p1, p2, chargeProd*0, sigma, epsilon*0)

            nb_force = system_copy.getForce(3)
            for i in range(nb_force.getNumParticles()):
                charge, sigma, epsilon = nb_force.getParticleParameters(i)
                if i in rest_atoms:
                    if test_case == 1:
                        nb_force.setParticleParameters(i, charge*0, sigma, epsilon*0)
                    else:
                        continue
                else:
                    if test_case == 0:
                        nb_force.setParticleParameters(i, charge*0, sigma, epsilon*0)
                    else:
                        continue     
            
        # Get energy
        thermostate = ThermodynamicState(system_copy, temperature=T_min)
        integrator = openmm.VerletIntegrator(1.0 * unit.femtosecond)
        context = thermostate.create_context(integrator)
        context.setPositions(positions)
#         sampler_state = SamplerState.from_context(context)
#         system_copy_energy = thermostate.reduced_potential(sampler_state)
        system_copy_energy = context.getState(getEnergy=True).getPotentialEnergy().value_in_unit_system(unit.md_unit_system)
        unmodified_energies.append(system_copy_energy)
    
    print(unmodified_energies)
    unmodified_energy = unmodified_energies[0] * rest_scaling + unmodified_energies[1] + (unmodified_energies[2] - unmodified_energies[0] - unmodified_energies[1]) * inter_scaling
    print(REST_energy)
    print(unmodified_energy)
    assert np.isclose(REST_energy, unmodified_energy), f"REST energy was {REST_energy} and unmodified_energy was {unmodified_energy}"

# %%
test_energy_scaling()
# Out:
# INFO:REST:No MonteCarloBarostat added.
# INFO:REST:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# INFO:REST:No unknown forces.
# alanine dipeptide in vacuum
# INFO:REST:No MonteCarloBarostat added.
# INFO:REST:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=3.2852863, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=3.2861648000000003, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=3.1855098), unit=nanometer)]
# [1.2664324958308815, 0.34497100125756114, 9.656921484626121]
# 6.667235068767628
# 6.66722757631924
# alanine dipeptide in solvent
# INFO:REST:No unknown forces.
# DEBUG:openmmforcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11
# [1.2664292771783718, 0.3449719651280984, 9.656918764249463]
# 6.667232296012481
# 6.6672266016383634
# alanine dipepetide with repartitioned hybrid system
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# WARNING:atom_mapping:Molecules do not appear to share a common scaffold.
# WARNING:atom_mapping:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:[Atom(name=CB, atomic number=6), Atom(name=HB1, atomic number=1), Atom(name=HB2, atomic number=1), Atom(name=HB3, atomic number=1)]
# INFO:proposal_generator:[Atom(name=CB, atomic number=6), Atom(name=CG2, atomic number=6), Atom(name=OG1, atomic number=8), Atom(name=HB, atomic number=1), Atom(name=HG1, atomic number=1), Atom(name=HG21, atomic number=1), Atom(name=HG22, atomic number=1), Atom(name=HG23, atomic number=1)]
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 8
# INFO:geometry:Atom index proposal order is [10, 18, 14, 13, 16, 19, 17, 15]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# making topology proposal
# generating geometry engine
# making geometry proposal from ALA to THR
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 11 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 43 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 72 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 1654 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (THR)> with neighbors [<Atom 9 (HA) of chain 0 residue 1 (THR)>, <Atom 10 (CB) of chain 0 residue 1 (THR)>, <Atom 11 (C) of chain 0 residue 1 (THR)>, <Atom 6 (N) of chain 0 residue 1 (THR)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {0: (7, 6, 8, 10, [1, Quantity(value=0.9900002084555819, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 1]), 1: (19, 18, 10, 8, [1, Quantity(value=-0.07858019216845058, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 6]), 2: (19, 18, 10, 14, [1, Quantity(value=2.118586571250296, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 6]), 3: (19, 18, 10, 13, [1, Quantity(value=-2.149781203448759, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 6]), 4: (8, 10, 14, 17, [1, Quantity(value=-2.1249532223845904, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 7]), 5: (8, 10, 14, 16, [1, Quantity(value=2.0543043017157916, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 5]), 6: (8, 10, 14, 15, [1, Quantity(value=-0.02223392579985184, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 8]), 7: (18, 10, 14, 17, [1, Quantity(value=2.0255587336734213, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 7]), 8: (18, 10, 14, 16, [1, Quantity(value=-0.07836904940578293, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 5]), 9: (18, 10, 14, 15, [1, Quantity(value=-2.154907276921426, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 8]), 10: (13, 10, 14, 17, [1, Quantity(value=0.007583009583349565, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 7]), 11: (13, 10, 14, 16, [1, Quantity(value=-2.096344773495849, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 5]), 12: (13, 10, 14, 15, [1, Quantity(value=2.1103023061680943, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 8]), 13: (18, 10, 8, 14, [1, Quantity(value=-1.0655064807976995, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 3])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -13.553917196274867
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context new positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 8 new atoms
# INFO:geometry:	reduced angle potential = 1.8764759956267916.
# INFO:geometry:	reduced angle potential = 0.7480530411444264.
# INFO:geometry:	reduced angle potential = 0.00025952110242746036.
# INFO:geometry:	reduced angle potential = 0.028641196311232166.
# INFO:geometry:	reduced angle potential = 0.0024587666803323263.
# INFO:geometry:	reduced angle potential = 0.08513584378342594.
# INFO:geometry:	reduced angle potential = 1.2242897963470216.
# INFO:geometry:	reduced angle potential = 0.2900992163235368.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce', 'MonteCarloBarostat']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 11 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 43 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 72 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.116481141712038
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: -39.98682378132465
# INFO:geometry:final reduced energy -30.870345104074598
# INFO:geometry:sum of energies: -30.870342639612616
# INFO:geometry:magnitude of difference in the energies: 2.4644619855962446e-06
# INFO:geometry:Final logp_proposal: 59.84296653065326
# added energy components: [('CustomBondForce', 0.3440959708274345), ('CustomAngleForce', 10.994248505225615), ('CustomTorsionForce', 16.956110095782638), ('CustomBondForce', -68.28127835316033)]
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 4
# INFO:geometry:Atom index proposal order is [10, 11, 13, 12]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 1631 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (ALA)> with neighbors [<Atom 9 (HA) of chain 0 residue 1 (ALA)>, <Atom 10 (CB) of chain 0 residue 1 (ALA)>, <Atom 14 (C) of chain 0 residue 1 (ALA)>, <Atom 6 (N) of chain 0 residue 1 (ALA)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {0: (7, 6, 8, 10, [1, Quantity(value=0.9799661941737812, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 1]), 1: (6, 8, 10, 11, [1, Quantity(value=2.105358864604291, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 2]), 2: (6, 8, 10, 12, [1, Quantity(value=-2.0823006129211796, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 4]), 3: (6, 8, 10, 13, [1, Quantity(value=0.018582237407944735, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 3]), 4: (14, 8, 10, 11, [1, Quantity(value=-0.036945135932107576, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 2]), 5: (14, 8, 10, 12, [1, Quantity(value=2.0585806937220097, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 4]), 6: (14, 8, 10, 13, [1, Quantity(value=-2.1237217631284597, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 3]), 7: (9, 8, 10, 11, [1, Quantity(value=-2.119603470065817, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 2]), 8: (9, 8, 10, 12, [1, Quantity(value=-0.024077640411697132, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 4]), 9: (9, 8, 10, 13, [1, Quantity(value=2.0768052099174152, unit=radian), Quantity(value=1200.0, unit=kilocalorie/mole), 3])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -5.78074351579233
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context old positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 4 new atoms
# INFO:geometry:	reduced angle potential = 0.08012165173241892.
# INFO:geometry:	reduced angle potential = 1.2915588460963948e-10.
# INFO:geometry:	reduced angle potential = 7.39096069988752e-11.
# INFO:geometry:	reduced angle potential = 3.205832446488702e-13.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce', 'MonteCarloBarostat']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 9.116481141712038
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: 20.67298667212561
# INFO:geometry:final reduced energy 29.78946596595155
# INFO:geometry:sum of energies: 29.789467813837646
# INFO:geometry:magnitude of difference in the energies: 1.8478860965842614e-06
# INFO:geometry:Final logp_proposal: -27102.43303179193
# INFO:relative:*** Generating RepartitionedHybridTopologyFactory ***
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce', 'MonteCarloBarostat'])
# added energy components: [('CustomBondForce', 0.0005202039273265048), ('CustomAngleForce', 0.45111977562481365), ('CustomTorsionForce', 7.25046332853325), ('CustomBondForce', 12.970883364040219)]
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce', 'MonteCarloBarostat'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 4
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:Added MonteCarloBarostat.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.56477354, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.56477354, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.56477354), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:	_add_nonbonded_force_terms: <openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2aabb197eed0> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is PME or Ewald
# INFO:relative:	_add_nonbonded_force_terms: 4 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 2 added to sterics_custom_nonbonded force
# INFO:REST:No MonteCarloBarostat added.
# INFO:REST:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.56477354, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.56477354, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.56477354), unit=nanometer)]
# INFO:REST:No unknown forces.
# [53.57283004118337, 10.335210739359, 112.52719556658857]
# 71.50057081468864
# 71.50055980472234
