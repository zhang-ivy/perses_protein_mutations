# %% [markdown]
# Generate vanilla and r-htfs in one go

# %%
import pickle
import os
from perses.app.relative_point_mutation_setup import PointMutationExecutor
from simtk import unit
from simtk.openmm import app
# Out:
# INFO:numexpr.utils:Note: detected 80 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# INFO:numexpr.utils:Note: NumExpr detected 80 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:rdkit:Enabling RDKit 2020.09.4 jupyter extensions

# %% [markdown]
# # barstar D35A apo with counterion fix (16/12)

# %%
solvent_delivery = PointMutationExecutor("../../input/mmc2_barstar.pdb",
                        '1',
                        '35',
                        'ALA',
#                         ligand_input='../../input/mmc2_barnase.pdb',
                        ionic_strength=0.05*unit.molar,
                        flatten_torsions=True,
                        flatten_exceptions=True, 
                        vanilla=True,
                        repartitioned=True,
                        conduct_endstate_validation=False
                       )
# Out:
# DEBUG:openmmforcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11
# INFO:setup:solvating at 0.05 M using tip3p
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{7: 10}, {8: 10}, {9: 10}, {7: 11}, {8: 11}, {9: 11}]
# INFO:proposal_generator:{7: 10}
# INFO:proposal_generator:{8: 10}
# INFO:proposal_generator:{9: 10}
# INFO:proposal_generator:{7: 11}
# INFO:proposal_generator:{8: 11}
# INFO:proposal_generator:{9: 11}
# INFO:proposal_generator:Returning map that best satisfies matching_criterion
# INFO:proposal_generator:Finding best map using matching_criterion name
# ...

# %%
import pickle
import os
out_dir = '/data/chodera/zhangi/perses_benchmark/neq/16/12/'
pickle.dump(solvent_delivery.get_apo_htf(), open(os.path.join(out_dir, "12_apo.pickle"), "wb" ))
pickle.dump(solvent_delivery.get_complex_htf(), open(os.path.join(out_dir, "12_complex.pickle"), "wb" ))
pickle.dump(solvent_delivery.get_apo_rhtf_0(), open(os.path.join(out_dir, "12_apo_0.pickle"), "wb" ))
pickle.dump(solvent_delivery.get_complex_rhtf_0(), open(os.path.join(out_dir, "12_complex_0.pickle"), "wb" ))
pickle.dump(solvent_delivery.get_apo_rhtf_1(), open(os.path.join(out_dir, "12_apo_1.pickle"), "wb" ))
pickle.dump(solvent_delivery.get_complex_rhtf_1(), open(os.path.join(out_dir, "12_complex_1.pickle"), "wb" ))

# Render atom map
from perses.utils.smallmolecules import  render_protein_residue_atom_mapping
atom_map_filename = os.path.join(out_dir, 'atom_map.png')
render_protein_residue_atom_mapping(solvent_delivery.get_apo_htf()._topology_proposal, atom_map_filename)

# %%
out_dir = '/data/chodera/zhangi/perses_benchmark/neq/16/12/'
with open(os.path.join(out_dir, "12_apo.pickle"), "rb") as f:
    htf = pickle.load(f)

# %%
htf._atom_classes['core_atoms']
# Out:
# {544,
#  545,
#  546,
#  547,
#  548,
#  549,
#  550,
#  551,
#  552,
#  553,
#  554,
#  555,
#  556,
#  557,
#  558,
#  559,
#  560,
#  561,
#  562,
#  563,
#  564,
#  565,
#  566,
#  571,
#  572,
#  575,
#  576,
#  577,
#  578,
#  579,
#  580,
#  581,
#  582,
#  583,
#  584,
#  14863}

# %%
htf._topology_proposal._new_to_old_atom_map[14861]
# Out:
# 14863

# %%
nb_force = htf.hybrid_system.getForce(7)
for i in range(nb_force.getNumParticles()):
    if i == 14863:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 14863 [Quantity(value=1.0, unit=elementary charge), Quantity(value=0.2439280690268249, unit=nanometer), Quantity(value=0.0, unit=kilojoule/mole)]

# %%
nb_force = htf._topology_proposal.new_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i == 14861:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 14861 [Quantity(value=0.0, unit=elementary charge), Quantity(value=0.2439280690268249, unit=nanometer), Quantity(value=0.00036584603119999996, unit=kilojoule/mole)]

# %%
nb_force = htf._topology_proposal.old_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i == 14863:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 14863 [Quantity(value=1.0, unit=elementary charge), Quantity(value=0.2439280690268249, unit=nanometer), Quantity(value=0.3658460312, unit=kilojoule/mole)]

# %%
out_dir = '/data/chodera/zhangi/perses_benchmark/neq/16/12/'
with open(os.path.join(out_dir, "12_complex.pickle"), "rb") as f:
    htf = pickle.load(f)

# %%
htf._atom_classes['core_atoms']
# Out:
# {544,
#  545,
#  546,
#  547,
#  548,
#  549,
#  550,
#  551,
#  552,
#  553,
#  554,
#  555,
#  556,
#  557,
#  558,
#  559,
#  560,
#  561,
#  562,
#  563,
#  564,
#  565,
#  566,
#  571,
#  572,
#  575,
#  576,
#  577,
#  578,
#  579,
#  580,
#  581,
#  582,
#  583,
#  584,
#  29465}

# %%
htf._topology_proposal._new_to_old_atom_map[29463]
# Out:
# 29465

# %%
nb_force = htf.hybrid_system.getForce(7)
for i in range(nb_force.getNumParticles()):
    if i == 29465:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 29465 [Quantity(value=1.0, unit=elementary charge), Quantity(value=0.2439280690268249, unit=nanometer), Quantity(value=0.0, unit=kilojoule/mole)]

# %%
nb_force = htf._topology_proposal.new_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i == 29463:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 29463 [Quantity(value=0.0, unit=elementary charge), Quantity(value=0.2439280690268249, unit=nanometer), Quantity(value=0.00036584603119999996, unit=kilojoule/mole)]

# %%
nb_force = htf._topology_proposal.old_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i == 29465:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 29465 [Quantity(value=1.0, unit=elementary charge), Quantity(value=0.2439280690268249, unit=nanometer), Quantity(value=0.3658460312, unit=kilojoule/mole)]

# %%
out_dir = '/data/chodera/zhangi/perses_benchmark/neq/16/12/'
with open(os.path.join(out_dir, "12_complex_0.pickle"), "rb") as f:
    htf = pickle.load(f)

# %%
htf._atom_classes['core_atoms']
# Out:
# {544,
#  545,
#  546,
#  547,
#  548,
#  549,
#  550,
#  551,
#  552,
#  553,
#  554,
#  555,
#  556,
#  557,
#  558,
#  559,
#  560,
#  561,
#  562,
#  563,
#  564,
#  565,
#  566,
#  571,
#  572,
#  575,
#  576,
#  577,
#  578,
#  579,
#  580,
#  581,
#  582,
#  583,
#  584,
#  29465}

# %%
htf._topology_proposal._new_to_old_atom_map[29463]
# Out:
# 29465

# %%
nb_force = htf.hybrid_system.getForce(4)
for i in range(nb_force.getNumParticles()):
    if i == 29465:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 29465 [Quantity(value=1.0, unit=elementary charge), Quantity(value=0.2439280690268249, unit=nanometer), Quantity(value=0.3658460312, unit=kilojoule/mole)]

# %%
nb_force = htf._topology_proposal.new_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i == 29463:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 29463 [Quantity(value=0.0, unit=elementary charge), Quantity(value=0.2439280690268249, unit=nanometer), Quantity(value=0.00036584603119999996, unit=kilojoule/mole)]

# %%
nb_force = htf._topology_proposal.old_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i == 29465:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 29465 [Quantity(value=1.0, unit=elementary charge), Quantity(value=0.2439280690268249, unit=nanometer), Quantity(value=0.3658460312, unit=kilojoule/mole)]

# %%
out_dir = '/data/chodera/zhangi/perses_benchmark/neq/16/12/'
with open(os.path.join(out_dir, "12_complex_1.pickle"), "rb") as f:
    htf = pickle.load(f)

# %%
htf._atom_classes['core_atoms']
# Out:
# {544,
#  545,
#  546,
#  547,
#  548,
#  549,
#  550,
#  551,
#  552,
#  553,
#  554,
#  555,
#  556,
#  557,
#  558,
#  559,
#  560,
#  561,
#  562,
#  563,
#  564,
#  565,
#  566,
#  571,
#  572,
#  575,
#  576,
#  577,
#  578,
#  579,
#  580,
#  581,
#  582,
#  583,
#  584,
#  29465}

# %%
htf._topology_proposal._new_to_old_atom_map[29463]
# Out:
# 29465

# %%
nb_force = htf.hybrid_system.getForce(4)
for i in range(nb_force.getNumParticles()):
    if i == 29465:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 29465 [Quantity(value=0.0, unit=elementary charge), Quantity(value=0.2439280690268249, unit=nanometer), Quantity(value=0.00036584603119999996, unit=kilojoule/mole)]

# %%
nb_force = htf._topology_proposal.new_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i == 29463:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 29463 [Quantity(value=0.0, unit=elementary charge), Quantity(value=0.2439280690268249, unit=nanometer), Quantity(value=0.00036584603119999996, unit=kilojoule/mole)]

# %%
nb_force = htf._topology_proposal.old_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i == 29465:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 29465 [Quantity(value=1.0, unit=elementary charge), Quantity(value=0.2439280690268249, unit=nanometer), Quantity(value=0.3658460312, unit=kilojoule/mole)]

# %% [markdown]
# # barstar A35A apo with counterion fix (16/13)

# %%
solvent_delivery = PointMutationExecutor("../../input/mmc2_barstar_D35A.pdb",
                        '1',
                        '35',
                        'ASP',
                        ligand_input='../../input/mmc2_barnase.pdb',
                        ionic_strength=0.05*unit.molar,
                        flatten_torsions=True,
                        flatten_exceptions=True, 
                        vanilla=True,
                        repartitioned=True,
                        conduct_endstate_validation=False
                       )
# Out:
# DEBUG:openmmforcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11
# INFO:setup:solvating at 0.05 M using tip3p
# INFO:setup:solvating at 0.05 M using tip3p
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{10: 7}, {11: 7}, {10: 8}, {11: 8}, {10: 9}, {11: 9}]
# INFO:proposal_generator:{10: 7}
# INFO:proposal_generator:{11: 7}
# INFO:proposal_generator:{10: 8}
# INFO:proposal_generator:{11: 8}
# INFO:proposal_generator:{10: 9}
# INFO:proposal_generator:{11: 9}
# INFO:proposal_generator:Returning map that best satisfies matching_criterion
# ...

# %%
import pickle
import os
out_dir = '/data/chodera/zhangi/perses_benchmark/neq/16/13/'
pickle.dump(solvent_delivery.get_apo_htf(), open(os.path.join(out_dir, "13_apo.pickle"), "wb" ))
pickle.dump(solvent_delivery.get_complex_htf(), open(os.path.join(out_dir, "13_complex.pickle"), "wb" ))
pickle.dump(solvent_delivery.get_apo_rhtf_0(), open(os.path.join(out_dir, "13_apo_0.pickle"), "wb" ))
pickle.dump(solvent_delivery.get_complex_rhtf_0(), open(os.path.join(out_dir, "13_complex_0.pickle"), "wb" ))
pickle.dump(solvent_delivery.get_apo_rhtf_1(), open(os.path.join(out_dir, "13_apo_1.pickle"), "wb" ))
pickle.dump(solvent_delivery.get_complex_rhtf_1(), open(os.path.join(out_dir, "13_complex_1.pickle"), "wb" ))

# Render atom map
from perses.utils.smallmolecules import  render_protein_residue_atom_mapping
atom_map_filename = os.path.join(out_dir, 'atom_map.png')
render_protein_residue_atom_mapping(solvent_delivery.get_apo_htf()._topology_proposal, atom_map_filename)

# %%
solvent_delivery.get_apo_htf()._atom_classes['core_atoms']
# Out:
# {544,
#  545,
#  546,
#  547,
#  548,
#  549,
#  550,
#  551,
#  552,
#  553,
#  554,
#  555,
#  556,
#  557,
#  558,
#  559,
#  560,
#  561,
#  562,
#  563,
#  564,
#  565,
#  566,
#  568,
#  569,
#  573,
#  574,
#  575,
#  576,
#  577,
#  578,
#  579,
#  580,
#  581,
#  582,
#  14875}

# %%
out_dir = '/data/chodera/zhangi/perses_benchmark/neq/16/13/'
with open(os.path.join(out_dir, "13_apo.pickle"), "rb") as f:
    htf = pickle.load(f)

# %%
htf._atom_classes['core_atoms']
# Out:
# {544,
#  545,
#  546,
#  547,
#  548,
#  549,
#  550,
#  551,
#  552,
#  553,
#  554,
#  555,
#  556,
#  557,
#  558,
#  559,
#  560,
#  561,
#  562,
#  563,
#  564,
#  565,
#  566,
#  568,
#  569,
#  573,
#  574,
#  575,
#  576,
#  577,
#  578,
#  579,
#  580,
#  581,
#  582,
#  14875}

# %%
htf._topology_proposal._new_to_old_atom_map[14877]
# Out:
# 14875

# %%
nb_force = htf.hybrid_system.getForce(7)
for i in range(nb_force.getNumParticles()):
    if i == 14875:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 14875 [Quantity(value=-1.0, unit=elementary charge), Quantity(value=0.4477656957373345, unit=nanometer), Quantity(value=0.0, unit=kilojoule/mole)]

# %%
for atom in htf.hybrid_topology.atoms:
    print(atom.index, atom)
# Out:
# 0 ACE0-CH3
# 1 ACE0-C
# 2 ACE0-O
# 3 ACE0-H1
# 4 ACE0-H2
# 5 ACE0-H3
# 6 LYS1-N
# 7 LYS1-CA
# 8 LYS1-C
# 9 LYS1-O
# 10 LYS1-CB
# 11 LYS1-CG
# 12 LYS1-CD
# 13 LYS1-CE
# 14 LYS1-NZ
# 15 LYS1-H2
# 16 LYS1-HA
# 17 LYS1-HB3
# 18 LYS1-HB2
# 19 LYS1-HG2
# 20 LYS1-HG3
# 21 LYS1-HD2
# 22 LYS1-HD3
# 23 LYS1-HE3
# 24 LYS1-HE2
# 25 LYS1-HZ1
# 26 LYS1-HZ2
# 27 LYS1-HZ3
# 28 LYS2-N
# 29 LYS2-CA
# 30 LYS2-C
# 31 LYS2-O
# 32 LYS2-CB
# 33 LYS2-CG
# 34 LYS2-CD
# 35 LYS2-CE
# 36 LYS2-NZ
# 37 LYS2-H
# 38 LYS2-HA
# 39 LYS2-HB3
# 40 LYS2-HB2
# 41 LYS2-HG2
# 42 LYS2-HG3
# 43 LYS2-HD3
# 44 LYS2-HD2
# 45 LYS2-HE3
# 46 LYS2-HE2
# 47 LYS2-HZ1
# 48 LYS2-HZ2
# 49 LYS2-HZ3
# 50 ALA3-N
# 51 ALA3-CA
# 52 ALA3-C
# 53 ALA3-O
# 54 ALA3-CB
# 55 ALA3-H
# 56 ALA3-HA
# 57 ALA3-HB1
# 58 ALA3-HB2
# 59 ALA3-HB3
# 60 VAL4-N
# 61 VAL4-CA
# 62 VAL4-C
# 63 VAL4-O
# 64 VAL4-CB
# 65 VAL4-CG1
# 66 VAL4-CG2
# 67 VAL4-H
# 68 VAL4-HA
# 69 VAL4-HB
# 70 VAL4-HG11
# 71 VAL4-HG12
# 72 VAL4-HG13
# 73 VAL4-HG21
# 74 VAL4-HG22
# ...

# %%
nb_force = htf.hybrid_system.getForce(7)
for i in range(nb_force.getNumParticles()):
    print(i, nb_force.getParticleParameters(i))
# Out:
# 0 [Quantity(value=-0.3662, unit=elementary charge), Quantity(value=0.3399669508423535, unit=nanometer), Quantity(value=0.4577296, unit=kilojoule/mole)]
# 1 [Quantity(value=0.5972, unit=elementary charge), Quantity(value=0.3399669508423535, unit=nanometer), Quantity(value=0.359824, unit=kilojoule/mole)]
# 2 [Quantity(value=-0.5679, unit=elementary charge), Quantity(value=0.2959921901149463, unit=nanometer), Quantity(value=0.87864, unit=kilojoule/mole)]
# 3 [Quantity(value=0.1123, unit=elementary charge), Quantity(value=0.2649532787749369, unit=nanometer), Quantity(value=0.06568879999999999, unit=kilojoule/mole)]
# 4 [Quantity(value=0.1123, unit=elementary charge), Quantity(value=0.2649532787749369, unit=nanometer), Quantity(value=0.06568879999999999, unit=kilojoule/mole)]
# 5 [Quantity(value=0.1123, unit=elementary charge), Quantity(value=0.2649532787749369, unit=nanometer), Quantity(value=0.06568879999999999, unit=kilojoule/mole)]
# ...

# %%
nb_force = htf._topology_proposal.new_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i == 14877:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 14877 [Quantity(value=-0.0, unit=elementary charge), Quantity(value=0.4477656957373345, unit=nanometer), Quantity(value=0.000148912744, unit=kilojoule/mole)]

# %%
nb_force = htf._topology_proposal.old_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i == 14875:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 14875 [Quantity(value=-1.0, unit=elementary charge), Quantity(value=0.4477656957373345, unit=nanometer), Quantity(value=0.14891274399999999, unit=kilojoule/mole)]

# %%
out_dir = '/data/chodera/zhangi/perses_benchmark/neq/16/13/'
with open(os.path.join(out_dir, "13_complex.pickle"), "rb") as f:
    htf = pickle.load(f)

# %%
htf._atom_classes['core_atoms']
# Out:
# {544,
#  545,
#  546,
#  547,
#  548,
#  549,
#  550,
#  551,
#  552,
#  553,
#  554,
#  555,
#  556,
#  557,
#  558,
#  559,
#  560,
#  561,
#  562,
#  563,
#  564,
#  565,
#  566,
#  568,
#  569,
#  573,
#  574,
#  575,
#  576,
#  577,
#  578,
#  579,
#  580,
#  581,
#  582,
#  29471}

# %%
htf._topology_proposal._new_to_old_atom_map[29473]
# Out:
# 29471

# %%
nb_force = htf.hybrid_system.getForce(7)
for i in range(nb_force.getNumParticles()):
    if i ==  29471:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 29471 [Quantity(value=-1.0, unit=elementary charge), Quantity(value=0.4477656957373345, unit=nanometer), Quantity(value=0.0, unit=kilojoule/mole)]

# %%
nb_force = htf._topology_proposal.new_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i ==  29473:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 29473 [Quantity(value=-0.0, unit=elementary charge), Quantity(value=0.4477656957373345, unit=nanometer), Quantity(value=0.000148912744, unit=kilojoule/mole)]

# %%
nb_force = htf._topology_proposal.old_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i ==  29471:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 29471 [Quantity(value=-1.0, unit=elementary charge), Quantity(value=0.4477656957373345, unit=nanometer), Quantity(value=0.14891274399999999, unit=kilojoule/mole)]

# %%
out_dir = '/data/chodera/zhangi/perses_benchmark/neq/16/13/'
with open(os.path.join(out_dir, "13_complex_0.pickle"), "rb") as f:
    htf = pickle.load(f)

# %%
htf._atom_classes['core_atoms']
# Out:
# {544,
#  545,
#  546,
#  547,
#  548,
#  549,
#  550,
#  551,
#  552,
#  553,
#  554,
#  555,
#  556,
#  557,
#  558,
#  559,
#  560,
#  561,
#  562,
#  563,
#  564,
#  565,
#  566,
#  568,
#  569,
#  573,
#  574,
#  575,
#  576,
#  577,
#  578,
#  579,
#  580,
#  581,
#  582,
#  29471}

# %%
htf._topology_proposal._new_to_old_atom_map[29473]
# Out:
# 29471

# %%
nb_force = htf.hybrid_system.getForce(4)
for i in range(nb_force.getNumParticles()):
    if i == 29471:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 29471 [Quantity(value=-1.0, unit=elementary charge), Quantity(value=0.4477656957373345, unit=nanometer), Quantity(value=0.14891274399999999, unit=kilojoule/mole)]

# %%
nb_force = htf._topology_proposal.new_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i == 29473:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 29473 [Quantity(value=-0.0, unit=elementary charge), Quantity(value=0.4477656957373345, unit=nanometer), Quantity(value=0.000148912744, unit=kilojoule/mole)]

# %%
nb_force = htf._topology_proposal.old_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i == 29473:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 29473 [Quantity(value=-1.0, unit=elementary charge), Quantity(value=0.4477656957373345, unit=nanometer), Quantity(value=0.14891274399999999, unit=kilojoule/mole)]

# %%
out_dir = '/data/chodera/zhangi/perses_benchmark/neq/16/13/'
with open(os.path.join(out_dir, "13_complex_1.pickle"), "rb") as f:
    htf = pickle.load(f)

# %%
htf._atom_classes['core_atoms']
# Out:
# {544,
#  545,
#  546,
#  547,
#  548,
#  549,
#  550,
#  551,
#  552,
#  553,
#  554,
#  555,
#  556,
#  557,
#  558,
#  559,
#  560,
#  561,
#  562,
#  563,
#  564,
#  565,
#  566,
#  568,
#  569,
#  573,
#  574,
#  575,
#  576,
#  577,
#  578,
#  579,
#  580,
#  581,
#  582,
#  29471}

# %%
htf._topology_proposal._new_to_old_atom_map[29473]
# Out:
# 29471

# %%
nb_force = htf.hybrid_system.getForce(4)
for i in range(nb_force.getNumParticles()):
    if i == 29471:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 29471 [Quantity(value=-0.0, unit=elementary charge), Quantity(value=0.4477656957373345, unit=nanometer), Quantity(value=0.000148912744, unit=kilojoule/mole)]

# %%
nb_force = htf._topology_proposal.new_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i == 29473:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 29473 [Quantity(value=-0.0, unit=elementary charge), Quantity(value=0.4477656957373345, unit=nanometer), Quantity(value=0.000148912744, unit=kilojoule/mole)]

# %%
nb_force = htf._topology_proposal.old_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i == 29471:
        print(i, nb_force.getParticleParameters(i))
# Out:
# 29471 [Quantity(value=-1.0, unit=elementary charge), Quantity(value=0.4477656957373345, unit=nanometer), Quantity(value=0.14891274399999999, unit=kilojoule/mole)]

# %% [markdown]
# # barstar D35A apo with counterion fix (16/14)

# %% [markdown]
# Water->ion implementation

# %%
solvent_delivery = PointMutationExecutor("../../input/mmc2_barstar.pdb",
                        '1',
                        '35',
                        'ALA',
                        ligand_input='../../input/mmc2_barnase.pdb',
                        ionic_strength=0.05*unit.molar,
                        flatten_torsions=True,
                        flatten_exceptions=True, 
                        vanilla=True,
                        repartitioned=True,
                        conduct_endstate_validation=False
                       )
# Out:
# DEBUG:openmmforcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11
# INFO:setup:solvating at 0.05 M using tip3p
# INFO:setup:solvating at 0.05 M using tip3p
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{7: 10}, {8: 10}, {9: 10}, {7: 11}, {8: 11}, {9: 11}]
# INFO:proposal_generator:{7: 10}
# INFO:proposal_generator:{8: 10}
# INFO:proposal_generator:{9: 10}
# INFO:proposal_generator:{7: 11}
# INFO:proposal_generator:{8: 11}
# INFO:proposal_generator:{9: 11}
# INFO:proposal_generator:Returning map that best satisfies matching_criterion
# ...

# %%
import pickle
import os
out_dir = '/data/chodera/zhangi/perses_benchmark/neq/16/14/'
pickle.dump(solvent_delivery.get_apo_htf(), open(os.path.join(out_dir, "14_apo.pickle"), "wb" ))
pickle.dump(solvent_delivery.get_complex_htf(), open(os.path.join(out_dir, "14_complex.pickle"), "wb" ))
pickle.dump(solvent_delivery.get_apo_rhtf_0(), open(os.path.join(out_dir, "14_apo_0.pickle"), "wb" ))
pickle.dump(solvent_delivery.get_complex_rhtf_0(), open(os.path.join(out_dir, "14_complex_0.pickle"), "wb" ))
pickle.dump(solvent_delivery.get_apo_rhtf_1(), open(os.path.join(out_dir, "14_apo_1.pickle"), "wb" ))
pickle.dump(solvent_delivery.get_complex_rhtf_1(), open(os.path.join(out_dir, "14_complex_1.pickle"), "wb" ))

# Render atom map
from perses.utils.smallmolecules import  render_protein_residue_atom_mapping
atom_map_filename = os.path.join(out_dir, 'atom_map.png')
render_protein_residue_atom_mapping(solvent_delivery.get_apo_htf()._topology_proposal, atom_map_filename)

# %%
out_dir = '/data/chodera/zhangi/perses_benchmark/neq/16/14/'
with open(os.path.join(out_dir, "14_apo.pickle"), "rb") as f:
    htf = pickle.load(f)

# %%
htf._atom_classes['core_atoms']
# Out:
# {544,
#  545,
#  546,
#  547,
#  548,
#  549,
#  550,
#  551,
#  552,
#  553,
#  554,
#  555,
#  556,
#  557,
#  558,
#  559,
#  560,
#  561,
#  562,
#  563,
#  564,
#  565,
#  566,
#  571,
#  572,
#  575,
#  576,
#  577,
#  578,
#  579,
#  580,
#  581,
#  582,
#  583,
#  584,
#  4069,
#  4070,
#  4071}

# %%
htf._topology_proposal._new_to_old_atom_map[4069]
# Out:
# 4071

# %%
nb_force = htf.hybrid_system.getForce(7)
for i in range(nb_force.getNumParticles()):
    if i in [4069, 4070, 4071]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 4069 -0.834 e 0.3814204681974235 nm 0.0 kJ/mol
# 4070 0.417 e 1.0 nm 0.0 kJ/mol
# 4071 0.417 e 1.0 nm 0.0 kJ/mol

# %%
nb_force = htf._topology_proposal.new_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i in [4067, 4068, 4069]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 4067 -1.0 e 0.4477656957373345 nm 0.14891274399999999 kJ/mol
# 4068 0.0 e 1.0 nm 0.0 kJ/mol
# 4069 0.0 e 1.0 nm 0.0 kJ/mol

# %%
nb_force = htf._topology_proposal.old_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i in [4069, 4070, 4071]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 4069 -0.834 e 0.3150752406575124 nm 0.635968 kJ/mol
# 4070 0.417 e 1.0 nm 0.0 kJ/mol
# 4071 0.417 e 1.0 nm 0.0 kJ/mol

# %%
out_dir = '/data/chodera/zhangi/perses_benchmark/neq/16/14/'
with open(os.path.join(out_dir, "14_complex.pickle"), "rb") as f:
    htf = pickle.load(f)

# %%
htf._atom_classes['core_atoms']
# Out:
# {544,
#  545,
#  546,
#  547,
#  548,
#  549,
#  550,
#  551,
#  552,
#  553,
#  554,
#  555,
#  556,
#  557,
#  558,
#  559,
#  560,
#  561,
#  562,
#  563,
#  564,
#  565,
#  566,
#  571,
#  572,
#  575,
#  576,
#  577,
#  578,
#  579,
#  580,
#  581,
#  582,
#  583,
#  584,
#  21729,
#  21730,
#  21731}

# %%
nb_force = htf.hybrid_system.getForce(7)
for i in range(nb_force.getNumParticles()):
    if i in [21729, 21730, 21731]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 21729 -0.834 e 0.3814204681974235 nm 0.0 kJ/mol
# 21730 0.417 e 1.0 nm 0.0 kJ/mol
# 21731 0.417 e 1.0 nm 0.0 kJ/mol

# %%
nb_force = htf._topology_proposal.new_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i in [21727, 21728, 21729]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 21727 -1.0 e 0.4477656957373345 nm 0.14891274399999999 kJ/mol
# 21728 0.0 e 1.0 nm 0.0 kJ/mol
# 21729 0.0 e 1.0 nm 0.0 kJ/mol

# %%
nb_force = htf._topology_proposal.old_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i in [21729, 21730, 21731]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 21729 -0.834 e 0.3150752406575124 nm 0.635968 kJ/mol
# 21730 0.417 e 1.0 nm 0.0 kJ/mol
# 21731 0.417 e 1.0 nm 0.0 kJ/mol

# %%
out_dir = '/data/chodera/zhangi/perses_benchmark/neq/16/14/'
with open(os.path.join(out_dir, "14_complex_0.pickle"), "rb") as f:
    htf = pickle.load(f)

# %%
htf._atom_classes['core_atoms']
# Out:
# {544,
#  545,
#  546,
#  547,
#  548,
#  549,
#  550,
#  551,
#  552,
#  553,
#  554,
#  555,
#  556,
#  557,
#  558,
#  559,
#  560,
#  561,
#  562,
#  563,
#  564,
#  565,
#  566,
#  571,
#  572,
#  575,
#  576,
#  577,
#  578,
#  579,
#  580,
#  581,
#  582,
#  583,
#  584,
#  21729,
#  21730,
#  21731}

# %%
nb_force = htf.hybrid_system.getForce(4)
for i in range(nb_force.getNumParticles()):
    if i in [21729, 21730, 21731]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 21729 -0.834 e 0.3150752406575124 nm 0.635968 kJ/mol
# 21730 0.417 e 1.0 nm 0.0 kJ/mol
# 21731 0.417 e 1.0 nm 0.0 kJ/mol

# %%
nb_force = htf._topology_proposal.new_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i in [21727, 21728, 21729]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 21727 -1.0 e 0.4477656957373345 nm 0.14891274399999999 kJ/mol
# 21728 0.0 e 1.0 nm 0.0 kJ/mol
# 21729 0.0 e 1.0 nm 0.0 kJ/mol

# %%
nb_force = htf._topology_proposal.old_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i in [21729, 21730, 21731]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 21729 -0.834 e 0.3150752406575124 nm 0.635968 kJ/mol
# 21730 0.417 e 1.0 nm 0.0 kJ/mol
# 21731 0.417 e 1.0 nm 0.0 kJ/mol

# %%
out_dir = '/data/chodera/zhangi/perses_benchmark/neq/16/14/'
with open(os.path.join(out_dir, "14_complex_1.pickle"), "rb") as f:
    htf = pickle.load(f)

# %%
htf._atom_classes['core_atoms']
# Out:
# {544,
#  545,
#  546,
#  547,
#  548,
#  549,
#  550,
#  551,
#  552,
#  553,
#  554,
#  555,
#  556,
#  557,
#  558,
#  559,
#  560,
#  561,
#  562,
#  563,
#  564,
#  565,
#  566,
#  571,
#  572,
#  575,
#  576,
#  577,
#  578,
#  579,
#  580,
#  581,
#  582,
#  583,
#  584,
#  21729,
#  21730,
#  21731}

# %%
nb_force = htf.hybrid_system.getForce(4)
for i in range(nb_force.getNumParticles()):
    if i in [21729, 21730, 21731]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 21729 -1.0 e 0.4477656957373345 nm 0.14891274399999999 kJ/mol
# 21730 0.0 e 1.0 nm 0.0 kJ/mol
# 21731 0.0 e 1.0 nm 0.0 kJ/mol

# %%
nb_force = htf._topology_proposal.new_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i in [21727, 21728, 21729]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 21727 -1.0 e 0.4477656957373345 nm 0.14891274399999999 kJ/mol
# 21728 0.0 e 1.0 nm 0.0 kJ/mol
# 21729 0.0 e 1.0 nm 0.0 kJ/mol

# %%
nb_force = htf._topology_proposal.old_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i in [21729, 21730, 21731]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 21729 -0.834 e 0.3150752406575124 nm 0.635968 kJ/mol
# 21730 0.417 e 1.0 nm 0.0 kJ/mol
# 21731 0.417 e 1.0 nm 0.0 kJ/mol

# %% [markdown]
# # barstar A35A apo with counterion fix (16/15)

# %% [markdown]
# water->ion implementation

# %%
solvent_delivery = PointMutationExecutor("../../input/mmc2_barstar_D35A.pdb",
                        '1',
                        '35',
                        'ASP',
                        ligand_input='../../input/mmc2_barnase.pdb',
                        ionic_strength=0.05*unit.molar,
                        flatten_torsions=True,
                        flatten_exceptions=True, 
                        vanilla=True,
                        repartitioned=True,
                        conduct_endstate_validation=False
                       )
# Out:
# DEBUG:openmmforcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11
# INFO:setup:solvating at 0.05 M using tip3p
# INFO:setup:solvating at 0.05 M using tip3p
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{10: 7}, {11: 7}, {10: 8}, {11: 8}, {10: 9}, {11: 9}]
# INFO:proposal_generator:{10: 7}
# INFO:proposal_generator:{11: 7}
# INFO:proposal_generator:{10: 8}
# INFO:proposal_generator:{11: 8}
# INFO:proposal_generator:{10: 9}
# INFO:proposal_generator:{11: 9}
# INFO:proposal_generator:Returning map that best satisfies matching_criterion
# ...

# %%
import pickle
import os
out_dir = '/data/chodera/zhangi/perses_benchmark/neq/16/15/'
pickle.dump(solvent_delivery.get_apo_htf(), open(os.path.join(out_dir, "15_apo.pickle"), "wb" ))
pickle.dump(solvent_delivery.get_complex_htf(), open(os.path.join(out_dir, "15_complex.pickle"), "wb" ))
pickle.dump(solvent_delivery.get_apo_rhtf_0(), open(os.path.join(out_dir, "15_apo_0.pickle"), "wb" ))
pickle.dump(solvent_delivery.get_complex_rhtf_0(), open(os.path.join(out_dir, "15_complex_0.pickle"), "wb" ))
pickle.dump(solvent_delivery.get_apo_rhtf_1(), open(os.path.join(out_dir, "15_apo_1.pickle"), "wb" ))
pickle.dump(solvent_delivery.get_complex_rhtf_1(), open(os.path.join(out_dir, "15_complex_1.pickle"), "wb" ))

# Render atom map
from perses.utils.smallmolecules import  render_protein_residue_atom_mapping
atom_map_filename = os.path.join(out_dir, 'atom_map.png')
render_protein_residue_atom_mapping(solvent_delivery.get_apo_htf()._topology_proposal, atom_map_filename)

# %% [markdown]
# ## Check N439K htf (14/30)

# %%
out_dir = '/data/chodera/zhangi/perses_benchmark/neq/14/30/'
with open(os.path.join(out_dir, "30_complex.pickle"), "rb") as f:
    htf = pickle.load(f)

# %%
htf._atom_classes['core_atoms']
# Out:
# {1622,
#  1623,
#  1624,
#  1625,
#  1626,
#  1627,
#  1628,
#  1629,
#  1630,
#  1631,
#  1632,
#  1633,
#  1634,
#  1635,
#  1636,
#  1645,
#  1646,
#  1647,
#  1648,
#  1649,
#  1650,
#  1651,
#  1652,
#  1653,
#  1654,
#  1655,
#  1656,
#  1657,
#  1658,
#  1659,
#  1660,
#  104834,
#  104835,
#  104836}

# %%
htf._topology_proposal._new_to_old_atom_map[104842]
# Out:
# 104834

# %%
nb_force = htf.hybrid_system.getForce(7)
for i in range(nb_force.getNumParticles()):
    if i in [104834,104835, 104836]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 104834 -0.834 e 0.38142046822517073 nm 0.0 kJ/mol
# 104835 0.417 e 0.08908987181403394 nm 0.0 kJ/mol
# 104836 0.417 e 0.08908987181403394 nm 0.0 kJ/mol

# %%
nb_force = htf._topology_proposal.new_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i in [104842, 104843, 104844]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 104842 -1.0 e 0.4477656957373345 nm 0.14891274399999999 kJ/mol
# 104843 0.0 e 0.08908987181403394 nm 0.0 kJ/mol
# 104844 0.0 e 0.08908987181403394 nm 0.0 kJ/mol

# %%
nb_force = htf._topology_proposal.old_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i in [104834,104835, 104836]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 104834 -0.834 e 0.315075240713007 nm 0.6359679988330078 kJ/mol
# 104835 0.417 e 0.08908987181403394 nm 0.0 kJ/mol
# 104836 0.417 e 0.08908987181403394 nm 0.0 kJ/mol

# %% [markdown]
# ## Check E484K htf (14/31)

# %%
out_dir = '/data/chodera/zhangi/perses_benchmark/neq/14/31/'
with open(os.path.join(out_dir, "31_complex.pickle"), "rb") as f:
    htf = pickle.load(f)

# %%
htf._atom_classes['core_atoms']
# Out:
# {2328,
#  2329,
#  2330,
#  2331,
#  2332,
#  2333,
#  2334,
#  2335,
#  2336,
#  2337,
#  2338,
#  2339,
#  2340,
#  2341,
#  2342,
#  2343,
#  2344,
#  2345,
#  2346,
#  2347,
#  2357,
#  2358,
#  2359,
#  2360,
#  2361,
#  2362,
#  2363,
#  2364,
#  2365,
#  121658,
#  121659,
#  121660,
#  167858,
#  167859,
#  167860}

# %%
htf._topology_proposal._new_to_old_atom_map[121665]
# Out:
# 121658

# %%
htf._topology_proposal._new_to_old_atom_map[167865]
# Out:
# 167858

# %%
nb_force = htf.hybrid_system.getForce(7)
for i in range(nb_force.getNumParticles()):
    if i in [121658, 121659, 121660, 167858, 167859, 167860]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 121658 -0.834 e 0.38142046822517073 nm 0.0 kJ/mol
# 121659 0.417 e 0.08908987181403394 nm 0.0 kJ/mol
# 121660 0.417 e 0.08908987181403394 nm 0.0 kJ/mol
# 167858 -0.834 e 0.38142046822517073 nm 0.0 kJ/mol
# 167859 0.417 e 0.08908987181403394 nm 0.0 kJ/mol
# 167860 0.417 e 0.08908987181403394 nm 0.0 kJ/mol

# %%
nb_force = htf._topology_proposal.new_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i in [121665, 121666, 121667, 167865, 167866, 167867]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 121665 -1.0 e 0.4477656957373345 nm 0.14891274399999999 kJ/mol
# 121666 0.0 e 0.08908987181403394 nm 0.0 kJ/mol
# 121667 0.0 e 0.08908987181403394 nm 0.0 kJ/mol
# 167865 -1.0 e 0.4477656957373345 nm 0.14891274399999999 kJ/mol
# 167866 0.0 e 0.08908987181403394 nm 0.0 kJ/mol
# 167867 0.0 e 0.08908987181403394 nm 0.0 kJ/mol

# %%
nb_force = htf._topology_proposal.old_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i in [121658, 121659, 121660, 167858, 167859, 167860]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 121658 -0.834 e 0.315075240713007 nm 0.6359679988330078 kJ/mol
# 121659 0.417 e 0.08908987181403394 nm 0.0 kJ/mol
# 121660 0.417 e 0.08908987181403394 nm 0.0 kJ/mol
# 167858 -0.834 e 0.315075240713007 nm 0.6359679988330078 kJ/mol
# 167859 0.417 e 0.08908987181403394 nm 0.0 kJ/mol
# 167860 0.417 e 0.08908987181403394 nm 0.0 kJ/mol

# %% [markdown]
# ## Check N501D htf (14/34)

# %%
out_dir = '/data/chodera/zhangi/perses_benchmark/neq/14/34/'
with open(os.path.join(out_dir, "34_complex.pickle"), "rb") as f:
    htf = pickle.load(f)

# %%
htf._atom_classes['core_atoms']
# Out:
# {2591,
#  2592,
#  2593,
#  2594,
#  2595,
#  2596,
#  2597,
#  2598,
#  2599,
#  2600,
#  2601,
#  2602,
#  2603,
#  2604,
#  2605,
#  2606,
#  2607,
#  2608,
#  2617,
#  2618,
#  2619,
#  2620,
#  2621,
#  2622,
#  2623,
#  2624,
#  2625,
#  143072,
#  143073,
#  143074}

# %%
htf._topology_proposal._new_to_old_atom_map[143070]
# Out:
# 143072

# %%
nb_force = htf.hybrid_system.getForce(7)
for i in range(nb_force.getNumParticles()):
    if i in [143072, 143073, 143074]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 143072 -0.834 e 0.27950165486991596 nm 0.0 kJ/mol
# 143073 0.417 e 0.08908987181403394 nm 0.0 kJ/mol
# 143074 0.417 e 0.08908987181403394 nm 0.0 kJ/mol

# %%
nb_force = htf._topology_proposal.new_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i in [143070, 143071, 143072]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 143070 1.0 e 0.2439280690268249 nm 0.3658460312 kJ/mol
# 143071 0.0 e 0.08908987181403394 nm 0.0 kJ/mol
# 143072 0.0 e 0.08908987181403394 nm 0.0 kJ/mol

# %%
nb_force = htf._topology_proposal.old_system.getForce(3)
for i in range(nb_force.getNumParticles()):
    if i in [143072, 143073, 143074]:
        charge, sigma, epsilon = nb_force.getParticleParameters(i)
        print(i, charge, sigma, epsilon)
# Out:
# 143072 -0.834 e 0.315075240713007 nm 0.6359679988330078 kJ/mol
# 143073 0.417 e 0.08908987181403394 nm 0.0 kJ/mol
# 143074 0.417 e 0.08908987181403394 nm 0.0 kJ/mol
