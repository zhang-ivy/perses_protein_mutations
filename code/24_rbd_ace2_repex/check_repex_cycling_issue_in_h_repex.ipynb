# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # N501Y complex

# %%
with open("/data/chodera/zhangi/perses_benchmark/repex/31/1/0/log.txt", "r") as f:
    lines = f.readlines()

# %%
times_before = []
for line in lines:
    if "Iteration took" in line:
        time = float(line.split(" ")[-1].strip('s.\n'))
        times_before.append(time)

# %%
plt.plot(times_before[1:300])
plt.xlabel('iteration number')
plt.ylabel('iteration length (s)')
plt.title('N501Y complex h-repex')
# Out:
# Text(0.5, 1.0, 'N501Y complex h-repex')

# %% [markdown]
# # T42A apo

# %%
with open("/data/chodera/zhangi/perses_benchmark/repex/31/0/1/31.0.1.0.stderr", "r") as f:
    lines = f.readlines()

# %%
times = []
for line in lines:
    if "Iteration took" in line:
        time = float(line.split(" ")[-1].strip('s.\n'))
        times.append(time)

# %%
plt.plot(times)
plt.xlabel('iteration number')
plt.ylabel('iteration length (s)')
plt.title('T42A apo h-repex')
# Out:
# Text(0.5, 1.0, 'T42A apo h-repex')

# %% [markdown]
# # T42A complex

# %%
with open("/data/chodera/zhangi/perses_benchmark/repex/31/0/1/log_complex.txt", "r") as f:
    lines = f.readlines()

# %%
times_before = []
for line in lines:
    if "Iteration took" in line:
        time = float(line.split(" ")[-1].strip('s.\n'))
        times_before.append(time)

# %%
plt.plot(times_before[1:])
plt.xlabel('iteration number')
plt.ylabel('iteration length (s)')
plt.title('T42A complex h-repex')
# Out:
# Text(0.5, 1.0, 'T42A complex h-repex')

# %% [markdown]
# # T42A complex

# %%
with open("/data/chodera/zhangi/perses_benchmark/repex/31/0/5/log_complex.txt", "r") as f:
    lines = f.readlines()

# %%
times = []
for line in lines:
    if "Iteration took" in line:
        time = float(line.split(" ")[-1].strip('s.\n'))
        times.append(time)

# %%
plt.plot(times_before[1:], label='before adding context_cache fix')
plt.plot(times[1:], label='after adding context_cache fix')
plt.xlabel('iteration number')
plt.ylabel('iteration length (s)')
plt.title('T42A complex h-repex')
plt.legend()

# %% [markdown]
# # N501Y complex

# %%
with open("/data/chodera/zhangi/perses_benchmark/repex/31/0/6/31.0.6.complex.stderr", "r") as f:
    lines = f.readlines()

# %%
times = []
for line in lines:
    if "Iteration took" in line:
        time = float(line.split(" ")[-1].strip('s.\n'))
        times.append(time)

# %%
plt.plot(times_before[1:], label='before adding context_cache fix')
plt.plot(times[1:], label='after adding context_cache fix')
plt.xlabel('iteration number')
plt.ylabel('iteration length (s)')
plt.title('N501Y complex h-repex')
plt.legend()
