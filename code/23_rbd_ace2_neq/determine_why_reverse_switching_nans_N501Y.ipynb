# %%
import logging
import pickle
import numpy as np
from openmmtools.integrators import PeriodicNonequilibriumIntegrator
from simtk import unit, openmm
import argparse
import os
import time
import mdtraj as md
from tqdm import tqdm
from openmmtools.constants import kB

# Set up logger
_logger = logging.getLogger()
_logger.setLevel(logging.INFO)

# %%
outdir = "/data/chodera/zhangi/perses_benchmark/neq/14/64/"
phase = 'complex'
sim_number = 1
old_aa_name = 'asn'
new_aa_name = 'tyr'
length = 1
cache = 1
cache_length = 1

# %% [markdown]
# ## Run neq integrator

# %%
# Define lambda functions
x = 'lambda'
DEFAULT_ALCHEMICAL_FUNCTIONS = {
                             'lambda_sterics_core': x,
                             'lambda_electrostatics_core': x,
                             'lambda_sterics_insert': f"select(step({x} - 0.5), 1.0, 2.0 * {x})",
                             'lambda_sterics_delete': f"select(step({x} - 0.5), 2.0 * ({x} - 0.5), 0.0)",
                             'lambda_electrostatics_insert': f"select(step({x} - 0.5), 2.0 * ({x} - 0.5), 0.0)",
                             'lambda_electrostatics_delete': f"select(step({x} - 0.5), 1.0, 2.0 * {x})",
                             'lambda_bonds': x,
                             'lambda_angles': x,
                             'lambda_torsions': x}

# Define simulation parameters
# nsteps_eq = 25000 # 100 ps 
nsteps_eq = 1
nsteps_neq = 100
neq_splitting='V R H O R V'
timestep = 4.0 * unit.femtosecond
platform_name = 'CUDA'
cache_length = 1
temperature = 298.0 * unit.kelvin
kT = kB * temperature

# %%
# Read in vanilla htf
i = os.path.basename(os.path.dirname(outdir))
with open(os.path.join("/data/chodera/zhangi/perses_benchmark/neq/15/64/", f"{i}_{phase}.pickle"), 'rb') as f:
    htf = pickle.load(f)

# %%
# Read in lambda = 0 cache
with open(os.path.join(outdir, f"{i}_{phase}_{old_aa_name}_{cache_length}ns_snapshots.npy"), 'rb') as f:
    subset_pos = np.load(f)
positions = subset_pos[sim_number]
system = htf.hybrid_system

# %%
# Set up integrator
integrator = PeriodicNonequilibriumIntegrator(DEFAULT_ALCHEMICAL_FUNCTIONS, nsteps_eq, nsteps_neq, neq_splitting, timestep=timestep, temperature=temperature)

# Set up context
platform = openmm.Platform.getPlatformByName(platform_name)
if platform_name in ['CUDA', 'OpenCL']:
    platform.setPropertyDefaultValue('Precision', 'mixed')
if platform_name in ['CUDA']:
    platform.setPropertyDefaultValue('DeterministicForces', 'true')
context = openmm.Context(system, integrator, platform)
context.setPeriodicBoxVectors(*system.getDefaultPeriodicBoxVectors())
context.setPositions(positions)
context.setVelocitiesToTemperature(temperature)

# Minimize
openmm.LocalEnergyMinimizer.minimize(context)

# %%
# Run eq forward (0 -> 1)
forward_eq_old, forward_eq_new = list(), list()
for fwd_step in range(nsteps_eq):
    initial_time = time.time()
    _logger.info(f'before eq step: {fwd_step}, potential energy: {context.getState(getEnergy=True).getPotentialEnergy()}')
    integrator.step(1)
    _logger.info(f'after step: {fwd_step}, potential energy: {context.getState(getEnergy=True).getPotentialEnergy()}')
    elapsed_time = (time.time() - initial_time) * unit.seconds
    # if fwd_step % 2500 == 0:
    #     _logger.info(f'forward EQ step: {fwd_step}, took: {elapsed_time / unit.seconds} seconds')
    #     pos = context.getState(getPositions=True, enforcePeriodicBox=False).getPositions(asNumpy=True)
    #     old_pos = np.asarray(htf.old_positions(pos))
    #     new_pos = np.asarray(htf.new_positions(pos))
    #     forward_eq_old.append(old_pos)
    #     forward_eq_new.append(new_pos)

# Run neq forward (0 -> 1)
forward_works_master = list()
forward_neq_old, forward_neq_new = list(), list()
forward_works = [integrator.get_protocol_work(dimensionless=True)]
for fwd_step in range(nsteps_neq):
    initial_time = time.time()
    _logger.info(f'forward NEQ step: {fwd_step}, potential energy: {context.getState(getEnergy=True).getPotentialEnergy()}')
    integrator.step(1)
    elapsed_time = (time.time() - initial_time) * unit.seconds
    forward_works.append(integrator.get_protocol_work(dimensionless=True))
    if fwd_step % 2500 == 0:
        _logger.info(f'forward NEQ step: {fwd_step}, took: {elapsed_time / unit.seconds} seconds')
#         pos = context.getState(getPositions=True, enforcePeriodicBox=False).getPositions(asNumpy=True)
#         old_pos = np.asarray(htf.old_positions(pos))
#         old_traj = md.Trajectory(old_pos, md.Topology.from_openmm(htf._topology_proposal.old_topology))
#         old_pos_solute = old_traj.atom_slice(old_traj.top.select("not water")).xyz[0]
        
#         new_pos = np.asarray(htf.new_positions(pos))
#         new_traj = md.Trajectory(new_pos, md.Topology.from_openmm(htf._topology_proposal.new_topology))
#         new_pos_solute = new_traj.atom_slice(new_traj.top.select("not water")).xyz[0]
        
#         forward_neq_old.append(old_pos_solute)
#         forward_neq_new.append(new_pos_solute)
forward_works_master.append(forward_works)
# Out:
# INFO:root:before eq step: 0, potential energy: -3009664.7529741605 kJ/mol
# INFO:root:after step: 0, potential energy: -2971060.284599786 kJ/mol
# INFO:root:forward NEQ step: 0, potential energy: -2971060.284599786 kJ/mol
# INFO:root:forward NEQ step: 0, took: 0.01717090606689453 seconds
# INFO:root:forward NEQ step: 1, potential energy: -2924276.372293562 kJ/mol
# INFO:root:forward NEQ step: 2, potential energy: -2859441.9024449727 kJ/mol
# INFO:root:forward NEQ step: 3, potential energy: -2813319.8552865805 kJ/mol
# INFO:root:forward NEQ step: 4, potential energy: -2775701.6820243406 kJ/mol
# INFO:root:forward NEQ step: 5, potential energy: -2758260.4419492763 kJ/mol
# INFO:root:forward NEQ step: 6, potential energy: -2752750.2931406316 kJ/mol
# INFO:root:forward NEQ step: 7, potential energy: -2757544.5490498072 kJ/mol
# INFO:root:forward NEQ step: 8, potential energy: -2763128.2292693937 kJ/mol
# INFO:root:forward NEQ step: 9, potential energy: -2766798.737853912 kJ/mol
# INFO:root:forward NEQ step: 10, potential energy: -2771906.2975764577 kJ/mol
# INFO:root:forward NEQ step: 11, potential energy: -2776002.254119429 kJ/mol
# INFO:root:forward NEQ step: 12, potential energy: -2782225.6218916555 kJ/mol
# INFO:root:forward NEQ step: 13, potential energy: -2785237.0267979163 kJ/mol
# INFO:root:forward NEQ step: 14, potential energy: -2787169.8692308255 kJ/mol
# INFO:root:forward NEQ step: 15, potential energy: -2784153.515407366 kJ/mol
# INFO:root:forward NEQ step: 16, potential energy: -2780609.542449097 kJ/mol
# INFO:root:forward NEQ step: 17, potential energy: -2774471.236747857 kJ/mol
# INFO:root:forward NEQ step: 18, potential energy: -2770502.5679162983 kJ/mol
# INFO:root:forward NEQ step: 19, potential energy: -2764226.311093443 kJ/mol
# INFO:root:forward NEQ step: 20, potential energy: -2761308.801211702 kJ/mol
# INFO:root:forward NEQ step: 21, potential energy: -2756731.021373158 kJ/mol
# INFO:root:forward NEQ step: 22, potential energy: -2753690.4936260926 kJ/mol
# INFO:root:forward NEQ step: 23, potential energy: -2749402.9735531253 kJ/mol
# INFO:root:forward NEQ step: 24, potential energy: -2746102.5934779765 kJ/mol
# INFO:root:forward NEQ step: 25, potential energy: -2743517.535897519 kJ/mol
# INFO:root:forward NEQ step: 26, potential energy: -2741161.2940407475 kJ/mol
# INFO:root:forward NEQ step: 27, potential energy: -2740955.877365436 kJ/mol
# INFO:root:forward NEQ step: 28, potential energy: -2739392.0278366306 kJ/mol
# INFO:root:forward NEQ step: 29, potential energy: -2740288.5053425613 kJ/mol
# INFO:root:forward NEQ step: 30, potential energy: -2738542.3399328664 kJ/mol
# INFO:root:forward NEQ step: 31, potential energy: -2738421.3193335435 kJ/mol
# INFO:root:forward NEQ step: 32, potential energy: -2737129.416559642 kJ/mol
# INFO:root:forward NEQ step: 33, potential energy: -2737166.130299633 kJ/mol
# INFO:root:forward NEQ step: 34, potential energy: -2736398.745794168 kJ/mol
# INFO:root:forward NEQ step: 35, potential energy: -2736143.722185917 kJ/mol
# INFO:root:forward NEQ step: 36, potential energy: -2735446.2664609747 kJ/mol
# INFO:root:forward NEQ step: 37, potential energy: -2733752.089440673 kJ/mol
# INFO:root:forward NEQ step: 38, potential energy: -2731827.9722011494 kJ/mol
# INFO:root:forward NEQ step: 39, potential energy: -2729547.714254944 kJ/mol
# INFO:root:forward NEQ step: 40, potential energy: -2729352.0837706537 kJ/mol
# INFO:root:forward NEQ step: 41, potential energy: -2728291.8534187805 kJ/mol
# INFO:root:forward NEQ step: 42, potential energy: -2728807.2056872617 kJ/mol
# INFO:root:forward NEQ step: 43, potential energy: -2727339.227157431 kJ/mol
# INFO:root:forward NEQ step: 44, potential energy: -2727470.260090469 kJ/mol
# INFO:root:forward NEQ step: 45, potential energy: -2725827.812281178 kJ/mol
# INFO:root:forward NEQ step: 46, potential energy: -2725864.427347207 kJ/mol
# INFO:root:forward NEQ step: 47, potential energy: -2725307.112086948 kJ/mol
# INFO:root:forward NEQ step: 48, potential energy: -2725757.263807642 kJ/mol
# INFO:root:forward NEQ step: 49, potential energy: -2725011.7545917057 kJ/mol
# INFO:root:forward NEQ step: 50, potential energy: -2724699.0101001696 kJ/mol
# INFO:root:forward NEQ step: 51, potential energy: -2723794.6290673125 kJ/mol
# INFO:root:forward NEQ step: 52, potential energy: -2723518.852113347 kJ/mol
# INFO:root:forward NEQ step: 53, potential energy: -2722821.3081516153 kJ/mol
# INFO:root:forward NEQ step: 54, potential energy: -2722789.7482442344 kJ/mol
# INFO:root:forward NEQ step: 55, potential energy: -2722348.6633045296 kJ/mol
# INFO:root:forward NEQ step: 56, potential energy: -2722509.3769078148 kJ/mol
# INFO:root:forward NEQ step: 57, potential energy: -2721624.6209936594 kJ/mol
# INFO:root:forward NEQ step: 58, potential energy: -2720846.317878341 kJ/mol
# INFO:root:forward NEQ step: 59, potential energy: -2719428.705158252 kJ/mol
# INFO:root:forward NEQ step: 60, potential energy: -2718806.544061907 kJ/mol
# INFO:root:forward NEQ step: 61, potential energy: -2718162.266502948 kJ/mol
# INFO:root:forward NEQ step: 62, potential energy: -2717392.2067432976 kJ/mol
# INFO:root:forward NEQ step: 63, potential energy: -2716689.6469025705 kJ/mol
# INFO:root:forward NEQ step: 64, potential energy: -2715185.192547821 kJ/mol
# INFO:root:forward NEQ step: 65, potential energy: -2714976.35229023 kJ/mol
# INFO:root:forward NEQ step: 66, potential energy: -2713787.2422820847 kJ/mol
# INFO:root:forward NEQ step: 67, potential energy: -2713804.9264726317 kJ/mol
# INFO:root:forward NEQ step: 68, potential energy: -2712699.5252469075 kJ/mol
# INFO:root:forward NEQ step: 69, potential energy: -2711816.8172033844 kJ/mol
# INFO:root:forward NEQ step: 70, potential energy: -2711115.179119011 kJ/mol
# INFO:root:forward NEQ step: 71, potential energy: -2710297.472967267 kJ/mol
# INFO:root:forward NEQ step: 72, potential energy: -2709726.754254541 kJ/mol
# INFO:root:forward NEQ step: 73, potential energy: -2708875.3427953124 kJ/mol
# INFO:root:forward NEQ step: 74, potential energy: -2708052.0115696476 kJ/mol
# INFO:root:forward NEQ step: 75, potential energy: -2707313.3352626953 kJ/mol
# INFO:root:forward NEQ step: 76, potential energy: -2706961.2032628753 kJ/mol
# INFO:root:forward NEQ step: 77, potential energy: -2706212.2769862176 kJ/mol
# INFO:root:forward NEQ step: 78, potential energy: -2705851.8918978116 kJ/mol
# INFO:root:forward NEQ step: 79, potential energy: -2704627.819616584 kJ/mol
# INFO:root:forward NEQ step: 80, potential energy: -2704425.9090879685 kJ/mol
# INFO:root:forward NEQ step: 81, potential energy: -2703497.8991768383 kJ/mol
# INFO:root:forward NEQ step: 82, potential energy: -2702525.805384793 kJ/mol
# INFO:root:forward NEQ step: 83, potential energy: -2702035.4622561773 kJ/mol
# INFO:root:forward NEQ step: 84, potential energy: -2701022.88947289 kJ/mol
# INFO:root:forward NEQ step: 85, potential energy: -2700624.6360954163 kJ/mol
# INFO:root:forward NEQ step: 86, potential energy: -2699748.306301147 kJ/mol
# INFO:root:forward NEQ step: 87, potential energy: -2699029.5419112667 kJ/mol
# INFO:root:forward NEQ step: 88, potential energy: -2697813.3680768693 kJ/mol
# INFO:root:forward NEQ step: 89, potential energy: -2697317.784102272 kJ/mol
# INFO:root:forward NEQ step: 90, potential energy: -2697121.599698875 kJ/mol
# INFO:root:forward NEQ step: 91, potential energy: -2697136.1763704955 kJ/mol
# INFO:root:forward NEQ step: 92, potential energy: -2696258.45433643 kJ/mol
# INFO:root:forward NEQ step: 93, potential energy: -2695368.867220315 kJ/mol
# INFO:root:forward NEQ step: 94, potential energy: -2694074.240608987 kJ/mol
# INFO:root:forward NEQ step: 95, potential energy: -2692874.259335023 kJ/mol
# INFO:root:forward NEQ step: 96, potential energy: -2692056.219653496 kJ/mol
# INFO:root:forward NEQ step: 97, potential energy: -2691734.8277002936 kJ/mol
# INFO:root:forward NEQ step: 98, potential energy: -2690656.6122634737 kJ/mol
# INFO:root:forward NEQ step: 99, potential energy: -2690092.6315667997 kJ/mol

# %%
# Read in lambda = 1 cache, if necessary
with open(os.path.join(outdir, f"{i}_{phase}_{new_aa_name}_{cache_length}ns_snapshots.npy"), 'rb') as f:
    subset_pos = np.load(f)
positions = subset_pos[sim_number]
context.setPositions(positions)

# %%
# Run eq reverse (1 -> 0)
reverse_eq_old, reverse_eq_new = list(), list()
for rev_step in range(nsteps_eq):
    initial_time = time.time()
    integrator.step(1)
    elapsed_time = (time.time() - initial_time) * unit.seconds
    # if rev_step % 2500 == 0:
    #     _logger.info(f'reverse EQ step: {rev_step}, took: {elapsed_time / unit.seconds} seconds')
    #     pos = context.getState(getPositions=True, enforcePeriodicBox=False).getPositions(asNumpy=True)
    #     old_pos = np.asarray(htf.old_positions(pos))
    #     new_pos = np.asarray(htf.new_positions(pos))
    #     reverse_eq_old.append(old_pos)
    #     reverse_eq_new.append(new_pos)

# Run neq reverse (1 -> 0)
reverse_works_master = list()
reverse_neq_old, reverse_neq_new = list(), list()
reverse_works = [integrator.get_protocol_work(dimensionless=True)]
for rev_step in range(nsteps_neq):
    initial_time = time.time()
    integrator.step(1)
    elapsed_time = (time.time() - initial_time) * unit.seconds
    reverse_works.append(integrator.get_protocol_work(dimensionless=True))
#     if rev_step % 2500 == 0:
    _logger.info(f'reverse NEQ step: {rev_step}, potential energy: {context.getState(getEnergy=True).getPotentialEnergy()}')
    pos = context.getState(getPositions=True, enforcePeriodicBox=False).getPositions(asNumpy=True)
#         old_pos = np.asarray(htf.old_positions(pos))
#         old_traj = md.Trajectory(old_pos, md.Topology.from_openmm(htf._topology_proposal.old_topology))
#         old_pos_solute = old_traj.atom_slice(old_traj.top.select("not water")).xyz[0]
        
    new_pos = np.asarray(htf.new_positions(pos))
    reverse_neq_new.append(new_pos)

#         new_traj = md.Trajectory(new_pos, md.Topology.from_openmm(htf._topology_proposal.new_topology))
#         new_pos_solute = new_traj.atom_slice(new_traj.top.select("not water")).xyz[0]

#         reverse_neq_old.append(old_pos_solute)
#         reverse_neq_new.append(new_pos_solute)
reverse_works_master.append(reverse_works)
# Out:
# INFO:root:reverse NEQ step: 0, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 1, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 2, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 3, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 4, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 5, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 6, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 7, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 8, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 9, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 10, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 11, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 12, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 13, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 14, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 15, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 16, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 17, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 18, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 19, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 20, potential energy: nan kJ/mol
# INFO:root:reverse NEQ step: 21, potential energy: nan kJ/mol
# --------------
# OpenMMExceptionTraceback (most recent call last)
# <ipython-input-9-ba268cc4cb38> in <module>
#      19 for rev_step in range(nsteps_neq):
#      20     initial_time = time.time()
# ---> 21     integrator.step(1)
#      22     elapsed_time = (time.time() - initial_time) * unit.seconds
#      23     reverse_works.append(integrator.get_protocol_work(dimensionless=True))
#
# ~/miniconda3/envs/perses-rbd-ace2/lib/python3.8/site-packages/simtk/openmm/openmm.py in step(self, steps)
#    4595             the number of time steps to take
#    4596         """
# -> 4597         return _openmm.CustomIntegrator_step(self, steps)
#    4598
#    4599     def getPerDofVariable(self, *args):
#
# OpenMMException: Particle coordinate is nan

# %%
old_traj = md.Trajectory(all_old, md.Topology.from_openmm(htf._topology_proposal.old_topology))

# %%
old_traj[0].save(f"check_{sim_number}_min.pdb")

# %%
old_traj.save(f"check_{sim_number}_min.dcd")

# %%
# Save works
with open(os.path.join(args.dir, f"{i}_{args.phase}_{args.sim_number}_forward.npy"), 'wb') as f:
    np.save(f, forward_works_master)
with open(os.path.join(args.dir, f"{i}_{args.phase}_{args.sim_number}_reverse.npy"), 'wb') as f:
    np.save(f, reverse_works_master)

# Save trajs
# with open(os.path.join(args.dir, f"{i}_{args.phase}_{args.sim_number}_forward_eq_old.npy"), 'wb') as f:
#     np.save(f, forward_eq_old)
# with open(os.path.join(args.dir, f"{i}_{args.phase}_{args.sim_number}_forward_eq_new.npy"), 'wb') as f:
#     np.save(f, forward_eq_new)
# with open(os.path.join(args.dir, f"{i}_{args.phase}_{args.sim_number}_reverse_eq_old.npy"), 'wb') as f:
#     np.save(f, reverse_eq_old)
# with open(os.path.join(args.dir, f"{i}_{args.phase}_{args.sim_number}_reverse_eq_new.npy"), 'wb') as f:
#     np.save(f, reverse_eq_new)

with open(os.path.join(args.dir, f"{i}_{args.phase}_{args.sim_number}_forward_neq_old.npy"), 'wb') as f:
    np.save(f, forward_neq_old)
with open(os.path.join(args.dir, f"{i}_{args.phase}_{args.sim_number}_forward_neq_new.npy"), 'wb') as f:
    np.save(f, forward_neq_new)
with open(os.path.join(args.dir, f"{i}_{args.phase}_{args.sim_number}_reverse_neq_old.npy"), 'wb') as f:
    np.save(f, reverse_neq_old)
with open(os.path.join(args.dir, f"{i}_{args.phase}_{args.sim_number}_reverse_neq_new.npy"), 'wb') as f:
    np.save(f, reverse_neq_new)

# %% [markdown]
# # Run vanilla MD

# %%
# Read in lambda = 1 cache, if necessary
with open(os.path.join(outdir, f"{i}_{phase}_{new_aa_name}_{cache_length}ns_snapshots.npy"), 'rb') as f:
    subset_pos = np.load(f)
positions = subset_pos[sim_number]
context.setPositions(positions)

# %%
from openmmtools.integrators import LangevinIntegrator
from perses.tests.utils import compute_potential_components

# Define simulation parameters
temperature = 298 * unit.kelvin
collision_rate = 1.0 / unit.picoseconds
nsteps = 10000
timestep = 1.0 * unit.femtosecond
platform_name = 'CUDA'
integrator = LangevinIntegrator(temperature, collision_rate, timestep)

kT = kB * temperature
beta = 1.0/kT

# Set up context
platform = openmm.Platform.getPlatformByName(platform_name)
if platform_name in ['CUDA', 'OpenCL']:
    platform.setPropertyDefaultValue('Precision', 'mixed')
if platform_name in ['CUDA']:
    platform.setPropertyDefaultValue('DeterministicForces', 'true')
context = openmm.Context(system, integrator, platform)
context.setPeriodicBoxVectors(*system.getDefaultPeriodicBoxVectors())
context.setPositions(positions)
context.setVelocitiesToTemperature(temperature)

# # Minimize
# openmm.LocalEnergyMinimizer.minimize(context)

# %%
all_old = []
pos = context.getState(getPositions=True, enforcePeriodicBox=False).getPositions(asNumpy=True)
old_pos = np.asarray(htf.old_positions(pos))
all_old.append(old_pos)

# %%
# Run equilibration
for step in range(10):
    integrator.step(1)
    pos = context.getState(getPositions=True, enforcePeriodicBox=False).getPositions(asNumpy=True)
    old_pos = np.asarray(htf.old_positions(pos))
    all_old.append(old_pos)
#     _logger.info(f'forward NEQ step: {step}, potential energy: {compute_potential_components(context, beta=beta)}')
    _logger.info(f'forward NEQ step: {step}, potential energy: {context.getState(getEnergy=True).getPotentialEnergy()}')
# Out:
# INFO:root:forward NEQ step: 0, potential energy: -2405496.951452459 kJ/mol
# INFO:root:forward NEQ step: 1, potential energy: -2405593.7487068693 kJ/mol
# INFO:root:forward NEQ step: 2, potential energy: -2405673.628566692 kJ/mol
# INFO:root:forward NEQ step: 3, potential energy: -2405728.3403970557 kJ/mol
# INFO:root:forward NEQ step: 4, potential energy: -2405766.8435500325 kJ/mol
# INFO:root:forward NEQ step: 5, potential energy: -2405807.5016522673 kJ/mol
# INFO:root:forward NEQ step: 6, potential energy: -2405872.777494036 kJ/mol
# INFO:root:forward NEQ step: 7, potential energy: -2405973.976228055 kJ/mol
# INFO:root:forward NEQ step: 8, potential energy: -2406120.8412914737 kJ/mol
# INFO:root:forward NEQ step: 9, potential energy: -2406281.3425999465 kJ/mol
