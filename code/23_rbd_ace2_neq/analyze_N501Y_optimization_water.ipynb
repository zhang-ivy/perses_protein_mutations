# %% [markdown]
# Analyze 15/98-111 neq switching

# %%
from perses.analysis.analysis import Analysis
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pymbar
# %matplotlib inline
import os
import itertools
from tqdm import tqdm_notebook
import pandas as pd
import tqdm
import warnings
warnings.filterwarnings('ignore')
from simtk.openmm import unit
from openmmtools.constants import kB
KT_KCALMOL = kB * 300 * unit.kelvin / unit.kilocalories_per_mole
import pandas as pd
import pickle

# %%
def bound_with_exp(forward_accumulated, reverse_accumulated):
    upper_dg, upper_ddg = pymbar.exp.EXP(forward_accumulated)
    lower_dg, lower_ddg = pymbar.exp.EXP(reverse_accumulated)
    return upper_dg, upper_ddg, lower_dg, lower_ddg
    
def analyze(forward_accumulated, reverse_accumulated): 
    # Compute dg, ddg
    dg, ddg = pymbar.bar.BAR(forward_accumulated, reverse_accumulated)
    return dg, ddg

def analyze_bootstrap(d_works):
    d_dgs_phase = {}
    complex_dg, complex_ddg = analyze(d_works['complex']['forward'], d_works['complex']['reverse'])
    apo_dg, apo_ddg = analyze(d_works['apo']['forward'], d_works['apo']['reverse'])
    d_dgs_phase['complex'] = (complex_dg, complex_ddg)
    d_dgs_phase['apo'] = (apo_dg, apo_ddg)
    
    binding_dg = complex_dg - apo_dg
#     binding_ddg = (apo_ddg**2 + complex_ddg**2)**0.5
    return d_dgs_phase, binding_dg
    
def plot(forward_work, reverse_work, dg, ddg, dir_num, phase, output_dir, title):
#     # Substract offset
#     print("subtracting offset")
    forward_work_offset = []
    for cycle in forward_work:
        forward_work_offset.append(np.array([val - cycle[0] for val in cycle[1:]]))
    forward_work_offset = np.array(forward_work_offset)

    reverse_work_offset = []
    for cycle in reverse_work:
        reverse_work_offset.append(np.array([val - cycle[0] for val in cycle[1:]]))
    reverse_work_offset = np.array(reverse_work_offset)

    # Plot work trajectories
    print("plotting work trajs")
    for cycle in forward_work_offset:
        x = [(i+1)*4e-4 for i in range(len(list(cycle)))]
        y = cycle
        plt.plot(x, y, color=sns.color_palette()[0])
    for cycle in reverse_work_offset:
        x = [(i+1)*4e-4 for i in range(len(list(cycle)))]
        y = -cycle
        plt.plot(x, y, color=sns.color_palette()[1])
    plt.xlabel("$t_{neq}$ (ns)")
    plt.ylabel("work (kT)")
    plt.title(f"{title} {phase}")
    plt.savefig(os.path.join(output_dir, f"{dir_num}_{phase}_work_traj.png"), dpi=500)
    print(f"saved to: {os.path.join(output_dir, f'{dir_num}_{phase}_work_traj.png')}")
    plt.clf()
    
    # Plot work distributions
    print("plotting work distrib")
    accumulated_forward = [cycle[-1] for cycle in forward_work_offset]
    accumulated_reverse = [-cycle[-1] for cycle in reverse_work_offset]
    sns.distplot(accumulated_forward)
    sns.distplot(accumulated_reverse)
    plt.axvline(dg)
    plt.axvline(dg + ddg, linestyle='dashed')
    plt.axvline(dg - ddg, linestyle='dashed')
    plt.xlabel("work (kT)")
    plt.ylabel("p(w)")
    plt.title(f"{title} {phase}")
    plt.savefig(os.path.join(output_dir, f"{dir_num}_{phase}_work_dist.png"), dpi=500)
    print(f"saved to: {os.path.join(output_dir, f'{dir_num}_{phase}_work_dist.png')}")
    plt.clf()

    return accumulated_forward

# %% [markdown]
# ## 15/98

# %%
# Load data into dicts and plot 
titles = ["N501Y"]
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
d_input = {}
dir_num = 15
forward = 98
for i in tqdm_notebook([forward]):
    print(f"dir: {i}")
    d_works = {"complex": {}, "apo":{}}
    d_combined_works = {"complex": {}, "apo":{}}
    for phase in phases:
        for direction in directions:
            all_arrays = []
            for j in range(100):
                path = f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{i}/{i}_{phase}_{j}_{direction}.npy"
                try:
                    if os.path.exists(path):
                        with open(path, 'rb') as f:
                            array = np.load(f)
                            if not np.isnan(np.sum(array)):
                                all_arrays.append(array)
                except:
                    continue
            print(len(all_arrays))
            if all_arrays:
                combined = np.concatenate(all_arrays)
                accumulated = np.array([cycle[-1] - cycle[0] for cycle in combined])
#                 combined = np.array([cycle[0::100] for cycle in combined])
                print(f"about to save: {phase} {direction}")
                d_combined_works[phase][direction] = combined
                d_works[phase][direction] = accumulated

    d_input[i] = d_works
    
    # Plot
    complex_dg, complex_ddg = analyze(d_works['complex']['forward'], d_works['complex']['reverse'])
    apo_dg, apo_ddg = analyze(d_works['apo']['forward'], d_works['apo']['reverse'])
    plot(d_combined_works['complex']['forward'], d_combined_works['complex']['reverse'], complex_dg, complex_ddg, i, 'complex', os.path.dirname(path), titles[i-forward])
    plot(d_combined_works['apo']['forward'], d_combined_works['apo']['reverse'], apo_dg, apo_ddg, i, 'apo', os.path.dirname(path), titles[i-forward])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# dir: 98
# 99
# about to save: complex forward
# 99
# about to save: complex reverse
# 100
# about to save: apo forward
# 100
# about to save: apo reverse
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/98/98_complex_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/98/98_complex_work_dist.png
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/98/98_apo_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/98/98_apo_work_dist.png

# %%
plt.hist(d_works['complex']['forward'])
plt.hist(d_works['complex']['reverse']*-1)
# Out:
# (array([ 6., 10., 12., 18., 22., 12.,  9.,  3.,  2.,  5.]),
#  array([ 72.60067787,  78.03079862,  83.46091937,  88.89104013,
#          94.32116088,  99.75128163, 105.18140238, 110.61152313,
#         116.04164389, 121.47176464, 126.90188539]),
#  <BarContainer object of 10 artists>)

# %%
# Bootstrap works
N_bootstraps = 10000
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
dgs_phase = {}
ddgs = {}
for i in [forward]:
    dgs_phase_all = []
    ddgs_all = []
    for _ in tqdm_notebook(range(N_bootstraps)):
        # Initialize data structure for works
        d_works = {"complex": {"forward":{}, "reverse":{}}, "apo":{"forward":{}, "reverse":{}}}

        # Save subsampled works
        for phase in phases:
            for direction in directions:
                work_array = np.array(d_input[i][phase][direction])
                num_samples = work_array.shape[0]
                subsample_indices = np.random.choice(range(num_samples), num_samples)
                d_works[phase][direction] = work_array[subsample_indices]
        d_dgs_phase, binding_dg = analyze_bootstrap(d_works)
        dgs_phase_all.append(d_dgs_phase)
        ddgs_all.append(binding_dg)
    dgs_phase[i] = dgs_phase_all
    ddgs[i] = ddgs_all
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
forward_ddg = np.mean(ddgs[forward])
forward_ci = np.percentile(ddgs[forward], 2.5), np.percentile(ddgs[forward], 97.5)
# reverse_ddg = np.mean(ddgs[reverse])
# reverse_ci = np.percentile(ddgs[reverse], 2.5), np.percentile(ddgs[reverse], 97.5)
# negative_reverse_ci = sorted(np.array(reverse_ci)*-1)
# discrepancy = tuple(np.array(forward_ci) - np.array(negative_reverse_ci))
# output_kt = [forward_ddg, forward_ci, reverse_ddg, reverse_ci, discrepancy]
# output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL]), round(reverse_ddg*KT_KCALMOL, 2), tuple([round(val, 2) for val in np.array(reverse_ci)*KT_KCALMOL]), tuple([round(val, 2) for val in np.array(discrepancy)*KT_KCALMOL])]

output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL])]

# %%
output_kcalmol
# Out:
# [5.41, (3.11, 7.34)]

# %%
# pd.DataFrame([output_kcalmol]).to_csv(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/analysis_{titles[0]}_{titles[1]}.csv")

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "wb") as f:
    pickle.dump(dgs_phase, f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "wb") as f:
    pickle.dump(ddgs, f)

# %%
# Plot ddgs
sns.distplot(np.array(ddgs[forward])*KT_KCALMOL, rug=True, label=titles[0])
# sns.distplot(np.array(ddgs[reverse])*-KT_KCALMOL, rug=True, label=f"-({titles[1]})")
plt.xlabel("binding ddg (kcal/mol)")
plt.legend()

# %% [markdown]
# ## 15/99

# %%
# Load data into dicts and plot 
titles = ["N501Y"]
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
d_input = {}
dir_num = 15
forward = 99
for i in tqdm_notebook([forward]):
    print(f"dir: {i}")
    d_works = {"complex": {}, "apo":{}}
    d_combined_works = {"complex": {}, "apo":{}}
    for phase in phases:
        for direction in directions:
            all_arrays = []
            for j in range(100):
                path = f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{i}/{i}_{phase}_{j}_{direction}.npy"
                try:
                    if os.path.exists(path):
                        with open(path, 'rb') as f:
                            array = np.load(f)
                            if not np.isnan(np.sum(array)):
                                all_arrays.append(array)
                except:
                    continue
            print(len(all_arrays))
            if all_arrays:
                combined = np.concatenate(all_arrays)
                accumulated = np.array([cycle[-1] - cycle[0] for cycle in combined])
#                 combined = np.array([cycle[0::100] for cycle in combined])
                print(f"about to save: {phase} {direction}")
                d_combined_works[phase][direction] = combined
                d_works[phase][direction] = accumulated

    d_input[i] = d_works
    
    # Plot
    complex_dg, complex_ddg = analyze(d_works['complex']['forward'], d_works['complex']['reverse'])
    apo_dg, apo_ddg = analyze(d_works['apo']['forward'], d_works['apo']['reverse'])
    plot(d_combined_works['complex']['forward'], d_combined_works['complex']['reverse'], complex_dg, complex_ddg, i, 'complex', os.path.dirname(path), titles[i-forward])
    plot(d_combined_works['apo']['forward'], d_combined_works['apo']['reverse'], apo_dg, apo_ddg, i, 'apo', os.path.dirname(path), titles[i-forward])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# dir: 99
# 100
# about to save: complex forward
# 100
# about to save: complex reverse
# 100
# about to save: apo forward
# 100
# about to save: apo reverse
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/99/99_complex_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/99/99_complex_work_dist.png
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/99/99_apo_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/99/99_apo_work_dist.png

# %%
plt.hist(d_works['complex']['forward'])
plt.hist(d_works['complex']['reverse']*-1)
# Out:
# (array([ 2.,  4.,  5., 14., 19., 10., 20., 15.,  8.,  3.]),
#  array([ 71.82556949,  76.9430034 ,  82.06043731,  87.17787122,
#          92.29530513,  97.41273904, 102.53017295, 107.64760686,
#         112.76504077, 117.88247467, 122.99990858]),
#  <BarContainer object of 10 artists>)

# %%
# Bootstrap works
N_bootstraps = 10000
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
dgs_phase = {}
ddgs = {}
for i in [forward]:
    dgs_phase_all = []
    ddgs_all = []
    for _ in tqdm_notebook(range(N_bootstraps)):
        # Initialize data structure for works
        d_works = {"complex": {"forward":{}, "reverse":{}}, "apo":{"forward":{}, "reverse":{}}}

        # Save subsampled works
        for phase in phases:
            for direction in directions:
                work_array = np.array(d_input[i][phase][direction])
                num_samples = work_array.shape[0]
                subsample_indices = np.random.choice(range(num_samples), num_samples)
                d_works[phase][direction] = work_array[subsample_indices]
        d_dgs_phase, binding_dg = analyze_bootstrap(d_works)
        dgs_phase_all.append(d_dgs_phase)
        ddgs_all.append(binding_dg)
    dgs_phase[i] = dgs_phase_all
    ddgs[i] = ddgs_all
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
forward_ddg = np.mean(ddgs[forward])
forward_ci = np.percentile(ddgs[forward], 2.5), np.percentile(ddgs[forward], 97.5)
# reverse_ddg = np.mean(ddgs[reverse])
# reverse_ci = np.percentile(ddgs[reverse], 2.5), np.percentile(ddgs[reverse], 97.5)
# negative_reverse_ci = sorted(np.array(reverse_ci)*-1)
# discrepancy = tuple(np.array(forward_ci) - np.array(negative_reverse_ci))
# output_kt = [forward_ddg, forward_ci, reverse_ddg, reverse_ci, discrepancy]
# output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL]), round(reverse_ddg*KT_KCALMOL, 2), tuple([round(val, 2) for val in np.array(reverse_ci)*KT_KCALMOL]), tuple([round(val, 2) for val in np.array(discrepancy)*KT_KCALMOL])]

output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL])]

# %%
output_kcalmol
# Out:
# [5.6, (3.24, 7.24)]

# %%
# pd.DataFrame([output_kcalmol]).to_csv(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/analysis_{titles[0]}_{titles[1]}.csv")

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "wb") as f:
    pickle.dump(dgs_phase, f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "wb") as f:
    pickle.dump(ddgs, f)

# %%
# Plot ddgs
sns.distplot(np.array(ddgs[forward])*KT_KCALMOL, rug=True, label=titles[0])
# sns.distplot(np.array(ddgs[reverse])*-KT_KCALMOL, rug=True, label=f"-({titles[1]})")
plt.xlabel("binding ddg (kcal/mol)")
plt.legend()

# %% [markdown]
# ## 15/100

# %%
# Load data into dicts and plot 
titles = ["D501Y"]
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
d_input = {}
dir_num = 15
forward = 100
for i in tqdm_notebook([forward]):
    print(f"dir: {i}")
    d_works = {"complex": {}, "apo":{}}
    d_combined_works = {"complex": {}, "apo":{}}
    for phase in phases:
        for direction in directions:
            all_arrays = []
            for j in range(100):
                path = f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{i}/{i}_{phase}_{j}_{direction}.npy"
                try:
                    if os.path.exists(path):
                        with open(path, 'rb') as f:
                            array = np.load(f)
                            if not np.isnan(np.sum(array)):
                                all_arrays.append(array)
                except:
                    continue
            print(len(all_arrays))
            if all_arrays:
                combined = np.concatenate(all_arrays)
                accumulated = np.array([cycle[-1] - cycle[0] for cycle in combined])
#                 combined = np.array([cycle[0::100] for cycle in combined])
                print(f"about to save: {phase} {direction}")
                d_combined_works[phase][direction] = combined
                d_works[phase][direction] = accumulated

    d_input[i] = d_works
    
    # Plot
    complex_dg, complex_ddg = analyze(d_works['complex']['forward'], d_works['complex']['reverse'])
    apo_dg, apo_ddg = analyze(d_works['apo']['forward'], d_works['apo']['reverse'])
    plot(d_combined_works['complex']['forward'], d_combined_works['complex']['reverse'], complex_dg, complex_ddg, i, 'complex', os.path.dirname(path), titles[i-forward])
    plot(d_combined_works['apo']['forward'], d_combined_works['apo']['reverse'], apo_dg, apo_ddg, i, 'apo', os.path.dirname(path), titles[i-forward])
    print("binding DDG: ", complex_dg*KT_KCALMOL - apo_dg*KT_KCALMOL, " (", ((apo_ddg**2 + complex_ddg**2)**0.5)*KT_KCALMOL, ")")
    print("complex DG: ", complex_dg*KT_KCALMOL, " (", complex_ddg*KT_KCALMOL,")")
    print("apo DG: ", apo_dg*KT_KCALMOL, " (", apo_ddg*KT_KCALMOL,")")
    
    complex_upper_dg, complex_upper_ddg, complex_lower_dg, complex_lower_ddg = bound_with_exp(d_works['complex']['forward'], d_works['complex']['reverse'])
    apo_upper_dg, apo_upper_ddg, apo_lower_dg, apo_lower_ddg = bound_with_exp(d_works['apo']['forward'], d_works['apo']['reverse'])
    print("binding DDG (upper): ", complex_upper_dg*KT_KCALMOL - apo_upper_dg*KT_KCALMOL, " (", ((apo_upper_ddg**2 + complex_upper_ddg**2)**0.5)*KT_KCALMOL, ")")
    print("complex DG: ", complex_upper_dg*KT_KCALMOL, " (", complex_upper_ddg*KT_KCALMOL,")")
    print("apo DG: ", apo_upper_dg*KT_KCALMOL, " (", apo_upper_ddg*KT_KCALMOL,")")
    print("binding DDG (lower): ", complex_lower_dg*-KT_KCALMOL - apo_lower_dg*-KT_KCALMOL, " (", ((apo_lower_ddg**2 + complex_lower_ddg**2)**0.5)*-KT_KCALMOL, ")")
    print("complex DG: ", complex_lower_dg*-KT_KCALMOL, " (", complex_lower_ddg*-KT_KCALMOL,")")
    print("apo DG: ", apo_lower_dg*-KT_KCALMOL, " (", apo_lower_ddg*-KT_KCALMOL,")")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# dir: 100
# 100
# about to save: complex forward
# 100
# about to save: complex reverse
# 100
# about to save: apo forward
# 100
# about to save: apo reverse
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/100/100_complex_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/100/100_complex_work_dist.png
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/100/100_apo_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/100/100_apo_work_dist.png
# binding DDG:  -8.17760476170172  ( 0.8618360665630025 )
# complex DG:  -24.41993650052538  ( 0.8278334518639207 )
# apo DG:  -16.242331738823662  ( 0.23969393318115884 )
# binding DDG (upper):  -7.1789876011262415  ( 0.7100229661974187 )
# complex DG:  -24.10968019251559  ( 0.5931157612869774 )
# apo DG:  -16.93069259138935  ( 0.39031564949505926 )
# binding DDG (lower):  -8.49015227642364  ( -0.6489093033472743 )
# complex DG:  -25.118473451875843  ( -0.5927710950479907 )
# apo DG:  -16.628321175452204  ( -0.2640183949012849 )

# %%
# Bound with EXP

# %%
complex_upper_dg, complex_upper_ddg,
# Out:
# (-40.44154006427378, 0.9948914556853273)

# %%
plt.hist(d_works['complex']['forward'])
plt.hist(d_works['complex']['reverse']*-1)
# Out:
# (array([ 4.,  8., 13., 18., 21., 18.,  9.,  7.,  1.,  1.]),
#  array([-90.16971121, -84.90565902, -79.64160683, -74.37755464,
#         -69.11350245, -63.84945026, -58.58539806, -53.32134587,
#         -48.05729368, -42.79324149, -37.5291893 ]),
#  <BarContainer object of 10 artists>)

# %%
# Bootstrap works
N_bootstraps = 10000
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
dgs_phase = {}
ddgs = {}
for i in [forward]:
    dgs_phase_all = []
    ddgs_all = []
    for _ in tqdm_notebook(range(N_bootstraps)):
        # Initialize data structure for works
        d_works = {"complex": {"forward":{}, "reverse":{}}, "apo":{"forward":{}, "reverse":{}}}

        # Save subsampled works
        for phase in phases:
            for direction in directions:
                work_array = np.array(d_input[i][phase][direction])
                num_samples = work_array.shape[0]
                subsample_indices = np.random.choice(range(num_samples), num_samples)
                d_works[phase][direction] = work_array[subsample_indices]
        d_dgs_phase, binding_dg = analyze_bootstrap(d_works)
        dgs_phase_all.append(d_dgs_phase)
        ddgs_all.append(binding_dg)
    dgs_phase[i] = dgs_phase_all
    ddgs[i] = ddgs_all
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
forward_ddg = np.mean(ddgs[forward])
forward_ci = np.percentile(ddgs[forward], 2.5), np.percentile(ddgs[forward], 97.5)
# reverse_ddg = np.mean(ddgs[reverse])
# reverse_ci = np.percentile(ddgs[reverse], 2.5), np.percentile(ddgs[reverse], 97.5)
# negative_reverse_ci = sorted(np.array(reverse_ci)*-1)
# discrepancy = tuple(np.array(forward_ci) - np.array(negative_reverse_ci))
# output_kt = [forward_ddg, forward_ci, reverse_ddg, reverse_ci, discrepancy]
# output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL]), round(reverse_ddg*KT_KCALMOL, 2), tuple([round(val, 2) for val in np.array(reverse_ci)*KT_KCALMOL]), tuple([round(val, 2) for val in np.array(discrepancy)*KT_KCALMOL])]

output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL])]

# %%
output_kcalmol
# Out:
# [-8.09, (-11.95, -4.32)]

# %%
# pd.DataFrame([output_kcalmol]).to_csv(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/analysis_{titles[0]}_{titles[1]}.csv")

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "wb") as f:
    pickle.dump(dgs_phase, f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "wb") as f:
    pickle.dump(ddgs, f)

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "rb") as f:
    dgs_phase = pickle.load(f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "rb") as f:
    ddgs = pickle.load(f)

# %%
# Plot ddgs
sns.distplot(np.array(ddgs[forward])*KT_KCALMOL, rug=True, label=titles[0])
# sns.distplot(np.array(ddgs[reverse])*-KT_KCALMOL, rug=True, label=f"-({titles[1]})")
plt.xlabel("binding ddg (kcal/mol)")
plt.legend()

# %%
np.std(np.array(ddgs[forward])*KT_KCALMOL)
# Out:
# 2.2677928138143346

# %%
dgs_phase[100]
# Out:
# [{'complex': (-37.52684049681961, 1.2154348772128662),
#   'apo': (-26.899197178783712, 0.3755128334865373)},
#  {'complex': (-43.50363830933394, 1.1071157870224537),
#   'apo': (-26.70241194844585, 0.389889230451633)},
#  {'complex': (-41.3523096152761, 1.404398805069801),
#   'apo': (-27.091825102116047, 0.37774387194334)},
#  {'complex': (-44.27081855480174, 1.0388339660637054),
#   'apo': (-26.66702800126189, 0.3755797554485731)},
#  {'complex': (-39.782883498009056, 0.7575957918884707),
#   'apo': (-26.91499597408786, 0.3459627910647482)},
#  {'complex': (-41.3459354542892, 1.4042231085515704),
#   'apo': (-28.197893733824127, 0.4754988111191073)},
#  {'complex': (-44.53996247966944, 0.8358919633421933),
#   'apo': (-28.46235302282063, 0.4939550279581089)},
#  {'complex': (-38.37498336799121, 1.0705532706479168),
#   'apo': (-26.27507031635537, 0.3804255368956422)},
#  {'complex': (-36.82804884225548, 1.2269398880624636),
#   'apo': (-27.083243454318904, 0.39979689383868683)},
#  {'complex': (-36.58777423346527, 1.394288014734834),
#   'apo': (-26.9484800581203, 0.4212194260548791)},
#  {'complex': (-37.09228449244718, 0.8408977467591193),
#   'apo': (-27.363978819532008, 0.3620861989492974)},
#  {'complex': (-37.39658472357311, 1.126542232003371),
#   'apo': (-28.114562157584615, 0.4241943937816228)},
#  {'complex': (-36.82034799080435, 1.2317396509502194),
#   'apo': (-26.941534178944124, 0.3783925511410745)},
#  {'complex': (-36.57591873966398, 1.4036474919824047),
#   'apo': (-27.034819164537247, 0.45920108674176285)},
#  {'complex': (-39.887329388697346, 1.2097538863417823),
#   'apo': (-26.396202079900732, 0.3774321214379987)},
#  {'complex': (-40.76608751023807, 1.3776062934935178),
#   'apo': (-28.422999488240443, 0.41670796405172555)},
#  {'complex': (-44.90341999711247, 1.3726530749328831),
#   'apo': (-28.207118921099394, 0.4354121507495531)},
#  {'complex': (-44.93241721138549, 1.3916808978935036),
#   'apo': (-28.460704834994207, 0.41490966735217455)},
#  {'complex': (-40.67039498247068, 1.3849303680159877),
#   'apo': (-27.819577940016853, 0.4006551656243254)},
#  {'complex': (-37.0622364364515, 1.2111088017437952),
#   'apo': (-27.29568823504171, 0.4217415749108822)},
#  {'complex': (-36.71655300813579, 1.2920421386431264),
#   'apo': (-26.381006049761833, 0.34374499815738735)},
#  {'complex': (-44.918879031576026, 1.38260276487604),
#   'apo': (-26.94904814375302, 0.3857674121292889)},
#  {'complex': (-37.62036909901103, 1.1792619823539634),
#   'apo': (-28.03433430605986, 0.5043162824949752)},
#  {'complex': (-39.38848846205192, 1.3460848011213755),
#   'apo': (-27.845334306458668, 0.4455624551914442)},
#  {'complex': (-44.20990063235398, 1.207917476373356),
#   'apo': (-27.248193801653844, 0.3629708353481603)},
#  {'complex': (-46.26862252216177, 1.0555719459012727),
#   'apo': (-27.034655654567995, 0.4289742923111971)},
#  {'complex': (-46.654564421135646, 1.067373605987049),
#   'apo': (-28.085724875516696, 0.39469602470571724)},
#  {'complex': (-45.580255643995166, 1.1433966841639804),
#   'apo': (-27.912365227054828, 0.39679046844506005)},
#  {'complex': (-45.59718213673191, 1.1549955787700645),
#   'apo': (-26.22861433448302, 0.3778937623185135)},
#  {'complex': (-40.859521872232264, 1.3697516995754555),
#   'apo': (-28.3901764469685, 0.4097544741659494)},
#  {'complex': (-44.210786727830715, 1.2086444127157083),
#   'apo': (-27.317794839220603, 0.31342282921363007)},
#  {'complex': (-37.53173846292139, 1.2142280788554054),
#   'apo': (-26.99820351865557, 0.3607465303478675)},
#  {'complex': (-36.57838734824932, 1.4011304202813915),
#   'apo': (-27.111411651624593, 0.42713341257804494)},
#  {'complex': (-43.78589856435134, 1.1390557631285068),
#   'apo': (-26.605055008244864, 0.340217525737482)},
#  {'complex': (-45.62221374328022, 1.1728275890653954),
#   'apo': (-27.37876026551879, 0.4168868703190672)},
#  {'complex': (-37.06055030814272, 1.2146742220814877),
#   'apo': (-27.909360651954376, 0.4217309871357298)},
#  {'complex': (-37.80218120764456, 1.1273145626780638),
#   'apo': (-27.949547124186267, 0.4088364639053856)},
#  {'complex': (-42.00161138900185, 0.8555520882037284),
#   'apo': (-26.95151010695085, 0.3787839423545218)},
#  {'complex': (-46.298460301790946, 1.0536150628030339),
#   'apo': (-27.250560695440768, 0.4080510124066783)},
#  {'complex': (-36.59515993781305, 1.3844722390129118),
#   'apo': (-26.470471973517153, 0.42617336974945863)},
#  {'complex': (-37.347514942644125, 0.9357858633761802),
#   'apo': (-26.42718419928937, 0.3416639404709765)},
#  {'complex': (-36.11263606207846, 1.203514449425836),
#   'apo': (-26.242549066417922, 0.3598252723917267)},
#  {'complex': (-38.015605721827676, 0.7019696539070076),
#   'apo': (-27.36278036716264, 0.45774096100220846)},
#  {'complex': (-40.95915554910958, 1.3885618023036355),
#   'apo': (-28.38110026140455, 0.3797033352360699)},
#  {'complex': (-36.725630717846656, 1.2875079540305943),
#   'apo': (-27.046186084915732, 0.4136718377582771)},
#  {'complex': (-36.37465494728121, 0.8482176732664508),
#   'apo': (-27.227689900317262, 0.42594200566210344)},
#  {'complex': (-44.885720692506325, 1.3625448434691119),
#   'apo': (-26.940084601311263, 0.340009252125918)},
#  {'complex': (-46.68669375472852, 1.0980839127833357),
#   'apo': (-26.560122474437335, 0.3990561000622865)},
#  {'complex': (-41.44803270970559, 1.3987550731539167),
#   'apo': (-26.321619261259265, 0.37707239268809883)},
#  {'complex': (-38.032727448868506, 1.0655408560896826),
#   'apo': (-28.07067994749574, 0.38956486245045036)},
#  {'complex': (-44.20774256344725, 1.207413250828633),
#   'apo': (-27.23813618996956, 0.3835561033258894)},
#  {'complex': (-40.57779995468135, 1.3733110824601453),
#   'apo': (-26.925271229514866, 0.4244254349225025)},
#  {'complex': (-45.62500149161751, 1.174916086327168),
#   'apo': (-27.805104998511247, 0.47627538817022225)},
#  {'complex': (-46.681415974950646, 1.0955671277039667),
#   'apo': (-27.86559218629856, 0.41830776020836113)},
#  {'complex': (-36.522878584139725, 1.0509335764394174),
#   'apo': (-27.481415679284115, 0.38695090325436055)},
#  {'complex': (-41.363733725666094, 0.9878151136935739),
#   'apo': (-27.43068613104277, 0.3767021673259065)},
#  {'complex': (-40.37943276866939, 1.2245124750675056),
#   'apo': (-27.659787345330447, 0.4284822168210946)},
#  {'complex': (-45.60303280752981, 1.159134607723788),
#   'apo': (-27.43603819358776, 0.4605019128882003)},
#  {'complex': (-44.99847134501466, 1.1965335419451237),
#   'apo': (-27.935907893819174, 0.4109944956190586)},
#  {'complex': (-37.18647227271556, 0.988717571752582),
#   'apo': (-26.799188191685385, 0.39327117388833155)},
#  {'complex': (-37.181489110018674, 0.9903984460810821),
#   'apo': (-27.37776897562777, 0.3596029586898713)},
#  {'complex': (-35.729335957157375, 1.3643141752378074),
#   'apo': (-27.04418533919734, 0.39355046298548807)},
#  {'complex': (-40.24114855766906, 1.3917956368324855),
#   'apo': (-27.560497112808946, 0.40037806865425185)},
#  {'complex': (-37.103631388758416, 1.0236516302989302),
#   'apo': (-25.980583489573263, 0.348667824780253)},
#  {'complex': (-39.52177930312659, 0.7344203117829212),
#   'apo': (-26.91943214503258, 0.412972428832843)},
#  {'complex': (-35.74202055396944, 0.9503773297521241),
#   'apo': (-26.75252295932242, 0.392857629054016)},
#  {'complex': (-37.8402176053436, 1.111503619813579),
#   'apo': (-27.20250908287221, 0.47686169600087347)},
#  {'complex': (-41.37101549068046, 1.4027322394526474),
#   'apo': (-27.074755570553286, 0.37766764811283327)},
#  {'complex': (-40.6313039309831, 1.1792546839399258),
#   'apo': (-27.205751109677472, 0.3724996133191022)},
#  {'complex': (-41.33467152826878, 0.9887195550243946),
#   'apo': (-27.2144554829988, 0.3381448412220336)},
#  {'complex': (-46.88319255904492, 0.787304617586628),
#   'apo': (-26.496744222920498, 0.38603196641419674)},
#  {'complex': (-44.98500517022586, 0.8367031426436493),
#   'apo': (-26.516738788407054, 0.3740759597765155)},
#  {'complex': (-36.7218713532499, 1.290409931520185),
#   'apo': (-27.783966840826093, 0.4157451332672677)},
#  {'complex': (-45.34784265799137, 0.8853482336743977),
#   'apo': (-27.690091979208436, 0.4190825617354757)},
#  {'complex': (-43.85177641296022, 0.9813270948761149),
#   'apo': (-26.86335861169737, 0.4115021532221979)},
#  {'complex': (-40.806445501727765, 1.374296689708038),
#   'apo': (-28.186536358822277, 0.33918408374186854)},
#  {'complex': (-45.600748299715015, 1.07153381071753),
#   'apo': (-27.35709507159982, 0.5105324478641733)},
#  {'complex': (-36.2560171891098, 1.0687992509507025),
#   'apo': (-26.65745850015521, 0.39478838801088506)},
#  {'complex': (-37.748525251584056, 1.1396586424640887),
#   'apo': (-27.00132680722614, 0.3590471903299929)},
#  {'complex': (-44.94790068105284, 0.9862446051659417),
#   'apo': (-27.02036028263259, 0.4211438622990238)},
#  {'complex': (-36.6558930538046, 0.9405367587479189),
#   'apo': (-28.377758256896016, 0.39672351225374064)},
#  {'complex': (-39.0003405894909, 1.205716026741922),
#   'apo': (-27.302918709244935, 0.34648015997881165)},
#  {'complex': (-42.49367641222477, 0.7799763341761212),
#   'apo': (-27.515426866935446, 0.3895324736056459)},
#  {'complex': (-36.8279590470777, 1.2245427214514844),
#   'apo': (-27.074225984769598, 0.40943781893038)},
#  {'complex': (-37.74272523325077, 1.1415929706781225),
#   'apo': (-26.20752750324914, 0.39807048982744775)},
#  {'complex': (-45.63054428769076, 1.178923101940303),
#   'apo': (-26.82973645386049, 0.35445139822086397)},
#  {'complex': (-44.90185345251859, 1.3724242113710015),
#   'apo': (-26.171739214919572, 0.3630725264931591)},
#  {'complex': (-37.12744004653766, 1.182365687808818),
#   'apo': (-27.125584892020267, 0.35928714985048504)},
#  {'complex': (-40.8904888221356, 1.3929031627432937),
#   'apo': (-26.425196253277562, 0.3928862955268242)},
#  {'complex': (-37.929795972515315, 1.089770949143337),
#   'apo': (-26.857295409637164, 0.38452566141931654)},
#  {'complex': (-44.2005003461775, 1.204692554941281),
#   'apo': (-26.653494994923033, 0.39312627214074075)},
#  {'complex': (-33.872770910650736, 1.2820131874446754),
#   'apo': (-27.839672989163024, 0.466994040350899)},
#  {'complex': (-46.70786011363667, 0.981492021069101),
#   'apo': (-26.84979063015752, 0.34519493630998815)},
#  {'complex': (-44.92334583722662, 1.3855593229752217),
#   'apo': (-26.66988093830626, 0.3842968704300908)},
#  {'complex': (-41.27831038294076, 1.405923061263853),
#   'apo': (-26.95617831513716, 0.36021427299463676)},
#  {'complex': (-43.84370506902844, 0.9798719181808252),
#   'apo': (-28.106718218216873, 0.3839429270355981)},
#  {'complex': (-46.59493567360132, 1.0941568430173618),
#   'apo': (-27.914358324298473, 0.49823389675883545)},
#  {'complex': (-43.53096275275094, 0.9477522598302743),
#   'apo': (-27.421279502969757, 0.37229966414649185)},
#  {'complex': (-37.77586000092301, 1.1318481528273237),
#   'apo': (-27.259288917521857, 0.38987205869254477)},
#  {'complex': (-44.2237524628548, 1.2135574229254957),
#   'apo': (-28.286667937299978, 0.41137844519521405)},
#  {'complex': (-43.80233464673722, 1.1439587992882618),
#   'apo': (-27.947037748762796, 0.5050939904391472)},
#  {'complex': (-45.59787755487315, 1.155391141692405),
#   'apo': (-26.96170455068437, 0.38023358602081075)},
#  {'complex': (-44.91087745577794, 0.9693551158551338),
#   'apo': (-27.442889543507285, 0.40495857905856636)},
#  {'complex': (-47.56220890564026, 0.8932071614635286),
#   'apo': (-26.731526907222797, 0.5494663474750592)},
#  {'complex': (-44.33257258926115, 0.8974192440372549),
#   'apo': (-27.8239395699437, 0.4629054100168576)},
#  {'complex': (-35.72832892097985, 1.3668697214468108),
#   'apo': (-27.139597247400168, 0.4096549620170752)},
#  {'complex': (-40.2424669736922, 1.3804580713547303),
#   'apo': (-27.916513586960264, 0.4126437216628917)},
#  {'complex': (-46.118311003469564, 1.03325609882348),
#   'apo': (-28.860678781071826, 0.47827948818759314)},
#  {'complex': (-43.79603656544304, 1.1422296331017967),
#   'apo': (-28.990962457820583, 0.47289485391482255)},
#  {'complex': (-42.69805451784866, 0.731087375666984),
#   'apo': (-27.222786201158517, 0.40053784979539264)},
#  {'complex': (-37.95410581092646, 1.0833591864360614),
#   'apo': (-26.417395915224343, 0.3890008932379652)},
#  {'complex': (-37.5297296815092, 1.2158553452039265),
#   'apo': (-27.57850605806041, 0.413348965674723)},
#  {'complex': (-43.90191788915335, 0.8442928023089391),
#   'apo': (-27.108469028762627, 0.42480332250914477)},
#  {'complex': (-43.89281874550713, 0.8431392243821043),
#   'apo': (-26.67864314028746, 0.4075068080472965)},
#  {'complex': (-36.38345140142913, 0.8427056070176148),
#   'apo': (-27.64001091049212, 0.49915104452952186)},
#  {'complex': (-40.955975071284065, 1.3894944117931693),
#   'apo': (-27.26107774252352, 0.4018507191034723)},
#  {'complex': (-37.7768533350484, 1.1306664393374235),
#   'apo': (-26.90794579664225, 0.37492742124548983)},
#  {'complex': (-44.8783682290419, 1.3576084825509216),
#   'apo': (-27.341743531192524, 0.36333581600275294)},
#  {'complex': (-37.80739137864336, 1.1204149667685128),
#   'apo': (-27.578426064132, 0.400442795892963)},
#  {'complex': (-36.45847811162452, 0.9406983961704437),
#   'apo': (-27.82836840141514, 0.4529578021556262)},
#  {'complex': (-40.9553853346994, 1.3895214561206737),
#   'apo': (-27.908975002898337, 0.3960364304941797)},
#  {'complex': (-44.934970705290525, 0.9802739591343408),
#   'apo': (-27.39826915033443, 0.417073315325881)},
#  {'complex': (-39.38041620452895, 0.9601590472791093),
#   'apo': (-26.467341730293608, 0.38565290225918836)},
#  {'complex': (-40.79564608916976, 1.3750488594931132),
#   'apo': (-26.733273222900728, 0.344282859470538)},
#  {'complex': (-45.96401360072576, 1.0405760109390847),
#   'apo': (-28.289816952996667, 0.39853602366782215)},
#  {'complex': (-44.88480271344813, 1.361652138186269),
#   'apo': (-27.143460873309255, 0.3530975029928885)},
#  {'complex': (-40.99384275326724, 0.798189808039585),
#   'apo': (-26.864943325952318, 0.32233573959213135)},
#  {'complex': (-41.01435963287338, 1.3854552005631546),
#   'apo': (-26.676679273005174, 0.4364020689553796)},
#  {'complex': (-37.90305092435883, 1.096111816263658),
#   'apo': (-27.668158900213577, 0.4079394446755587)},
#  {'complex': (-40.969581440934896, 1.3877493937020116),
#   'apo': (-27.515292296800617, 0.36947940653817196)},
#  {'complex': (-35.74948882549439, 1.3440163572518065),
#   'apo': (-28.070744575576413, 0.4478166207032147)},
#  {'complex': (-44.996891076944195, 1.1962181049586098),
#   'apo': (-28.39898872754105, 0.43032947955274503)},
#  {'complex': (-41.463857926061024, 1.4002124212754368),
#   'apo': (-28.174576355979326, 0.5039762955028767)},
#  {'complex': (-41.27563366403409, 1.406615268694974),
#   'apo': (-27.476904856599543, 0.37910987800467427)},
#  {'complex': (-44.287842811478285, 0.8894840236676164),
#   'apo': (-27.530839368331314, 0.45940348395782227)},
#  {'complex': (-36.2520247286384, 1.072844016060879),
#   'apo': (-27.523271626105583, 0.42157280715981205)},
#  {'complex': (-44.58337214496316, 0.7693462200499966),
#   'apo': (-27.865491433985618, 0.42750009130649874)},
#  {'complex': (-40.96531142302756, 1.3886932946007795),
#   'apo': (-26.967757507457804, 0.3995198659569417)},
#  {'complex': (-41.11872894387741, 0.9819363703001771),
#   'apo': (-27.740782591019173, 0.41159841479839565)},
#  {'complex': (-40.57965141456065, 1.1956744385644331),
#   'apo': (-27.163534872926775, 0.3792469096035659)},
#  {'complex': (-40.87804130602362, 1.3936952682446098),
#   'apo': (-26.742626263070736, 0.35046662599858386)},
#  {'complex': (-45.543129767348134, 1.118303261481781),
#   'apo': (-26.676209034821063, 0.38989689412975387)},
#  {'complex': (-35.815022926623726, 1.1339028226777415),
#   'apo': (-27.55643946569522, 0.4606094945023245)},
#  {'complex': (-40.8310505108208, 0.9738803284495482),
#   'apo': (-26.794487098548558, 0.42164442523186363)},
#  {'complex': (-41.09560894939655, 0.9826975464747866),
#   'apo': (-26.925475337830044, 0.39520748947088935)},
#  {'complex': (-37.7457267688176, 1.1405964311883554),
#   'apo': (-27.556182663140962, 0.36770918663187746)},
#  {'complex': (-41.3161953441027, 0.9888363201371653),
#   'apo': (-26.365214432020853, 0.39805068998620186)},
#  {'complex': (-41.07096249555491, 0.9834523726962962),
#   'apo': (-26.404633702591692, 0.3717477128460087)},
#  {'complex': (-44.97751008478301, 0.9186975831623587),
#   'apo': (-27.18615011574715, 0.41878765492893677)},
#  {'complex': (-42.41444799956942, 0.7670244342573692),
#   'apo': (-27.325528626868923, 0.41291940124428805)},
#  {'complex': (-40.67521698963709, 1.3850183887683247),
#   'apo': (-29.182143206479147, 0.39559679683452886)},
#  {'complex': (-39.901443446139155, 0.8745856208801546),
#   'apo': (-26.975818125896506, 0.3999404612177189)},
#  {'complex': (-37.52947477028213, 1.2159493049868895),
#   'apo': (-27.905875262527058, 0.42240519274164173)},
#  {'complex': (-46.32945518681591, 1.0509248930698107),
#   'apo': (-27.78760938421341, 0.3843025924963365)},
#  {'complex': (-37.18556335430588, 1.156901353484005),
#   'apo': (-27.857995001453865, 0.5212817927455483)},
#  {'complex': (-35.826878631138634, 1.120200117568277),
#   'apo': (-26.86712867010926, 0.4392096590852742)},
#  {'complex': (-44.20451909878646, 1.2065967355132285),
#   'apo': (-27.024741039968237, 0.3422523640375121)},
#  {'complex': (-44.51390017426081, 0.8960038406641755),
#   'apo': (-26.42358283204827, 0.37896364449611397)},
#  {'complex': (-47.40278202575742, 1.202686790798917),
#   'apo': (-28.06014801026954, 0.48023109955571586)},
#  {'complex': (-37.348107598945475, 1.1446735084226243),
#   'apo': (-27.293329540112396, 0.3708442789676992)},
#  {'complex': (-40.23989030252385, 0.7988178682101633),
#   'apo': (-27.041902525208126, 0.33956650358002727)},
#  {'complex': (-44.19750619387625, 1.20395972819337),
#   'apo': (-26.07326025750905, 0.3587555208314335)},
#  {'complex': (-41.368863646533, 1.402707589506049),
#   'apo': (-27.862283144794457, 0.40165774381160024)},
#  {'complex': (-40.882908324367286, 1.3939012224485605),
#   'apo': (-26.666475094675718, 0.4976505551114143)},
#  {'complex': (-36.59085298717226, 1.391213532544138),
#   'apo': (-27.819298096224443, 0.3720392303437675)},
#  {'complex': (-34.32547595203308, 0.8674441933006203),
#   'apo': (-26.47243119206645, 0.3932256172960098)},
#  {'complex': (-41.41831976224335, 1.401038650064232),
#   'apo': (-27.582792984809625, 0.48496810384220645)},
#  {'complex': (-40.82605291623516, 1.3727818613313467),
#   'apo': (-27.290037821662395, 0.4195767666107067)},
#  {'complex': (-43.54519447646461, 0.949277099268783),
#   'apo': (-27.122806773430238, 0.4049197985536326)},
#  {'complex': (-43.82895133647175, 0.9775912180950317),
#   'apo': (-27.067765765604065, 0.43060298969019073)},
#  {'complex': (-47.48295844880653, 0.6793416652976689),
#   'apo': (-26.991268410043435, 0.33549388954382064)},
#  {'complex': (-44.994641593301374, 1.1953314066968326),
#   'apo': (-27.293056709519497, 0.38779576862061393)},
#  {'complex': (-41.41632454160046, 1.401705370540973),
#   'apo': (-27.772955499091786, 0.401142494694565)},
#  {'complex': (-44.93518389070907, 0.7962825234251303),
#   'apo': (-27.26878411551149, 0.3837785799889608)},
#  {'complex': (-40.959126715925464, 0.9771394079431318),
#   'apo': (-27.222263871717207, 0.36156535634459425)},
#  {'complex': (-34.23299068959267, 1.2820514353141537),
#   'apo': (-27.55731042503638, 0.4091929945647577)},
#  {'complex': (-40.95280825115336, 1.3892951235525228),
#   'apo': (-26.363287748336887, 0.3276154948056627)},
#  {'complex': (-47.28081559959073, 1.118700582676183),
#   'apo': (-26.86845983661169, 0.398066132174031)},
#  {'complex': (-41.43202243696396, 1.400866354724163),
#   'apo': (-27.896964927873757, 0.40449734594342085)},
#  {'complex': (-39.37054142834221, 0.7890651155860262),
#   'apo': (-26.314133700041122, 0.36366947874383077)},
#  {'complex': (-43.803125053494355, 1.143407649216921),
#   'apo': (-27.6752601858331, 0.33962134810950645)},
#  {'complex': (-40.60724395708602, 1.1417556942526188),
#   'apo': (-26.63683962870945, 0.38710742177185853)},
#  {'complex': (-45.56589095901744, 1.133444670166449),
#   'apo': (-27.376448915173444, 0.46520161770367124)},
#  {'complex': (-35.980430370033574, 0.9825616668155375),
#   'apo': (-27.74103431682309, 0.4169179369556592)},
#  {'complex': (-40.88002005615275, 1.3938580691624678),
#   'apo': (-26.80005822433113, 0.42578741868131675)},
#  {'complex': (-46.64064138362174, 1.0875204831953336),
#   'apo': (-27.75592714579484, 0.4439291369376201)},
#  {'complex': (-41.937854113029445, 0.9377506952017631),
#   'apo': (-27.160333895768208, 0.4149769917053894)},
#  {'complex': (-36.1127178620259, 1.1926886853477954),
#   'apo': (-27.11516582174569, 0.371464414365198)},
#  {'complex': (-37.391170828376296, 1.1299142598844396),
#   'apo': (-26.519819671802892, 0.34555986466963123)},
#  {'complex': (-42.05989446613734, 0.8355225009726428),
#   'apo': (-26.55006174078723, 0.34353389026744213)},
#  {'complex': (-44.99028230668039, 1.1935279996349448),
#   'apo': (-27.45122033216606, 0.3616737751546498)},
#  {'complex': (-40.88902299641323, 1.392901819380217),
#   'apo': (-27.16580160524848, 0.3766611537426811)},
#  {'complex': (-41.11473837016337, 0.800906226818431),
#   'apo': (-27.765756102261896, 0.3954428212106122)},
#  {'complex': (-37.95338979491494, 1.0817245588771631),
#   'apo': (-26.822478536611438, 0.43717026500119716)},
#  {'complex': (-36.114745510548005, 1.1914102956057726),
#   'apo': (-27.731346130279015, 0.3947658261683895)},
#  {'complex': (-38.05405087229836, 1.0604683345831774),
#   'apo': (-27.855267707932292, 0.47469850528751534)},
#  {'complex': (-40.98694548896487, 1.3873135655112392),
#   'apo': (-26.536727767320567, 0.3797435908757429)},
#  {'complex': (-37.15015417629682, 1.003945762276301),
#   'apo': (-27.548352255950086, 0.379618700488289)},
#  {'complex': (-44.278003021040064, 1.0404456586246016),
#   'apo': (-27.631589372232593, 0.4151143941541809)},
#  {'complex': (-38.02407362790698, 0.862764425322099),
#   'apo': (-28.99180311488269, 0.3939729449509252)},
#  {'complex': (-41.29166383750322, 1.4063063147991977),
#   'apo': (-26.257833454376513, 0.3812327817331204)},
#  {'complex': (-37.74390669734448, 1.1411945211023862),
#   'apo': (-27.68381746160169, 0.42300673553533397)},
#  {'complex': (-47.626280018873054, 0.7243921488519501),
#   'apo': (-27.98548456406826, 0.469632392949071)},
#  {'complex': (-44.27885458743614, 1.0407051732043286),
#   'apo': (-27.48617462724097, 0.4570188886452824)},
#  {'complex': (-37.905937131015605, 1.0962133797033806),
#   'apo': (-27.282058116229194, 0.4447706945703509)},
#  {'complex': (-36.584256618228345, 1.3977489095207312),
#   'apo': (-27.84357978260611, 0.40342463255696925)},
#  {'complex': (-43.8463875273943, 0.9802977995665214),
#   'apo': (-27.52664945382907, 0.4335774503908823)},
#  {'complex': (-44.96784013429345, 0.9154391709359667),
#   'apo': (-28.066846894536535, 0.43502844296346915)},
#  {'complex': (-44.8930455426371, 1.366806912829255),
#   'apo': (-27.630223438490344, 0.3448575008443082)},
#  {'complex': (-44.93062553365396, 1.390493977224348),
#   'apo': (-28.104500161317183, 0.5097311301545593)},
#  {'complex': (-42.45451405971218, 1.0717172497884395),
#   'apo': (-27.734904488532166, 0.47723893833101294)},
#  {'complex': (-34.34639221991658, 1.1977824051925539),
#   'apo': (-27.5747771973614, 0.38784486628443704)},
#  {'complex': (-40.95614814719141, 0.9770879517672675),
#   'apo': (-27.009910469934937, 0.35573502475609087)},
#  {'complex': (-39.84189213052069, 0.9367522525561082),
#   'apo': (-26.76062315549465, 0.40824863489671465)},
#  {'complex': (-40.92239097525654, 1.3904395670704663),
#   'apo': (-27.286294261511394, 0.4030206245882712)},
#  {'complex': (-41.27975746948195, 1.4068031118397804),
#   'apo': (-26.889131191659683, 0.40337607954371574)},
#  {'complex': (-37.92793214216331, 1.0884636575048043),
#   'apo': (-26.120012707857914, 0.3552887395396025)},
#  {'complex': (-41.2810224180273, 0.9894529745365371),
#   'apo': (-27.096877482010168, 0.4287954731089984)},
#  {'complex': (-36.83301632604559, 1.2226685677786928),
#   'apo': (-26.454957250751423, 0.4060568981760915)},
#  {'complex': (-37.99391669631987, 0.8367186991921018),
#   'apo': (-27.297666411392814, 0.33926583024647566)},
#  {'complex': (-46.63937189922557, 0.7638417970672171),
#   'apo': (-26.192556838224192, 0.4362974531506259)},
#  {'complex': (-44.9385785852969, 0.9820201858209082),
#   'apo': (-26.979482592217042, 0.4249609151151756)},
#  {'complex': (-40.8184759576658, 1.1138663551072403),
#   'apo': (-26.57018566771964, 0.3987350840379714)},
#  {'complex': (-37.838782246741964, 1.1127882922827588),
#   'apo': (-26.779644737125423, 0.4923312515881197)},
#  {'complex': (-34.79751545337091, 1.0126479597995692),
#   'apo': (-27.002729428073856, 0.36852363981594904)},
#  {'complex': (-40.44805169288206, 0.7574829581401392),
#   'apo': (-28.141986760776703, 0.5547188964881312)},
#  {'complex': (-37.7743848584684, 1.131446646290376),
#   'apo': (-27.02388037686001, 0.38328200068178697)},
#  {'complex': (-37.10317983110782, 1.0238439124916376),
#   'apo': (-27.71968899290661, 0.3914165270790637)},
#  {'complex': (-36.729033907408336, 1.283743304226282),
#   'apo': (-28.2947727214158, 0.38047674662330394)},
#  {'complex': (-37.193555108414614, 1.1533776103690851),
#   'apo': (-26.866891131823426, 0.36939840425034776)},
#  {'complex': (-36.580899293853996, 1.4011511932474205),
#   'apo': (-26.556932324501716, 0.3676120954248912)},
#  {'complex': (-44.91923028843015, 0.9730092435584817),
#   'apo': (-26.84970216186888, 0.382216876107158)},
#  {'complex': (-41.46171826708796, 1.4001212879521816),
#   'apo': (-26.071954091604344, 0.42215534982072694)},
#  {'complex': (-40.27529339964261, 0.9367378167717821),
#   'apo': (-27.612191305654402, 0.3837742083918436)},
#  {'complex': (-40.00246960128511, 0.7954199102672346),
#   'apo': (-26.692686904926862, 0.37407888297982095)},
#  {'complex': (-37.92749255728618, 1.0894815301784073),
#   'apo': (-26.986838047499027, 0.3743529394560569)},
#  {'complex': (-44.95933486847844, 0.6691124194521839),
#   'apo': (-27.684395537176087, 0.43358782231272186)},
#  {'complex': (-44.20096924265487, 1.2051977929249673),
#   'apo': (-27.170735707565566, 0.37576330519590245)},
#  {'complex': (-44.20544481756557, 1.2068880415323193),
#   'apo': (-26.96359093304224, 0.38397803691063676)},
#  {'complex': (-45.51565411503713, 1.1009185814571487),
#   'apo': (-27.616581512980435, 0.4643045378670788)},
#  {'complex': (-40.88283207840394, 0.980589878977671),
#   'apo': (-27.14327810553416, 0.4142681596377527)},
#  {'complex': (-40.875188346989724, 1.3936006932104836),
#   'apo': (-26.671699116092718, 0.4604404415729727)},
#  {'complex': (-40.50454326558598, 1.380181282752181),
#   'apo': (-27.15213366418253, 0.3670910347627358)},
#  {'complex': (-39.96785190334233, 1.0933782990212617),
#   'apo': (-27.708440910661107, 0.3991316194660823)},
#  {'complex': (-44.959168620705896, 1.1819152805601574),
#   'apo': (-26.084063994565515, 0.38423748349482695)},
#  {'complex': (-42.05988295549548, 1.0151152159793013),
#   'apo': (-26.84196044238427, 0.3661878313817018)},
#  {'complex': (-44.841255872031425, 1.3359905898066313),
#   'apo': (-28.242349337644175, 0.4864494300521957)},
#  {'complex': (-37.24195785583045, 1.13491337816013),
#   'apo': (-26.901032550007667, 0.4144097038745659)},
#  {'complex': (-40.53540320814471, 1.0974415539717606),
#   'apo': (-27.38291691338034, 0.4116559609932106)},
#  {'complex': (-41.28039311077938, 1.4059841611942614),
#   'apo': (-28.054754824967837, 0.3632995719596573)},
#  {'complex': (-44.92113446878571, 0.9737837516212915),
#   'apo': (-27.989113383648178, 0.42394647282929426)},
#  {'complex': (-40.950908474034186, 1.389279190954877),
#   'apo': (-27.813140156410213, 0.4969438382314781)},
#  {'complex': (-36.846347385321344, 1.1394235070729852),
#   'apo': (-27.84186806802451, 0.38352803677303626)},
#  {'complex': (-40.37660805300508, 1.2200528872126963),
#   'apo': (-27.154620620032745, 0.364213186589842)},
#  {'complex': (-46.04029963819961, 1.0967787745856745),
#   'apo': (-28.375617110946422, 0.4052633304575153)},
#  {'complex': (-36.57930403546239, 1.4027488370672074),
#   'apo': (-28.0133569160725, 0.46757408415958357)},
#  {'complex': (-40.61870129750787, 1.1589339584017588),
#   'apo': (-27.28822896164142, 0.3987388399708805)},
#  {'complex': (-44.221780007336605, 0.8520005376026553),
#   'apo': (-26.911052357777315, 0.4262164126554983)},
#  {'complex': (-34.328413143109266, 1.2327846795870983),
#   'apo': (-27.625268155070742, 0.39689302453811254)},
#  {'complex': (-44.21433697162245, 1.2099349368829615),
#   'apo': (-27.670697143675397, 0.38668849256631754)},
#  {'complex': (-37.14890812351661, 1.0041026461619518),
#   'apo': (-27.932611879592976, 0.410114260673923)},
#  {'complex': (-45.626714084211464, 1.1759911059480248),
#   'apo': (-28.716496546328706, 0.36573105729666283)},
#  {'complex': (-46.71982225010289, 1.1086474891886309),
#   'apo': (-28.19443541800764, 0.4118386567119745)},
#  {'complex': (-34.48107625976027, 1.1567632804557422),
#   'apo': (-27.553000491365022, 0.4119994776000894)},
#  {'complex': (-46.0156546795768, 1.0785522691634246),
#   'apo': (-27.38264043346935, 0.41285717434295544)},
#  {'complex': (-41.4014236300365, 1.401875335206692),
#   'apo': (-27.73479116271005, 0.43702132612107325)},
#  {'complex': (-40.89329647067691, 1.3930681536975031),
#   'apo': (-26.142572709869825, 0.42712931239187235)},
#  {'complex': (-38.63336016934702, 0.7492067388077028),
#   'apo': (-27.525373614274095, 0.39760396821695193)},
#  {'complex': (-40.037989026768784, 0.895120513779004),
#   'apo': (-26.99500427958679, 0.369427756219426)},
#  {'complex': (-36.585522413473264, 0.9824292804521465),
#   'apo': (-26.183089141554948, 0.49746987040807683)},
#  {'complex': (-44.21639927085115, 1.2111076338708104),
#   'apo': (-27.596881953814652, 0.4958505532453963)},
#  {'complex': (-37.57518720920293, 1.1970732861043623),
#   'apo': (-27.936461452680923, 0.4620185903890504)},
#  {'complex': (-40.88137348028622, 1.3938617128348318),
#   'apo': (-27.288826054926155, 0.46410769218891607)},
#  {'complex': (-44.98612915382061, 1.1921543634390728),
#   'apo': (-26.88872556218148, 0.42759362333395984)},
#  {'complex': (-36.83763507842414, 1.2210623845665216),
#   'apo': (-26.772087165647534, 0.35541063397234174)},
#  {'complex': (-43.89114926061438, 0.8429275341496413),
#   'apo': (-27.419824514019247, 0.3476598777600754)},
#  {'complex': (-37.52973248155424, 1.2150703104342944),
#   'apo': (-27.5975650068647, 0.4038659051933379)},
#  {'complex': (-43.8385526881739, 0.9790292983471168),
#   'apo': (-28.62478323273785, 0.39338615088367407)},
#  {'complex': (-40.6924830081076, 1.1061646326786876),
#   'apo': (-26.949168507180225, 0.3931338907830386)},
#  {'complex': (-36.38116077025655, 0.9819502716484556),
#   'apo': (-26.816164331162827, 0.38908479280024194)},
#  {'complex': (-36.1098925946228, 1.2033724515473578),
#   'apo': (-26.367848520058665, 0.3297056940621673)},
#  {'complex': (-45.532913113827625, 1.1119505259490954),
#   'apo': (-26.936208560593712, 0.4057520569569042)},
#  {'complex': (-37.12642327048155, 1.178982581464652),
#   'apo': (-28.137766815976377, 0.39385167105850827)},
#  {'complex': (-43.802365068550706, 1.1439762357691736),
#   'apo': (-27.049481517231094, 0.4323308145563748)},
#  {'complex': (-41.081684399382716, 0.9830620290045999),
#   'apo': (-26.604151640265684, 0.392140770510421)},
#  {'complex': (-37.39081548850805, 1.128676620863351),
#   'apo': (-26.50953076536447, 0.41409321150202444)},
#  {'complex': (-37.74539410492576, 1.1415548287761164),
#   'apo': (-27.648620112405933, 0.4954276026807154)},
#  {'complex': (-44.28824822565302, 1.042303457145102),
#   'apo': (-28.11420086279679, 0.419869829769013)},
#  {'complex': (-44.99162089162051, 0.7250270379809624),
#   'apo': (-27.38205536213938, 0.40426741220642787)},
#  {'complex': (-43.850373290066166, 0.9807591284170921),
#   'apo': (-26.957992408688064, 0.3879014030819708)},
#  {'complex': (-37.61863989031776, 1.1807296490409347),
#   'apo': (-25.86038190142824, 0.3944924085029492)},
#  {'complex': (-46.75452728820723, 1.0864612917868524),
#   'apo': (-27.468319478991802, 0.41683517022628286)},
#  {'complex': (-41.27795329597757, 1.4067462580196417),
#   'apo': (-27.120489056553122, 0.41659515491025456)},
#  {'complex': (-39.692119293182486, 1.1333209138176217),
#   'apo': (-27.30476391543099, 0.4044222839574793)},
#  {'complex': (-36.13014305298893, 1.1932445127600215),
#   'apo': (-27.738836331634083, 0.4435484687661139)},
#  {'complex': (-44.26059500599936, 1.0366705323856962),
#   'apo': (-27.876643042062604, 0.3773893613309835)},
#  {'complex': (-35.33510130713103, 1.1574854423934937),
#   'apo': (-26.413492994409356, 0.3551566208506966)},
#  {'complex': (-40.243729192980524, 1.3609247994223068),
#   'apo': (-28.57799812767396, 0.4508627569406285)},
#  {'complex': (-36.835684028222985, 1.145216700403616),
#   'apo': (-27.691004793768116, 0.47628186641643777)},
#  {'complex': (-42.48272886477889, 0.7794349222406913),
#   'apo': (-27.356639085485693, 0.441051473749218)},
#  {'complex': (-46.445990820739766, 1.0727792513914334),
#   'apo': (-27.65159338155043, 0.4281893582982328)},
#  {'complex': (-42.53823655722802, 0.7410243104455347),
#   'apo': (-26.75056802476769, 0.38963364151502666)},
#  {'complex': (-36.58275772045748, 0.9839318108542057),
#   'apo': (-27.14300958939192, 0.40367140316119926)},
#  {'complex': (-45.016484343090696, 1.2037363559905618),
#   'apo': (-27.163717507831613, 0.4142887856564834)},
#  {'complex': (-41.32504644948513, 0.9887732849192217),
#   'apo': (-26.800612420901317, 0.3833458937779968)},
#  {'complex': (-39.97877948300413, 1.0889600372643373),
#   'apo': (-27.479716347423405, 0.381884111253452)},
#  {'complex': (-41.32203801729557, 0.9884154512960366),
#   'apo': (-26.938770877992017, 0.3779249450356833)},
#  {'complex': (-40.88857750663287, 0.9802482106210444),
#   'apo': (-27.47464240538474, 0.42054016132926975)},
#  {'complex': (-37.09260132833398, 0.8412485714567746),
#   'apo': (-28.256192177657248, 0.35365602771812005)},
#  {'complex': (-35.32047550382721, 1.1757458216245966),
#   'apo': (-26.731358047201798, 0.4423239820392122)},
#  {'complex': (-40.33216926286749, 1.3018802455718865),
#   'apo': (-25.24030540113938, 0.38915802816515976)},
#  {'complex': (-41.281999517114755, 0.9897923760265066),
#   'apo': (-27.382200713086117, 0.3876787684686757)},
#  {'complex': (-41.50344272852028, 1.0608714989827244),
#   'apo': (-28.488898888988466, 0.47030305019451507)},
#  {'complex': (-44.51372187041965, 0.8959349737069434),
#   'apo': (-26.483584736569654, 0.4167691897013991)},
#  {'complex': (-44.91131798625531, 0.9693927329445657),
#   'apo': (-27.21246092819811, 0.38787872841710574)},
#  {'complex': (-40.652178236024355, 1.3857949041781854),
#   'apo': (-27.528601660354493, 0.36336590169766203)},
#  {'complex': (-41.34466689611055, 1.4042083922667534),
#   'apo': (-27.87552524094713, 0.4905892479154682)},
#  {'complex': (-40.28424348544619, 0.9464806160751204),
#   'apo': (-27.059190799482497, 0.3727127761955458)},
#  {'complex': (-44.90697090537133, 0.9675772944554029),
#   'apo': (-27.63564645123946, 0.35892195949009936)},
#  {'complex': (-41.86827573661975, 1.0433380516485395),
#   'apo': (-27.376123416911646, 0.37587704250015525)},
#  {'complex': (-46.76258453792676, 0.7727799459535053),
#   'apo': (-27.15127478191291, 0.3825999686481805)},
#  {'complex': (-44.94089538676505, 1.3967326835658862),
#   'apo': (-28.25508317062826, 0.500425099974653)},
#  {'complex': (-44.9766063734447, 0.9183728262003765),
#   'apo': (-27.25970848570065, 0.38412871477648586)},
#  {'complex': (-37.53116739864275, 1.214466563845),
#   'apo': (-26.15242559621789, 0.438562029338524)},
#  {'complex': (-41.29660417705348, 1.4055735834810532),
#   'apo': (-26.382947028018332, 0.3721754959824108)},
#  {'complex': (-41.27676317740424, 1.4067258902682815),
#   'apo': (-26.851238700059895, 0.410559552037092)},
#  {'complex': (-40.7922620807025, 1.374992403793523),
#   'apo': (-28.089248018798564, 0.39769114976173536)},
#  {'complex': (-36.90689368861114, 1.1066550714864247),
#   'apo': (-26.85579853268787, 0.3630493517987667)},
#  {'complex': (-37.35124852069481, 1.1420416014168773),
#   'apo': (-27.7130204493238, 0.4211309000424879)},
#  {'complex': (-46.311214324671326, 1.0035127561457118),
#   'apo': (-27.273388262343794, 0.382808063123729)},
#  {'complex': (-45.63118945160603, 1.1794600551636387),
#   'apo': (-27.485619283854717, 0.3578722524532555)},
#  {'complex': (-40.31238477573704, 1.290687155409896),
#   'apo': (-26.173121662086515, 0.4709871373427456)},
#  {'complex': (-46.45660229051489, 1.0495491188612767),
#   'apo': (-27.21761609707631, 0.39596404278683284)},
#  {'complex': (-37.066821723217274, 1.2110718761692283),
#   'apo': (-27.277426806787414, 0.4837224773598655)},
#  {'complex': (-44.854963198720064, 1.343445597081493),
#   'apo': (-28.264923190116082, 0.45436317134158133)},
#  {'complex': (-41.324452169961184, 0.9887523228375947),
#   'apo': (-27.224485675782706, 0.414365382996959)},
#  {'complex': (-41.36692579198466, 1.404181200057764),
#   'apo': (-27.786287287872423, 0.4077049151510054)},
#  {'complex': (-41.427105739398584, 1.4021570925219298),
#   'apo': (-27.229236916054134, 0.37915105380645997)},
#  {'complex': (-36.65251811511766, 0.9426226779136281),
#   'apo': (-27.48653046525752, 0.3702937717238524)},
#  {'complex': (-47.03429411723621, 0.8238331133571956),
#   'apo': (-26.121884062500904, 0.35622905780538794)},
#  {'complex': (-36.90524284381102, 1.107924317366535),
#   'apo': (-28.157229749861457, 0.4233666163643058)},
#  {'complex': (-36.909858073707525, 0.8770480129088865),
#   'apo': (-27.53714802990581, 0.3698377496057046)},
#  {'complex': (-43.89173612916125, 0.8430979521952806),
#   'apo': (-28.92542256866507, 0.38072787191872126)},
#  {'complex': (-40.38455557024469, 1.375208839589906),
#   'apo': (-26.847550409649866, 0.35781572748592344)},
#  {'complex': (-47.20083155693688, 0.822536269913863),
#   'apo': (-27.373633165775555, 0.43289084315858384)},
#  {'complex': (-36.714000933362655, 1.2940521092393162),
#   'apo': (-27.00172452963768, 0.4033625779340124)},
#  {'complex': (-44.899336169181495, 1.3709629282892342),
#   'apo': (-26.143157458263783, 0.41621021532551294)},
#  {'complex': (-41.14063156127016, 1.3778529982004009),
#   'apo': (-27.299208372349373, 0.4791841876351992)},
#  {'complex': (-42.44546931483075, 1.215887883560989),
#   'apo': (-27.137632120503053, 0.3648512275223471)},
#  {'complex': (-44.203214467687374, 1.2057074214896628),
#   'apo': (-27.760069150211454, 0.41918416482239157)},
#  {'complex': (-36.099491076073036, 1.2082053288940446),
#   'apo': (-26.483876525916124, 0.344529850462155)},
#  {'complex': (-40.94037672872937, 1.3898810209647607),
#   'apo': (-27.020127691649073, 0.3863246291324295)},
#  {'complex': (-37.190867228328315, 1.1532863378030893),
#   'apo': (-27.54327826351965, 0.3976567354473951)},
#  {'complex': (-33.2180105156526, 1.0534351600189376),
#   'apo': (-27.81109517961209, 0.38335771665711155)},
#  {'complex': (-44.898756549240176, 1.369814298729743),
#   'apo': (-27.48724476572187, 0.3821610392008853)},
#  {'complex': (-45.53721788181627, 1.114652790806938),
#   'apo': (-26.898739985802855, 0.4313289805077512)},
#  {'complex': (-44.93724784491947, 1.3946130670002912),
#   'apo': (-26.32972208241025, 0.4055448659303843)},
#  {'complex': (-36.71759622026563, 1.2900171842908466),
#   'apo': (-26.867654396325637, 0.43989953369779505)},
#  {'complex': (-40.80448017246944, 1.3742373895272864),
#   'apo': (-27.180196874391513, 0.3508076745134783)},
#  {'complex': (-40.38360641389697, 1.2310076100101395),
#   'apo': (-27.271582776383102, 0.38179962454536803)},
#  {'complex': (-44.202948761385876, 1.2055521211863784),
#   'apo': (-28.090292868217038, 0.43092787184585657)},
#  {'complex': (-40.90921182796615, 1.39227791829187),
#   'apo': (-27.69639682168149, 0.41854087847164007)},
#  {'complex': (-40.85052397710003, 1.3704700634796407),
#   'apo': (-26.89275681289213, 0.3698165375383366)},
#  {'complex': (-42.132440071951805, 0.7763523186860573),
#   'apo': (-27.641841686680507, 0.3467353506698649)},
#  {'complex': (-39.77579452425909, 1.0132118975340505),
#   'apo': (-26.827906076747826, 0.45721426528610903)},
#  {'complex': (-40.317966535440576, 1.2908088099868644),
#   'apo': (-26.964025744652304, 0.4739678202877157)},
#  {'complex': (-39.966184086153675, 1.0968199353062391),
#   'apo': (-27.627040275145433, 0.44299345727992573)},
#  {'complex': (-37.777605987770066, 1.1304223855517717),
#   'apo': (-27.440398664946724, 0.422570794892717)},
#  {'complex': (-44.64281503284757, 0.7469369171447431),
#   'apo': (-27.214942736569164, 0.3990585891937218)},
#  {'complex': (-39.83465585312397, 0.9403891395723974),
#   'apo': (-28.113200041558507, 0.3842761140482066)},
#  {'complex': (-36.133380587187055, 1.1921892776438823),
#   'apo': (-26.64420200480251, 0.374865231319974)},
#  {'complex': (-38.428746414775325, 0.8679647470420088),
#   'apo': (-27.7404035891278, 0.38233589970569126)},
#  {'complex': (-39.02865610505334, 1.1744112388647512),
#   'apo': (-27.0099139514678, 0.4179834005228199)},
#  {'complex': (-44.28541439682978, 1.0421032451099168),
#   'apo': (-26.59413794904013, 0.4252113958529381)},
#  {'complex': (-36.133106701936754, 1.1922926379465688),
#   'apo': (-26.676025764355092, 0.3801560159678789)},
#  {'complex': (-41.29310167470565, 1.4063999007850345),
#   'apo': (-27.475756676680323, 0.35818792631875673)},
#  {'complex': (-41.14161935331126, 1.3779564173291508),
#   'apo': (-28.28748156705359, 0.35537859912510084)},
#  {'complex': (-46.6934115703845, 1.0941038633573823),
#   'apo': (-26.862862692179633, 0.3265080789275209)},
#  {'complex': (-36.71203387683602, 1.2967767146605138),
#   'apo': (-26.21021237978256, 0.40169023086764905)},
#  {'complex': (-35.81476435349194, 1.1341985003790176),
#   'apo': (-27.24797226317009, 0.3738966402802072)},
#  {'complex': (-46.31776391296587, 1.0495747060529745),
#   'apo': (-27.874345467638616, 0.37804257358413945)},
#  {'complex': (-45.548359441710566, 1.1218717697085467),
#   'apo': (-26.367166494682415, 0.41807260532073465)},
#  {'complex': (-40.68579231978902, 1.3839923695015977),
#   'apo': (-27.932312587560627, 0.3788814393297833)},
#  {'complex': (-44.92257926140706, 1.3854449315796604),
#   'apo': (-26.807047651267197, 0.3746946400492737)},
#  {'complex': (-41.69819215100581, 0.8504254968510107),
#   'apo': (-27.61579405855581, 0.48385198883308655)},
#  {'complex': (-44.857439316207774, 1.3456349882560024),
#   'apo': (-26.95856314861027, 0.3713303529955432)},
#  {'complex': (-46.92551062839778, 1.1393084349089888),
#   'apo': (-27.459038889207676, 0.4346938677123193)},
#  {'complex': (-47.11671835263506, 0.6969039865697815),
#   'apo': (-29.287005541849755, 0.4217151316823801)},
#  {'complex': (-36.58672871466821, 0.8548343082083375),
#   'apo': (-28.216122349720834, 0.4170280130867484)},
#  {'complex': (-36.738793533262196, 0.9538870462728994),
#   'apo': (-27.212882303504525, 0.39999684372004385)},
#  {'complex': (-45.710592142919225, 1.1290352266247599),
#   'apo': (-27.448115048926084, 0.4229110769278897)},
#  {'complex': (-46.70602552440459, 0.7749556964076169),
#   'apo': (-26.83088879839557, 0.3968545553934197)},
#  {'complex': (-36.838916938120896, 1.143332233090701),
#   'apo': (-26.938576308258607, 0.3967076772582378)},
#  {'complex': (-36.302360656953006, 0.8950970846132207),
#   'apo': (-27.377674558172313, 0.43648688346534664)},
#  {'complex': (-40.97247396021156, 1.3878144282148361),
#   'apo': (-26.16903965245178, 0.39353948177521736)},
#  {'complex': (-45.01142537141474, 1.201952139336821),
#   'apo': (-26.806756009282616, 0.4505468188223602)},
#  {'complex': (-35.77935189775555, 1.3136521710627864),
#   'apo': (-26.74422142123791, 0.33148275748630646)},
#  {'complex': (-43.799314848634744, 1.1413863952672736),
#   'apo': (-26.235406118097433, 0.34454853770668126)},
#  {'complex': (-46.618041133786654, 1.0745816070174454),
#   'apo': (-28.065811368217396, 0.40559371417353546)},
#  {'complex': (-42.36751226128332, 0.7701970632181143),
#   'apo': (-27.942508896476582, 0.4163092591947377)},
#  {'complex': (-45.67073896461312, 0.8160095163113142),
#   'apo': (-26.846771293241705, 0.34741488310210134)},
#  {'complex': (-37.661248489230324, 1.1646368498662414),
#   'apo': (-27.185591565477413, 0.4553544778290271)},
#  {'complex': (-45.020181122695185, 1.2053196009991742),
#   'apo': (-26.529784230790487, 0.389685016987779)},
#  {'complex': (-47.36864245502371, 0.9300637441838238),
#   'apo': (-27.987916871045734, 0.36631643493407257)},
#  {'complex': (-38.40146530721417, 0.8720666219533798),
#   'apo': (-26.806911957819796, 0.2966388855046843)},
#  {'complex': (-36.832422522447615, 1.2218064659814152),
#   'apo': (-26.811438192184422, 0.3933054178652136)},
#  {'complex': (-47.03216226570792, 1.1019872193950715),
#   'apo': (-26.728666200660463, 0.38356311616465705)},
#  {'complex': (-44.877050850382, 1.3572665503671544),
#   'apo': (-26.515052189051634, 0.4830888632316195)},
#  {'complex': (-44.86756162106843, 1.3515239024726167),
#   'apo': (-26.78856326618257, 0.35248290822602485)},
#  {'complex': (-42.77814232412538, 0.6962648678467679),
#   'apo': (-26.589947557569005, 0.39269561685855797)},
#  {'complex': (-40.89084989058404, 1.3928882721777582),
#   'apo': (-27.979000185780528, 0.44176635512121093)},
#  {'complex': (-36.36934466456392, 0.9909793709242576),
#   'apo': (-26.443460755648083, 0.4313802438465376)},
#  {'complex': (-36.25604147986175, 1.0683130188574839),
#   'apo': (-26.844602969663757, 0.3469564718738426)},
#  {'complex': (-46.581407895533566, 1.0933419239350126),
#   'apo': (-28.432782990620286, 0.5051849420609318)},
#  {'complex': (-37.10919911523723, 1.3767563719804388),
#   'apo': (-27.322104787384472, 0.433996718139868)},
#  {'complex': (-43.82777151737453, 0.9775543996548185),
#   'apo': (-26.744278517522766, 0.47422221641673307)},
#  {'complex': (-46.63377621305108, 0.7676027120104241),
#   'apo': (-26.972010125865225, 0.46218689348152875)},
#  {'complex': (-36.58479185823991, 1.3947160718080673),
#   'apo': (-26.441013884007496, 0.37505623494756124)},
#  {'complex': (-37.58178994521925, 1.1953319183436697),
#   'apo': (-27.170001062146316, 0.3766953131790805)},
#  {'complex': (-37.897882921231655, 1.1180673550458393),
#   'apo': (-27.303930972960618, 0.4181081042442267)},
#  {'complex': (-38.235440621672, 0.897635610188361),
#   'apo': (-27.776630202326945, 0.4665677278544998)},
#  {'complex': (-40.27608636595823, 0.9366166320608432),
#   'apo': (-27.389214693811955, 0.39660573655427017)},
#  {'complex': (-36.3745675952132, 0.9862854432012583),
#   'apo': (-26.28120318116901, 0.44824719025535337)},
#  {'complex': (-36.592259351197974, 1.3898064574870144),
#   'apo': (-27.57648685950741, 0.4225998175964147)},
#  {'complex': (-45.58428968916205, 1.14593846810379),
#   'apo': (-27.5821636830779, 0.48218438568832855)},
#  {'complex': (-43.313494039233134, 0.9299895341853895),
#   'apo': (-28.28858884732787, 0.4291445251068992)},
#  {'complex': (-41.29168688711091, 0.9897315814744929),
#   'apo': (-26.789979584834878, 0.3964244363923422)},
#  {'complex': (-45.38476374434244, 0.8558292826000427),
#   'apo': (-27.02241841997133, 0.3939144312841361)},
#  {'complex': (-38.74715918326562, 0.737585237651756),
#   'apo': (-26.93219309299927, 0.43471336881705763)},
#  {'complex': (-35.742924295012266, 1.350999776855214),
#   'apo': (-27.67043096736836, 0.3737199702003419)},
#  {'complex': (-35.7668991184498, 1.3262741367573656),
#   'apo': (-27.34382563531493, 0.41724775854785773)},
#  {'complex': (-43.345726465823844, 0.7981629486921853),
#   'apo': (-27.384159844220996, 0.49934345982690514)},
#  {'complex': (-40.73247929998534, 1.3802231116329566),
#   'apo': (-26.30813650023249, 0.34696254542113364)},
#  {'complex': (-39.973998434159505, 1.0983080155021743),
#   'apo': (-27.265421258927436, 0.4357784523884135)},
#  {'complex': (-41.38893967371688, 0.987164869953013),
#   'apo': (-26.849544666349015, 0.4176666229837695)},
#  {'complex': (-41.08184175515815, 1.381562623542702),
#   'apo': (-27.110736217154326, 0.36929232919335897)},
#  {'complex': (-45.62606573388796, 1.1756956202044009),
#   'apo': (-26.677658864725473, 0.28811530430912385)},
#  {'complex': (-41.07332699426648, 1.3820944742848125),
#   'apo': (-27.535051382631778, 0.5049469116127703)},
#  {'complex': (-44.215764651109716, 1.2108689071616778),
#   'apo': (-26.94664341742799, 0.3868998011916248)},
#  {'complex': (-45.406385294198536, 0.8646135909829845),
#   'apo': (-28.407762811014244, 0.3895442715485519)},
#  {'complex': (-36.711330251674724, 0.9123634176863066),
#   'apo': (-27.017835466346366, 0.3764207889357848)},
#  {'complex': (-36.59484661045793, 1.3847977260634015),
#   'apo': (-27.033148118177557, 0.3817305729262939)},
#  {'complex': (-43.850182863222265, 0.9807542816208015),
#   'apo': (-25.882180162722946, 0.37664535760847045)},
#  {'complex': (-40.469304245335245, 1.3661899740825911),
#   'apo': (-26.846906538946257, 0.3564813649666202)},
#  {'complex': (-41.524239317626765, 0.9353547925014322),
# ...
#  {'complex': (-37.809493473619646, 1.1214830871926336),
#   'apo': (-27.423104847796097, 0.39348069025651183)},
#  {'complex': (-37.902183138726606, 1.0963739953880067),
#   'apo': (-26.67534426732013, 0.40597358941068323)},
#  {'complex': (-40.23907027208837, 1.3563206471176223),
#   'apo': (-27.014157214697132, 0.3488427876049957)},
#  {'complex': (-42.85311341328968, 1.2248478359210428),
#   'apo': (-28.024881311534624, 0.37806237110707863)},
#  {'complex': (-37.05539204690525, 1.2137842598941642),
#   'apo': (-27.184561019184017, 0.3599410701809169)},
#  {'complex': (-39.890255763753224, 1.2068852579434945),
#   'apo': (-26.767837540599633, 0.3650205168948562)},
#  {'complex': (-41.257247286510186, 1.4061195573161793),
#   'apo': (-27.761265844786347, 0.46314266419499434)},
#  {'complex': (-44.89231417574575, 1.3659813380533914),
#   'apo': (-26.239087317590883, 0.390301355225428)},
#  {'complex': (-40.66358040305253, 1.3653176100893734),
#   'apo': (-28.178648491880896, 0.4203113638222728)},
#  {'complex': (-38.03458166392833, 1.0650933563751723),
#   'apo': (-26.775178824634697, 0.3543197960391823)},
#  {'complex': (-40.243856285388645, 1.402535093707253),
#   'apo': (-27.44907830500217, 0.43259137896854893)},
#  {'complex': (-40.275841522552064, 0.9392799675867869),
#   'apo': (-26.574372876604713, 0.38476233807630655)},
#  {'complex': (-37.477389498238324, 1.104295152712352),
#   'apo': (-27.977496136529112, 0.3954419203535938)},
#  {'complex': (-44.51991157514743, 0.8979625304779345),
#   'apo': (-27.271454579315982, 0.4895156214659145)},
#  {'complex': (-36.11309979924457, 1.2051601486683083),
#   'apo': (-28.363703358957444, 0.4130035847542562)},
#  {'complex': (-41.356304216727615, 1.4030054669445422),
#   'apo': (-28.40687704721377, 0.4714550181961314)},
#  {'complex': (-40.23617477754558, 1.3795089757760506),
#   'apo': (-27.130646829135927, 0.42063488512291825)},
#  {'complex': (-47.17523598049222, 1.1147275936930565),
#   'apo': (-26.83970788007132, 0.4069709951716666)},
#  {'complex': (-44.21477306076223, 1.2100422904883843),
#   'apo': (-27.659979707277436, 0.4789946588902029)},
#  {'complex': (-44.974380745229574, 0.9176830107887747),
#   'apo': (-28.063134944588242, 0.4985565184086696)},
#  {'complex': (-41.95291396207832, 1.094577149309997),
#   'apo': (-26.83337981579112, 0.4001260491351498)},
#  {'complex': (-36.90764875267041, 1.1058819516056202),
#   'apo': (-27.385418003279636, 0.44612302186885283)},
#  {'complex': (-44.83827758772629, 1.3345823149569331),
#   'apo': (-26.876406525330736, 0.4384181750689116)},
#  {'complex': (-36.10984510177462, 1.206241055198916),
#   'apo': (-27.371108089238092, 0.39568498377397576)},
#  {'complex': (-41.09428389741716, 0.9826868745489156),
#   'apo': (-27.55164992656112, 0.44826219341052115)},
#  {'complex': (-40.9514253228181, 1.3894241370227263),
#   'apo': (-26.840511455385414, 0.45578286627069337)},
#  {'complex': (-37.34455624865072, 1.1419830355668654),
#   'apo': (-27.333514919524923, 0.4023747385677558)},
#  {'complex': (-41.41169722105715, 1.4022883255427763),
#   'apo': (-27.151805478993825, 0.4783473664725042)},
#  {'complex': (-43.84519880793159, 0.9803115452920019),
#   'apo': (-27.625461566645836, 0.45388684653959166)},
#  {'complex': (-36.58771761943729, 1.394293341965967),
#   'apo': (-27.79995380628594, 0.46499056119227344)},
#  {'complex': (-43.887954369845474, 0.8425262439116512),
#   'apo': (-26.21145511706809, 0.3733831010426097)},
#  {'complex': (-47.024158265615114, 0.7902036723327046),
#   'apo': (-26.234293206754106, 0.35162728618065914)},
#  {'complex': (-35.506652634968596, 0.858669916096765),
#   'apo': (-27.30090355490305, 0.4045512061956884)},
#  {'complex': (-46.59292626603834, 1.0751611177388527),
#   'apo': (-28.10639721195547, 0.3645616127525009)},
#  {'complex': (-44.88332270532557, 1.3607024378088763),
#   'apo': (-26.963638785029993, 0.38886443798685516)},
#  {'complex': (-36.25908581641812, 1.0665136801855102),
#   'apo': (-27.57836516160601, 0.38273220050597667)},
#  {'complex': (-36.83095869899841, 1.2239049827925248),
#   'apo': (-27.71115631205661, 0.385698215999865)},
#  {'complex': (-39.96663446704212, 1.0969582573783714),
#   'apo': (-26.589244784462554, 0.378734573943682)},
#  {'complex': (-37.90496306204207, 1.0947027492137593),
#   'apo': (-26.663992759752905, 0.34980421554237334)},
#  {'complex': (-36.71342497752731, 1.2957201613179297),
#   'apo': (-26.849977123309834, 0.4206886892750875)},
#  {'complex': (-47.11760635189466, 1.0965225471879687),
#   'apo': (-27.81204060080474, 0.36412347570379494)},
#  {'complex': (-41.97386571729004, 0.8301500578188502),
#   'apo': (-27.583855140890353, 0.4986946959479602)},
#  {'complex': (-41.45715180202196, 1.399866786010121),
#   'apo': (-27.402165998637482, 0.46365172446576775)},
#  {'complex': (-41.41245599409556, 1.4014771931378154),
#   'apo': (-26.965056610654575, 0.4040052121099618)},
#  {'complex': (-36.71258107990864, 1.295142012596448),
#   'apo': (-27.83526915700339, 0.4622523777849306)},
#  {'complex': (-38.031776189776416, 0.8296676524964677),
#   'apo': (-26.64770883941955, 0.5133022367583402)},
#  {'complex': (-45.6027489413249, 1.158601676183172),
#   'apo': (-27.408436073274736, 0.48489950980535834)},
#  {'complex': (-41.28909750825043, 1.4062450265373707),
#   'apo': (-27.483821384230783, 0.37056358604932577)},
#  {'complex': (-41.27641440300418, 1.405861589656514),
#   'apo': (-27.84865484604531, 0.4427874969038635)},
#  {'complex': (-40.91703974241887, 1.3912988867467195),
#   'apo': (-27.104492153163537, 0.3707486674210069)},
#  {'complex': (-37.95554513871461, 1.0829706287381005),
#   'apo': (-27.941341334301182, 0.3946000924232998)},
#  {'complex': (-46.02389216140398, 1.0844162293080788),
#   'apo': (-28.464441626644447, 0.47351145136732253)},
#  {'complex': (-47.30832418370657, 0.8828253345756788),
#   'apo': (-26.78778230085574, 0.43125768024650823)},
#  {'complex': (-44.88350087315207, 1.3603680594445482),
#   'apo': (-27.555599209760704, 0.40511667425482734)},
#  {'complex': (-47.48936291891003, 0.681478260512305),
#   'apo': (-26.626498411606725, 0.3436363931974876)},
#  {'complex': (-47.11033615042198, 0.8173250202596929),
#   'apo': (-27.289029790624678, 0.37716188128711026)},
#  {'complex': (-44.90351820228624, 1.3724383691963773),
#   'apo': (-27.596094403237718, 0.371258474939252)},
#  {'complex': (-40.9550897611433, 1.3894240958841853),
#   'apo': (-26.52201457398221, 0.416389621791164)},
#  {'complex': (-39.37210318266936, 1.363757665851015),
#   'apo': (-26.81796985162732, 0.37045495573674253)},
#  {'complex': (-40.230612051474765, 0.9781921916047108),
#   'apo': (-28.304036073990005, 0.45634046304878934)},
#  {'complex': (-36.24682405180812, 1.0770776854247184),
#   'apo': (-26.393912994412208, 0.3479312519457775)},
#  {'complex': (-37.458463055462715, 1.330464750564801),
#   'apo': (-27.313636537787882, 0.43333088589730157)},
#  {'complex': (-43.79746862607409, 1.1421999354663543),
#   'apo': (-27.88630332416461, 0.4363772069484995)},
#  {'complex': (-37.06132514635956, 1.2142226716220428),
#   'apo': (-27.09339641569332, 0.385502613436855)},
#  {'complex': (-44.20166153596039, 1.2051906747406278),
#   'apo': (-27.317384716263774, 0.4055379496633883)},
#  {'complex': (-37.928915240129676, 1.08999843751899),
#   'apo': (-28.099454658839335, 0.4811891386592556)},
#  {'complex': (-44.85139884768826, 1.3415643973131335),
#   'apo': (-28.083421892992124, 0.3646997104595471)},
#  {'complex': (-35.801278055836406, 1.2920094112642944),
#   'apo': (-27.32527665896855, 0.39180392066477265)},
#  {'complex': (-41.07631874777375, 0.9829211306625448),
#   'apo': (-27.29294929192808, 0.3951514237455614)},
#  {'complex': (-40.51647091762856, 1.3788335993390524),
#   'apo': (-27.05320528670581, 0.4164426781183803)},
#  {'complex': (-47.070102614638735, 0.6628946043341803),
#   'apo': (-27.61880024531487, 0.4738020198397817)},
#  {'complex': (-44.932433808936864, 1.3919299642382699),
#   'apo': (-27.302338090205048, 0.43716849258985646)},
#  {'complex': (-44.92306475449916, 0.9747795049505541),
#   'apo': (-28.37281533006977, 0.41040317589080083)},
#  {'complex': (-41.361142659641395, 0.9880315620226117),
#   'apo': (-26.040220595299406, 0.3394183706898264)},
#  {'complex': (-41.426915805455955, 1.4013243243547335),
#   'apo': (-26.945274134043718, 0.34751503720751925)},
#  {'complex': (-43.85347335173349, 0.9816280623010057),
#   'apo': (-26.711884144729343, 0.42659497123352796)},
#  {'complex': (-44.9019550154622, 1.3724669430858134),
#   'apo': (-26.85926168436548, 0.38980416097065534)},
#  {'complex': (-36.58466217306927, 0.982576290451304),
#   'apo': (-26.209420877820186, 0.3764926198840313)},
#  {'complex': (-45.64837767077175, 1.095544797182359),
#   'apo': (-26.934044847186172, 0.37563899706610177)},
#  {'complex': (-41.350115645673526, 1.4035865208654217),
#   'apo': (-27.567405980387864, 0.43669670958667534)},
#  {'complex': (-41.0245994621949, 1.3848413849395336),
#   'apo': (-28.20280426365502, 0.40524031771236385)},
#  {'complex': (-37.065982005934934, 0.8508600752080819),
#   'apo': (-28.29730064456981, 0.4619027023352039)},
#  {'complex': (-37.577631040401656, 1.1961342103869084),
#   'apo': (-27.613894816943297, 0.4634801277730372)},
#  {'complex': (-41.35008841086449, 1.4036190586129607),
#   'apo': (-27.548541355626753, 0.36132317349714266)},
#  {'complex': (-43.85376709545879, 0.981503718600632),
#   'apo': (-26.716249075349104, 0.4370098927927379)},
#  {'complex': (-47.47954202080728, 0.8108264903373642),
#   'apo': (-26.95755719890739, 0.41080532562166194)},
#  {'complex': (-37.06300901060355, 1.213226390612011),
#   'apo': (-27.633474948304002, 0.4313360481082641)},
#  {'complex': (-44.918923258460374, 1.3828123212665089),
#   'apo': (-26.381779390219315, 0.44584280484327593)},
#  {'complex': (-47.19465496633706, 0.7849735126000642),
#   'apo': (-27.526057591147662, 0.37976692463407585)},
#  {'complex': (-41.12042098355883, 1.3787788312504319),
#   'apo': (-27.148591646005126, 0.4445885166690533)},
#  {'complex': (-40.8878812753423, 1.3928868443663855),
#   'apo': (-27.518694275266512, 0.4935789724343257)},
#  {'complex': (-36.907585554491796, 1.1062860435358675),
#   'apo': (-26.986693365552696, 0.3614679758404728)},
#  {'complex': (-38.05323987404662, 1.0597467929643807),
#   'apo': (-26.77870193514151, 0.4372801217652136)},
#  {'complex': (-46.83772932124856, 1.105594651786228),
#   'apo': (-27.621329312619658, 0.45890935300882485)},
#  {'complex': (-44.89819982179249, 1.3701137320781984),
#   'apo': (-27.061307698132733, 0.35127625806878)},
#  {'complex': (-35.81045217154357, 1.1393397681561452),
#   'apo': (-29.336751045125194, 0.5062111682518303)},
#  {'complex': (-44.86983124633171, 1.3526567450635574),
#   'apo': (-27.949180390893652, 0.4787292186702185)},
#  {'complex': (-37.444554376302214, 1.3572316829587596),
#   'apo': (-26.84163759612642, 0.3650186305153186)},
#  {'complex': (-33.39265690833951, 1.1081746593431667),
#   'apo': (-26.991207572567678, 0.3186514400026026)},
#  {'complex': (-37.19161735303343, 1.2687924841775031),
#   'apo': (-27.440960430703676, 0.46947400764627223)},
#  {'complex': (-37.1343178100511, 1.1789507660533047),
#   'apo': (-27.13085045625997, 0.3300798834912842)},
#  {'complex': (-47.554306693727085, 1.2150783454537182),
#   'apo': (-29.184593923719884, 0.3825796536583605)},
#  {'complex': (-40.38258865930784, 1.222130807386734),
#   'apo': (-27.331179327214397, 0.4558306521234947)},
#  {'complex': (-44.858135074649105, 1.3450186810145657),
#   'apo': (-26.679277095379163, 0.3813080764435954)},
#  {'complex': (-35.7044832862071, 1.3936463939694863),
#   'apo': (-29.04995738970387, 0.42120382301818116)},
#  {'complex': (-37.11606999445846, 0.8149595531843095),
#   'apo': (-27.46180006822533, 0.3944354637186487)},
#  {'complex': (-36.72990612318521, 1.281853669284073),
#   'apo': (-27.80083972958528, 0.37075907050339596)},
#  {'complex': (-36.590075662396764, 1.3906950408789787),
#   'apo': (-26.89021934055158, 0.43615386520209887)},
#  {'complex': (-44.247081547981495, 0.7951305591586391),
#   'apo': (-26.87634100263683, 0.3125296314682557)},
#  {'complex': (-36.10103977677382, 1.2064656105498341),
#   'apo': (-26.52915310977076, 0.3371568261353398)},
#  {'complex': (-39.371165045755, 1.3494336535495048),
#   'apo': (-26.969943822387954, 0.4141984973476426)},
#  {'complex': (-41.472206437736226, 1.400504765364761),
#   'apo': (-27.90704493078155, 0.37207407300378564)},
#  {'complex': (-36.18263490566048, 0.7926154242248965),
#   'apo': (-27.60175699212716, 0.38677729790242776)},
#  {'complex': (-44.982254537427345, 1.1906597366115814),
#   'apo': (-27.39824846367038, 0.4719483379344017)},
#  {'complex': (-36.10782410330232, 1.199180168032597),
#   'apo': (-27.256110418752396, 0.39986004356036353)},
#  {'complex': (-46.413475681961174, 1.045456612344717),
#   'apo': (-27.086427678585476, 0.3702350871082685)},
#  {'complex': (-37.144592318431535, 1.0063352520070228),
#   'apo': (-28.03043663726333, 0.4636907719297898)},
#  {'complex': (-37.52754090853523, 1.21593970698537),
#   'apo': (-28.06742391242026, 0.4220772108197934)},
#  {'complex': (-35.82854488142435, 1.1182716335716323),
#   'apo': (-26.575186127700125, 0.4536704682601976)},
#  {'complex': (-43.83658593201961, 0.9786038413571675),
#   'apo': (-27.419475716705584, 0.4064652668513438)},
#  {'complex': (-37.80810589186047, 1.1218732213364133),
#   'apo': (-27.743151157643847, 0.4295069102611299)},
#  {'complex': (-45.00854528276222, 1.2005451250496992),
#   'apo': (-27.309892332115833, 0.5013819952495802)},
#  {'complex': (-46.44749163871836, 1.07316003743189),
#   'apo': (-28.152432899247284, 0.38187322124311596)},
#  {'complex': (-39.156235757614034, 0.8895446991158925),
#   'apo': (-28.20086282021478, 0.43704323068964357)},
#  {'complex': (-41.2856604787474, 1.4061409872562036),
#   'apo': (-28.91763044654261, 0.3470455553125549)},
#  {'complex': (-44.924984830330146, 1.169603300996932),
#   'apo': (-27.450630263227527, 0.37543570963618633)},
#  {'complex': (-45.02464854855686, 1.207183418743723),
#   'apo': (-27.18022589014853, 0.4121769037091941)},
#  {'complex': (-46.04415118694801, 1.1001301445643985),
#   'apo': (-27.879123339904712, 0.3915413702154389)},
#  {'complex': (-45.606257100302194, 1.161299777237919),
#   'apo': (-26.976508474460445, 0.47977850536723254)},
#  {'complex': (-40.28830027997809, 0.755949573118261),
#   'apo': (-28.44739892029155, 0.4711377397678916)},
#  {'complex': (-40.2324469625279, 1.3918075159163144),
#   'apo': (-28.141276060211457, 0.4218211310427215)},
#  {'complex': (-40.87500909608298, 1.3936992226630742),
#   'apo': (-26.570349558337327, 0.3618755821198276)},
#  {'complex': (-44.203934144066906, 1.2063735369121364),
#   'apo': (-28.19432951932043, 0.39396371350365617)},
#  {'complex': (-43.88936033919658, 0.8427029768276031),
#   'apo': (-26.730609539542186, 0.32899912843761125)},
#  {'complex': (-42.96194407267369, 0.9081105108351906),
#   'apo': (-26.699167982177148, 0.43012164710788425)},
#  {'complex': (-37.77651793960813, 1.13076858585157),
#   'apo': (-29.310707194945202, 0.44556552180436293)},
#  {'complex': (-37.18403909310143, 0.9897264132186206),
#   'apo': (-27.113408211714614, 0.4530572945235657)},
#  {'complex': (-36.84651708208702, 1.139330983954726),
#   'apo': (-27.04698132711825, 0.4480601735048306)},
#  {'complex': (-41.278708279557094, 1.404204429012665),
#   'apo': (-26.908161511403677, 0.3866887995841918)},
#  {'complex': (-45.35896804180193, 0.8909350418140141),
#   'apo': (-28.095879678816605, 0.4139687658101841)},
#  {'complex': (-40.898961998275105, 1.0086441967432795),
#   'apo': (-27.346474509903196, 0.4342889301927318)},
#  {'complex': (-41.49618195874378, 1.398872925069787),
#   'apo': (-26.369490746930627, 0.44615251270525674)},
#  {'complex': (-46.7146168976022, 1.1038298033092098),
#   'apo': (-27.21268106396596, 0.3528442484884045)},
#  {'complex': (-42.38831177886903, 0.8368807484325825),
#   'apo': (-28.21267257763613, 0.4737664381675754)},
#  {'complex': (-40.7334602072488, 1.3802350342983152),
#   'apo': (-27.191205544579546, 0.3722095267993897)},
#  {'complex': (-38.05416181532545, 1.059510633289602),
#   'apo': (-25.759897072610514, 0.37376649529106265)},
#  {'complex': (-45.610999090371, 1.16491470153885),
#   'apo': (-26.575199674513385, 0.3873813997871638)},
#  {'complex': (-40.96961810102453, 1.3878285309983471),
#   'apo': (-26.78766818240688, 0.4012136875968391)},
#  ...]

# %%
apo_dg = np.mean([d['apo'][0] for d in dgs_phase[forward]])
apo_ci = np.percentile([d['apo'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['apo'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_apo = [round(apo_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(apo_ci)*KT_KCALMOL])]

complex_dg = np.mean([d['complex'][0] for d in dgs_phase[forward]])
complex_ci = np.percentile([d['complex'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['complex'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_complex = [round(complex_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(complex_ci)*KT_KCALMOL])]

# %%
output_kcalmol_apo
# Out:
# [-16.27, (-17.1, -15.58)]

# %%
output_kcalmol_complex
# Out:
# [-24.36, (-28.07, -20.66)]

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['apo'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("apo binding dg (kcal/mol)")
plt.legend()

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['complex'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("complex binding dg (kcal/mol)")
plt.legend()

# %% [markdown]
# ## 15/101

# %%
# Load data into dicts and plot 
titles = ["N501Y"]
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
d_input = {}
dir_num = 15
forward = 101
for i in tqdm_notebook([forward]):
    print(f"dir: {i}")
    d_works = {"complex": {}, "apo":{}}
    d_combined_works = {"complex": {}, "apo":{}}
    for phase in phases:
        for direction in directions:
            all_arrays = []
            for j in range(100):
                path = f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{i}/{i}_{phase}_{j}_{direction}.npy"
                try:
                    if os.path.exists(path):
                        with open(path, 'rb') as f:
                            array = np.load(f)
                            if not np.isnan(np.sum(array)):
                                all_arrays.append(array)
                except:
                    continue
            print(len(all_arrays))
            if all_arrays:
                combined = np.concatenate(all_arrays)
                accumulated = np.array([cycle[-1] - cycle[0] for cycle in combined])
#                 combined = np.array([cycle[0::100] for cycle in combined])
                print(f"about to save: {phase} {direction}")
                d_combined_works[phase][direction] = combined
                d_works[phase][direction] = accumulated

    d_input[i] = d_works
    
    # Plot
    complex_dg, complex_ddg = analyze(d_works['complex']['forward'], d_works['complex']['reverse'])
    apo_dg, apo_ddg = analyze(d_works['apo']['forward'], d_works['apo']['reverse'])
    plot(d_combined_works['complex']['forward'], d_combined_works['complex']['reverse'], complex_dg, complex_ddg, i, 'complex', os.path.dirname(path), titles[i-forward])
    plot(d_combined_works['apo']['forward'], d_combined_works['apo']['reverse'], apo_dg, apo_ddg, i, 'apo', os.path.dirname(path), titles[i-forward])
    print("binding DDG: ", complex_dg*KT_KCALMOL - apo_dg*KT_KCALMOL, " (", ((apo_ddg**2 + complex_ddg**2)**0.5)*KT_KCALMOL, ")")
    print("\tcomplex DG: ", complex_dg*KT_KCALMOL, " (", complex_ddg*KT_KCALMOL,")")
    print("\tapo DG: ", apo_dg*KT_KCALMOL, " (", apo_ddg*KT_KCALMOL,")")
    
    complex_upper_dg, complex_upper_ddg, complex_lower_dg, complex_lower_ddg = bound_with_exp(d_works['complex']['forward'], d_works['complex']['reverse'])
    apo_upper_dg, apo_upper_ddg, apo_lower_dg, apo_lower_ddg = bound_with_exp(d_works['apo']['forward'], d_works['apo']['reverse'])
    print("binding DDG (upper): ", complex_upper_dg*KT_KCALMOL - apo_upper_dg*KT_KCALMOL, " (", ((apo_upper_ddg**2 + complex_upper_ddg**2)**0.5)*KT_KCALMOL, ")")
    print("\tcomplex DG: ", complex_upper_dg*KT_KCALMOL, " (", complex_upper_ddg*KT_KCALMOL,")")
    print("\tapo DG: ", apo_upper_dg*KT_KCALMOL, " (", apo_upper_ddg*KT_KCALMOL,")")
    print("binding DDG (lower): ", complex_lower_dg*-KT_KCALMOL - apo_lower_dg*-KT_KCALMOL, " (", ((apo_lower_ddg**2 + complex_lower_ddg**2)**0.5)*-KT_KCALMOL, ")")
    print("\tcomplex DG: ", complex_lower_dg*-KT_KCALMOL, " (", complex_lower_ddg*-KT_KCALMOL,")")
    print("\tapo DG: ", apo_lower_dg*-KT_KCALMOL, " (", apo_lower_ddg*-KT_KCALMOL,")")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# dir: 101
# 100
# about to save: complex forward
# 100
# about to save: complex reverse
# 100
# about to save: apo forward
# 100
# about to save: apo reverse
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/101/101_complex_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/101/101_complex_work_dist.png
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/101/101_apo_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/101/101_apo_work_dist.png
# binding DDG:  6.393769432622705  ( 0.37894431084663893 )
# 	complex DG:  72.47565055964398  ( 0.2487178894473215 )
# 	apo DG:  66.08188112702128  ( 0.28589893702478864 )
# binding DDG (upper):  3.56434261373974  ( 0.49261330934311637 )
# 	complex DG:  70.80330403381843  ( 0.40163341177116224 )
# 	apo DG:  67.2389614200787  ( 0.28523407070515416 )
# binding DDG (lower):  5.171662962410622  ( -0.6550216848076331 )
# 	complex DG:  72.79043518276687  ( -0.28716457291984593 )
# 	apo DG:  67.61877222035625  ( -0.5887188765684287 )

# %%
plt.hist(d_works['complex']['forward'])
plt.hist(d_works['complex']['reverse']*-1)
# Out:
# (array([ 2.,  0.,  1.,  4., 15., 23., 15., 12., 14., 14.]),
#  array([ 60.32283194,  66.86225004,  73.40166813,  79.94108623,
#          86.48050433,  93.01992242,  99.55934052, 106.09875862,
#         112.63817671, 119.17759481, 125.71701291]),
#  <BarContainer object of 10 artists>)

# %%
np.min(d_works['complex']['forward'])
# Out:
# 114.68461284877577

# %%
for i, val in enumerate(d_works['complex']['forward']):
    if val < 124:
        print(i, val)
# Out:
# 16 119.97206974964992
# 35 122.11408575356683
# 36 121.15509761907886
# 49 121.3035222944735
# 50 116.86455490357022
# 61 121.08291465787849
# 77 120.94683120090193
# 82 115.26823931386434
# 92 123.23198645637977
# 96 114.68461284877577
# 98 119.8048862075043

# %%
# Bootstrap works
N_bootstraps = 10000
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
dgs_phase = {}
ddgs = {}
for i in [forward]:
    dgs_phase_all = []
    ddgs_all = []
    for _ in tqdm_notebook(range(N_bootstraps)):
        # Initialize data structure for works
        d_works = {"complex": {"forward":{}, "reverse":{}}, "apo":{"forward":{}, "reverse":{}}}

        # Save subsampled works
        for phase in phases:
            for direction in directions:
                work_array = np.array(d_input[i][phase][direction])
                num_samples = work_array.shape[0]
                subsample_indices = np.random.choice(range(num_samples), num_samples)
                d_works[phase][direction] = work_array[subsample_indices]
        d_dgs_phase, binding_dg = analyze_bootstrap(d_works)
        dgs_phase_all.append(d_dgs_phase)
        ddgs_all.append(binding_dg)
    dgs_phase[i] = dgs_phase_all
    ddgs[i] = ddgs_all
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
forward_ddg = np.mean(ddgs[forward])
forward_ci = np.percentile(ddgs[forward], 2.5), np.percentile(ddgs[forward], 97.5)
# reverse_ddg = np.mean(ddgs[reverse])
# reverse_ci = np.percentile(ddgs[reverse], 2.5), np.percentile(ddgs[reverse], 97.5)
# negative_reverse_ci = sorted(np.array(reverse_ci)*-1)
# discrepancy = tuple(np.array(forward_ci) - np.array(negative_reverse_ci))
# output_kt = [forward_ddg, forward_ci, reverse_ddg, reverse_ci, discrepancy]
# output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL]), round(reverse_ddg*KT_KCALMOL, 2), tuple([round(val, 2) for val in np.array(reverse_ci)*KT_KCALMOL]), tuple([round(val, 2) for val in np.array(discrepancy)*KT_KCALMOL])]

output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL])]

# %%
output_kcalmol
# Out:
# [6.38, (5.13, 7.62)]

# %%
# pd.DataFrame([output_kcalmol]).to_csv(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/analysis_{titles[0]}_{titles[1]}.csv")

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "wb") as f:
    pickle.dump(dgs_phase, f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "wb") as f:
    pickle.dump(ddgs, f)

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "rb") as f:
    dgs_phase = pickle.load(f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "rb") as f:
    ddgs = pickle.load(f)

# %%
# Plot ddgs
sns.distplot(np.array(ddgs[forward])*KT_KCALMOL, rug=True, label=titles[0])
# sns.distplot(np.array(ddgs[reverse])*-KT_KCALMOL, rug=True, label=f"-({titles[1]})")
plt.xlabel("binding ddg (kcal/mol)")
plt.legend()

# %%
# Get the std error
np.std(np.array(ddgs[forward])*KT_KCALMOL)
# Out:
# 0.6420463719906756

# %%
apo_dg = np.mean([d['apo'][0] for d in dgs_phase[forward]])
apo_ci = np.percentile([d['apo'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['apo'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_apo = [round(apo_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(apo_ci)*KT_KCALMOL])]

complex_dg = np.mean([d['complex'][0] for d in dgs_phase[forward]])
complex_ci = np.percentile([d['complex'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['complex'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_complex = [round(complex_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(complex_ci)*KT_KCALMOL])]

# %%
output_kcalmol_apo
# Out:
# [66.1, (65.51, 66.8)]

# %%
output_kcalmol_complex
# Out:
# [72.48, (71.42, 73.57)]

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['apo'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("apo binding dg (kcal/mol)")
plt.legend()

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['complex'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("complex binding dg (kcal/mol)")
plt.legend()

# %% [markdown]
# ## 15/102

# %%
# Load data into dicts and plot 
titles = ["D501Y"]
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
d_input = {}
dir_num = 15
forward = 102
for i in tqdm_notebook([forward]):
    print(f"dir: {i}")
    d_works = {"complex": {}, "apo":{}}
    d_combined_works = {"complex": {}, "apo":{}}
    for phase in phases:
        for direction in directions:
            all_arrays = []
            for j in range(100):
                path = f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{i}/{i}_{phase}_{j}_{direction}.npy"
                try:
                    if os.path.exists(path):
                        with open(path, 'rb') as f:
                            array = np.load(f)
                            if not np.isnan(np.sum(array)):
                                all_arrays.append(array)
                except:
                    continue
            print(len(all_arrays))
            if all_arrays:
                combined = np.concatenate(all_arrays)
                accumulated = np.array([cycle[-1] - cycle[0] for cycle in combined])
#                 combined = np.array([cycle[0::100] for cycle in combined])
                print(f"about to save: {phase} {direction}")
                d_combined_works[phase][direction] = combined
                d_works[phase][direction] = accumulated

    d_input[i] = d_works
    
    # Plot
    complex_dg, complex_ddg = analyze(d_works['complex']['forward'], d_works['complex']['reverse'])
    apo_dg, apo_ddg = analyze(d_works['apo']['forward'], d_works['apo']['reverse'])
    plot(d_combined_works['complex']['forward'], d_combined_works['complex']['reverse'], complex_dg, complex_ddg, i, 'complex', os.path.dirname(path), titles[i-forward])
    plot(d_combined_works['apo']['forward'], d_combined_works['apo']['reverse'], apo_dg, apo_ddg, i, 'apo', os.path.dirname(path), titles[i-forward])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# dir: 102
# 100
# about to save: complex forward
# 100
# about to save: complex reverse
# 100
# about to save: apo forward
# 100
# about to save: apo reverse
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/102/102_complex_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/102/102_complex_work_dist.png
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/102/102_apo_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/102/102_apo_work_dist.png

# %%
plt.hist(d_works['complex']['forward'])
plt.hist(d_works['complex']['reverse']*-1)
# Out:
# (array([ 7.,  2.,  7., 12., 17., 25., 12., 10.,  4.,  4.]),
#  array([-92.09512707, -86.66601337, -81.23689968, -75.80778599,
#         -70.37867229, -64.9495586 , -59.52044491, -54.09133122,
#         -48.66221752, -43.23310383, -37.80399014]),
#  <BarContainer object of 10 artists>)

# %%
# Bootstrap works
N_bootstraps = 10000
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
dgs_phase = {}
ddgs = {}
for i in [forward]:
    dgs_phase_all = []
    ddgs_all = []
    for _ in tqdm_notebook(range(N_bootstraps)):
        # Initialize data structure for works
        d_works = {"complex": {"forward":{}, "reverse":{}}, "apo":{"forward":{}, "reverse":{}}}

        # Save subsampled works
        for phase in phases:
            for direction in directions:
                work_array = np.array(d_input[i][phase][direction])
                num_samples = work_array.shape[0]
                subsample_indices = np.random.choice(range(num_samples), num_samples)
                d_works[phase][direction] = work_array[subsample_indices]
        d_dgs_phase, binding_dg = analyze_bootstrap(d_works)
        dgs_phase_all.append(d_dgs_phase)
        ddgs_all.append(binding_dg)
    dgs_phase[i] = dgs_phase_all
    ddgs[i] = ddgs_all
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
forward_ddg = np.mean(ddgs[forward])
forward_ci = np.percentile(ddgs[forward], 2.5), np.percentile(ddgs[forward], 97.5)
# reverse_ddg = np.mean(ddgs[reverse])
# reverse_ci = np.percentile(ddgs[reverse], 2.5), np.percentile(ddgs[reverse], 97.5)
# negative_reverse_ci = sorted(np.array(reverse_ci)*-1)
# discrepancy = tuple(np.array(forward_ci) - np.array(negative_reverse_ci))
# output_kt = [forward_ddg, forward_ci, reverse_ddg, reverse_ci, discrepancy]
# output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL]), round(reverse_ddg*KT_KCALMOL, 2), tuple([round(val, 2) for val in np.array(reverse_ci)*KT_KCALMOL]), tuple([round(val, 2) for val in np.array(discrepancy)*KT_KCALMOL])]

output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL])]

# %%
output_kcalmol
# Out:
# [-6.42, (-7.93, -4.51)]

# %%
# pd.DataFrame([output_kcalmol]).to_csv(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/analysis_{titles[0]}_{titles[1]}.csv")

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "wb") as f:
    pickle.dump(dgs_phase, f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "wb") as f:
    pickle.dump(ddgs, f)

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "rb") as f:
    dgs_phase = pickle.load(f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "rb") as f:
    ddgs = pickle.load(f)

# %%
# Plot ddgs
sns.distplot(np.array(ddgs[forward])*KT_KCALMOL, rug=True, label=titles[0])
# sns.distplot(np.array(ddgs[reverse])*-KT_KCALMOL, rug=True, label=f"-({titles[1]})")
plt.xlabel("binding ddg (kcal/mol)")
plt.legend()

# %%
# Get the std error
np.std(np.array(ddgs[forward])*KT_KCALMOL)
# Out:
# 0.8682643578873515

# %%
apo_dg = np.mean([d['apo'][0] for d in dgs_phase[forward]])
apo_ci = np.percentile([d['apo'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['apo'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_apo = [round(apo_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(apo_ci)*KT_KCALMOL])]

complex_dg = np.mean([d['complex'][0] for d in dgs_phase[forward]])
complex_ci = np.percentile([d['complex'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['complex'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_complex = [round(complex_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(complex_ci)*KT_KCALMOL])]

# %%
output_kcalmol_apo
# Out:
# [-17.03, (-17.69, -16.31)]

# %%
output_kcalmol_complex
# Out:
# [-23.45, (-24.78, -21.56)]

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['apo'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("apo binding dg (kcal/mol)")
plt.legend()

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['complex'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("complex binding dg (kcal/mol)")
plt.legend()

# %% [markdown]
# ## 15/103

# %%
# Load data into dicts and plot 
titles = ["N501Y"]
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
d_input = {}
dir_num = 15
forward = 103
for i in tqdm_notebook([forward]):
    print(f"dir: {i}")
    d_works = {"complex": {}, "apo":{}}
    d_combined_works = {"complex": {}, "apo":{}}
    for phase in phases:
        for direction in directions:
            all_arrays = []
            for j in range(100):
                path = f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{i}/{i}_{phase}_{j}_{direction}.npy"
                try:
                    if os.path.exists(path):
                        with open(path, 'rb') as f:
                            array = np.load(f)
                            if not np.isnan(np.sum(array)):
                                all_arrays.append(array)
                except:
                    continue
            print(len(all_arrays))
            if all_arrays:
                combined = np.concatenate(all_arrays)
                accumulated = np.array([cycle[-1] - cycle[0] for cycle in combined])
#                 combined = np.array([cycle[0::100] for cycle in combined])
                print(f"about to save: {phase} {direction}")
                d_combined_works[phase][direction] = combined
                d_works[phase][direction] = accumulated

    d_input[i] = d_works
    
    # Plot
    complex_dg, complex_ddg = analyze(d_works['complex']['forward'], d_works['complex']['reverse'])
    apo_dg, apo_ddg = analyze(d_works['apo']['forward'], d_works['apo']['reverse'])
    plot(d_combined_works['complex']['forward'], d_combined_works['complex']['reverse'], complex_dg, complex_ddg, i, 'complex', os.path.dirname(path), titles[i-forward])
    plot(d_combined_works['apo']['forward'], d_combined_works['apo']['reverse'], apo_dg, apo_ddg, i, 'apo', os.path.dirname(path), titles[i-forward])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# dir: 103
# 100
# about to save: complex forward
# 100
# about to save: complex reverse
# 100
# about to save: apo forward
# 100
# about to save: apo reverse
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/103/103_complex_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/103/103_complex_work_dist.png
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/103/103_apo_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/103/103_apo_work_dist.png

# %%
plt.hist(d_works['complex']['forward'])
plt.hist(d_works['complex']['reverse']*-1)
# Out:
# (array([ 7.,  6., 14., 11., 11., 12., 11.,  9., 11.,  8.]),
#  array([ 79.83417969,  84.28255994,  88.73094019,  93.17932044,
#          97.6277007 , 102.07608095, 106.5244612 , 110.97284145,
#         115.4212217 , 119.86960195, 124.3179822 ]),
#  <BarContainer object of 10 artists>)

# %%
# Bootstrap works
N_bootstraps = 10000
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
dgs_phase = {}
ddgs = {}
for i in [forward]:
    dgs_phase_all = []
    ddgs_all = []
    for _ in tqdm_notebook(range(N_bootstraps)):
        # Initialize data structure for works
        d_works = {"complex": {"forward":{}, "reverse":{}}, "apo":{"forward":{}, "reverse":{}}}

        # Save subsampled works
        for phase in phases:
            for direction in directions:
                work_array = np.array(d_input[i][phase][direction])
                num_samples = work_array.shape[0]
                subsample_indices = np.random.choice(range(num_samples), num_samples)
                d_works[phase][direction] = work_array[subsample_indices]
        d_dgs_phase, binding_dg = analyze_bootstrap(d_works)
        dgs_phase_all.append(d_dgs_phase)
        ddgs_all.append(binding_dg)
    dgs_phase[i] = dgs_phase_all
    ddgs[i] = ddgs_all
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
forward_ddg = np.mean(ddgs[forward])
forward_ci = np.percentile(ddgs[forward], 2.5), np.percentile(ddgs[forward], 97.5)
# reverse_ddg = np.mean(ddgs[reverse])
# reverse_ci = np.percentile(ddgs[reverse], 2.5), np.percentile(ddgs[reverse], 97.5)
# negative_reverse_ci = sorted(np.array(reverse_ci)*-1)
# discrepancy = tuple(np.array(forward_ci) - np.array(negative_reverse_ci))
# output_kt = [forward_ddg, forward_ci, reverse_ddg, reverse_ci, discrepancy]
# output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL]), round(reverse_ddg*KT_KCALMOL, 2), tuple([round(val, 2) for val in np.array(reverse_ci)*KT_KCALMOL]), tuple([round(val, 2) for val in np.array(discrepancy)*KT_KCALMOL])]

output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL])]

# %%
output_kcalmol
# Out:
# [6.74, (5.85, 7.66)]

# %%
# pd.DataFrame([output_kcalmol]).to_csv(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/analysis_{titles[0]}_{titles[1]}.csv")

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "wb") as f:
    pickle.dump(dgs_phase, f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "wb") as f:
    pickle.dump(ddgs, f)

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "rb") as f:
    dgs_phase = pickle.load(f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "rb") as f:
    ddgs = pickle.load(f)

# %%
# Plot ddgs
sns.distplot(np.array(ddgs[forward])*KT_KCALMOL, rug=True, label=titles[0])
# sns.distplot(np.array(ddgs[reverse])*-KT_KCALMOL, rug=True, label=f"-({titles[1]})")
plt.xlabel("binding ddg (kcal/mol)")
plt.legend()

# %%
# Get the std error
np.std(np.array(ddgs[forward])*KT_KCALMOL)
# Out:
# 0.46718413071325304

# %%
apo_dg = np.mean([d['apo'][0] for d in dgs_phase[forward]])
apo_ci = np.percentile([d['apo'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['apo'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_apo = [round(apo_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(apo_ci)*KT_KCALMOL])]

complex_dg = np.mean([d['complex'][0] for d in dgs_phase[forward]])
complex_ci = np.percentile([d['complex'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['complex'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_complex = [round(complex_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(complex_ci)*KT_KCALMOL])]

# %%
output_kcalmol_apo
# Out:
# [66.29, (65.83, 66.71)]

# %%
output_kcalmol_complex
# Out:
# [73.03, (72.25, 73.84)]

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['apo'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("apo binding dg (kcal/mol)")
plt.legend()

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['complex'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("complex binding dg (kcal/mol)")
plt.legend()

# %% [markdown]
# ## 15/104

# %%
# Load data into dicts and plot 
titles = ["D501Y"]
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
d_input = {}
dir_num = 15
forward = 104
for i in tqdm_notebook([forward]):
    print(f"dir: {i}")
    d_works = {"complex": {}, "apo":{}}
    d_combined_works = {"complex": {}, "apo":{}}
    for phase in phases:
        for direction in directions:
            all_arrays = []
            for j in range(100):
                path = f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{i}/{i}_{phase}_{j}_{direction}.npy"
                try:
                    if os.path.exists(path):
                        with open(path, 'rb') as f:
                            array = np.load(f)
                            if not np.isnan(np.sum(array)):
                                all_arrays.append(array)
                except:
                    continue
            print(len(all_arrays))
            if all_arrays:
                combined = np.concatenate(all_arrays)
                accumulated = np.array([cycle[-1] - cycle[0] for cycle in combined])
#                 combined = np.array([cycle[0::100] for cycle in combined])
                print(f"about to save: {phase} {direction}")
                d_combined_works[phase][direction] = combined
                d_works[phase][direction] = accumulated

    d_input[i] = d_works
    
    # Plot
    complex_dg, complex_ddg = analyze(d_works['complex']['forward'], d_works['complex']['reverse'])
    apo_dg, apo_ddg = analyze(d_works['apo']['forward'], d_works['apo']['reverse'])
    plot(d_combined_works['complex']['forward'], d_combined_works['complex']['reverse'], complex_dg, complex_ddg, i, 'complex', os.path.dirname(path), titles[i-forward])
    plot(d_combined_works['apo']['forward'], d_combined_works['apo']['reverse'], apo_dg, apo_ddg, i, 'apo', os.path.dirname(path), titles[i-forward])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# dir: 104
# 100
# about to save: complex forward
# 100
# about to save: complex reverse
# 100
# about to save: apo forward
# 100
# about to save: apo reverse
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/104/104_complex_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/104/104_complex_work_dist.png
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/104/104_apo_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/104/104_apo_work_dist.png

# %%
plt.hist(d_works['complex']['forward'])
plt.hist(d_works['complex']['reverse']*-1)
# Out:
# (array([ 1.,  0.,  6.,  9., 12., 27., 18., 16.,  6.,  5.]),
#  array([-108.69680701, -101.51370704,  -94.33060707,  -87.14750709,
#          -79.96440712,  -72.78130715,  -65.59820718,  -58.4151072 ,
#          -51.23200723,  -44.04890726,  -36.86580729]),
#  <BarContainer object of 10 artists>)

# %%
# Bootstrap works
N_bootstraps = 10000
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
dgs_phase = {}
ddgs = {}
for i in [forward]:
    dgs_phase_all = []
    ddgs_all = []
    for _ in tqdm_notebook(range(N_bootstraps)):
        # Initialize data structure for works
        d_works = {"complex": {"forward":{}, "reverse":{}}, "apo":{"forward":{}, "reverse":{}}}

        # Save subsampled works
        for phase in phases:
            for direction in directions:
                work_array = np.array(d_input[i][phase][direction])
                num_samples = work_array.shape[0]
                subsample_indices = np.random.choice(range(num_samples), num_samples)
                d_works[phase][direction] = work_array[subsample_indices]
        d_dgs_phase, binding_dg = analyze_bootstrap(d_works)
        dgs_phase_all.append(d_dgs_phase)
        ddgs_all.append(binding_dg)
    dgs_phase[i] = dgs_phase_all
    ddgs[i] = ddgs_all
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
forward_ddg = np.mean(ddgs[forward])
forward_ci = np.percentile(ddgs[forward], 2.5), np.percentile(ddgs[forward], 97.5)
# reverse_ddg = np.mean(ddgs[reverse])
# reverse_ci = np.percentile(ddgs[reverse], 2.5), np.percentile(ddgs[reverse], 97.5)
# negative_reverse_ci = sorted(np.array(reverse_ci)*-1)
# discrepancy = tuple(np.array(forward_ci) - np.array(negative_reverse_ci))
# output_kt = [forward_ddg, forward_ci, reverse_ddg, reverse_ci, discrepancy]
# output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL]), round(reverse_ddg*KT_KCALMOL, 2), tuple([round(val, 2) for val in np.array(reverse_ci)*KT_KCALMOL]), tuple([round(val, 2) for val in np.array(discrepancy)*KT_KCALMOL])]

output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL])]

# %%
output_kcalmol
# Out:
# [-4.73, (-6.47, -2.53)]

# %%
# pd.DataFrame([output_kcalmol]).to_csv(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/analysis_{titles[0]}_{titles[1]}.csv")

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "wb") as f:
    pickle.dump(dgs_phase, f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "wb") as f:
    pickle.dump(ddgs, f)

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "rb") as f:
    dgs_phase = pickle.load(f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "rb") as f:
    ddgs = pickle.load(f)

# %%
# Plot ddgs
sns.distplot(np.array(ddgs[forward])*KT_KCALMOL, rug=True, label=titles[0])
# sns.distplot(np.array(ddgs[reverse])*-KT_KCALMOL, rug=True, label=f"-({titles[1]})")
plt.xlabel("binding ddg (kcal/mol)")
plt.legend()

# %%
# Get the std error
np.std(np.array(ddgs[forward])*KT_KCALMOL)
# Out:
# 0.9325669731491429

# %%
apo_dg = np.mean([d['apo'][0] for d in dgs_phase[forward]])
apo_ci = np.percentile([d['apo'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['apo'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_apo = [round(apo_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(apo_ci)*KT_KCALMOL])]

complex_dg = np.mean([d['complex'][0] for d in dgs_phase[forward]])
complex_ci = np.percentile([d['complex'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['complex'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_complex = [round(complex_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(complex_ci)*KT_KCALMOL])]

# %%
output_kcalmol_apo
# Out:
# [-17.24, (-17.84, -16.6)]

# %%
output_kcalmol_complex
# Out:
# [-21.96, (-23.61, -19.73)]

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['apo'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("apo binding dg (kcal/mol)")
plt.legend()

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['complex'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("complex binding dg (kcal/mol)")
plt.legend()

# %% [markdown]
# ## 15/105

# %%
# Load data into dicts and plot 
titles = ["D501Y"]
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
d_input = {}
dir_num = 15
forward = 105
for i in tqdm_notebook([forward]):
    print(f"dir: {i}")
    d_works = {"complex": {}, "apo":{}}
    d_combined_works = {"complex": {}, "apo":{}}
    for phase in phases:
        for direction in directions:
            all_arrays = []
            for j in range(100):
                path = f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{i}/{i}_{phase}_{j}_{direction}.npy"
                try:
                    if os.path.exists(path):
                        with open(path, 'rb') as f:
                            array = np.load(f)
                            if not np.isnan(np.sum(array)):
                                all_arrays.append(array)
                except:
                    continue
            print(len(all_arrays))
            if all_arrays:
                combined = np.concatenate(all_arrays)
                accumulated = np.array([cycle[-1] - cycle[0] for cycle in combined])
#                 combined = np.array([cycle[0::100] for cycle in combined])
                print(f"about to save: {phase} {direction}")
                d_combined_works[phase][direction] = combined
                d_works[phase][direction] = accumulated

    d_input[i] = d_works
    
    # Plot
    complex_dg, complex_ddg = analyze(d_works['complex']['forward'], d_works['complex']['reverse'])
    apo_dg, apo_ddg = analyze(d_works['apo']['forward'], d_works['apo']['reverse'])
    plot(d_combined_works['complex']['forward'], d_combined_works['complex']['reverse'], complex_dg, complex_ddg, i, 'complex', os.path.dirname(path), titles[i-forward])
    plot(d_combined_works['apo']['forward'], d_combined_works['apo']['reverse'], apo_dg, apo_ddg, i, 'apo', os.path.dirname(path), titles[i-forward])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# dir: 105
# 100
# about to save: complex forward
# 100
# about to save: complex reverse
# 100
# about to save: apo forward
# 100
# about to save: apo reverse
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/105/105_complex_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/105/105_complex_work_dist.png
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/105/105_apo_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/105/105_apo_work_dist.png

# %%
plt.hist(d_works['complex']['forward'])
plt.hist(d_works['complex']['reverse']*-1)
# Out:
# (array([ 1.,  2.,  6.,  6., 11., 27., 22., 14.,  6.,  5.]),
#  array([-96.08729584, -90.43472707, -84.78215829, -79.12958951,
#         -73.47702074, -67.82445196, -62.17188319, -56.51931441,
#         -50.86674563, -45.21417686, -39.56160808]),
#  <BarContainer object of 10 artists>)

# %%
# Bootstrap works
N_bootstraps = 10000
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
dgs_phase = {}
ddgs = {}
for i in [forward]:
    dgs_phase_all = []
    ddgs_all = []
    for _ in tqdm_notebook(range(N_bootstraps)):
        # Initialize data structure for works
        d_works = {"complex": {"forward":{}, "reverse":{}}, "apo":{"forward":{}, "reverse":{}}}

        # Save subsampled works
        for phase in phases:
            for direction in directions:
                work_array = np.array(d_input[i][phase][direction])
                num_samples = work_array.shape[0]
                subsample_indices = np.random.choice(range(num_samples), num_samples)
                d_works[phase][direction] = work_array[subsample_indices]
        d_dgs_phase, binding_dg = analyze_bootstrap(d_works)
        dgs_phase_all.append(d_dgs_phase)
        ddgs_all.append(binding_dg)
    dgs_phase[i] = dgs_phase_all
    ddgs[i] = ddgs_all
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
forward_ddg = np.mean(ddgs[forward])
forward_ci = np.percentile(ddgs[forward], 2.5), np.percentile(ddgs[forward], 97.5)
# reverse_ddg = np.mean(ddgs[reverse])
# reverse_ci = np.percentile(ddgs[reverse], 2.5), np.percentile(ddgs[reverse], 97.5)
# negative_reverse_ci = sorted(np.array(reverse_ci)*-1)
# discrepancy = tuple(np.array(forward_ci) - np.array(negative_reverse_ci))
# output_kt = [forward_ddg, forward_ci, reverse_ddg, reverse_ci, discrepancy]
# output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL]), round(reverse_ddg*KT_KCALMOL, 2), tuple([round(val, 2) for val in np.array(reverse_ci)*KT_KCALMOL]), tuple([round(val, 2) for val in np.array(discrepancy)*KT_KCALMOL])]

output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL])]

# %%
output_kcalmol
# Out:
# [-7.56, (-8.94, -5.95)]

# %%
# pd.DataFrame([output_kcalmol]).to_csv(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/analysis_{titles[0]}_{titles[1]}.csv")

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "wb") as f:
    pickle.dump(dgs_phase, f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "wb") as f:
    pickle.dump(ddgs, f)

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "rb") as f:
    dgs_phase = pickle.load(f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "rb") as f:
    ddgs = pickle.load(f)

# %%
# Plot ddgs
sns.distplot(np.array(ddgs[forward])*KT_KCALMOL, rug=True, label=titles[0])
# sns.distplot(np.array(ddgs[reverse])*-KT_KCALMOL, rug=True, label=f"-({titles[1]})")
plt.xlabel("binding ddg (kcal/mol)")
plt.legend()

# %%
# Get the std error
np.std(np.array(ddgs[forward])*KT_KCALMOL)
# Out:
# 0.825114919054056

# %%
apo_dg = np.mean([d['apo'][0] for d in dgs_phase[forward]])
apo_ci = np.percentile([d['apo'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['apo'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_apo = [round(apo_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(apo_ci)*KT_KCALMOL])]

complex_dg = np.mean([d['complex'][0] for d in dgs_phase[forward]])
complex_ci = np.percentile([d['complex'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['complex'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_complex = [round(complex_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(complex_ci)*KT_KCALMOL])]

# %%
output_kcalmol_apo
# Out:
# [-16.73, (-17.38, -16.05)]

# %%
output_kcalmol_complex
# Out:
# [-24.29, (-25.5, -22.86)]

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['apo'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("apo binding dg (kcal/mol)")
plt.legend()

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['complex'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("complex binding dg (kcal/mol)")
plt.legend()

# %% [markdown]
# ## 15/106

# %%
# Load data into dicts and plot 
titles = ["D501Y"]
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
d_input = {}
dir_num = 15
forward = 106
for i in tqdm_notebook([forward]):
    print(f"dir: {i}")
    d_works = {"complex": {}, "apo":{}}
    d_combined_works = {"complex": {}, "apo":{}}
    for phase in phases:
        for direction in directions:
            all_arrays = []
            for j in range(100):
                path = f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{i}/{i}_{phase}_{j}_{direction}.npy"
                try:
                    if os.path.exists(path):
                        with open(path, 'rb') as f:
                            array = np.load(f)
                            if not np.isnan(np.sum(array)):
                                all_arrays.append(array)
                except:
                    continue
            print(len(all_arrays))
            if all_arrays:
                combined = np.concatenate(all_arrays)
                accumulated = np.array([cycle[-1] - cycle[0] for cycle in combined])
#                 combined = np.array([cycle[0::100] for cycle in combined])
                print(f"about to save: {phase} {direction}")
                d_combined_works[phase][direction] = combined
                d_works[phase][direction] = accumulated

    d_input[i] = d_works
    
    # Plot
    complex_dg, complex_ddg = analyze(d_works['complex']['forward'], d_works['complex']['reverse'])
    apo_dg, apo_ddg = analyze(d_works['apo']['forward'], d_works['apo']['reverse'])
    plot(d_combined_works['complex']['forward'], d_combined_works['complex']['reverse'], complex_dg, complex_ddg, i, 'complex', os.path.dirname(path), titles[i-forward])
    plot(d_combined_works['apo']['forward'], d_combined_works['apo']['reverse'], apo_dg, apo_ddg, i, 'apo', os.path.dirname(path), titles[i-forward])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# dir: 106
# 100
# about to save: complex forward
# 100
# about to save: complex reverse
# 100
# about to save: apo forward
# 100
# about to save: apo reverse
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/106/106_complex_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/106/106_complex_work_dist.png
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/106/106_apo_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/106/106_apo_work_dist.png

# %%
plt.hist(d_works['complex']['forward'])
plt.hist(d_works['complex']['reverse']*-1)
# Out:
# (array([ 2.,  1., 10.,  6., 16., 17., 17., 17.,  9.,  5.]),
#  array([-89.27103931, -84.09939693, -78.92775454, -73.75611216,
#         -68.58446978, -63.4128274 , -58.24118501, -53.06954263,
#         -47.89790025, -42.72625787, -37.55461548]),
#  <BarContainer object of 10 artists>)

# %%
# Bootstrap works
N_bootstraps = 10000
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
dgs_phase = {}
ddgs = {}
for i in [forward]:
    dgs_phase_all = []
    ddgs_all = []
    for _ in tqdm_notebook(range(N_bootstraps)):
        # Initialize data structure for works
        d_works = {"complex": {"forward":{}, "reverse":{}}, "apo":{"forward":{}, "reverse":{}}}

        # Save subsampled works
        for phase in phases:
            for direction in directions:
                work_array = np.array(d_input[i][phase][direction])
                num_samples = work_array.shape[0]
                subsample_indices = np.random.choice(range(num_samples), num_samples)
                d_works[phase][direction] = work_array[subsample_indices]
        d_dgs_phase, binding_dg = analyze_bootstrap(d_works)
        dgs_phase_all.append(d_dgs_phase)
        ddgs_all.append(binding_dg)
    dgs_phase[i] = dgs_phase_all
    ddgs[i] = ddgs_all
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
forward_ddg = np.mean(ddgs[forward])
forward_ci = np.percentile(ddgs[forward], 2.5), np.percentile(ddgs[forward], 97.5)
# reverse_ddg = np.mean(ddgs[reverse])
# reverse_ci = np.percentile(ddgs[reverse], 2.5), np.percentile(ddgs[reverse], 97.5)
# negative_reverse_ci = sorted(np.array(reverse_ci)*-1)
# discrepancy = tuple(np.array(forward_ci) - np.array(negative_reverse_ci))
# output_kt = [forward_ddg, forward_ci, reverse_ddg, reverse_ci, discrepancy]
# output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL]), round(reverse_ddg*KT_KCALMOL, 2), tuple([round(val, 2) for val in np.array(reverse_ci)*KT_KCALMOL]), tuple([round(val, 2) for val in np.array(discrepancy)*KT_KCALMOL])]

output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL])]

# %%
output_kcalmol
# Out:
# [-6.14, (-8.81, -4.06)]

# %%
# pd.DataFrame([output_kcalmol]).to_csv(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/analysis_{titles[0]}_{titles[1]}.csv")

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "wb") as f:
    pickle.dump(dgs_phase, f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "wb") as f:
    pickle.dump(ddgs, f)

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "rb") as f:
    dgs_phase = pickle.load(f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "rb") as f:
    ddgs = pickle.load(f)

# %%
# Plot ddgs
sns.distplot(np.array(ddgs[forward])*KT_KCALMOL, rug=True, label=titles[0])
# sns.distplot(np.array(ddgs[reverse])*-KT_KCALMOL, rug=True, label=f"-({titles[1]})")
plt.xlabel("binding ddg (kcal/mol)")
plt.legend()

# %%
# Get the std error
np.std(np.array(ddgs[forward])*KT_KCALMOL) / np.sqrt(10000)
# Out:
# 0.012344191387849202

# %%
apo_dg = np.mean([d['apo'][0] for d in dgs_phase[forward]])
apo_ci = np.percentile([d['apo'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['apo'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_apo = [round(apo_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(apo_ci)*KT_KCALMOL])]

complex_dg = np.mean([d['complex'][0] for d in dgs_phase[forward]])
complex_ci = np.percentile([d['complex'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['complex'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_complex = [round(complex_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(complex_ci)*KT_KCALMOL])]

# %%
output_kcalmol_apo
# Out:
# [-16.87, (-17.44, -16.27)]

# %%
output_kcalmol_complex
# Out:
# [-23.01, (-25.62, -21.03)]

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['apo'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("apo binding dg (kcal/mol)")
plt.legend()

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['complex'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("complex binding dg (kcal/mol)")
plt.legend()

# %% [markdown]
# ## 15/107

# %%
# Load data into dicts and plot 
titles = ["N501Y"]
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
d_input = {}
dir_num = 15
forward = 107
for i in tqdm_notebook([forward]):
    print(f"dir: {i}")
    d_works = {"complex": {}, "apo":{}}
    d_combined_works = {"complex": {}, "apo":{}}
    for phase in phases:
        for direction in directions:
            all_arrays = []
            for j in range(100):
                path = f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{i}/{i}_{phase}_{j}_{direction}.npy"
                try:
                    if os.path.exists(path):
                        with open(path, 'rb') as f:
                            array = np.load(f)
                            if not np.isnan(np.sum(array)):
                                all_arrays.append(array)
                except:
                    continue
            print(len(all_arrays))
            if all_arrays:
                combined = np.concatenate(all_arrays)
                accumulated = np.array([cycle[-1] - cycle[0] for cycle in combined])
#                 combined = np.array([cycle[0::100] for cycle in combined])
                print(f"about to save: {phase} {direction}")
                d_combined_works[phase][direction] = combined
                d_works[phase][direction] = accumulated

    d_input[i] = d_works
    
    # Plot
    complex_dg, complex_ddg = analyze(d_works['complex']['forward'], d_works['complex']['reverse'])
    apo_dg, apo_ddg = analyze(d_works['apo']['forward'], d_works['apo']['reverse'])
    plot(d_combined_works['complex']['forward'], d_combined_works['complex']['reverse'], complex_dg, complex_ddg, i, 'complex', os.path.dirname(path), titles[i-forward])
    plot(d_combined_works['apo']['forward'], d_combined_works['apo']['reverse'], apo_dg, apo_ddg, i, 'apo', os.path.dirname(path), titles[i-forward])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# dir: 107
# 100
# about to save: complex forward
# 100
# about to save: complex reverse
# 100
# about to save: apo forward
# 100
# about to save: apo reverse
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/107/107_complex_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/107/107_complex_work_dist.png
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/107/107_apo_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/107/107_apo_work_dist.png

# %%
plt.hist(d_works['complex']['forward'])
plt.hist(d_works['complex']['reverse']*-1)
# Out:
# (array([ 5.,  3.,  9., 19., 18., 19., 10.,  4.,  7.,  6.]),
#  array([ 74.25177233,  79.60066334,  84.94955436,  90.29844537,
#          95.64733639, 100.9962274 , 106.34511841, 111.69400943,
#         117.04290044, 122.39179145, 127.74068247]),
#  <BarContainer object of 10 artists>)

# %%
# Bootstrap works
N_bootstraps = 10000
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
dgs_phase = {}
ddgs = {}
for i in [forward]:
    dgs_phase_all = []
    ddgs_all = []
    for _ in tqdm_notebook(range(N_bootstraps)):
        # Initialize data structure for works
        d_works = {"complex": {"forward":{}, "reverse":{}}, "apo":{"forward":{}, "reverse":{}}}

        # Save subsampled works
        for phase in phases:
            for direction in directions:
                work_array = np.array(d_input[i][phase][direction])
                num_samples = work_array.shape[0]
                subsample_indices = np.random.choice(range(num_samples), num_samples)
                d_works[phase][direction] = work_array[subsample_indices]
        d_dgs_phase, binding_dg = analyze_bootstrap(d_works)
        dgs_phase_all.append(d_dgs_phase)
        ddgs_all.append(binding_dg)
    dgs_phase[i] = dgs_phase_all
    ddgs[i] = ddgs_all
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
forward_ddg = np.mean(ddgs[forward])
forward_ci = np.percentile(ddgs[forward], 2.5), np.percentile(ddgs[forward], 97.5)
# reverse_ddg = np.mean(ddgs[reverse])
# reverse_ci = np.percentile(ddgs[reverse], 2.5), np.percentile(ddgs[reverse], 97.5)
# negative_reverse_ci = sorted(np.array(reverse_ci)*-1)
# discrepancy = tuple(np.array(forward_ci) - np.array(negative_reverse_ci))
# output_kt = [forward_ddg, forward_ci, reverse_ddg, reverse_ci, discrepancy]
# output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL]), round(reverse_ddg*KT_KCALMOL, 2), tuple([round(val, 2) for val in np.array(reverse_ci)*KT_KCALMOL]), tuple([round(val, 2) for val in np.array(discrepancy)*KT_KCALMOL])]

output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL])]

# %%
output_kcalmol
# Out:
# [5.97, (4.45, 7.27)]

# %%
# pd.DataFrame([output_kcalmol]).to_csv(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/analysis_{titles[0]}_{titles[1]}.csv")

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "wb") as f:
    pickle.dump(dgs_phase, f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "wb") as f:
    pickle.dump(ddgs, f)

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "rb") as f:
    dgs_phase = pickle.load(f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "rb") as f:
    ddgs = pickle.load(f)

# %%
# Plot ddgs
sns.distplot(np.array(ddgs[forward])*KT_KCALMOL, rug=True, label=titles[0])
# sns.distplot(np.array(ddgs[reverse])*-KT_KCALMOL, rug=True, label=f"-({titles[1]})")
plt.xlabel("binding ddg (kcal/mol)")
plt.legend()

# %%
# Get the std error
np.std(np.array(ddgs[forward])*KT_KCALMOL) / np.sqrt(10000)
# Out:
# 0.007092508285801375

# %%
apo_dg = np.mean([d['apo'][0] for d in dgs_phase[forward]])
apo_ci = np.percentile([d['apo'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['apo'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_apo = [round(apo_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(apo_ci)*KT_KCALMOL])]

complex_dg = np.mean([d['complex'][0] for d in dgs_phase[forward]])
complex_ci = np.percentile([d['complex'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['complex'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_complex = [round(complex_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(complex_ci)*KT_KCALMOL])]

# %%
output_kcalmol_apo
# Out:
# [66.57, (66.11, 67.05)]

# %%
output_kcalmol_complex
# Out:
# [72.54, (71.07, 73.75)]

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['apo'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("apo binding dg (kcal/mol)")
plt.legend()

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['complex'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("complex binding dg (kcal/mol)")
plt.legend()

# %% [markdown]
# ## 15/108

# %%
# Load data into dicts and plot 
titles = ["N501Y"]
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
d_input = {}
dir_num = 15
forward = 108
for i in tqdm_notebook([forward]):
    print(f"dir: {i}")
    d_works = {"complex": {}, "apo":{}}
    d_combined_works = {"complex": {}, "apo":{}}
    for phase in phases:
        for direction in directions:
            all_arrays = []
            for j in range(100):
                path = f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{i}/{i}_{phase}_{j}_{direction}.npy"
                try:
                    if os.path.exists(path):
                        with open(path, 'rb') as f:
                            array = np.load(f)
                            if not np.isnan(np.sum(array)):
                                all_arrays.append(array)
                except:
                    continue
            print(len(all_arrays))
            if all_arrays:
                combined = np.concatenate(all_arrays)
                accumulated = np.array([cycle[-1] - cycle[0] for cycle in combined])
#                 combined = np.array([cycle[0::100] for cycle in combined])
                print(f"about to save: {phase} {direction}")
                d_combined_works[phase][direction] = combined
                d_works[phase][direction] = accumulated

    d_input[i] = d_works
    
    # Plot
    complex_dg, complex_ddg = analyze(d_works['complex']['forward'], d_works['complex']['reverse'])
    apo_dg, apo_ddg = analyze(d_works['apo']['forward'], d_works['apo']['reverse'])
    plot(d_combined_works['complex']['forward'], d_combined_works['complex']['reverse'], complex_dg, complex_ddg, i, 'complex', os.path.dirname(path), titles[i-forward])
    plot(d_combined_works['apo']['forward'], d_combined_works['apo']['reverse'], apo_dg, apo_ddg, i, 'apo', os.path.dirname(path), titles[i-forward])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# dir: 108
# 100
# about to save: complex forward
# 100
# about to save: complex reverse
# 100
# about to save: apo forward
# 100
# about to save: apo reverse
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/108/108_complex_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/108/108_complex_work_dist.png
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/108/108_apo_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/108/108_apo_work_dist.png

# %%
plt.hist(d_works['complex']['forward'])
plt.hist(d_works['complex']['reverse']*-1)
# Out:
# (array([ 2.,  3.,  6., 11., 14., 15., 18., 15.,  9.,  7.]),
#  array([ 73.13211012,  78.21295982,  83.29380951,  88.3746592 ,
#          93.45550889,  98.53635858, 103.61720827, 108.69805796,
#         113.77890766, 118.85975735, 123.94060704]),
#  <BarContainer object of 10 artists>)

# %%
np.std(d_works['complex']['forward'])
# Out:
# 11.047282237443461

# %%
np.std(d_works['complex']['reverse']*-1)
# Out:
# 10.997621563777273

# %%
# Bootstrap works
N_bootstraps = 10000
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
dgs_phase = {}
ddgs = {}
for i in [forward]:
    dgs_phase_all = []
    ddgs_all = []
    for _ in tqdm_notebook(range(N_bootstraps)):
        # Initialize data structure for works
        d_works = {"complex": {"forward":{}, "reverse":{}}, "apo":{"forward":{}, "reverse":{}}}

        # Save subsampled works
        for phase in phases:
            for direction in directions:
                work_array = np.array(d_input[i][phase][direction])
                num_samples = work_array.shape[0]
                subsample_indices = np.random.choice(range(num_samples), num_samples)
                d_works[phase][direction] = work_array[subsample_indices]
        d_dgs_phase, binding_dg = analyze_bootstrap(d_works)
        dgs_phase_all.append(d_dgs_phase)
        ddgs_all.append(binding_dg)
    dgs_phase[i] = dgs_phase_all
    ddgs[i] = ddgs_all
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
forward_ddg = np.mean(ddgs[forward])
forward_ci = np.percentile(ddgs[forward], 2.5), np.percentile(ddgs[forward], 97.5)
# reverse_ddg = np.mean(ddgs[reverse])
# reverse_ci = np.percentile(ddgs[reverse], 2.5), np.percentile(ddgs[reverse], 97.5)
# negative_reverse_ci = sorted(np.array(reverse_ci)*-1)
# discrepancy = tuple(np.array(forward_ci) - np.array(negative_reverse_ci))
# output_kt = [forward_ddg, forward_ci, reverse_ddg, reverse_ci, discrepancy]
# output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL]), round(reverse_ddg*KT_KCALMOL, 2), tuple([round(val, 2) for val in np.array(reverse_ci)*KT_KCALMOL]), tuple([round(val, 2) for val in np.array(discrepancy)*KT_KCALMOL])]

output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL])]

# %%
output_kcalmol
# Out:
# [6.91, (5.78, 7.87)]

# %%
# pd.DataFrame([output_kcalmol]).to_csv(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/analysis_{titles[0]}_{titles[1]}.csv")

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "wb") as f:
    pickle.dump(dgs_phase, f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "wb") as f:
    pickle.dump(ddgs, f)

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "rb") as f:
    dgs_phase = pickle.load(f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "rb") as f:
    ddgs = pickle.load(f)

# %%
# Plot ddgs
sns.distplot(np.array(ddgs[forward])*KT_KCALMOL, rug=True, label=titles[0])
# sns.distplot(np.array(ddgs[reverse])*-KT_KCALMOL, rug=True, label=f"-({titles[1]})")
plt.xlabel("binding ddg (kcal/mol)")
plt.legend()

# %%
# Get the std error
np.std(np.array(ddgs[forward])*KT_KCALMOL)
# Out:
# 0.5399799741849337

# %%
apo_dg = np.mean([d['apo'][0] for d in dgs_phase[forward]])
apo_ci = np.percentile([d['apo'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['apo'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_apo = [round(apo_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(apo_ci)*KT_KCALMOL])]

complex_dg = np.mean([d['complex'][0] for d in dgs_phase[forward]])
complex_ci = np.percentile([d['complex'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['complex'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_complex = [round(complex_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(complex_ci)*KT_KCALMOL])]

# %%
output_kcalmol_apo
# Out:
# [66.31, (65.93, 66.66)]

# %%
output_kcalmol_complex
# Out:
# [73.22, (72.17, 74.09)]

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['apo'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("apo binding dg (kcal/mol)")
plt.legend()

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['complex'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("complex binding dg (kcal/mol)")
plt.legend()

# %% [markdown]
# ## 15/109

# %%
# Load data into dicts and plot 
titles = ["N501Y"]
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
d_input = {}
dir_num = 15
forward = 109
for i in tqdm_notebook([forward]):
    print(f"dir: {i}")
    d_works = {"complex": {}, "apo":{}}
    d_combined_works = {"complex": {}, "apo":{}}
    for phase in phases:
        for direction in directions:
            all_arrays = []
            for j in range(100):
                path = f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{i}/{i}_{phase}_{j}_{direction}.npy"
                try:
                    if os.path.exists(path):
                        with open(path, 'rb') as f:
                            array = np.load(f)
                            if not np.isnan(np.sum(array)):
                                all_arrays.append(array)
                except:
                    continue
            print(len(all_arrays))
            if all_arrays:
                combined = np.concatenate(all_arrays)
                accumulated = np.array([cycle[-1] - cycle[0] for cycle in combined])
#                 combined = np.array([cycle[0::100] for cycle in combined])
                print(f"about to save: {phase} {direction}")
                d_combined_works[phase][direction] = combined
                d_works[phase][direction] = accumulated

    d_input[i] = d_works
    
    # Plot
    complex_dg, complex_ddg = analyze(d_works['complex']['forward'], d_works['complex']['reverse'])
    apo_dg, apo_ddg = analyze(d_works['apo']['forward'], d_works['apo']['reverse'])
    plot(d_combined_works['complex']['forward'], d_combined_works['complex']['reverse'], complex_dg, complex_ddg, i, 'complex', os.path.dirname(path), titles[i-forward])
    plot(d_combined_works['apo']['forward'], d_combined_works['apo']['reverse'], apo_dg, apo_ddg, i, 'apo', os.path.dirname(path), titles[i-forward])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# dir: 109
# 100
# about to save: complex forward
# 100
# about to save: complex reverse
# 100
# about to save: apo forward
# 100
# about to save: apo reverse
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/109/109_complex_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/109/109_complex_work_dist.png
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/109/109_apo_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/109/109_apo_work_dist.png

# %%
plt.hist(d_works['complex']['forward'])
plt.hist(d_works['complex']['reverse']*-1)
# Out:
# (array([ 9., 10., 18., 15., 16.,  8.,  8., 10.,  4.,  2.]),
#  array([ 79.16606315,  83.81863053,  88.47119791,  93.12376529,
#          97.77633267, 102.42890005, 107.08146743, 111.73403482,
#         116.3866022 , 121.03916958, 125.69173696]),
#  <BarContainer object of 10 artists>)

# %%
np.std(d_works['complex']['forward'])
# Out:
# 8.127364208591532

# %%
np.std(d_works['complex']['reverse']*-1)
# Out:
# 11.034107691855507

# %%
# Bootstrap works
N_bootstraps = 10000
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
dgs_phase = {}
ddgs = {}
for i in [forward]:
    dgs_phase_all = []
    ddgs_all = []
    for _ in tqdm_notebook(range(N_bootstraps)):
        # Initialize data structure for works
        d_works = {"complex": {"forward":{}, "reverse":{}}, "apo":{"forward":{}, "reverse":{}}}

        # Save subsampled works
        for phase in phases:
            for direction in directions:
                work_array = np.array(d_input[i][phase][direction])
                num_samples = work_array.shape[0]
                subsample_indices = np.random.choice(range(num_samples), num_samples)
                d_works[phase][direction] = work_array[subsample_indices]
        d_dgs_phase, binding_dg = analyze_bootstrap(d_works)
        dgs_phase_all.append(d_dgs_phase)
        ddgs_all.append(binding_dg)
    dgs_phase[i] = dgs_phase_all
    ddgs[i] = ddgs_all
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
forward_ddg = np.mean(ddgs[forward])
forward_ci = np.percentile(ddgs[forward], 2.5), np.percentile(ddgs[forward], 97.5)
# reverse_ddg = np.mean(ddgs[reverse])
# reverse_ci = np.percentile(ddgs[reverse], 2.5), np.percentile(ddgs[reverse], 97.5)
# negative_reverse_ci = sorted(np.array(reverse_ci)*-1)
# discrepancy = tuple(np.array(forward_ci) - np.array(negative_reverse_ci))
# output_kt = [forward_ddg, forward_ci, reverse_ddg, reverse_ci, discrepancy]
# output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL]), round(reverse_ddg*KT_KCALMOL, 2), tuple([round(val, 2) for val in np.array(reverse_ci)*KT_KCALMOL]), tuple([round(val, 2) for val in np.array(discrepancy)*KT_KCALMOL])]

output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL])]

# %%
output_kcalmol
# Out:
# [6.05, (4.88, 7.23)]

# %%
# pd.DataFrame([output_kcalmol]).to_csv(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/analysis_{titles[0]}_{titles[1]}.csv")

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "wb") as f:
    pickle.dump(dgs_phase, f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "wb") as f:
    pickle.dump(ddgs, f)

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "rb") as f:
    dgs_phase = pickle.load(f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "rb") as f:
    ddgs = pickle.load(f)

# %%
# Plot ddgs
sns.distplot(np.array(ddgs[forward])*KT_KCALMOL, rug=True, label=titles[0])
# sns.distplot(np.array(ddgs[reverse])*-KT_KCALMOL, rug=True, label=f"-({titles[1]})")
plt.xlabel("binding ddg (kcal/mol)")
plt.legend()

# %%
# Get the std error
np.std(np.array(ddgs[forward])*KT_KCALMOL) / np.sqrt(10000)
# Out:
# 0.0060247277831465725

# %%
apo_dg = np.mean([d['apo'][0] for d in dgs_phase[forward]])
apo_ci = np.percentile([d['apo'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['apo'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_apo = [round(apo_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(apo_ci)*KT_KCALMOL])]

complex_dg = np.mean([d['complex'][0] for d in dgs_phase[forward]])
complex_ci = np.percentile([d['complex'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['complex'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_complex = [round(complex_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(complex_ci)*KT_KCALMOL])]

# %%
output_kcalmol_apo
# Out:
# [66.21, (65.84, 66.64)]

# %%
output_kcalmol_complex
# Out:
# [72.26, (71.17, 73.38)]

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['apo'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("apo binding dg (kcal/mol)")
plt.legend()

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['complex'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("complex binding dg (kcal/mol)")
plt.legend()

# %% [markdown]
# ## 15/110

# %%
# Load data into dicts and plot 
titles = ["N501Y"]
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
d_input = {}
dir_num = 15
forward = 110
for i in tqdm_notebook([forward]):
    print(f"dir: {i}")
    d_works = {"complex": {}, "apo":{}}
    d_combined_works = {"complex": {}, "apo":{}}
    for phase in phases:
        for direction in directions:
            all_arrays = []
            for j in range(500):
                path = f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{i}/{i}_{phase}_{j}_{direction}.npy"
                try:
                    if os.path.exists(path):
                        with open(path, 'rb') as f:
                            array = np.load(f)
                            if not np.isnan(np.sum(array)):
                                all_arrays.append(array)
                except:
                    continue
            print(len(all_arrays))
            if all_arrays:
                combined = np.concatenate(all_arrays)
                accumulated = np.array([cycle[-1] - cycle[0] for cycle in combined])
#                 combined = np.array([cycle[0::100] for cycle in combined])
                print(f"about to save: {phase} {direction}")
                d_combined_works[phase][direction] = combined
                d_works[phase][direction] = accumulated

    d_input[i] = d_works
    
    # Plot
    complex_dg, complex_ddg = analyze(d_works['complex']['forward'], d_works['complex']['reverse'])
    apo_dg, apo_ddg = analyze(d_works['apo']['forward'], d_works['apo']['reverse'])
    plot(d_combined_works['complex']['forward'], d_combined_works['complex']['reverse'], complex_dg, complex_ddg, i, 'complex', os.path.dirname(path), titles[i-forward])
    plot(d_combined_works['apo']['forward'], d_combined_works['apo']['reverse'], apo_dg, apo_ddg, i, 'apo', os.path.dirname(path), titles[i-forward])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# dir: 110
# 500
# about to save: complex forward
# 500
# about to save: complex reverse
# 500
# about to save: apo forward
# 500
# about to save: apo reverse
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/110/110_complex_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/110/110_complex_work_dist.png
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/110/110_apo_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/110/110_apo_work_dist.png

# %%
plt.hist(d_works['complex']['forward'])
plt.hist(d_works['complex']['reverse']*-1)
# Out:
# (array([  4.,   4.,  41.,  72.,  94.,  96., 100.,  58.,  25.,   6.]),
#  array([ 67.62905571,  73.88154384,  80.13403198,  86.38652011,
#          92.63900825,  98.89149638, 105.14398452, 111.39647266,
#         117.64896079, 123.90144893, 130.15393706]),
#  <BarContainer object of 10 artists>)

# %%
# Bootstrap works
N_bootstraps = 10000
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
dgs_phase = {}
ddgs = {}
for i in [forward]:
    dgs_phase_all = []
    ddgs_all = []
    for _ in tqdm_notebook(range(N_bootstraps)):
        # Initialize data structure for works
        d_works = {"complex": {"forward":{}, "reverse":{}}, "apo":{"forward":{}, "reverse":{}}}

        # Save subsampled works
        for phase in phases:
            for direction in directions:
                work_array = np.array(d_input[i][phase][direction])
                num_samples = work_array.shape[0]
                subsample_indices = np.random.choice(range(num_samples), num_samples)
                d_works[phase][direction] = work_array[subsample_indices]
        d_dgs_phase, binding_dg = analyze_bootstrap(d_works)
        dgs_phase_all.append(d_dgs_phase)
        ddgs_all.append(binding_dg)
    dgs_phase[i] = dgs_phase_all
    ddgs[i] = ddgs_all
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
forward_ddg = np.mean(ddgs[forward])
forward_ci = np.percentile(ddgs[forward], 2.5), np.percentile(ddgs[forward], 97.5)
# reverse_ddg = np.mean(ddgs[reverse])
# reverse_ci = np.percentile(ddgs[reverse], 2.5), np.percentile(ddgs[reverse], 97.5)
# negative_reverse_ci = sorted(np.array(reverse_ci)*-1)
# discrepancy = tuple(np.array(forward_ci) - np.array(negative_reverse_ci))
# output_kt = [forward_ddg, forward_ci, reverse_ddg, reverse_ci, discrepancy]
# output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL]), round(reverse_ddg*KT_KCALMOL, 2), tuple([round(val, 2) for val in np.array(reverse_ci)*KT_KCALMOL]), tuple([round(val, 2) for val in np.array(discrepancy)*KT_KCALMOL])]

output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL])]

# %%
output_kcalmol
# Out:
# [5.97, (4.45, 7.27)]

# %%
# pd.DataFrame([output_kcalmol]).to_csv(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/analysis_{titles[0]}_{titles[1]}.csv")

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "wb") as f:
    pickle.dump(dgs_phase, f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "wb") as f:
    pickle.dump(ddgs, f)

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "rb") as f:
    dgs_phase = pickle.load(f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "rb") as f:
    ddgs = pickle.load(f)

# %%
# Plot ddgs
sns.distplot(np.array(ddgs[forward])*KT_KCALMOL, rug=True, label=titles[0])
# sns.distplot(np.array(ddgs[reverse])*-KT_KCALMOL, rug=True, label=f"-({titles[1]})")
plt.xlabel("binding ddg (kcal/mol)")
plt.legend()

# %%
# Get the std error
np.std(np.array(ddgs[forward])*KT_KCALMOL) / np.sqrt(10000)
# Out:
# 0.007092508285801375

# %%
apo_dg = np.mean([d['apo'][0] for d in dgs_phase[forward]])
apo_ci = np.percentile([d['apo'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['apo'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_apo = [round(apo_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(apo_ci)*KT_KCALMOL])]

complex_dg = np.mean([d['complex'][0] for d in dgs_phase[forward]])
complex_ci = np.percentile([d['complex'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['complex'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_complex = [round(complex_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(complex_ci)*KT_KCALMOL])]

# %%
output_kcalmol_apo
# Out:
# [66.57, (66.11, 67.05)]

# %%
output_kcalmol_complex
# Out:
# [72.54, (71.07, 73.75)]

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['apo'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("apo binding dg (kcal/mol)")
plt.legend()

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['complex'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("complex binding dg (kcal/mol)")
plt.legend()

# %% [markdown]
# ## 15/111

# %%
# Load data into dicts and plot 
titles = ["N501Y"]
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
d_input = {}
dir_num = 15
forward = 111
for i in tqdm_notebook([forward]):
    print(f"dir: {i}")
    d_works = {"complex": {}, "apo":{}}
    d_combined_works = {"complex": {}, "apo":{}}
    for phase in phases:
        for direction in directions:
            all_arrays = []
            for j in range(500):
                path = f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{i}/{i}_{phase}_{j}_{direction}.npy"
                try:
                    if os.path.exists(path):
                        with open(path, 'rb') as f:
                            array = np.load(f)
                            if not np.isnan(np.sum(array)):
                                all_arrays.append(array)
                except:
                    continue
            print(len(all_arrays))
            if all_arrays:
                combined = np.concatenate(all_arrays)
                accumulated = np.array([cycle[-1] - cycle[0] for cycle in combined])
#                 combined = np.array([cycle[0::100] for cycle in combined])
                print(f"about to save: {phase} {direction}")
                d_combined_works[phase][direction] = combined
                d_works[phase][direction] = accumulated

    d_input[i] = d_works
    
    # Plot
    complex_dg, complex_ddg = analyze(d_works['complex']['forward'], d_works['complex']['reverse'])
    apo_dg, apo_ddg = analyze(d_works['apo']['forward'], d_works['apo']['reverse'])
    plot(d_combined_works['complex']['forward'], d_combined_works['complex']['reverse'], complex_dg, complex_ddg, i, 'complex', os.path.dirname(path), titles[i-forward])
    plot(d_combined_works['apo']['forward'], d_combined_works['apo']['reverse'], apo_dg, apo_ddg, i, 'apo', os.path.dirname(path), titles[i-forward])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# dir: 111
# 100
# about to save: complex forward
# 100
# about to save: complex reverse
# 100
# about to save: apo forward
# 100
# about to save: apo reverse
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/111/111_complex_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/111/111_complex_work_dist.png
# plotting work trajs
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/111/111_apo_work_traj.png
# plotting work distrib
# saved to: /data/chodera/zhangi/perses_benchmark/neq/15/111/111_apo_work_dist.png

# %%
d_works['apo']['forward']
# Out:
# array([159538.34956467, 162558.99018735, 115962.58093846, 192613.82354545,
#        153634.75990577, 222927.76822346, 147457.81042827, 166829.5403137 ,
#        108151.53342929, 162270.61063362, 107332.05237182, 123303.56231555,
#         88065.30262187, 123689.1293128 , 200381.48259827, 197836.4602025 ,
#         97842.79960781, 123020.50229442, 229227.79610928, 135345.87049295,
#        217267.58176321, 145152.78298413, 113195.3811762 , 130065.3825477 ,
#        137048.23012138, 106254.44468309, 190174.98538578, 185608.55313458,
#        159276.91046295, 193221.54614683, 122623.75092401, 151232.39423222,
#        205160.60113928,  71374.79690719, 166854.2540671 ,  87943.95806361,
#        137172.82649035, 145538.91876794, 216912.65950855, 133527.92152557,
#        204122.64524631, 128961.49033171, 206235.92323033, 108313.56846499,
#        165974.43988471, 151039.7234614 , 167276.17473259, 209258.12952944,
#         95490.08879993, 111601.02392849,  95687.44409908, 101080.38882286,
#        141595.53871779, 110797.26084334, 157411.66288832, 152977.95072077,
#        180528.4717312 , 210054.79928691, 184139.29608668, 141552.04025546,
#        124410.78745615, 194425.22858118, 101383.9892247 , 173319.75380673,
#        151135.41445683, 120734.79158408, 161979.09295078, 160133.32418032,
#        179153.36457373, 120779.69450779, 195048.53114794,  80773.85936945,
#        128518.22662721, 110168.08213408, 134741.45331129, 122770.81242767,
#        197994.45536633,  91604.42046572, 122507.00188607, 136633.19514336,
#         88701.64197118, 182745.14559319, 162467.04127107, 229910.39919837,
#        151633.32811227, 182774.89950385, 137612.18193211, 116989.86698242,
#         89321.63397102, 180613.95516188, 113444.97334767, 190075.318157  ,
#        134174.07011848, 158657.48673843, 150623.8627449 , 141965.38727914,
#         82579.85285276, 126700.92054887, 147171.58201291, 148648.24356837])

# %%
plt.hist(d_works['complex']['forward'])
# plt.hist(d_works['complex']['reverse']*-1)
# Out:
# (array([ 3., 10., 11., 16., 14., 16.,  7., 12.,  6.,  5.]),
#  array([ 71374.79690719,  87228.35713631, 103081.91736542, 118935.47759454,
#         134789.03782366, 150642.59805278, 166496.1582819 , 182349.71851101,
#         198203.27874013, 214056.83896925, 229910.39919837]),
#  <BarContainer object of 10 artists>)

# %%
# Bootstrap works
N_bootstraps = 10000
phases = ['complex', 'apo']
directions = ['forward', 'reverse']
dgs_phase = {}
ddgs = {}
for i in [forward]:
    dgs_phase_all = []
    ddgs_all = []
    for _ in tqdm_notebook(range(N_bootstraps)):
        # Initialize data structure for works
        d_works = {"complex": {"forward":{}, "reverse":{}}, "apo":{"forward":{}, "reverse":{}}}

        # Save subsampled works
        for phase in phases:
            for direction in directions:
                work_array = np.array(d_input[i][phase][direction])
                num_samples = work_array.shape[0]
                subsample_indices = np.random.choice(range(num_samples), num_samples)
                d_works[phase][direction] = work_array[subsample_indices]
        d_dgs_phase, binding_dg = analyze_bootstrap(d_works)
        dgs_phase_all.append(d_dgs_phase)
        ddgs_all.append(binding_dg)
    dgs_phase[i] = dgs_phase_all
    ddgs[i] = ddgs_all
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
forward_ddg = np.mean(ddgs[forward])
forward_ci = np.percentile(ddgs[forward], 2.5), np.percentile(ddgs[forward], 97.5)
# reverse_ddg = np.mean(ddgs[reverse])
# reverse_ci = np.percentile(ddgs[reverse], 2.5), np.percentile(ddgs[reverse], 97.5)
# negative_reverse_ci = sorted(np.array(reverse_ci)*-1)
# discrepancy = tuple(np.array(forward_ci) - np.array(negative_reverse_ci))
# output_kt = [forward_ddg, forward_ci, reverse_ddg, reverse_ci, discrepancy]
# output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL]), round(reverse_ddg*KT_KCALMOL, 2), tuple([round(val, 2) for val in np.array(reverse_ci)*KT_KCALMOL]), tuple([round(val, 2) for val in np.array(discrepancy)*KT_KCALMOL])]

output_kcalmol = [round(forward_ddg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(forward_ci)*KT_KCALMOL])]

# %%
output_kcalmol
# Out:
# [5.97, (4.45, 7.27)]

# %%
# pd.DataFrame([output_kcalmol]).to_csv(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/analysis_{titles[0]}_{titles[1]}.csv")

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "wb") as f:
    pickle.dump(dgs_phase, f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "wb") as f:
    pickle.dump(ddgs, f)

# %%
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/dgs_phase.pickle", "rb") as f:
    dgs_phase = pickle.load(f)
with open(f"/data/chodera/zhangi/perses_benchmark/neq/{dir_num}/{forward}/ddgs.pickle", "rb") as f:
    ddgs = pickle.load(f)

# %%
# Plot ddgs
sns.distplot(np.array(ddgs[forward])*KT_KCALMOL, rug=True, label=titles[0])
# sns.distplot(np.array(ddgs[reverse])*-KT_KCALMOL, rug=True, label=f"-({titles[1]})")
plt.xlabel("binding ddg (kcal/mol)")
plt.legend()

# %%
# Get the std error
np.std(np.array(ddgs[forward])*KT_KCALMOL) / np.sqrt(10000)
# Out:
# 0.007092508285801375

# %%
apo_dg = np.mean([d['apo'][0] for d in dgs_phase[forward]])
apo_ci = np.percentile([d['apo'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['apo'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_apo = [round(apo_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(apo_ci)*KT_KCALMOL])]

complex_dg = np.mean([d['complex'][0] for d in dgs_phase[forward]])
complex_ci = np.percentile([d['complex'][0] for d in dgs_phase[forward]], 2.5), np.percentile([d['complex'][0] for d in dgs_phase[forward]], 97.5)
output_kcalmol_complex = [round(complex_dg*KT_KCALMOL, 2), tuple([round(val, 2)for val in np.array(complex_ci)*KT_KCALMOL])]

# %%
output_kcalmol_apo
# Out:
# [66.57, (66.11, 67.05)]

# %%
output_kcalmol_complex
# Out:
# [72.54, (71.07, 73.75)]

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['apo'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("apo binding dg (kcal/mol)")
plt.legend()

# %%
# Plot ddgs
sns.distplot(np.array([dgs_phase[forward][i]['complex'][0]*KT_KCALMOL for i in range(100)]), rug=True, label=titles[0])
plt.xlabel("complex binding dg (kcal/mol)")
plt.legend()
