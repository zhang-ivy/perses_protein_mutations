# %%
import pickle
import os
from perses.annihilation.rest import RESTTopologyFactory
from perses.annihilation.lambda_protocol import RESTState
from openmmtools.states import SamplerState, ThermodynamicState, CompoundThermodynamicState
from openmmtools import cache, utils
from perses.dispersed.utils import configure_platform
cache.global_context_cache.platform = configure_platform(utils.get_fastest_platform().getName())
from simtk import openmm, unit
import math
from openmmtools.constants import kB
from openmmtools import mcmc, multistate
import argparse
import copy
from perses.dispersed import feptasks
import numpy as np
from simtk.openmm import app
from openmmforcefields.generators import SystemGenerator
import pickle
import mdtraj as md
import itertools
from perses.tests.utils import compute_potential_components
# Out:
# INFO:numexpr.utils:Note: detected 72 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# INFO:numexpr.utils:Note: NumExpr detected 72 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# DEBUG:numba.core.interpreter:label 0:
#     a = arg(0, name=a)                       ['a']
#     b = arg(1, name=b)                       ['b']
#     $0.1 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims-jan2021/lib/python3.6/site-packages/numpy/__init__.py'>) ['$0.1']
#     $0.2 = getattr(value=$0.1, attr=zeros)   ['$0.1', '$0.2']
#     $const0.3 = const(int, 3)                ['$const0.3']
#     $0.4 = call $0.2($const0.3, func=$0.2, args=[Var($const0.3, coordinate_numba.py:6)], kws=(), vararg=None) ['$0.2', '$0.4', '$const0.3']
#     c = $0.4                                 ['$0.4', 'c']
#     $const0.6 = const(int, 1)                ['$const0.6']
#     $0.7 = getitem(value=a, index=$const0.6, fn=<built-in function getitem>) ['$0.7', '$const0.6', 'a']
#     $const0.9 = const(int, 2)                ['$const0.9']
#     $0.10 = getitem(value=b, index=$const0.9, fn=<built-in function getitem>) ['$0.10', '$const0.9', 'b']
#     $0.11 = $0.7 * $0.10                     ['$0.10', '$0.11', '$0.7']
#     $const0.13 = const(int, 2)               ['$const0.13']
#     $0.14 = getitem(value=a, index=$const0.13, fn=<built-in function getitem>) ['$0.14', '$const0.13', 'a']
#     $const0.16 = const(int, 1)               ['$const0.16']
#     $0.17 = getitem(value=b, index=$const0.16, fn=<built-in function getitem>) ['$0.17', '$const0.16', 'b']
#     $0.18 = $0.14 * $0.17                    ['$0.14', '$0.17', '$0.18']
#     $0.19 = $0.11 - $0.18                    ['$0.11', '$0.18', '$0.19']
#     $const0.21 = const(int, 0)               ['$const0.21']
#     c[$const0.21] = $0.19                    ['$0.19', '$const0.21', 'c']
#     $const0.23 = const(int, 2)               ['$const0.23']
#     $0.24 = getitem(value=a, index=$const0.23, fn=<built-in function getitem>) ['$0.24', '$const0.23', 'a']
#     $const0.26 = const(int, 0)               ['$const0.26']
#     $0.27 = getitem(value=b, index=$const0.26, fn=<built-in function getitem>) ['$0.27', '$const0.26', 'b']
#     $0.28 = $0.24 * $0.27                    ['$0.24', '$0.27', '$0.28']
#     $const0.30 = const(int, 0)               ['$const0.30']
#     $0.31 = getitem(value=a, index=$const0.30, fn=<built-in function getitem>) ['$0.31', '$const0.30', 'a']
#     $const0.33 = const(int, 2)               ['$const0.33']
#     $0.34 = getitem(value=b, index=$const0.33, fn=<built-in function getitem>) ['$0.34', '$const0.33', 'b']
#     $0.35 = $0.31 * $0.34                    ['$0.31', '$0.34', '$0.35']
#     $0.36 = $0.28 - $0.35                    ['$0.28', '$0.35', '$0.36']
#     $const0.38 = const(int, 1)               ['$const0.38']
#     c[$const0.38] = $0.36                    ['$0.36', '$const0.38', 'c']
#     $const0.40 = const(int, 0)               ['$const0.40']
#     $0.41 = getitem(value=a, index=$const0.40, fn=<built-in function getitem>) ['$0.41', '$const0.40', 'a']
#     $const0.43 = const(int, 1)               ['$const0.43']
#     $0.44 = getitem(value=b, index=$const0.43, fn=<built-in function getitem>) ['$0.44', '$const0.43', 'b']
#     $0.45 = $0.41 * $0.44                    ['$0.41', '$0.44', '$0.45']
#     $const0.47 = const(int, 1)               ['$const0.47']
#     $0.48 = getitem(value=a, index=$const0.47, fn=<built-in function getitem>) ['$0.48', '$const0.47', 'a']
#     $const0.50 = const(int, 0)               ['$const0.50']
#     $0.51 = getitem(value=b, index=$const0.50, fn=<built-in function getitem>) ['$0.51', '$const0.50', 'b']
#     $0.52 = $0.48 * $0.51                    ['$0.48', '$0.51', '$0.52']
#     $0.53 = $0.45 - $0.52                    ['$0.45', '$0.52', '$0.53']
#     $const0.55 = const(int, 2)               ['$const0.55']
#     c[$const0.55] = $0.53                    ['$0.53', '$const0.55', 'c']
#     $0.57 = cast(value=c)                    ['$0.57', 'c']
#     return $0.57                             ['$0.57']
#
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb822c7630>
# DEBUG:numba.core.ssa:on stmt: a = arg(0, name=a)
# DEBUG:numba.core.ssa:on stmt: b = arg(1, name=b)
# DEBUG:numba.core.ssa:on stmt: $0.1 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims-jan2021/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $0.2 = getattr(value=$0.1, attr=zeros)
# DEBUG:numba.core.ssa:on stmt: $const0.3 = const(int, 3)
# DEBUG:numba.core.ssa:on stmt: $0.4 = call $0.2($const0.3, func=$0.2, args=[Var($const0.3, coordinate_numba.py:6)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: c = $0.4
# DEBUG:numba.core.ssa:on stmt: $const0.6 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $0.7 = static_getitem(value=a, index=1, index_var=$const0.6, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $const0.9 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $0.10 = static_getitem(value=b, index=2, index_var=$const0.9, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $0.11 = $0.7 * $0.10
# DEBUG:numba.core.ssa:on stmt: $const0.13 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $0.14 = static_getitem(value=a, index=2, index_var=$const0.13, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $const0.16 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $0.17 = static_getitem(value=b, index=1, index_var=$const0.16, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $0.18 = $0.14 * $0.17
# DEBUG:numba.core.ssa:on stmt: $0.19 = $0.11 - $0.18
# DEBUG:numba.core.ssa:on stmt: $const0.21 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: c[0] = $0.19
# DEBUG:numba.core.ssa:on stmt: $const0.23 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $0.24 = static_getitem(value=a, index=2, index_var=$const0.23, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $const0.26 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $0.27 = static_getitem(value=b, index=0, index_var=$const0.26, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $0.28 = $0.24 * $0.27
# DEBUG:numba.core.ssa:on stmt: $const0.30 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $0.31 = static_getitem(value=a, index=0, index_var=$const0.30, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $const0.33 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $0.34 = static_getitem(value=b, index=2, index_var=$const0.33, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $0.35 = $0.31 * $0.34
# DEBUG:numba.core.ssa:on stmt: $0.36 = $0.28 - $0.35
# DEBUG:numba.core.ssa:on stmt: $const0.38 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: c[1] = $0.36
# DEBUG:numba.core.ssa:on stmt: $const0.40 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $0.41 = static_getitem(value=a, index=0, index_var=$const0.40, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $const0.43 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $0.44 = static_getitem(value=b, index=1, index_var=$const0.43, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $0.45 = $0.41 * $0.44
# DEBUG:numba.core.ssa:on stmt: $const0.47 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $0.48 = static_getitem(value=a, index=1, index_var=$const0.47, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $const0.50 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $0.51 = static_getitem(value=b, index=0, index_var=$const0.50, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $0.52 = $0.48 * $0.51
# DEBUG:numba.core.ssa:on stmt: $0.53 = $0.45 - $0.52
# DEBUG:numba.core.ssa:on stmt: $const0.55 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: c[2] = $0.53
# DEBUG:numba.core.ssa:on stmt: $0.57 = cast(value=c)
# DEBUG:numba.core.ssa:on stmt: return $0.57
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$0.1': [<numba.core.ir.Assign object at 0x2aeb822d86d8>],
#              '$0.10': [<numba.core.ir.Assign object at 0x2aeb822ec630>],
#              '$0.11': [<numba.core.ir.Assign object at 0x2aeb822d8fd0>],
#              '$0.14': [<numba.core.ir.Assign object at 0x2aeb822ec7b8>],
#              '$0.17': [<numba.core.ir.Assign object at 0x2aeb822ec828>],
#              '$0.18': [<numba.core.ir.Assign object at 0x2aeb822e25c0>],
#              '$0.19': [<numba.core.ir.Assign object at 0x2aeb822e26a0>],
#              '$0.2': [<numba.core.ir.Assign object at 0x2aeb822d87b8>],
#              '$0.24': [<numba.core.ir.Assign object at 0x2aeb822ec898>],
#              '$0.27': [<numba.core.ir.Assign object at 0x2aeb822ec908>],
#              '$0.28': [<numba.core.ir.Assign object at 0x2aeb822e2e48>],
#              '$0.31': [<numba.core.ir.Assign object at 0x2aeb822ec978>],
#              '$0.34': [<numba.core.ir.Assign object at 0x2aeb822ec9e8>],
#              '$0.35': [<numba.core.ir.Assign object at 0x2aeb822e7438>],
#              '$0.36': [<numba.core.ir.Assign object at 0x2aeb822e7518>],
#              '$0.4': [<numba.core.ir.Assign object at 0x2aeb822d8978>],
#              '$0.41': [<numba.core.ir.Assign object at 0x2aeb822eca58>],
#              '$0.44': [<numba.core.ir.Assign object at 0x2aeb822ecac8>],
#              '$0.45': [<numba.core.ir.Assign object at 0x2aeb822e7cc0>],
#              '$0.48': [<numba.core.ir.Assign object at 0x2aeb822ecb38>],
#              '$0.51': [<numba.core.ir.Assign object at 0x2aeb822ecba8>],
#              '$0.52': [<numba.core.ir.Assign object at 0x2aeb822ec2b0>],
#              '$0.53': [<numba.core.ir.Assign object at 0x2aeb822ec390>],
#              '$0.57': [<numba.core.ir.Assign object at 0x2aeb822ec710>],
#              '$0.7': [<numba.core.ir.Assign object at 0x2aeb822d84a8>],
#              '$const0.13': [<numba.core.ir.Assign object at 0x2aeb822e2198>],
#              '$const0.16': [<numba.core.ir.Assign object at 0x2aeb822e2400>],
#              '$const0.21': [<numba.core.ir.Assign object at 0x2aeb822e2828>],
#              '$const0.23': [<numba.core.ir.Assign object at 0x2aeb822e2a20>],
#              '$const0.26': [<numba.core.ir.Assign object at 0x2aeb822e2c88>],
#              '$const0.3': [<numba.core.ir.Assign object at 0x2aeb822d8898>],
#              '$const0.30': [<numba.core.ir.Assign object at 0x2aeb822e2fd0>],
#              '$const0.33': [<numba.core.ir.Assign object at 0x2aeb822e7278>],
#              '$const0.38': [<numba.core.ir.Assign object at 0x2aeb822e76a0>],
#              '$const0.40': [<numba.core.ir.Assign object at 0x2aeb822e7898>],
#              '$const0.43': [<numba.core.ir.Assign object at 0x2aeb822e7b00>],
#              '$const0.47': [<numba.core.ir.Assign object at 0x2aeb822e7e48>],
#              '$const0.50': [<numba.core.ir.Assign object at 0x2aeb822ec0f0>],
#              '$const0.55': [<numba.core.ir.Assign object at 0x2aeb822ec518>],
#              '$const0.6': [<numba.core.ir.Assign object at 0x2aeb822d8ba8>],
#              '$const0.9': [<numba.core.ir.Assign object at 0x2aeb822d8e10>],
#              'a': [<numba.core.ir.Assign object at 0x2aeb822d8550>],
#              'b': [<numba.core.ir.Assign object at 0x2aeb822d85f8>],
#              'c': [<numba.core.ir.Assign object at 0x2aeb822d8a20>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.interpreter:label 0:
#     a = arg(0, name=a)                       ['a']
#     $0.1 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims-jan2021/lib/python3.6/site-packages/numpy/__init__.py'>) ['$0.1']
#     $0.2 = getattr(value=$0.1, attr=dot)     ['$0.1', '$0.2']
#     $0.5 = call $0.2(a, a, func=$0.2, args=[Var(a, coordinate_numba.py:14), Var(a, coordinate_numba.py:14)], kws=(), vararg=None) ['$0.2', '$0.5', 'a', 'a']
#     n_2 = $0.5                               ['$0.5', 'n_2']
#     $0.6 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims-jan2021/lib/python3.6/site-packages/numpy/__init__.py'>) ['$0.6']
#     $0.7 = getattr(value=$0.6, attr=sqrt)    ['$0.6', '$0.7']
#     $0.9 = call $0.7(n_2, func=$0.7, args=[Var(n_2, coordinate_numba.py:14)], kws=(), vararg=None) ['$0.7', '$0.9', 'n_2']
#     $0.10 = cast(value=$0.9)                 ['$0.10', '$0.9']
#     return $0.10                             ['$0.10']
#
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb822ec1d0>
# DEBUG:numba.core.ssa:on stmt: a = arg(0, name=a)
# DEBUG:numba.core.ssa:on stmt: $0.1 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims-jan2021/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $0.2 = getattr(value=$0.1, attr=dot)
# DEBUG:numba.core.ssa:on stmt: $0.5 = call $0.2(a, a, func=$0.2, args=[Var(a, coordinate_numba.py:14), Var(a, coordinate_numba.py:14)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: n_2 = $0.5
# DEBUG:numba.core.ssa:on stmt: $0.6 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims-jan2021/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $0.7 = getattr(value=$0.6, attr=sqrt)
# DEBUG:numba.core.ssa:on stmt: $0.9 = call $0.7(n_2, func=$0.7, args=[Var(n_2, coordinate_numba.py:14)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: $0.10 = cast(value=$0.9)
# DEBUG:numba.core.ssa:on stmt: return $0.10
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$0.1': [<numba.core.ir.Assign object at 0x2aeb823495f8>],
#              '$0.10': [<numba.core.ir.Assign object at 0x2aeb824ffda0>],
#              '$0.2': [<numba.core.ir.Assign object at 0x2aeb82349240>],
#              '$0.5': [<numba.core.ir.Assign object at 0x2aeb82349b70>],
#              '$0.6': [<numba.core.ir.Assign object at 0x2aeb8234e198>],
#              '$0.7': [<numba.core.ir.Assign object at 0x2aeb8234e2e8>],
#              '$0.9': [<numba.core.ir.Assign object at 0x2aeb824faba8>],
#              'a': [<numba.core.ir.Assign object at 0x2aeb823499e8>],
#              'n_2': [<numba.core.ir.Assign object at 0x2aeb82349e10>]})
# DEBUG:numba.core.ssa:SSA violators set()
# /home/zhangi/miniconda3/envs/perses-sims-jan2021/lib/python3.6/site-packages/perses-0.8.2.dev0-py3.6.egg/perses/rjmc/coordinate_numba.py:14: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, A), array(float64, 1d, A))
#   n_2 = np.dot(a, a)
# DEBUG:numba.core.interpreter:label 0:
#     a = arg(0, name=a)                       ['a']
#     b = arg(1, name=b)                       ['b']
#     $0.2 = getattr(value=a, attr=shape)      ['$0.2', 'a']
#     $0.4 = exhaust_iter(value=$0.2, count=1) ['$0.2', '$0.4']
#     $0.3 = static_getitem(value=$0.4, index=0, index_var=None, fn=<built-in function getitem>) ['$0.3', '$0.4']
#     m = $0.3                                 ['$0.3', 'm']
#     $0.6 = getattr(value=b, attr=shape)      ['$0.6', 'b']
#     $0.8 = exhaust_iter(value=$0.6, count=1) ['$0.6', '$0.8']
#     $0.7 = static_getitem(value=$0.8, index=0, index_var=None, fn=<built-in function getitem>) ['$0.7', '$0.8']
#     n = $0.7                                 ['$0.7', 'n']
#     $0.11 = m != n                           ['$0.11', 'm', 'n']
#     bool24 = global(bool: <class 'bool'>)    ['bool24']
#     $24pred = call bool24($0.11, func=bool24, args=(Var($0.11, linalg.py:510),), kws=(), vararg=None) ['$0.11', '$24pred', 'bool24']
#     branch $24pred, 26, 34                   ['$24pred']
# label 26:
#     $26.1 = global(ValueError: <class 'ValueError'>) ['$26.1']
#     $const26.2 = const(str, incompatible array sizes for np.dot(a, b) (vector * vector)) ['$const26.2']
#     $26.3 = call $26.1($const26.2, func=$26.1, args=[Var($const26.2, linalg.py:511)], kws=(), vararg=None) ['$26.1', '$26.3', '$const26.2']
#     raise $26.3                              ['$26.3']
# label 34:
#     $const34.1 = const(NoneType, None)       ['$const34.1']
#     $34.2 = cast(value=$const34.1)           ['$34.2', '$const34.1']
#     return $34.2                             ['$34.2']
#
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb82554240>
# DEBUG:numba.core.ssa:on stmt: a = arg(0, name=a)
# DEBUG:numba.core.ssa:on stmt: b = arg(1, name=b)
# DEBUG:numba.core.ssa:on stmt: $0.2 = getattr(value=a, attr=shape)
# DEBUG:numba.core.ssa:on stmt: $0.4 = exhaust_iter(value=$0.2, count=1)
# DEBUG:numba.core.ssa:on stmt: $0.3 = static_getitem(value=$0.4, index=0, index_var=None, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: m = $0.3
# DEBUG:numba.core.ssa:on stmt: $0.6 = getattr(value=b, attr=shape)
# DEBUG:numba.core.ssa:on stmt: $0.8 = exhaust_iter(value=$0.6, count=1)
# DEBUG:numba.core.ssa:on stmt: $0.7 = static_getitem(value=$0.8, index=0, index_var=None, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: n = $0.7
# DEBUG:numba.core.ssa:on stmt: $0.11 = m != n
# DEBUG:numba.core.ssa:on stmt: bool24 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $24pred = call bool24($0.11, func=bool24, args=(Var($0.11, linalg.py:510),), kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: branch $24pred, 26, 34
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 26
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb82554240>
# DEBUG:numba.core.ssa:on stmt: $26.1 = global(ValueError: <class 'ValueError'>)
# DEBUG:numba.core.ssa:on stmt: $const26.2 = const(str, incompatible array sizes for np.dot(a, b) (vector * vector))
# DEBUG:numba.core.ssa:on stmt: $26.3 = call $26.1($const26.2, func=$26.1, args=[Var($const26.2, linalg.py:511)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: <static> raise <class 'ValueError'>('incompatible array sizes for np.dot(a, b) (vector * vector)')
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 34
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb82554240>
# DEBUG:numba.core.ssa:on stmt: $const34.1 = const(NoneType, None)
# DEBUG:numba.core.ssa:on stmt: $34.2 = cast(value=$const34.1)
# DEBUG:numba.core.ssa:on stmt: return $34.2
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$0.11': [<numba.core.ir.Assign object at 0x2aeb825615f8>],
#              '$0.2': [<numba.core.ir.Assign object at 0x2aeb82554da0>],
#              '$0.3': [<numba.core.ir.Assign object at 0x2aeb82554f60>],
#              '$0.4': [<numba.core.ir.Assign object at 0x2aeb82554e80>],
#              '$0.6': [<numba.core.ir.Assign object at 0x2aeb82561198>],
#              '$0.7': [<numba.core.ir.Assign object at 0x2aeb82561358>],
#              '$0.8': [<numba.core.ir.Assign object at 0x2aeb82561278>],
#              '$24pred': [<numba.core.ir.Assign object at 0x2aeb825617f0>],
#              '$26.1': [<numba.core.ir.Assign object at 0x2aeb82561898>],
#              '$26.3': [<numba.core.ir.Assign object at 0x2aeb82561a58>],
#              '$34.2': [<numba.core.ir.Assign object at 0x2aeb82561cf8>],
#              '$const26.2': [<numba.core.ir.Assign object at 0x2aeb82561978>],
#              '$const34.1': [<numba.core.ir.Assign object at 0x2aeb82561c18>],
#              'a': [<numba.core.ir.Assign object at 0x2aeb82554b70>],
#              'b': [<numba.core.ir.Assign object at 0x2aeb82554c18>],
#              'bool24': [<numba.core.ir.Assign object at 0x2aeb82561710>],
#              'm': [<numba.core.ir.Assign object at 0x2aeb82554fd0>],
#              'n': [<numba.core.ir.Assign object at 0x2aeb825613c8>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.interpreter:label 0:
#     n = arg(0, name=n)                       ['n']
#     $0.2 = freevar(_maxint: 2147483647)      ['$0.2']
#     $0.3 = n > $0.2                          ['$0.2', '$0.3', 'n']
#     bool8 = global(bool: <class 'bool'>)     ['bool8']
#     $8pred = call bool8($0.3, func=bool8, args=(Var($0.3, linalg.py:308),), kws=(), vararg=None) ['$0.3', '$8pred', 'bool8']
#     branch $8pred, 10, 18                    ['$8pred']
# label 10:
#     $10.1 = global(OverflowError: <class 'OverflowError'>) ['$10.1']
#     $const10.2 = const(str, array size too large to fit in C int) ['$const10.2']
#     $10.3 = call $10.1($const10.2, func=$10.1, args=[Var($const10.2, linalg.py:309)], kws=(), vararg=None) ['$10.1', '$10.3', '$const10.2']
#     raise $10.3                              ['$10.3']
# label 18:
#     $const18.1 = const(NoneType, None)       ['$const18.1']
#     $18.2 = cast(value=$const18.1)           ['$18.2', '$const18.1']
#     return $18.2                             ['$18.2']
#
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb824e2748>
# DEBUG:numba.core.ssa:on stmt: n = arg(0, name=n)
# DEBUG:numba.core.ssa:on stmt: $0.2 = freevar(_maxint: 2147483647)
# DEBUG:numba.core.ssa:on stmt: $0.3 = n > $0.2
# DEBUG:numba.core.ssa:on stmt: bool8 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $8pred = call bool8($0.3, func=bool8, args=(Var($0.3, linalg.py:308),), kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: branch $8pred, 10, 18
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 10
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb824e2748>
# DEBUG:numba.core.ssa:on stmt: $10.1 = global(OverflowError: <class 'OverflowError'>)
# DEBUG:numba.core.ssa:on stmt: $const10.2 = const(str, array size too large to fit in C int)
# DEBUG:numba.core.ssa:on stmt: $10.3 = call $10.1($const10.2, func=$10.1, args=[Var($const10.2, linalg.py:309)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: <static> raise <class 'OverflowError'>('array size too large to fit in C int')
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 18
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb824e2748>
# DEBUG:numba.core.ssa:on stmt: $const18.1 = const(NoneType, None)
# DEBUG:numba.core.ssa:on stmt: $18.2 = cast(value=$const18.1)
# DEBUG:numba.core.ssa:on stmt: return $18.2
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$0.2': [<numba.core.ir.Assign object at 0x2aeb824fa940>],
#              '$0.3': [<numba.core.ir.Assign object at 0x2aeb824fa6d8>],
#              '$10.1': [<numba.core.ir.Assign object at 0x2aeb824fa390>],
#              '$10.3': [<numba.core.ir.Assign object at 0x2aeb824fa128>],
#              '$18.2': [<numba.core.ir.Assign object at 0x2aeb824faa58>],
#              '$8pred': [<numba.core.ir.Assign object at 0x2aeb824fa470>],
#              '$const10.2': [<numba.core.ir.Assign object at 0x2aeb824fa2b0>],
#              '$const18.1': [<numba.core.ir.Assign object at 0x2aeb824fa550>],
#              'bool8': [<numba.core.ir.Assign object at 0x2aeb824fa6a0>],
#              'n': [<numba.core.ir.Assign object at 0x2aeb824fa8d0>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.interpreter:label 0:
#     axis = arg(0, name=axis)                 ['axis']
#     angle = arg(1, name=angle)               ['angle']
#     $0.1 = global(_norm: CPUDispatcher(<function _norm at 0x2aeb823f4f28>)) ['$0.1']
#     $0.3 = call $0.1(axis, func=$0.1, args=[Var(axis, coordinate_numba.py:22)], kws=(), vararg=None) ['$0.1', '$0.3', 'axis']
#     axis_norm = $0.3                         ['$0.3', 'axis_norm']
#     jump 10                                  []
# label 10:
#     jump 12                                  []
# label 12:
#     $12.1 = global(range: <class 'range'>)   ['$12.1']
#     $const12.2 = const(int, 3)               ['$const12.2']
#     $12.3 = call $12.1($const12.2, func=$12.1, args=[Var($const12.2, coordinate_numba.py:23)], kws=(), vararg=None) ['$12.1', '$12.3', '$const12.2']
#     $12.4 = getiter(value=$12.3)             ['$12.3', '$12.4']
#     $phi20.1 = $12.4                         ['$12.4', '$phi20.1']
#     jump 20                                  []
# label 20:
#     $20.2 = iternext(value=$phi20.1)         ['$20.2', '$phi20.1']
#     $20.3 = pair_first(value=$20.2)          ['$20.2', '$20.3']
#     $20.4 = pair_second(value=$20.2)         ['$20.2', '$20.4']
#     $phi22.1 = $20.3                         ['$20.3', '$phi22.1']
#     $phi42.1 = $20.3                         ['$20.3', '$phi42.1']
#     $phi42.2 = $phi20.1                      ['$phi20.1', '$phi42.2']
#     branch $20.4, 22, 42                     ['$20.4']
# label 22:
#     k = $phi22.1                             ['$phi22.1', 'k']
#     $22.4 = getitem(value=axis, index=k, fn=<built-in function getitem>) ['$22.4', 'axis', 'k']
#     $22.6 = $22.4 / axis_norm                ['$22.4', '$22.6', 'axis_norm']
#     axis[k] = $22.6                          ['$22.6', 'axis', 'k']
#     jump 20                                  []
# label 42:
#     jump 44                                  []
# label 44:
#     $const44.2 = const(int, 2)               ['$const44.2']
#     $44.3 = axis ** $const44.2               ['$44.3', '$const44.2', 'axis']
#     axis_squared = $44.3                     ['$44.3', 'axis_squared']
#     $44.4 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims-jan2021/lib/python3.6/site-packages/numpy/__init__.py'>) ['$44.4']
#     $44.5 = getattr(value=$44.4, attr=cos)   ['$44.4', '$44.5']
#     $44.7 = call $44.5(angle, func=$44.5, args=[Var(angle, coordinate_numba.py:22)], kws=(), vararg=None) ['$44.5', '$44.7', 'angle']
#     cos_angle = $44.7                        ['$44.7', 'cos_angle']
#     $44.8 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims-jan2021/lib/python3.6/site-packages/numpy/__init__.py'>) ['$44.8']
#     $44.9 = getattr(value=$44.8, attr=sin)   ['$44.8', '$44.9']
#     $44.11 = call $44.9(angle, func=$44.9, args=[Var(angle, coordinate_numba.py:22)], kws=(), vararg=None) ['$44.11', '$44.9', 'angle']
#     sin_angle = $44.11                       ['$44.11', 'sin_angle']
#     $44.12 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims-jan2021/lib/python3.6/site-packages/numpy/__init__.py'>) ['$44.12']
#     $44.13 = getattr(value=$44.12, attr=zeros) ['$44.12', '$44.13']
#     $const_3 = const(int, 3)                 ['$const_3']
#     $const_3.1 = const(int, 3)               ['$const_3.1']
#     $const44.14 = build_tuple(items=[Var($const_3, coordinate_numba.py:29), Var($const_3.1, coordinate_numba.py:29)]) ['$const44.14', '$const_3', '$const_3.1']
#     $44.15 = global(float64: float64)        ['$44.15']
#     $44.17 = call $44.13($const44.14, func=$44.13, args=[Var($const44.14, coordinate_numba.py:29)], kws=[('dtype', Var($44.15, coordinate_numba.py:29))], vararg=None) ['$44.13', '$44.15', '$44.17', '$const44.14']
#     rotation_matrix = $44.17                 ['$44.17', 'rotation_matrix']
#     $const44.20 = const(int, 0)              ['$const44.20']
#     $44.21 = getitem(value=axis_squared, index=$const44.20, fn=<built-in function getitem>) ['$44.21', '$const44.20', 'axis_squared']
#     $const44.22 = const(float, 1.0)          ['$const44.22']
#     $44.24 = $const44.22 - cos_angle         ['$44.24', '$const44.22', 'cos_angle']
#     $44.25 = $44.21 * $44.24                 ['$44.21', '$44.24', '$44.25']
#     $44.26 = cos_angle + $44.25              ['$44.25', '$44.26', 'cos_angle']
#     $const_0 = const(int, 0)                 ['$const_0']
#     $const_0.1 = const(int, 0)               ['$const_0.1']
#     $const44.28 = build_tuple(items=[Var($const_0, coordinate_numba.py:31), Var($const_0.1, coordinate_numba.py:31)]) ['$const44.28', '$const_0', '$const_0.1']
#     rotation_matrix[$const44.28] = $44.26    ['$44.26', '$const44.28', 'rotation_matrix']
#     $const44.30 = const(int, 0)              ['$const44.30']
#     $44.31 = getitem(value=axis, index=$const44.30, fn=<built-in function getitem>) ['$44.31', '$const44.30', 'axis']
#     $const44.33 = const(int, 1)              ['$const44.33']
#     $44.34 = getitem(value=axis, index=$const44.33, fn=<built-in function getitem>) ['$44.34', '$const44.33', 'axis']
#     $44.35 = $44.31 * $44.34                 ['$44.31', '$44.34', '$44.35']
#     $const44.36 = const(float, 1.0)          ['$const44.36']
#     $44.38 = $const44.36 - cos_angle         ['$44.38', '$const44.36', 'cos_angle']
#     $44.39 = $44.35 * $44.38                 ['$44.35', '$44.38', '$44.39']
#     $const44.41 = const(int, 2)              ['$const44.41']
#     $44.42 = getitem(value=axis, index=$const44.41, fn=<built-in function getitem>) ['$44.42', '$const44.41', 'axis']
#     $44.44 = $44.42 * sin_angle              ['$44.42', '$44.44', 'sin_angle']
#     $44.45 = $44.39 - $44.44                 ['$44.39', '$44.44', '$44.45']
#     $const_0.2 = const(int, 0)               ['$const_0.2']
#     $const_1 = const(int, 1)                 ['$const_1']
#     $const44.47 = build_tuple(items=[Var($const_0.2, coordinate_numba.py:32), Var($const_1, coordinate_numba.py:32)]) ['$const44.47', '$const_0.2', '$const_1']
#     rotation_matrix[$const44.47] = $44.45    ['$44.45', '$const44.47', 'rotation_matrix']
#     $const44.49 = const(int, 0)              ['$const44.49']
#     $44.50 = getitem(value=axis, index=$const44.49, fn=<built-in function getitem>) ['$44.50', '$const44.49', 'axis']
#     $const44.52 = const(int, 2)              ['$const44.52']
#     $44.53 = getitem(value=axis, index=$const44.52, fn=<built-in function getitem>) ['$44.53', '$const44.52', 'axis']
#     $44.54 = $44.50 * $44.53                 ['$44.50', '$44.53', '$44.54']
#     $const44.55 = const(float, 1.0)          ['$const44.55']
#     $44.57 = $const44.55 - cos_angle         ['$44.57', '$const44.55', 'cos_angle']
#     $44.58 = $44.54 * $44.57                 ['$44.54', '$44.57', '$44.58']
#     $const44.60 = const(int, 1)              ['$const44.60']
#     $44.61 = getitem(value=axis, index=$const44.60, fn=<built-in function getitem>) ['$44.61', '$const44.60', 'axis']
#     $44.63 = $44.61 * sin_angle              ['$44.61', '$44.63', 'sin_angle']
#     $44.64 = $44.58 + $44.63                 ['$44.58', '$44.63', '$44.64']
#     $const_0.3 = const(int, 0)               ['$const_0.3']
#     $const_2 = const(int, 2)                 ['$const_2']
#     $const44.66 = build_tuple(items=[Var($const_0.3, coordinate_numba.py:33), Var($const_2, coordinate_numba.py:33)]) ['$const44.66', '$const_0.3', '$const_2']
#     rotation_matrix[$const44.66] = $44.64    ['$44.64', '$const44.66', 'rotation_matrix']
#     $const44.68 = const(int, 1)              ['$const44.68']
#     $44.69 = getitem(value=axis, index=$const44.68, fn=<built-in function getitem>) ['$44.69', '$const44.68', 'axis']
#     $const44.71 = const(int, 0)              ['$const44.71']
#     $44.72 = getitem(value=axis, index=$const44.71, fn=<built-in function getitem>) ['$44.72', '$const44.71', 'axis']
#     $44.73 = $44.69 * $44.72                 ['$44.69', '$44.72', '$44.73']
#     $const44.74 = const(float, 1.0)          ['$const44.74']
#     $44.76 = $const44.74 - cos_angle         ['$44.76', '$const44.74', 'cos_angle']
#     $44.77 = $44.73 * $44.76                 ['$44.73', '$44.76', '$44.77']
#     $const44.79 = const(int, 2)              ['$const44.79']
#     $44.80 = getitem(value=axis, index=$const44.79, fn=<built-in function getitem>) ['$44.80', '$const44.79', 'axis']
#     $44.82 = $44.80 * sin_angle              ['$44.80', '$44.82', 'sin_angle']
#     $44.83 = $44.77 + $44.82                 ['$44.77', '$44.82', '$44.83']
#     $const_1.1 = const(int, 1)               ['$const_1.1']
#     $const_0.4 = const(int, 0)               ['$const_0.4']
#     $const44.85 = build_tuple(items=[Var($const_1.1, coordinate_numba.py:35), Var($const_0.4, coordinate_numba.py:35)]) ['$const44.85', '$const_0.4', '$const_1.1']
#     rotation_matrix[$const44.85] = $44.83    ['$44.83', '$const44.85', 'rotation_matrix']
#     $const44.88 = const(int, 1)              ['$const44.88']
#     $44.89 = getitem(value=axis_squared, index=$const44.88, fn=<built-in function getitem>) ['$44.89', '$const44.88', 'axis_squared']
#     $const44.90 = const(float, 1.0)          ['$const44.90']
#     $44.92 = $const44.90 - cos_angle         ['$44.92', '$const44.90', 'cos_angle']
#     $44.93 = $44.89 * $44.92                 ['$44.89', '$44.92', '$44.93']
#     $44.94 = cos_angle + $44.93              ['$44.93', '$44.94', 'cos_angle']
#     $const_1.2 = const(int, 1)               ['$const_1.2']
#     $const_1.3 = const(int, 1)               ['$const_1.3']
#     $const44.96 = build_tuple(items=[Var($const_1.2, coordinate_numba.py:36), Var($const_1.3, coordinate_numba.py:36)]) ['$const44.96', '$const_1.2', '$const_1.3']
#     rotation_matrix[$const44.96] = $44.94    ['$44.94', '$const44.96', 'rotation_matrix']
#     $const44.98 = const(int, 1)              ['$const44.98']
#     $44.99 = getitem(value=axis, index=$const44.98, fn=<built-in function getitem>) ['$44.99', '$const44.98', 'axis']
#     $const44.101 = const(int, 2)             ['$const44.101']
#     $44.102 = getitem(value=axis, index=$const44.101, fn=<built-in function getitem>) ['$44.102', '$const44.101', 'axis']
#     $44.103 = $44.99 * $44.102               ['$44.102', '$44.103', '$44.99']
#     $const44.104 = const(float, 1.0)         ['$const44.104']
#     $44.106 = $const44.104 - cos_angle       ['$44.106', '$const44.104', 'cos_angle']
#     $44.107 = $44.103 * $44.106              ['$44.103', '$44.106', '$44.107']
#     $const44.109 = const(int, 0)             ['$const44.109']
#     $44.110 = getitem(value=axis, index=$const44.109, fn=<built-in function getitem>) ['$44.110', '$const44.109', 'axis']
#     $44.112 = $44.110 * sin_angle            ['$44.110', '$44.112', 'sin_angle']
#     $44.113 = $44.107 - $44.112              ['$44.107', '$44.112', '$44.113']
#     $const_1.4 = const(int, 1)               ['$const_1.4']
#     $const_2.1 = const(int, 2)               ['$const_2.1']
#     $const44.115 = build_tuple(items=[Var($const_1.4, coordinate_numba.py:37), Var($const_2.1, coordinate_numba.py:37)]) ['$const44.115', '$const_1.4', '$const_2.1']
#     rotation_matrix[$const44.115] = $44.113  ['$44.113', '$const44.115', 'rotation_matrix']
#     $const44.117 = const(int, 2)             ['$const44.117']
#     $44.118 = getitem(value=axis, index=$const44.117, fn=<built-in function getitem>) ['$44.118', '$const44.117', 'axis']
#     $const44.120 = const(int, 0)             ['$const44.120']
#     $44.121 = getitem(value=axis, index=$const44.120, fn=<built-in function getitem>) ['$44.121', '$const44.120', 'axis']
#     $44.122 = $44.118 * $44.121              ['$44.118', '$44.121', '$44.122']
#     $const44.123 = const(float, 1.0)         ['$const44.123']
#     $44.125 = $const44.123 - cos_angle       ['$44.125', '$const44.123', 'cos_angle']
#     $44.126 = $44.122 * $44.125              ['$44.122', '$44.125', '$44.126']
#     $const44.128 = const(int, 1)             ['$const44.128']
#     $44.129 = getitem(value=axis, index=$const44.128, fn=<built-in function getitem>) ['$44.129', '$const44.128', 'axis']
#     $44.131 = $44.129 * sin_angle            ['$44.129', '$44.131', 'sin_angle']
#     $44.132 = $44.126 - $44.131              ['$44.126', '$44.131', '$44.132']
#     $const_2.2 = const(int, 2)               ['$const_2.2']
#     $const_0.5 = const(int, 0)               ['$const_0.5']
#     $const44.134 = build_tuple(items=[Var($const_2.2, coordinate_numba.py:39), Var($const_0.5, coordinate_numba.py:39)]) ['$const44.134', '$const_0.5', '$const_2.2']
#     rotation_matrix[$const44.134] = $44.132  ['$44.132', '$const44.134', 'rotation_matrix']
#     $const44.136 = const(int, 2)             ['$const44.136']
#     $44.137 = getitem(value=axis, index=$const44.136, fn=<built-in function getitem>) ['$44.137', '$const44.136', 'axis']
#     $const44.139 = const(int, 1)             ['$const44.139']
#     $44.140 = getitem(value=axis, index=$const44.139, fn=<built-in function getitem>) ['$44.140', '$const44.139', 'axis']
#     $44.141 = $44.137 * $44.140              ['$44.137', '$44.140', '$44.141']
#     $const44.142 = const(float, 1.0)         ['$const44.142']
#     $44.144 = $const44.142 - cos_angle       ['$44.144', '$const44.142', 'cos_angle']
#     $44.145 = $44.141 * $44.144              ['$44.141', '$44.144', '$44.145']
#     $const44.147 = const(int, 0)             ['$const44.147']
#     $44.148 = getitem(value=axis, index=$const44.147, fn=<built-in function getitem>) ['$44.148', '$const44.147', 'axis']
#     $44.150 = $44.148 * sin_angle            ['$44.148', '$44.150', 'sin_angle']
#     $44.151 = $44.145 + $44.150              ['$44.145', '$44.150', '$44.151']
#     $const_2.3 = const(int, 2)               ['$const_2.3']
#     $const_1.5 = const(int, 1)               ['$const_1.5']
#     $const44.153 = build_tuple(items=[Var($const_2.3, coordinate_numba.py:40), Var($const_1.5, coordinate_numba.py:40)]) ['$const44.153', '$const_1.5', '$const_2.3']
#     rotation_matrix[$const44.153] = $44.151  ['$44.151', '$const44.153', 'rotation_matrix']
#     $const44.156 = const(int, 2)             ['$const44.156']
#     $44.157 = getitem(value=axis_squared, index=$const44.156, fn=<built-in function getitem>) ['$44.157', '$const44.156', 'axis_squared']
#     $const44.158 = const(float, 1.0)         ['$const44.158']
#     $44.160 = $const44.158 - cos_angle       ['$44.160', '$const44.158', 'cos_angle']
#     $44.161 = $44.157 * $44.160              ['$44.157', '$44.160', '$44.161']
#     $44.162 = cos_angle + $44.161            ['$44.161', '$44.162', 'cos_angle']
#     $const_2.4 = const(int, 2)               ['$const_2.4']
#     $const_2.5 = const(int, 2)               ['$const_2.5']
#     $const44.164 = build_tuple(items=[Var($const_2.4, coordinate_numba.py:41), Var($const_2.5, coordinate_numba.py:41)]) ['$const44.164', '$const_2.4', '$const_2.5']
#     rotation_matrix[$const44.164] = $44.162  ['$44.162', '$const44.164', 'rotation_matrix']
#     $44.166 = cast(value=rotation_matrix)    ['$44.166', 'rotation_matrix']
#     return $44.166                           ['$44.166']
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb826a9518>
# DEBUG:numba.core.ssa:on stmt: axis = arg(0, name=axis)
# DEBUG:numba.core.ssa:on stmt: angle = arg(1, name=angle)
# DEBUG:numba.core.ssa:on stmt: $0.1 = global(_norm: CPUDispatcher(<function _norm at 0x2aeb823f4f28>))
# DEBUG:numba.core.ssa:on stmt: $0.3 = call $0.1(axis, func=$0.1, args=[Var(axis, coordinate_numba.py:22)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: axis_norm = $0.3
# DEBUG:numba.core.ssa:on stmt: jump 10
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 10
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb826a9518>
# DEBUG:numba.core.ssa:on stmt: jump 12
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 12
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb826a9518>
# DEBUG:numba.core.ssa:on stmt: $12.1 = global(range: <class 'range'>)
# DEBUG:numba.core.ssa:on stmt: $const12.2 = const(int, 3)
# DEBUG:numba.core.ssa:on stmt: $12.3 = call $12.1($const12.2, func=$12.1, args=[Var($const12.2, coordinate_numba.py:23)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: $12.4 = getiter(value=$12.3)
# DEBUG:numba.core.ssa:on stmt: $phi20.1 = $12.4
# DEBUG:numba.core.ssa:on stmt: jump 20
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 20
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb826a9518>
# DEBUG:numba.core.ssa:on stmt: $20.2 = iternext(value=$phi20.1)
# DEBUG:numba.core.ssa:on stmt: $20.3 = pair_first(value=$20.2)
# DEBUG:numba.core.ssa:on stmt: $20.4 = pair_second(value=$20.2)
# DEBUG:numba.core.ssa:on stmt: $phi22.1 = $20.3
# DEBUG:numba.core.ssa:on stmt: $phi42.1 = $20.3
# DEBUG:numba.core.ssa:on stmt: $phi42.2 = $phi20.1
# DEBUG:numba.core.ssa:on stmt: branch $20.4, 22, 42
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 22
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb826a9518>
# DEBUG:numba.core.ssa:on stmt: k = $phi22.1
# DEBUG:numba.core.ssa:on stmt: $22.4 = getitem(value=axis, index=k, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $22.6 = $22.4 / axis_norm
# DEBUG:numba.core.ssa:on stmt: axis[k] = $22.6
# DEBUG:numba.core.ssa:on stmt: jump 20
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 42
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb826a9518>
# DEBUG:numba.core.ssa:on stmt: jump 44
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 44
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb826a9518>
# DEBUG:numba.core.ssa:on stmt: $const44.2 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $44.3 = axis ** $const44.2
# DEBUG:numba.core.ssa:on stmt: axis_squared = $44.3
# DEBUG:numba.core.ssa:on stmt: $44.4 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims-jan2021/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $44.5 = getattr(value=$44.4, attr=cos)
# DEBUG:numba.core.ssa:on stmt: $44.7 = call $44.5(angle, func=$44.5, args=[Var(angle, coordinate_numba.py:22)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: cos_angle = $44.7
# DEBUG:numba.core.ssa:on stmt: $44.8 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims-jan2021/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $44.9 = getattr(value=$44.8, attr=sin)
# DEBUG:numba.core.ssa:on stmt: $44.11 = call $44.9(angle, func=$44.9, args=[Var(angle, coordinate_numba.py:22)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: sin_angle = $44.11
# DEBUG:numba.core.ssa:on stmt: $44.12 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims-jan2021/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $44.13 = getattr(value=$44.12, attr=zeros)
# DEBUG:numba.core.ssa:on stmt: $const_3 = const(int, 3)
# DEBUG:numba.core.ssa:on stmt: $const_3.1 = const(int, 3)
# DEBUG:numba.core.ssa:on stmt: $const44.14 = build_tuple(items=[Var($const_3, coordinate_numba.py:29), Var($const_3.1, coordinate_numba.py:29)])
# DEBUG:numba.core.ssa:on stmt: $44.15 = global(float64: float64)
# DEBUG:numba.core.ssa:on stmt: $44.17 = call $44.13($const44.14, func=$44.13, args=[Var($const44.14, coordinate_numba.py:29)], kws=[('dtype', Var($44.15, coordinate_numba.py:29))], vararg=None)
# DEBUG:numba.core.ssa:on stmt: rotation_matrix = $44.17
# DEBUG:numba.core.ssa:on stmt: $const44.20 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $44.21 = static_getitem(value=axis_squared, index=0, index_var=$const44.20, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $const44.22 = const(float, 1.0)
# DEBUG:numba.core.ssa:on stmt: $44.24 = $const44.22 - cos_angle
# DEBUG:numba.core.ssa:on stmt: $44.25 = $44.21 * $44.24
# DEBUG:numba.core.ssa:on stmt: $44.26 = cos_angle + $44.25
# DEBUG:numba.core.ssa:on stmt: $const_0 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $const_0.1 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $const44.28 = build_tuple(items=[Var($const_0, coordinate_numba.py:31), Var($const_0.1, coordinate_numba.py:31)])
# DEBUG:numba.core.ssa:on stmt: rotation_matrix[(0, 0)] = $44.26
# DEBUG:numba.core.ssa:on stmt: $const44.30 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $44.31 = static_getitem(value=axis, index=0, index_var=$const44.30, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $const44.33 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $44.34 = static_getitem(value=axis, index=1, index_var=$const44.33, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $44.35 = $44.31 * $44.34
# DEBUG:numba.core.ssa:on stmt: $const44.36 = const(float, 1.0)
# DEBUG:numba.core.ssa:on stmt: $44.38 = $const44.36 - cos_angle
# DEBUG:numba.core.ssa:on stmt: $44.39 = $44.35 * $44.38
# DEBUG:numba.core.ssa:on stmt: $const44.41 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $44.42 = static_getitem(value=axis, index=2, index_var=$const44.41, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $44.44 = $44.42 * sin_angle
# DEBUG:numba.core.ssa:on stmt: $44.45 = $44.39 - $44.44
# DEBUG:numba.core.ssa:on stmt: $const_0.2 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $const_1 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $const44.47 = build_tuple(items=[Var($const_0.2, coordinate_numba.py:32), Var($const_1, coordinate_numba.py:32)])
# DEBUG:numba.core.ssa:on stmt: rotation_matrix[(0, 1)] = $44.45
# DEBUG:numba.core.ssa:on stmt: $const44.49 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $44.50 = static_getitem(value=axis, index=0, index_var=$const44.49, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $const44.52 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $44.53 = static_getitem(value=axis, index=2, index_var=$const44.52, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $44.54 = $44.50 * $44.53
# DEBUG:numba.core.ssa:on stmt: $const44.55 = const(float, 1.0)
# DEBUG:numba.core.ssa:on stmt: $44.57 = $const44.55 - cos_angle
# DEBUG:numba.core.ssa:on stmt: $44.58 = $44.54 * $44.57
# DEBUG:numba.core.ssa:on stmt: $const44.60 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $44.61 = static_getitem(value=axis, index=1, index_var=$const44.60, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $44.63 = $44.61 * sin_angle
# DEBUG:numba.core.ssa:on stmt: $44.64 = $44.58 + $44.63
# DEBUG:numba.core.ssa:on stmt: $const_0.3 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $const_2 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $const44.66 = build_tuple(items=[Var($const_0.3, coordinate_numba.py:33), Var($const_2, coordinate_numba.py:33)])
# DEBUG:numba.core.ssa:on stmt: rotation_matrix[(0, 2)] = $44.64
# DEBUG:numba.core.ssa:on stmt: $const44.68 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $44.69 = static_getitem(value=axis, index=1, index_var=$const44.68, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $const44.71 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $44.72 = static_getitem(value=axis, index=0, index_var=$const44.71, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $44.73 = $44.69 * $44.72
# DEBUG:numba.core.ssa:on stmt: $const44.74 = const(float, 1.0)
# DEBUG:numba.core.ssa:on stmt: $44.76 = $const44.74 - cos_angle
# DEBUG:numba.core.ssa:on stmt: $44.77 = $44.73 * $44.76
# DEBUG:numba.core.ssa:on stmt: $const44.79 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $44.80 = static_getitem(value=axis, index=2, index_var=$const44.79, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $44.82 = $44.80 * sin_angle
# DEBUG:numba.core.ssa:on stmt: $44.83 = $44.77 + $44.82
# DEBUG:numba.core.ssa:on stmt: $const_1.1 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $const_0.4 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $const44.85 = build_tuple(items=[Var($const_1.1, coordinate_numba.py:35), Var($const_0.4, coordinate_numba.py:35)])
# DEBUG:numba.core.ssa:on stmt: rotation_matrix[(1, 0)] = $44.83
# DEBUG:numba.core.ssa:on stmt: $const44.88 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $44.89 = static_getitem(value=axis_squared, index=1, index_var=$const44.88, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $const44.90 = const(float, 1.0)
# DEBUG:numba.core.ssa:on stmt: $44.92 = $const44.90 - cos_angle
# DEBUG:numba.core.ssa:on stmt: $44.93 = $44.89 * $44.92
# DEBUG:numba.core.ssa:on stmt: $44.94 = cos_angle + $44.93
# DEBUG:numba.core.ssa:on stmt: $const_1.2 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $const_1.3 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $const44.96 = build_tuple(items=[Var($const_1.2, coordinate_numba.py:36), Var($const_1.3, coordinate_numba.py:36)])
# DEBUG:numba.core.ssa:on stmt: rotation_matrix[(1, 1)] = $44.94
# DEBUG:numba.core.ssa:on stmt: $const44.98 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $44.99 = static_getitem(value=axis, index=1, index_var=$const44.98, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $const44.101 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $44.102 = static_getitem(value=axis, index=2, index_var=$const44.101, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $44.103 = $44.99 * $44.102
# DEBUG:numba.core.ssa:on stmt: $const44.104 = const(float, 1.0)
# DEBUG:numba.core.ssa:on stmt: $44.106 = $const44.104 - cos_angle
# DEBUG:numba.core.ssa:on stmt: $44.107 = $44.103 * $44.106
# DEBUG:numba.core.ssa:on stmt: $const44.109 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $44.110 = static_getitem(value=axis, index=0, index_var=$const44.109, fn=<built-in function getitem>)
# ...
# DEBUG:numba.core.ssa:on stmt: $102pred = call bool102($96.3, func=bool102, args=(Var($96.3, coordinate_numba.py:121),), kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: branch $102pred, 104, 108
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 104
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x2aeb82626f98>
# DEBUG:numba.core.ssa:on stmt: $const104.1 = const(float, -1.0)
# DEBUG:numba.core.ssa:on stmt: cos_theta.2 = $const104.1
# DEBUG:numba.core.ssa:on stmt: jump 108
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 108
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x2aeb82626f98>
# DEBUG:numba.core.ssa:on stmt: $108.1 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims-jan2021/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $108.2 = getattr(value=$108.1, attr=arccos)
# DEBUG:numba.core.ssa:on stmt: $108.4 = call $108.2(cos_theta, func=$108.2, args=[Var(cos_theta, coordinate_numba.py:118)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:find_def var='cos_theta' stmt=$108.4 = call $108.2(cos_theta, func=$108.2, args=[Var(cos_theta, coordinate_numba.py:118)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:find_def_from_top label 108
# DEBUG:numba.core.ssa:insert phi node cos_theta.3 = phi(incoming_values=[], incoming_blocks=[]) at 108
# DEBUG:numba.core.ssa:find_def_from_bottom label 96
# DEBUG:numba.core.ssa:find_def_from_top label 96
# DEBUG:numba.core.ssa:idom 0 from label 96
# DEBUG:numba.core.ssa:find_def_from_bottom label 0
# DEBUG:numba.core.ssa:incoming_def cos_theta = $0.32
# DEBUG:numba.core.ssa:find_def_from_bottom label 90
# DEBUG:numba.core.ssa:incoming_def cos_theta.1 = $const90.1
# DEBUG:numba.core.ssa:find_def_from_bottom label 104
# DEBUG:numba.core.ssa:incoming_def cos_theta.2 = $const104.1
# DEBUG:numba.core.ssa:replaced with: $108.4 = call $108.2(cos_theta.3, func=$108.2, args=[Var(cos_theta.3, coordinate_numba.py:123)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: theta = $108.4
# DEBUG:numba.core.ssa:on stmt: $108.5 = global(_cross_vec3: CPUDispatcher(<function _cross_vec3 at 0x2aeb81901bf8>))
# DEBUG:numba.core.ssa:on stmt: $108.8 = call $108.5(a_u, b_u, func=$108.5, args=[Var(a_u, coordinate_numba.py:110), Var(b_u, coordinate_numba.py:111)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: plane1 = $108.8
# DEBUG:numba.core.ssa:on stmt: $108.9 = global(_cross_vec3: CPUDispatcher(<function _cross_vec3 at 0x2aeb81901bf8>))
# DEBUG:numba.core.ssa:on stmt: $108.12 = call $108.9(b_u, c_u, func=$108.9, args=[Var(b_u, coordinate_numba.py:111), Var(c_u, coordinate_numba.py:112)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: plane2 = $108.12
# DEBUG:numba.core.ssa:on stmt: $108.13 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims-jan2021/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $108.14 = getattr(value=$108.13, attr=dot)
# DEBUG:numba.core.ssa:on stmt: $108.17 = call $108.14(plane1, plane2, func=$108.14, args=[Var(plane1, coordinate_numba.py:126), Var(plane2, coordinate_numba.py:127)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: $108.18 = global(_norm: CPUDispatcher(<function _norm at 0x2aeb823f4f28>))
# DEBUG:numba.core.ssa:on stmt: $108.20 = call $108.18(plane1, func=$108.18, args=[Var(plane1, coordinate_numba.py:126)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: $108.21 = global(_norm: CPUDispatcher(<function _norm at 0x2aeb823f4f28>))
# DEBUG:numba.core.ssa:on stmt: $108.23 = call $108.21(plane2, func=$108.21, args=[Var(plane2, coordinate_numba.py:127)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: $108.24 = $108.20 * $108.23
# DEBUG:numba.core.ssa:on stmt: $108.25 = $108.17 / $108.24
# DEBUG:numba.core.ssa:on stmt: cos_phi = $108.25
# DEBUG:numba.core.ssa:on stmt: $const108.27 = const(float, -1.0)
# DEBUG:numba.core.ssa:on stmt: $108.28 = cos_phi < $const108.27
# DEBUG:numba.core.ssa:on stmt: bool172 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $172pred = call bool172($108.28, func=bool172, args=(Var($108.28, coordinate_numba.py:130),), kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: branch $172pred, 174, 180
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 174
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x2aeb82626f98>
# DEBUG:numba.core.ssa:on stmt: $const174.1 = const(float, -1.0)
# DEBUG:numba.core.ssa:on stmt: cos_phi.1 = $const174.1
# DEBUG:numba.core.ssa:on stmt: jump 192
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 180
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x2aeb82626f98>
# DEBUG:numba.core.ssa:on stmt: $const180.2 = const(float, 1.0)
# DEBUG:numba.core.ssa:on stmt: $180.3 = cos_phi > $const180.2
# DEBUG:numba.core.ssa:on stmt: bool186 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $186pred = call bool186($180.3, func=bool186, args=(Var($180.3, coordinate_numba.py:132),), kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: branch $186pred, 188, 192
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 188
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x2aeb82626f98>
# DEBUG:numba.core.ssa:on stmt: $const188.1 = const(float, 1.0)
# DEBUG:numba.core.ssa:on stmt: cos_phi.2 = $const188.1
# DEBUG:numba.core.ssa:on stmt: jump 192
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 192
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x2aeb82626f98>
# DEBUG:numba.core.ssa:on stmt: cos_phi.3 = phi(incoming_values=[Var(cos_phi.2, coordinate_numba.py:133), Var(cos_phi, coordinate_numba.py:129), Var(cos_phi.1, coordinate_numba.py:131)], incoming_blocks=[188, 180, 174])
# DEBUG:numba.core.ssa:on stmt: $192.1 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims-jan2021/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $192.2 = getattr(value=$192.1, attr=arccos)
# DEBUG:numba.core.ssa:on stmt: $192.4 = call $192.2(cos_phi.3, func=$192.2, args=[Var(cos_phi.3, coordinate_numba.py:135)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: phi = $192.4
# DEBUG:numba.core.ssa:on stmt: $192.5 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims-jan2021/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $192.6 = getattr(value=$192.5, attr=dot)
# DEBUG:numba.core.ssa:on stmt: $192.9 = call $192.6(a, plane2, func=$192.6, args=[Var(a, coordinate_numba.py:106), Var(plane2, coordinate_numba.py:127)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: $const192.10 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $192.11 = $192.9 <= $const192.10
# DEBUG:numba.core.ssa:on stmt: bool216 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $216pred = call bool216($192.11, func=bool216, args=(Var($192.11, coordinate_numba.py:137),), kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: branch $216pred, 218, 224
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 218
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x2aeb82626f98>
# DEBUG:numba.core.ssa:on stmt: $218.2 = unary(fn=<built-in function neg>, value=phi)
# DEBUG:numba.core.ssa:on stmt: phi.1 = $218.2
# DEBUG:numba.core.ssa:on stmt: jump 224
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 224
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x2aeb82626f98>
# DEBUG:numba.core.ssa:on stmt: phi.2 = phi(incoming_values=[Var(phi, coordinate_numba.py:135), Var(phi.1, coordinate_numba.py:138)], incoming_blocks=[192, 218])
# DEBUG:numba.core.ssa:on stmt: $224.1 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims-jan2021/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $224.2 = getattr(value=$224.1, attr=array)
# DEBUG:numba.core.ssa:on stmt: $224.6 = build_list(items=[Var(r, coordinate_numba.py:115), Var(theta, coordinate_numba.py:123), Var(phi.2, coordinate_numba.py:140)])
# DEBUG:numba.core.ssa:on stmt: $224.7 = call $224.2($224.6, func=$224.2, args=[Var($224.6, coordinate_numba.py:140)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: $224.8 = cast(value=$224.7)
# DEBUG:numba.core.ssa:on stmt: return $224.8
# /home/zhangi/miniconda3/envs/perses-sims-jan2021/lib/python3.6/site-packages/perses-0.8.2.dev0-py3.6.egg/perses/rjmc/coordinate_numba.py:129: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, A), array(float64, 1d, A))
#   cos_phi = np.dot(plane1, plane2) / (_norm(plane1)*_norm(plane2))
# /home/zhangi/miniconda3/envs/perses-sims-jan2021/lib/python3.6/site-packages/perses-0.8.2.dev0-py3.6.egg/perses/rjmc/coordinate_numba.py:137: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 1d, A))
#   if np.dot(a, plane2) <= 0:
# DEBUG:numba.core.interpreter:label 0:
#     atom_position_1 = arg(0, name=atom_position_1) ['atom_position_1']
#     bond_position_1 = arg(1, name=bond_position_1) ['bond_position_1']
#     $0.3 = atom_position_1 - bond_position_1 ['$0.3', 'atom_position_1', 'bond_position_1']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb82b37278>
# DEBUG:numba.core.ssa:on stmt: atom_position_1 = arg(0, name=atom_position_1)
# DEBUG:numba.core.ssa:on stmt: bond_position_1 = arg(1, name=bond_position_1)
# DEBUG:numba.core.ssa:on stmt: $0.3 = atom_position_1 - bond_position_1
# DEBUG:numba.core.ssa:on stmt: $0.4 = cast(value=$0.3)
# DEBUG:numba.core.ssa:on stmt: return $0.4
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$0.3': [<numba.core.ir.Assign object at 0x2aeb82b378d0>],
#              '$0.4': [<numba.core.ir.Assign object at 0x2aeb82b377f0>],
#              'atom_position_1': [<numba.core.ir.Assign object at 0x2aeb82b30278>],
#              'bond_position_1': [<numba.core.ir.Assign object at 0x2aeb82b37ac8>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.interpreter:label 0:
#     angle_position_1 = arg(0, name=angle_position_1) ['angle_position_1']
#     bond_position_2 = arg(1, name=bond_position_2) ['bond_position_2']
#     $0.3 = angle_position_1 - bond_position_2 ['$0.3', 'angle_position_1', 'bond_position_2']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb8239b2e8>
# DEBUG:numba.core.ssa:on stmt: angle_position_1 = arg(0, name=angle_position_1)
# DEBUG:numba.core.ssa:on stmt: bond_position_2 = arg(1, name=bond_position_2)
# DEBUG:numba.core.ssa:on stmt: $0.3 = angle_position_1 - bond_position_2
# DEBUG:numba.core.ssa:on stmt: $0.4 = cast(value=$0.3)
# DEBUG:numba.core.ssa:on stmt: return $0.4
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$0.3': [<numba.core.ir.Assign object at 0x2aeb8239bc18>],
#              '$0.4': [<numba.core.ir.Assign object at 0x2aeb8239b198>],
#              'angle_position_1': [<numba.core.ir.Assign object at 0x2aeb8239b710>],
#              'bond_position_2': [<numba.core.ir.Assign object at 0x2aeb8239b438>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.interpreter:label 0:
#     angle_position_2 = arg(0, name=angle_position_2) ['angle_position_2']
#     torsion_position_1 = arg(1, name=torsion_position_1) ['torsion_position_1']
#     $0.3 = angle_position_2 - torsion_position_1 ['$0.3', 'angle_position_2', 'torsion_position_1']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb82af0630>
# DEBUG:numba.core.ssa:on stmt: angle_position_2 = arg(0, name=angle_position_2)
# DEBUG:numba.core.ssa:on stmt: torsion_position_1 = arg(1, name=torsion_position_1)
# DEBUG:numba.core.ssa:on stmt: $0.3 = angle_position_2 - torsion_position_1
# DEBUG:numba.core.ssa:on stmt: $0.4 = cast(value=$0.3)
# DEBUG:numba.core.ssa:on stmt: return $0.4
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$0.3': [<numba.core.ir.Assign object at 0x2aeb82ad7be0>],
#              '$0.4': [<numba.core.ir.Assign object at 0x2aeb82ad7cc0>],
#              'angle_position_2': [<numba.core.ir.Assign object at 0x2aeb82ad7908>],
#              'torsion_position_1': [<numba.core.ir.Assign object at 0x2aeb82ad79b0>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.interpreter:label 0:
#     _0_13_1 = arg(0, name=_0_13_1)           ['_0_13_1']
#     a_1 = arg(1, name=a_1)                   ['a_1']
#     $0.3 = a_1 / _0_13_1                     ['$0.3', '_0_13_1', 'a_1']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb82817048>
# DEBUG:numba.core.ssa:on stmt: _0_13_1 = arg(0, name=_0_13_1)
# DEBUG:numba.core.ssa:on stmt: a_1 = arg(1, name=a_1)
# DEBUG:numba.core.ssa:on stmt: $0.3 = a_1 / _0_13_1
# DEBUG:numba.core.ssa:on stmt: $0.4 = cast(value=$0.3)
# DEBUG:numba.core.ssa:on stmt: return $0.4
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$0.3': [<numba.core.ir.Assign object at 0x2aeb828178d0>],
#              '$0.4': [<numba.core.ir.Assign object at 0x2aeb828179b0>],
#              '_0_13_1': [<numba.core.ir.Assign object at 0x2aeb828175f8>],
#              'a_1': [<numba.core.ir.Assign object at 0x2aeb828176a0>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.interpreter:label 0:
#     _0_18_1 = arg(0, name=_0_18_1)           ['_0_18_1']
#     b_1 = arg(1, name=b_1)                   ['b_1']
#     $0.3 = b_1 / _0_18_1                     ['$0.3', '_0_18_1', 'b_1']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb823cf390>
# DEBUG:numba.core.ssa:on stmt: _0_18_1 = arg(0, name=_0_18_1)
# DEBUG:numba.core.ssa:on stmt: b_1 = arg(1, name=b_1)
# DEBUG:numba.core.ssa:on stmt: $0.3 = b_1 / _0_18_1
# DEBUG:numba.core.ssa:on stmt: $0.4 = cast(value=$0.3)
# DEBUG:numba.core.ssa:on stmt: return $0.4
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$0.3': [<numba.core.ir.Assign object at 0x2aeb823e3e80>],
#              '$0.4': [<numba.core.ir.Assign object at 0x2aeb823e3f60>],
#              '_0_18_1': [<numba.core.ir.Assign object at 0x2aeb823e3ba8>],
#              'b_1': [<numba.core.ir.Assign object at 0x2aeb823e3c50>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.interpreter:label 0:
#     _0_23_1 = arg(0, name=_0_23_1)           ['_0_23_1']
#     c_1 = arg(1, name=c_1)                   ['c_1']
#     $0.3 = c_1 / _0_23_1                     ['$0.3', '_0_23_1', 'c_1']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2aeb82ca5f60>
# DEBUG:numba.core.ssa:on stmt: _0_23_1 = arg(0, name=_0_23_1)
# DEBUG:numba.core.ssa:on stmt: c_1 = arg(1, name=c_1)
# DEBUG:numba.core.ssa:on stmt: $0.3 = c_1 / _0_23_1
# DEBUG:numba.core.ssa:on stmt: $0.4 = cast(value=$0.3)
# DEBUG:numba.core.ssa:on stmt: return $0.4
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$0.3': [<numba.core.ir.Assign object at 0x2aeb82ca5b70>],
#              '$0.4': [<numba.core.ir.Assign object at 0x2aeb82ca5ac8>],
#              '_0_23_1': [<numba.core.ir.Assign object at 0x2aeb82ca56a0>],
#              'c_1': [<numba.core.ir.Assign object at 0x2aeb82ca5710>]})
# DEBUG:numba.core.ssa:SSA violators set()

# %% [markdown]
# test the energy discrepancy of the alanine dipeptide in vacuum

# %%
from openmmtools.testsystems import AlanineDipeptideVacuum
ala = AlanineDipeptideVacuum()

# %%
res1 = list(ala.topology.residues())[1]
rest_atoms = [atom.index for atom in res1.atoms()][:3]

# %%
ala.system.getForces()
# Out:
# [<simtk.openmm.openmm.HarmonicBondForce; proxy of <Swig Object of type 'OpenMM::HarmonicBondForce *' at 0x2aeb83d616f0> >,
#  <simtk.openmm.openmm.HarmonicAngleForce; proxy of <Swig Object of type 'OpenMM::HarmonicAngleForce *' at 0x2aeb83d61810> >,
#  <simtk.openmm.openmm.PeriodicTorsionForce; proxy of <Swig Object of type 'OpenMM::PeriodicTorsionForce *' at 0x2aeb83d61840> >,
#  <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2aeb83d61870> >,
#  <simtk.openmm.openmm.CMMotionRemover; proxy of <Swig Object of type 'OpenMM::CMMotionRemover *' at 0x2aeb83d618a0> >]

# %%
ala.system.removeForce(4) #remove CMM

# %%
ala.system.getForces()
# Out:
# [<simtk.openmm.openmm.HarmonicBondForce; proxy of <Swig Object of type 'OpenMM::HarmonicBondForce *' at 0x2aeb83d61a20> >,
#  <simtk.openmm.openmm.HarmonicAngleForce; proxy of <Swig Object of type 'OpenMM::HarmonicAngleForce *' at 0x2aeb83d61b10> >,
#  <simtk.openmm.openmm.PeriodicTorsionForce; proxy of <Swig Object of type 'OpenMM::PeriodicTorsionForce *' at 0x2aeb83d61b40> >,
#  <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2aeb83d61b70> >]

# %%
rtf = RESTTopologyFactory(system = ala.system, solute_region=rest_atoms, use_dispersion_correction=False)
# Out:
# INFO:REST:No MonteCarloBarostat added.
# INFO:REST:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# INFO:REST:No unknown forces.

# %%
ss = SamplerState(positions=ala.positions)

# %%
og_thermostate = ThermodynamicState(ala.system, temperature=300*unit.kelvin)
og_integrator = openmm.VerletIntegrator(1.0*unit.femtosecond)
og_context = og_thermostate.create_context(og_integrator)
ss.apply_to_context(og_context)
ss.update_from_context(og_context)
print(ss.potential_energy)
# Out:
# -88.08855006542615 kJ/mol

# %%
thermostate = ThermodynamicState(rtf.REST_system, temperature=300*unit.kelvin)
integrator = openmm.VerletIntegrator(1.0*unit.femtosecond)
context = thermostate.create_context(integrator)
ss.apply_to_context(context)
ss.update_from_context(context)

# %%
ss.potential_energy
# Out:
# Quantity(value=-88.08855001708469, unit=kilojoule/mole)

# %%
og_forces = [q[1] for q in compute_potential_components(og_context, thermostate.beta)]
# Out:
# conducting subsequent work with the following platform: CUDA

# %%
new_forces = [q[1] for q in compute_potential_components(context, thermostate.beta)]
# Out:
# conducting subsequent work with the following platform: CUDA

# %%
og_forces[0] - new_forces[0] #bond
# Out:
# 0.0

# %%
og_forces[1] - new_forces[1] #angle
# Out:
# 0.0

# %%
og_forces[2] - new_forces[2] #torsion
# Out:
# -4.320749028785542e-06

# %%
np.array(og_forces[3:]).sum() - np.array(new_forces[3:]).sum() #nonbonded
# Out:
# 0.0

# %% [markdown]
# test the energy discrepancy of the alanine dipeptide in solvent

# %%
from openmmtools.testsystems import AlanineDipeptideExplicit
ala = AlanineDipeptideExplicit()

# %%
res1 = list(ala.topology.residues())[1]
rest_atoms = [atom.index for atom in res1.atoms()][:3]

# %%
ala.system.getForces()
# Out:
# [<simtk.openmm.openmm.HarmonicBondForce; proxy of <Swig Object of type 'OpenMM::HarmonicBondForce *' at 0x2aeb8241b030> >,
#  <simtk.openmm.openmm.HarmonicAngleForce; proxy of <Swig Object of type 'OpenMM::HarmonicAngleForce *' at 0x2aeb8241ba50> >,
#  <simtk.openmm.openmm.PeriodicTorsionForce; proxy of <Swig Object of type 'OpenMM::PeriodicTorsionForce *' at 0x2aeb8241b0f0> >,
#  <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2aeb8241bf60> >,
#  <simtk.openmm.openmm.CMMotionRemover; proxy of <Swig Object of type 'OpenMM::CMMotionRemover *' at 0x2aeb8241b600> >]

# %%
ala.system.removeForce(4) #remove CMM

# %%
# ala.system.getForce(3).setNonbondedMethod(openmm.NonbondedForce.NoCutoff)

# %%
rtf = RESTTopologyFactory(system = ala.system, solute_region=rest_atoms, use_dispersion_correction=True)
# Out:
# INFO:REST:No MonteCarloBarostat added.
# INFO:REST:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=3.2852863, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=3.2861648000000003, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=3.1855098), unit=nanometer)]
# INFO:REST:No unknown forces.

# %%
ss = SamplerState(positions=ala.positions)

# %%
og_thermostate = ThermodynamicState(ala.system, temperature=300*unit.kelvin)
og_integrator = openmm.VerletIntegrator(1.0*unit.femtosecond)
og_context = og_thermostate.create_context(og_integrator)
ss.apply_to_context(og_context)
ss.update_from_context(og_context)
print(ss.potential_energy)
# Out:
# -24659.300241990102 kJ/mol

# %%
thermostate = ThermodynamicState(rtf.REST_system, temperature=300*unit.kelvin)
integrator = openmm.VerletIntegrator(1.0*unit.femtosecond)
context = thermostate.create_context(integrator)
ss.apply_to_context(context)
ss.update_from_context(context)

# %%
ss.potential_energy
# Out:
# Quantity(value=-24659.300434891753, unit=kilojoule/mole)

# %%
og_forces = [q[1] for q in compute_potential_components(og_context, thermostate.beta)]
# Out:
# conducting subsequent work with the following platform: CUDA

# %%
new_forces = [q[1] for q in compute_potential_components(context, thermostate.beta)]
# Out:
# conducting subsequent work with the following platform: CUDA

# %%
og_forces[0] - new_forces[0] #bond
# Out:
# 0.0

# %%
og_forces[1] - new_forces[1] #angle
# Out:
# 0.0

# %%
og_forces[2] - new_forces[2] #torsion
# Out:
# -3.2982395725689173e-06

# %%
np.array(og_forces[3:]).sum() - np.array(new_forces[3:]).sum() #nonbonded
# Out:
# 8.063402310654055e-05

# %%
og_forces
# Out:
# [0.03455181083219596,
#  0.6071348482604662,
#  3.229847881682588,
#  -9889.978580573495,
#  0.0]

# %%
new_forces
# Out:
# [0.03455181083219596,
#  0.6071348482604662,
#  3.2298511799221608,
#  -9889.978661207519,
#  0.0]

# %% [markdown]
# the discrepancy is clearly coming from the nonbonded force; are these exceptions?

# %% [markdown]
# Create solvate alanine vanilla system

# %%
pdb = app.PDBFile("../../input/ala_vacuum.pdb")

forcefield_files = ['amber14/protein.ff14SB.xml', 'amber14/tip3p.xml']
barostat = openmm.MonteCarloBarostat(1.0 * unit.atmosphere, 298 * unit.kelvin, 50)
system_generator = SystemGenerator(forcefields=forcefield_files,
                               barostat=barostat,
                               forcefield_kwargs={'removeCMMotion': False,
                                                    'ewaldErrorTolerance': 1e-4,
                                                    'constraints' : app.HBonds,
                                                    'hydrogenMass' : 4 * unit.amus},
                                periodic_forcefield_kwargs={'nonbondedMethod': app.PME},
                                small_molecule_forcefield='gaff-2.11',
                                nonperiodic_forcefield_kwargs=None, 
                                   molecules=None, 
                                   cache=None)
modeller = app.Modeller(pdb.topology, pdb.positions)
modeller.addSolvent(system_generator.forcefield, model='tip3p', padding=9*unit.angstroms, ionicStrength=0.15*unit.molar)
solvated_topology = modeller.getTopology()
solvated_positions = modeller.getPositions()

# Canonicalize the solvated positions: turn tuples into np.array
positions = unit.quantity.Quantity(value=np.array([list(atom_pos) for atom_pos in solvated_positions.value_in_unit_system(unit.md_unit_system)]), unit=unit.nanometers)
sys = system_generator.create_system(solvated_topology)
# Out:
# DEBUG:openmmforcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11

# %%
for i in range(sys.getNumForces()):
    print(sys.getForce(i))
# Out:
# <simtk.openmm.openmm.HarmonicBondForce; proxy of <Swig Object of type 'OpenMM::HarmonicBondForce *' at 0x2aeb83d61cf0> >
# <simtk.openmm.openmm.HarmonicAngleForce; proxy of <Swig Object of type 'OpenMM::HarmonicAngleForce *' at 0x2aeb83d61cf0> >
# <simtk.openmm.openmm.PeriodicTorsionForce; proxy of <Swig Object of type 'OpenMM::PeriodicTorsionForce *' at 0x2aeb83d61cf0> >
# <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2aeb83d61cf0> >
# <simtk.openmm.openmm.MonteCarloBarostat; proxy of <Swig Object of type 'OpenMM::MonteCarloBarostat *' at 0x2aeb83d61cf0> >

# %% [markdown]
# Create a subclass of the RESTTopologyFactory so that we can play around with the functions and test the energies

# %%
class RESTTEST(RESTTopologyFactory):
    """
    subclass REST, but manually set and scale per particle parameters with the given naught and scaled betas
    """

    def __init__(self, system, solute_region, use_dispersion_correction=False, beta0, beta_m):
        self._beta0 = beta0
        self._beta_m = beta_m
        super().__init__(system, solute_region, use_dispersion_correction)\
    
    def bonded_scale(self, identifier):
        if identifier==0:
            out = self._beta_m/self._beta0
        elif identifier==1:
            out = 1.
        elif identifier==2:
            out= np.sqrt(self._beta_m/self._beta0)
        else:
            raise Exception as e:
                print(e)
        return out
        
    
    def _add_bond_force_terms(self):
        force = openmm.HarmonicBondForce()
        self._out_system.addForce(force)
        self._out_system_forces[force.__class__.__name__] = force
    
    def _add_angle_force_terms(self):
        force = openmm.HarmonicAngleForce()
        self._out_system.addForce(force)
        self._out_system_forces[force.__class__.__name__] = force
    
    def _add_torsion_force_terms(self):
        force = openmm.PeriodicTorsionForce()
        self._out_system.addForce(force)
        self._out_system_forces[force.__class__.__name__] = force
    
    def _add_nonbonded_force_terms(self)
        
        epsilon_solvent = self._og_system_forces['NonbondedForce'].getReactionFieldDielectric()
        r_cutoff = self._og_system_forces['NonbondedForce'].getCutoffDistance()
        
        if self._nonbonded_method != openmm.NonbondedForce.NoCutoff:
            standard_nonbonded_force.setReactionFieldDielectric(epsilon_solvent)
            standard_nonbonded_force.setCutoffDistance(r_cutoff)
        if self._nonbonded_method in [openmm.NonbondedForce.PME, openmm.NonbondedForce.Ewald]:
            [alpha_ewald, nx, ny, nz] = self._og_system_forces['NonbondedForce'].getPMEParameters()
            delta = self._og_system_forces['NonbondedForce'].getEwaldErrorTolerance()
            standard_nonbonded_force.setPMEParameters(alpha_ewald, nx, ny, nz)
            standard_nonbonded_force.setEwaldErrorTolerance(delta)
        standard_nonbonded_force.setNonbondedMethod(self._nonbonded_method)
        
        if self._og_system_forces['NonbondedForce'].getUseSwitchingFunction():
            switching_distance = self._og_system_forces['NonbondedForce'].getSwitchingDistance()
            standard_nonbonded_force.setUseSwitchingFunction(True)
            standard_nonbonded_force.setSwitchingDistance(switching_distance)
        else:
            standard_nonbonded_force.setUseSwitchingFunction(False)
    
    def _add_bonds(self):
        force = self._og_bond_forces['HarmonicBondForce']
        for bond_idx in range(force.getNumBonds()):
            p1, p2, length, k = force.getBondParameters(bond_idx)
            identifier = self.get_identifier([p1, p2])
            scale = self.bonded_scale(identifier)
            self._out_system_forces['HarmonicBondForce'].addBond(p1, p2, length, k*scale)
    
    def _add_angles(self):
        force = self._og_bond_forces['HarmonicAngleForce']
        for angle_idx in range(force.getNumAngles()):
            p1, p2, p3, theta0, k = force.getAngleParameters(angle_idx)
            identifier = self.get_identifier([p1, p2, p3])
            scale = self.bonded_scale(identifier)
            self._out_system_forces['HarmonicAngleForce'].addAngle(p1, p2, p3, theta0, k*scale)
    
    def _add_torsions(self):
        force = self._og_bond_forces['PeriodicTorsionForce']
        for torsion_idx in range(force.getNumTorsions(force)):
            p1, p2, p3, p4, per, phase, k = force.getTorsionParameters(torsion_idx)
            identifier = self.get_identifier([p1, p2, p3, p4])
            scale = self.bonded_scale(identifier)
            self._out_system_forces['PeriodicTorsionForce'].addTorsion(p1, p2, p3, p4, per, phase, k*scale)
    
    def _add_nonbondeds(self):
        force = self._og_system_forces
        for particle_idx in range
    
            
            
        
        
        
        
    
        
    def _add_nonbonded_force_terms(self):
        from openmmtools.constants import ONE_4PI_EPS0 # OpenMM constant for Coulomb interactions (implicitly in md_unit_system units)
        standard_nonbonded_force = openmm.NonbondedForce()
        self._out_system.addForce(standard_nonbonded_force)
        self._out_system_forces[standard_nonbonded_force.__class__.__name__] = standard_nonbonded_force
        
        
    def _add_nonbondeds(self):
        self._solute_exceptions, self._interexceptions = [], []

        #the output nonbonded force _only_ contains solvent atoms (the rest are zeroed); same with exceptions
        """
        First, handle the NonbondedForce in the out_system
        """
        og_nb_force = self._og_system_forces['NonbondedForce']
        for particle_idx in range(self._num_particles):
            q, sigma, epsilon = og_nb_force.getParticleParameters(particle_idx)
            identifier = self.get_identifier(particle_idx)

            if identifier == 1:
                self._out_system_forces['NonbondedForce'].addParticle(q, sigma, epsilon)
                self._out_system_forces['CustomNonbondedForce'].addParticle([q, sigma, epsilon, identifier])
            else:
                self._out_system_forces['NonbondedForce'].addParticle(q*0.0, sigma, epsilon*0.0)
                self._out_system_forces['CustomNonbondedForce'].addParticle([q, sigma, epsilon, identifier])

        #add appropriate interaction group
        solute_ig, solvent_ig = set(self._solute_region), set(self._solvent_region)
        self._out_system_forces['CustomNonbondedForce'].addInteractionGroup(solute_ig, solvent_ig)
        self._out_system_forces['CustomNonbondedForce'].addInteractionGroup(solute_ig, solute_ig)

        #handle exceptions
        for exception_idx in range(og_nb_force.getNumExceptions()):
            p1, p2, chargeProd, sigma, epsilon = og_nb_force.getExceptionParameters(exception_idx)
            identifier = self.get_identifier([p1, p2])
            if identifier == 1:
                self._out_system_forces['NonbondedForce'].addException(p1, p2, chargeProd, sigma, epsilon)
                self._out_system_forces['CustomNonbondedForce'].addExclusion(p1, p2) #maintain consistent exclusions w/ exceptions
            elif identifier == 0:
                self._solute_exceptions.append([p1, p2, [chargeProd, sigma, epsilon]])
                self._out_system_forces['NonbondedForce'].addException(p1, p2, chargeProd*0.0, sigma, epsilon*0.0)
                self._out_system_forces['CustomNonbondedForce'].addExclusion(p1, p2) #maintain consistent exclusions w/ exceptions
            elif identifier == 2:
                self._interexceptions.append([p1, p2, [chargeProd, sigma, epsilon]])
                self._out_system_forces['NonbondedForce'].addException(p1, p2, chargeProd*0.0, sigma, epsilon*0.0)
                self._out_system_forces['CustomNonbondedForce'].addExclusion(p1, p2) #maintain consistent exclusions w/ exceptions

        #now add the CustomBondForce for exceptions
        exception_force = self._out_system_forces['CustomExceptionForce']

        for solute_exception_term in self._solute_exceptions:
            p1, p2, [chargeProd, sigma, epsilon] = solute_exception_term
            if (chargeProd.value_in_unit_system(unit.md_unit_system) != 0.0) or (epsilon.value_in_unit_system(unit.md_unit_system) != 0.0):
                identifier = 0
                exception_force.addBond(p1, p2, [chargeProd, sigma, epsilon, identifier])

        for interexception_term in self._interexceptions:
            p1, p2, [chargeProd, sigma, epsilon] = interexception_term
            if (chargeProd.value_in_unit_system(unit.md_unit_system) != 0.0) or (epsilon.value_in_unit_system(unit.md_unit_system) != 0.0):
                identifier = 2
                exception_force.addBond(p1, p2, [chargeProd, sigma, epsilon, identifier])
# Out:
#   File "<ipython-input-38-c0112c437797>", line 19
#     raise Exception as e:
#                      ^
# SyntaxError: invalid syntax

# %%
# Create REST system
factory = REST2(sys, solute_region=list(range(0, 22)))
REST_system = factory.REST_system

# %%
REST_system.getForces()

# %%
for i in range(REST_system.getForce(5).getNumParticles()):
    print(i, REST_system.getForce(5).getParticleParameters(i))

# %% [markdown]
# Get the energy of the REST system at the thermodynamic state where energy is scaled to 600K

# %%
T_min = 298.0 *unit.kelvin
T = 600.0 * unit.kelvin

# Create thermodynamic state
lambda_zero_alchemical_state = RESTState.from_system(REST_system)
thermostate = ThermodynamicState(REST_system, temperature=T_min)
compound_thermodynamic_state = CompoundThermodynamicState(thermostate,
                                                          composable_states=[lambda_zero_alchemical_state])

# Set alchemical parameters
beta_0 = 1 / (kB * T_min)
beta_m = 1 / (kB * T)
compound_thermodynamic_state.set_alchemical_parameters(beta_0, beta_m)

integrator = openmm.VerletIntegrator(1.0*unit.femtosecond)
context = compound_thermodynamic_state.create_context(integrator)
context.setPositions(positions)
sampler_state = SamplerState.from_context(context)
compound_thermodynamic_state.reduced_potential(sampler_state)

# %% [markdown]
# Get energy of vanilla system (after manually scaling energies) at same thermostate as above

# %%
system = sys

# Compute energy for non-RESTified system
protein = list(range(0, 22))
environment = list(range(22, system.getNumParticles()))
protein_scaling = beta_m / beta_0
inter_scaling = np.sqrt(beta_m / beta_0)

# Scale the terms in the bond force appropriately
bond_force = system.getForce(0)
for bond in range(bond_force.getNumBonds()):
    p1, p2, length, k = bond_force.getBondParameters(bond)
    if p1 in protein and p2 in protein:
        bond_force.setBondParameters(bond, p1, p2, length, k * protein_scaling)
    elif (p1 in protein and p2 in environment) or (p1 in environment and p2 in protein):
        bond_force.setBondParameters(bond, p1, p2, length, k * inter_scaling)

# Scale the terms in the angle force appropriately
angle_force = system.getForce(1)
for angle_index in range(angle_force.getNumAngles()):
    p1, p2, p3, angle, k = angle_force.getAngleParameters(angle_index)
    if p1 in protein and p2 in protein and p3 in protein:
        angle_force.setAngleParameters(angle_index, p1, p2, p3, angle, k * protein_scaling)
    elif set([p1, p2, p3]).intersection(set(protein)) != set() and set([p1, p2, p3]).intersection(set(environment)) != set():
        angle_force.setAngleParameters(angle_index, p1, p2, p3, angle, k * inter_scaling)

# Scale the terms in the torsion force appropriately
torsion_force = system.getForce(2)
for torsion_index in range(torsion_force.getNumTorsions()):
    p1, p2, p3, p4, periodicity, phase, k = torsion_force.getTorsionParameters(torsion_index)
    if p1 in protein and p2 in protein and p3 in protein and p4 in protein:
        torsion_force.setTorsionParameters(torsion_index, p1, p2, p3, p4, periodicity, phase, k * protein_scaling)
    elif set([p1, p2, p3, p4]).intersection(set(protein)) != set() and set([p1, p2, p3, p4]).intersection(set(environment)) != set():
        torsion_force.setTorsionParameters(torsion_index, p1, p2, p3, p4, periodicity, phase, k * inter_scaling)

# Scale the exceptions in the nonbonded force appropriately
nb_force = system.getForce(3)
for nb_index in range(nb_force.getNumExceptions()):
    p1, p2, chargeProd, sigma, epsilon = nb_force.getExceptionParameters(nb_index)
    if p1 in protein and p2 in protein:
        nb_force.setExceptionParameters(nb_index, p1, p2, protein_scaling * chargeProd, sigma, protein_scaling * epsilon)
    elif (p1 in protein and p2 in environment) or (p1 in environment and p2 in protein):
        nb_force.setExceptionParameters(nb_index, p1, p2, inter_scaling * chargeProd, sigma, inter_scaling * epsilon)

exception_pairs = [tuple(sorted([nb_force.getExceptionParameters(nb_index)[0], nb_force.getExceptionParameters(nb_index)[1]])) for nb_index in range(nb_force.getNumExceptions())]
solute_pairs = set([tuple(sorted(pair)) for pair in list(itertools.product(protein, protein))])
# Scale nonbonded interactions for solute region by adding exceptions for all pairs of atoms 
for pair in list(solute_pairs):
    p1 = pair[0]
    p2 = pair[1]
    p1_charge, p1_sigma, p1_epsilon = nb_force.getParticleParameters(p1)
    p2_charge, p2_sigma, p2_epsilon = nb_force.getParticleParameters(p2)
    if p1 != p2:
        if pair not in exception_pairs:
#             print(pair)
            nb_force.addException(p1, p2, p1_charge*p2_charge*protein_scaling, 0.5*(p1_sigma+p2_sigma), np.sqrt(p1_epsilon*p2_epsilon)*protein_scaling)
        
# Scale nonbonded interactions for inter region by adding exceptions for all pairs of atoms 
# traj = md.Trajectory(np.array(positions), md.Topology.from_openmm(solvated_topology))
# nearby_waters = md.compute_neighbors(traj, 0.4, list(range(0,22)), haystack_indices=list(range(22, solvated_topology.getNumAtoms())))[0]
for pair in list(itertools.product(protein, environment)):
    p1 = pair[0]
    p2 = int(pair[1]) # otherwise, will be a numpy int
    p1_charge, p1_sigma, p1_epsilon = nb_force.getParticleParameters(p1)
    p2_charge, p2_sigma, p2_epsilon = nb_force.getParticleParameters(p2)
    nb_force.addException(p1, p2, p1_charge*p2_charge*inter_scaling, 0.5*(p1_sigma+p2_sigma), np.sqrt(p1_epsilon*p2_epsilon)*inter_scaling)

# Save energy
thermostate = ThermodynamicState(system, temperature=T_min)
integrator = openmm.VerletIntegrator(1.0*unit.femtosecond)
context = thermostate.create_context(integrator)
context.setPositions(positions)
sampler_state = SamplerState.from_context(context)
thermostate.reduced_potential(sampler_state)
