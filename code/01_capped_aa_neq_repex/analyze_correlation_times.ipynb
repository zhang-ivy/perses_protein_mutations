# %%
import mdtraj as md
import pickle
import numpy as np
from matplotlib import pyplot as plt
from simtk import openmm, unit

# %% [markdown]
# ### 2.5 ns of equilibration for fully interacting system at SER endstate

# %%
with open("/data/chodera/zhangi/perses_benchmark/neq/3/6/6_solvent.pickle", 'rb') as f:
    htf = pickle.load(f)
# Out:
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=6)
#            2	LOAD_GLOBAL(arg=0, lineno=6)
#            4	LOAD_METHOD(arg=1, lineno=6)
#            6	LOAD_CONST(arg=1, lineno=6)
#            8	CALL_METHOD(arg=1, lineno=6)
#           10	STORE_FAST(arg=2, lineno=6)
#           12	LOAD_FAST(arg=0, lineno=7)
#           14	LOAD_CONST(arg=2, lineno=7)
#           16	BINARY_SUBSCR(arg=None, lineno=7)
#           18	LOAD_FAST(arg=1, lineno=7)
#           20	LOAD_CONST(arg=3, lineno=7)
#           22	BINARY_SUBSCR(arg=None, lineno=7)
#           24	BINARY_MULTIPLY(arg=None, lineno=7)
#           26	LOAD_FAST(arg=0, lineno=7)
#           28	LOAD_CONST(arg=3, lineno=7)
#           30	BINARY_SUBSCR(arg=None, lineno=7)
#           32	LOAD_FAST(arg=1, lineno=7)
#           34	LOAD_CONST(arg=2, lineno=7)
#           36	BINARY_SUBSCR(arg=None, lineno=7)
#           38	BINARY_MULTIPLY(arg=None, lineno=7)
#           40	BINARY_SUBTRACT(arg=None, lineno=7)
# ...

# %%
old_top = md.Topology.from_openmm(htf._topology_proposal.old_topology)

# %%
with open("/data/chodera/zhangi/perses_benchmark/neq/3/6/6_solvent_equil_old.npy", 'rb') as f:
    pos = np.load(f)

# %%
for atom in traj.topology.atoms:
    print(atom, atom.index)
# Out:
# ACE1-H1 0
# ACE1-CH3 1
# ACE1-H2 2
# ACE1-H3 3
# ACE1-C 4
# ACE1-O 5
# SER2-N 6
# SER2-H 7
# SER2-CA 8
# SER2-HA 9
# SER2-CB 10
# SER2-HB2 11
# SER2-HB3 12
# SER2-C 13
# SER2-O 14
# SER2-OG 15
# SER2-HG 16
# NME3-N 17
# NME3-H 18
# NME3-C 19
# NME3-H1 20
# NME3-H2 21
# NME3-H3 22
# HOH4-O 23
# HOH4-H1 24
# HOH4-H2 25
# HOH5-O 26
# HOH5-H1 27
# HOH5-H2 28
# HOH6-O 29
# HOH6-H1 30
# HOH6-H2 31
# HOH7-O 32
# HOH7-H1 33
# HOH7-H2 34
# HOH8-O 35
# HOH8-H1 36
# HOH8-H2 37
# HOH9-O 38
# HOH9-H1 39
# HOH9-H2 40
# HOH10-O 41
# HOH10-H1 42
# HOH10-H2 43
# HOH11-O 44
# HOH11-H1 45
# HOH11-H2 46
# HOH12-O 47
# HOH12-H1 48
# HOH12-H2 49
# HOH13-O 50
# HOH13-H1 51
# HOH13-H2 52
# HOH14-O 53
# HOH14-H1 54
# HOH14-H2 55
# HOH15-O 56
# HOH15-H1 57
# HOH15-H2 58
# HOH16-O 59
# HOH16-H1 60
# HOH16-H2 61
# HOH17-O 62
# HOH17-H1 63
# HOH17-H2 64
# HOH18-O 65
# HOH18-H1 66
# HOH18-H2 67
# HOH19-O 68
# HOH19-H1 69
# HOH19-H2 70
# HOH20-O 71
# HOH20-H1 72
# HOH20-H2 73
# HOH21-O 74
# HOH21-H1 75
# ...

# %%
traj = md.Trajectory(np.array(pos), old_top)

# %%
traj.save("test_old.pdb")

# %%
traj
# Out:
# <mdtraj.Trajectory with 835 frames, 1989 atoms, 661 residues, without unitcells at 0x2ba0293c83c8>

# %%
dihedrals = np.sin(md.compute_dihedrals(traj, np.array([[15, 10, 8, 6]])))

# %%
len(dihedrals)
# Out:
# 835

# %%
plt.hist(dihedrals)
plt.xlabel("dihedral angle (radians)")
plt.show()
# Out:
# DEBUG:matplotlib.font_manager:findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# DEBUG:matplotlib.font_manager:findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(<Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal bold normal>) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal regular normal>) = 10.05
# DEBUG:matplotlib.font_manager:findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>) = 1.05
# DEBUG:matplotlib.font_manager:findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal bold normal>) = 10.335
# DEBUG:matplotlib.font_manager:findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal bold normal>) = 10.335
# ...

# %%
max(dihedrals)
# Out:
# array([2.0020642], dtype=float32)

# %%
for i, dihedral in enumerate(dihedrals):
    if dihedral > 1.9:
        print(i)
# Out:
# 193
# 291
# 336
# 469
# 496
# 522
# 573
# 600
# 679

# %%
for i in [193, 291, 336]:
    traj[i].save(f"{i}.pdb")

# %%
min(dihedrals)
# Out:
# array([-3.1407504], dtype=float32)

# %%
for i, dihedral in enumerate(dihedrals):
    if dihedral < -0.9:
        print(i)
# Out:
# 779
# 786
# 806
# 820

# %%
for i in [779, 786, 806]:
    traj[i].save(f"{i}.pdb")

# %%
from perses.dispersed import feptasks
# Out:
# RDKit WARNING: [15:06:27] Enabling RDKit 2019.09.3 jupyter extensions

# %%
dihedrals_

# %%
feptasks.compute_timeseries(dihedrals)
# Out:
# [770, 2.9980567, 22.014261, array([[ 1.3936204 ],
#         [-0.52025473],
#         [-0.41925317],
#         [-0.9304024 ],
#         [-0.4762037 ],
#         [-0.22608417],
#         [-0.39828575],
#         [-0.51943076],
#         [-0.32162717],
#         [-0.48238656],
#         [-0.8159023 ],
#         [-0.6446296 ],
#         [-0.9213844 ],
#         [-0.58004904],
#         [-0.2871382 ],
#         [-0.4642847 ],
#         [-0.43342298],
#         [-0.80531317],
#         [-0.83840835],
#         [-0.0624272 ],
#         [-0.24008921],
#         [-0.19096383]], dtype=float32), [770,
#   773,
#   776,
#   779,
#   782,
#   785,
#   788,
#   791,
#   794,
#   797,
#   800,
#   803,
#   806,
#   809,
#   812,
#   815,
#   818,
#   821,
#   824,
#   827,
#   830,
#   833]]

# %%
plt.scatter(range(835), dihedrals)
plt.ylabel("sin(dihedral)")
plt.xlabel("iteration number")
plt.show()

# %% [markdown]
# ### 2.5 ns of equilibration for SER endstate with alcohol electrostatics turned off

# %%
with open("/data/chodera/zhangi/perses_benchmark/neq/3/6/6_solvent.pickle", 'rb') as f:
    htf = pickle.load(f)

# %%
old_top = md.Topology.from_openmm(htf._topology_proposal.old_topology)

# %%
with open("/data/chodera/zhangi/perses_benchmark/neq/3/6/6_solvent_equil_old_no_alc_elec.npy", 'rb') as f:
    pos = np.load(f)

# %%
traj = md.Trajectory(np.array(pos), old_top)

# %%
for atom in htf._topology_proposal.old_topology.atoms():
    print(atom, atom.id)
# Out:
# <Atom 0 (H1) of chain 0 residue 0 (ACE)> 1
# <Atom 1 (CH3) of chain 0 residue 0 (ACE)> 2
# <Atom 2 (H2) of chain 0 residue 0 (ACE)> 3
# <Atom 3 (H3) of chain 0 residue 0 (ACE)> 4
# <Atom 4 (C) of chain 0 residue 0 (ACE)> 5
# <Atom 5 (O) of chain 0 residue 0 (ACE)> 6
# <Atom 6 (N) of chain 0 residue 1 (SER)> 7
# <Atom 7 (H) of chain 0 residue 1 (SER)> 8
# <Atom 8 (CA) of chain 0 residue 1 (SER)> 9
# <Atom 9 (HA) of chain 0 residue 1 (SER)> 10
# <Atom 10 (CB) of chain 0 residue 1 (SER)> 11
# <Atom 11 (HB2) of chain 0 residue 1 (SER)> 12
# <Atom 12 (HB3) of chain 0 residue 1 (SER)> 13
# <Atom 13 (C) of chain 0 residue 1 (SER)> 14
# <Atom 14 (O) of chain 0 residue 1 (SER)> 15
# <Atom 15 (OG) of chain 0 residue 1 (SER)> 16
# <Atom 16 (HG) of chain 0 residue 1 (SER)> 17
# <Atom 17 (N) of chain 0 residue 2 (NME)> 18
# <Atom 18 (H) of chain 0 residue 2 (NME)> 19
# <Atom 19 (C) of chain 0 residue 2 (NME)> 20
# <Atom 20 (H1) of chain 0 residue 2 (NME)> 21
# ...

# %%
dihedrals = md.compute_dihedrals(traj, np.array([[9, 8, 11, 12]]))

# %%
plt.hist(dihedrals)
plt.show()

# %%
list(dihedrals).index(max(dihedrals))
# Out:
# 748

# %%
for i, dihedral in enumerate(dihedrals):
    if dihedral < -3.1:
        print(i)
# Out:
# 20
# 82
# 264
# 266
# 284
# 334
# 521
# 546
# 597
# 670
# 758

# %%
for i, dihedral in enumerate(dihedrals):
    if dihedral > 3:
        print(i)
# Out:
# 21
# 22
# 29
# 51
# 300
# 428
# 438
# 549
# 716
# 734
# 748
# 821

# %%
list(dihedrals).index(min(dihedrals))
# Out:
# 521

# %%
traj.save("test.pdb") ## This shows that all the frames are have the same alcohol rotamer --> see 1_4_frames.pse

# %%
traj
# Out:
# <mdtraj.Trajectory with 835 frames, 1989 atoms, 661 residues, without unitcells at 0x2b5f776cd0b8>
