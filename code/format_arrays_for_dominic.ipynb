# %%
import pickle
import numpy as np
import os

import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %%
with open(os.path.join(f"/data/chodera/zhangi/perses_benchmark/neq/7/29/29_vacuum.pickle"), "rb") as f:
    htf = pickle.load(f)

# %%
for atom in htf._topology_proposal.old_topology.atoms():
    print(atom)
# Out:
# <Atom 0 (H1) of chain 0 residue 0 (ACE)>
# <Atom 1 (CH3) of chain 0 residue 0 (ACE)>
# <Atom 2 (H2) of chain 0 residue 0 (ACE)>
# <Atom 3 (H3) of chain 0 residue 0 (ACE)>
# <Atom 4 (C) of chain 0 residue 0 (ACE)>
# <Atom 5 (O) of chain 0 residue 0 (ACE)>
# <Atom 6 (N) of chain 0 residue 1 (ALA)>
# <Atom 7 (H) of chain 0 residue 1 (ALA)>
# <Atom 8 (CA) of chain 0 residue 1 (ALA)>
# <Atom 9 (HA) of chain 0 residue 1 (ALA)>
# <Atom 10 (CB) of chain 0 residue 1 (ALA)>
# <Atom 11 (HB2) of chain 0 residue 1 (ALA)>
# <Atom 12 (HB3) of chain 0 residue 1 (ALA)>
# <Atom 13 (C) of chain 0 residue 1 (ALA)>
# <Atom 14 (O) of chain 0 residue 1 (ALA)>
# <Atom 15 (HB1) of chain 0 residue 1 (ALA)>
# <Atom 16 (N) of chain 0 residue 2 (NME)>
# <Atom 17 (H) of chain 0 residue 2 (NME)>
# <Atom 18 (C) of chain 0 residue 2 (NME)>
# <Atom 19 (H1) of chain 0 residue 2 (NME)>
# <Atom 20 (H2) of chain 0 residue 2 (NME)>
# <Atom 21 (H3) of chain 0 residue 2 (NME)>

# %%
htf.hybrid_topology.n_atoms
# Out:
# 29

# %%
j = 29
forward_before = np.empty([100, 29, 3])
for i in range(100):
    with open(os.path.join(f"/data/chodera/zhangi/perses_benchmark/neq/7/{j}/{j}_vacuum_{i}_forward_before.npy"), "rb") as f:
        arr = np.load(f)
        forward_before[i] = arr

forward_after = np.empty([100, 29, 3])
for i in range(100):
    with open(os.path.join(f"/data/chodera/zhangi/perses_benchmark/neq/7/{j}/{j}_vacuum_{i}_forward_before.npy"), "rb") as f:
        arr = np.load(f)
        forward_after[i] = arr

reverse_before = np.empty([100, 29, 3])
for i in range(100):
    with open(os.path.join(f"/data/chodera/zhangi/perses_benchmark/neq/7/{j}/{j}_vacuum_{i}_forward_before.npy"), "rb") as f:
        arr = np.load(f)
        reverse_before[i] = arr

reverse_after = np.empty([100, 29, 3])
for i in range(100):
    with open(os.path.join(f"/data/chodera/zhangi/perses_benchmark/neq/7/{j}/{j}_vacuum_{i}_forward_before.npy"), "rb") as f:
        arr = np.load(f)
        reverse_after[i] = arr
ala_thr_pos = np.array([forward_before, forward_after, reverse_before, reverse_after])
       
ala_thr_works = np.empty([2, 100, 1])
ala_thr_forward_works = np.empty([100, 1])
ala_thr_reverse_works = np.empty([100, 1])
for i in range(100):
    with open(os.path.join(f"/data/chodera/zhangi/perses_benchmark/neq/7/{j}/{j}_vacuum_{i}_forward.npy"), "rb") as f:
        arr = np.load(f)
        ala_thr_forward_works[i] = arr[-1] - arr[0]
for i in range(100):
    with open(os.path.join(f"/data/chodera/zhangi/perses_benchmark/neq/7/{j}/{j}_vacuum_{i}_reverse.npy"), "rb") as f:
        arr = np.load(f)
        ala_thr_reverse_works[i] = arr[-1] - arr[0]
ala_thr_works = np.array([ala_thr_forward_works, ala_thr_reverse_works])

# %%
ala_thr_pos.shape
# Out:
# (4, 100, 29, 3)

# %%
ala_thr_works.shape
# Out:
# (100, 1)

# %%
j = 30
forward_before = np.empty([100, 28, 3])
for i in range(100):
    with open(os.path.join(f"/data/chodera/zhangi/perses_benchmark/neq/7/{j}/{j}_vacuum_{i}_forward_before.npy"), "rb") as f:
        arr = np.load(f)
        forward_before[i] = arr

forward_after = np.empty([100, 28, 3])
for i in range(100):
    with open(os.path.join(f"/data/chodera/zhangi/perses_benchmark/neq/7/{j}/{j}_vacuum_{i}_forward_before.npy"), "rb") as f:
        arr = np.load(f)
        forward_after[i] = arr

reverse_before = np.empty([100, 28, 3])
for i in range(100):
    with open(os.path.join(f"/data/chodera/zhangi/perses_benchmark/neq/7/{j}/{j}_vacuum_{i}_forward_before.npy"), "rb") as f:
        arr = np.load(f)
        reverse_before[i] = arr

reverse_after = np.empty([100, 28, 3])
for i in range(100):
    with open(os.path.join(f"/data/chodera/zhangi/perses_benchmark/neq/7/{j}/{j}_vacuum_{i}_forward_before.npy"), "rb") as f:
        arr = np.load(f)
        reverse_after[i] = arr
thr_ala_pos = np.array([forward_before, forward_after, reverse_before, reverse_after])
       
thr_ala_works = np.empty([2, 100, 1])
thr_ala_forward_works = np.empty([100, 1])
thr_ala_reverse_works = np.empty([100, 1])
for i in range(100):
    with open(os.path.join(f"/data/chodera/zhangi/perses_benchmark/neq/7/{j}/{j}_vacuum_{i}_forward.npy"), "rb") as f:
        arr = np.load(f)
        thr_ala_forward_works[i] = arr[-1] - arr[0]
for i in range(100):
    with open(os.path.join(f"/data/chodera/zhangi/perses_benchmark/neq/7/{j}/{j}_vacuum_{i}_reverse.npy"), "rb") as f:
        arr = np.load(f)
        thr_ala_reverse_works[i] = arr[-1] - arr[0]
thr_ala_works = np.array([thr_ala_forward_works, thr_ala_reverse_works])

# %%
ala_thr_works
# Out:
# array([[[ 52.89920328],
#         [ 52.66627805],
#         [ 52.55047395],
#         [ 53.45417739],
#         [ 51.69078938],
#         [ 52.32320211],
#         [ 51.99084216],
#         [ 51.991322  ],
#         [ 52.51978277],
#         [ 52.52945564],
#         [ 51.94512478],
#         [ 53.50817533],
#         [ 52.20087593],
#         [ 52.3649752 ],
#         [ 52.42658077],
#         [ 53.31430771],
#         [ 52.17399126],
#         [ 52.39886566],
#         [ 52.0944145 ],
#         [ 51.32706684],
#         [ 51.9671849 ],
#         [ 52.37851177],
#         [ 52.48541735],
#         [ 53.18798235],
#         [ 53.06686412],
#         [ 51.968866  ],
#         [ 52.71718535],
#         [ 52.11921145],
#         [ 53.22563003],
#         [ 52.23503223],
#         [ 52.75027889],
#         [ 52.00469379],
#         [ 53.62369842],
#         [ 52.83994679],
#         [ 51.36844784],
#         [ 52.28296265],
#         [ 52.90261318],
#         [ 52.66458355],
# ...

# %%
thr_ala_works
# Out:
# array([[[-50.3901299 ],
#         [-28.72208139],
#         [-28.02258254],
#         [-50.51417709],
#         [-30.39764836],
#         [-49.17885788],
#         [-28.09655491],
#         [-50.67884791],
#         [-50.22094499],
#         [-30.5601372 ],
#         [-50.9711475 ],
#         [-27.08182371],
#         [-50.79286932],
#         [-28.49376126],
#         [-50.34673974],
#         [-28.90559875],
#         [-50.53125917],
#         [-51.12970699],
#         [-50.42735375],
#         [-51.78692151],
#         [-27.22574576],
#         [-34.96645204],
#         [-50.11727108],
#         [-50.52596956],
#         [-52.28971519],
#         [-31.31522862],
#         [-50.95249764],
#         [-50.62381115],
#         [-51.36715786],
#         [-50.86590483],
#         [-49.96903679],
#         [-52.45318246],
#         [-50.94931042],
#         [-50.71017566],
#         [-29.55639202],
#         [-51.1588402 ],
#         [-50.886426  ],
#         [-31.33349773],
# ...

# %%
import seaborn as sns
sns.distplot(thr_ala_works[0])
sns.distplot(-thr_ala_works[1])

# %%
sns.distplot(ala_thr_works[0])
sns.distplot(-ala_thr_works[1])

# %%
with open(os.path.join(f"/data/chodera/zhangi/perses_benchmark/neq/7/29/ala_thr_pos.npy"), "wb") as f:
    np.save(f, ala_thr_pos)
with open(os.path.join(f"/data/chodera/zhangi/perses_benchmark/neq/7/30/thr_ala_pos.npy"), "wb") as f:
    np.save(f, thr_ala_pos)
with open(os.path.join(f"/data/chodera/zhangi/perses_benchmark/neq/7/29/ala_thr_works.npy"), "wb") as f:
    np.save(f, ala_thr_works)
with open(os.path.join(f"/data/chodera/zhangi/perses_benchmark/neq/7/30/thr_ala_works.npy"), "wb") as f:
    np.save(f, thr_ala_works)
