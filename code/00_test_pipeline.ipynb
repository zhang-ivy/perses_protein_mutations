# %%
from __future__ import absolute_import

from perses.samplers import multistate
from perses.utils.openeye import *
from perses.annihilation.relative import HybridTopologyFactory
from perses.annihilation.lambda_protocol import LambdaProtocol
from perses.rjmc.topology_proposal import PointMutationEngine
from perses.rjmc.geometry import FFAllAngleGeometryEngine

import simtk.openmm as openmm
import simtk.openmm.app as app
import simtk.unit as unit
import numpy as np
from openmoltools import forcefield_generators
import copy
import mdtraj as md
from openmmtools.constants import kB
from pkg_resources import resource_filename
from perses.tests.utils import validate_endstate_energies

ENERGY_THRESHOLD = 1e-2
temperature = 300 * unit.kelvin
kT = kB * temperature
beta = 1.0/kT

# %%
from pkg_resources import resource_filename
from perses.app.relative_point_mutation_setup import PointMutationExecutor

# %% [markdown]
# # Sub class PointMutationExecutor for apo

# %%
class ApoPointMutationExecutor(PointMutationExecutor):
    def __init__(self,
                 receptor_filename,
                 mutation_chain_id,
                 mutation_residue_id,
                 proposed_residue, phase = 'complex',
                 conduct_endstate_validation = False,
                 forcefield_files = ['amber14/protein.ff14SB.xml', 'amber14/tip3p.xml'],
                 barostat = openmm.MonteCarloBarostat(1.0 * unit.atmosphere, temperature, 50),
                 forcefield_kwargs = {'removeCMMotion': False, 'ewaldErrorTolerance': 1e-4, 'nonbondedMethod': app.PME, 'constraints' : app.HBonds, 'hydrogenMass' : 4 * unit.amus},
                 **kwargs):
        """
        arguments
            receptor_filename : str
                path to receptor; .pdb
            mutation_chain_id : str
                name of the chain to be mutated
            mutation_residue_id : str
                residue id to change
            proposed_residue : str
                three letter code of the residue to mutate to
            phase : str, default complex
                if phase == vacuum, then the complex will not be solvated with water; else, it will be solvated with tip3p
            conduct_endstate_validation : bool, default True
                whether to conduct an endstate validation of the hybrid topology factory
            forcefield_files : list of str, default ['amber14/protein.ff14SB.xml', 'amber14/tip3p.xml']
                forcefield files for proteins and solvent
            barostat : openmm.MonteCarloBarostat, default openmm.MonteCarloBarostat(1.0 * unit.atmosphere, 300 * unit.kelvin, 50)
                barostat to use
            forcefield_kwargs : dict, default {'removeCMMotion': False, 'ewaldErrorTolerance': 1e-4, 'nonbondedMethod': app.NoCutoff, 'constraints' : app.HBonds, 'hydrogenMass' : 4 * unit.amus}
                forcefield kwargs for system parametrization
        TODO : allow argument for separate apo structure if it exists separately
               allow argument for specator ligands besides the 'ligand_filename'
        """
        from openforcefield.topology import Molecule
        from openmmforcefields.generators import SystemGenerator

        # First thing to do is make a complex and apo...
        pdbfile = open(receptor_filename, 'r')
        pdb = app.PDBFile(pdbfile)
        pdbfile.close()
        receptor_positions, receptor_topology, receptor_md_topology = pdb.positions, pdb.topology, md.Topology.from_openmm(pdb.topology)
        receptor_topology = receptor_md_topology.to_openmm()
        receptor_n_atoms = receptor_md_topology.n_atoms

        # Now for a system_generator
        self.system_generator = SystemGenerator(forcefields = forcefield_files,
                                                barostat=barostat,
                                                forcefield_kwargs=forcefield_kwargs,
                                                cache=None)

        # Create apo inputs...
        apo_topology, apo_positions, apo_system = self._solvate(receptor_topology, receptor_positions, 'tip3p', phase = phase)

        geometry_engine = FFAllAngleGeometryEngine(metadata=None,
                                                use_sterics=False,
                                                n_bond_divisions=100,
                                                n_angle_divisions=180,
                                                n_torsion_divisions=360,
                                                verbose=True,
                                                storage=None,
                                                bond_softening_constant=1.0,
                                                angle_softening_constant=1.0,
                                                neglect_angles = False,
                                                use_14_nonbondeds = True)


        # Run pipeline...
        point_mutation_engine = PointMutationEngine(wildtype_topology = apo_topology,
                                                             system_generator = self.system_generator,
                                                             chain_id = mutation_chain_id, #denote the chain id allowed to mutate (it's always a string variable)
                                                             max_point_mutants = 1,
                                                             residues_allowed_to_mutate = [mutation_residue_id], #the residue ids allowed to mutate
                                                             allowed_mutations = [(mutation_residue_id, proposed_residue)], #the residue ids allowed to mutate with the three-letter code allowed to change
                                                             aggregate = True) #always allow aggregation

        topology_proposal = point_mutation_engine.propose(apo_system, apo_topology)

        new_positions, logp_proposal = geometry_engine.propose(topology_proposal, apo_positions, beta)
        logp_reverse = geometry_engine.logp_reverse(topology_proposal, new_positions, apo_positions, beta)

        forward_htf = HybridTopologyFactory(topology_proposal = topology_proposal,
                                             current_positions =  apo_positions,
                                             new_positions = new_positions,
                                             use_dispersion_correction = False,
                                             functions=None,
                                             softcore_alpha = None,
                                             bond_softening_constant=1.0,
                                             angle_softening_constant=1.0,
                                             soften_only_new = False,
                                             neglected_new_angle_terms = [],
                                             neglected_old_angle_terms = [],
                                             softcore_LJ_v2 = True,
                                             softcore_electrostatics = True,
                                             softcore_LJ_v2_alpha = 0.85,
                                             softcore_electrostatics_alpha = 0.3,
                                             softcore_sigma_Q = 1.0,
                                             interpolate_old_and_new_14s = False,
                                             omitted_terms = None)

        if not topology_proposal.unique_new_atoms:
            assert geometry_engine.forward_final_context_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.forward_final_context_reduced_potential})"
            assert geometry_engine.forward_atoms_with_positions_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's forward atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.forward_atoms_with_positions_reduced_potential})"
            vacuum_added_valence_energy = 0.0
        else:
            added_valence_energy = geometry_engine.forward_final_context_reduced_potential - geometry_engine.forward_atoms_with_positions_reduced_potential

        if not topology_proposal.unique_old_atoms:
            assert geometry_engine.reverse_final_context_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.reverse_final_context_reduced_potential})"
            assert geometry_engine.reverse_atoms_with_positions_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.reverse_atoms_with_positions_reduced_potential})"
            subtracted_valence_energy = 0.0
        else:
            subtracted_valence_energy = geometry_engine.reverse_final_context_reduced_potential - geometry_engine.reverse_atoms_with_positions_reduced_potential


        if conduct_endstate_validation:
            zero_state_error, one_state_error = validate_endstate_energies(forward_htf._topology_proposal, forward_htf, added_valence_energy, subtracted_valence_energy, beta = beta, ENERGY_THRESHOLD = ENERGY_THRESHOLD)
        else:
            pass

        self.apo_htf = forward_htf

# %%
apm_delivery = ApoPointMutationExecutor('../input/ala_vacuum.pdb', 
                         '1', 
                         '2', 
                         'VAL',
                        )
apo_htf = apm_delivery.get_apo_htf()
# Out:
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:[4, 4, 4, 4, 4, 4]
# WARNING:proposal_generator:	rank_degenerate_maps: 'NoneType' object has no attribute 'IsAromatic'
# INFO:proposal_generator:Maximum atom matched after hydrogen exceptions: 2
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 8
# INFO:geometry:Atom index proposal order is [18, 14, 16, 19, 21, 20, 17, 15]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 11 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 48 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 72 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 2096 in the reference Nonbonded force
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -16.061296701914923
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context new positions
# INFO:geometry:There are 8 new atoms
# INFO:geometry:	reduced angle potential = 0.509035099709229.
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:	reduced angle potential = 0.08293842667589812.
# INFO:geometry:	reduced angle potential = 0.6194253769438156.
# INFO:geometry:	reduced angle potential = 0.030346637540318577.
# INFO:geometry:	reduced angle potential = 1.068531219068106.
# INFO:geometry:	reduced angle potential = 1.8926670905584193.
# INFO:geometry:	reduced angle potential = 0.0008237038458572306.
# INFO:geometry:	reduced angle potential = 0.16255297674230146.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce', 'MonteCarloBarostat']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 11 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 48 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 72 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 16.820920233259045
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# added energy components: [('CustomBondForce', 1.2554869050155106), ('CustomAngleForce', 17.76802239126454), ('CustomTorsionForce', 5.55867409916658), ('CustomBondForce', -55.82269544869614)]
# INFO:geometry:total reduced energy added from growth system: -31.240512053249514
# INFO:geometry:final reduced energy -14.419589764007295
# INFO:geometry:sum of energies: -14.419591819990469
# INFO:geometry:magnitude of difference in the energies: 2.0559831739319634e-06
# INFO:geometry:Final logp_proposal: 37.69393956952278
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 2
# INFO:geometry:Atom index proposal order is [15, 11]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 2060 in the reference Nonbonded force
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -2.8903717578961645
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context old positions
# INFO:geometry:There are 2 new atoms
# INFO:geometry:	reduced angle potential = 1.1491328110690509.
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:	reduced angle potential = 8.578546222633222e-06.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce', 'MonteCarloBarostat']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 16.82092023325904
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# added energy components: [('CustomBondForce', 0.0), ('CustomAngleForce', 1.5196339774707472), ('CustomTorsionForce', 0.0036836193671578284), ('CustomBondForce', 7.60944778229808)]
# INFO:geometry:total reduced energy added from growth system: 9.132765379135986
# INFO:geometry:final reduced energy 25.953685947680075
# INFO:geometry:sum of energies: 25.953685612395027
# INFO:geometry:magnitude of difference in the energies: 3.3528504772561973e-07
# INFO:geometry:Final logp_proposal: 10.491261016710139
# INFO:relative:Beginning nonbonded method, total particle, barostat, and exceptions retrieval...
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce', 'MonteCarloBarostat'])
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce', 'MonteCarloBarostat'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 4
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:Added MonteCarloBarostat.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.7648, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.7648, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.7648), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:Adding bond force terms...
# INFO:relative:Adding angle force terms...
# INFO:relative:Adding torsion force terms...
# INFO:relative:Adding nonbonded force terms...
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2ba6bd9dbde0> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is PME or Ewald
# INFO:relative:	_add_nonbonded_force_terms: 4 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 2 added to sterics_custom_nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.CustomNonbondedForce; proxy of <Swig Object of type 'OpenMM::CustomNonbondedForce *' at 0x2ba6bd9dbd80> > added to hybrid system
# INFO:relative:Handling harmonic bonds...
# INFO:relative:	handle_harmonic_bonds: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_bonds: looping through new_system to add relevant terms...
# INFO:relative:Handling harmonic angles...
# INFO:relative:	handle_harmonic_angles: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_angles: looping through new_system to add relevant terms...
# INFO:relative:Handling torsion forces...
# INFO:relative:	handle_periodic_torsion_forces: looping through old_system to add relevant terms...
# INFO:relative:	handle_periodic_torsion_forces: looping through new_system to add relevant terms...
# INFO:relative:Handling nonbonded forces...
# INFO:relative:	handle_nonbonded: looping through all particles in hybrid...
# INFO:relative:	handle_nonbonded: Handling Interaction Groups...
# INFO:relative:	handle_nonbonded: Handling Hybrid Exceptions...
# INFO:relative:	handle_nonbonded: Handling Original Exceptions...
# INFO:relative:Handling unique_new/old interaction exceptions...
# INFO:relative:There are old or new system exceptions...proceeding.

# %%
# Now we can build the hybrid repex samplers
from perses.annihilation.lambda_protocol import LambdaProtocol
from openmmtools.multistate import MultiStateReporter
from perses.samplers.multistate import HybridRepexSampler
from openmmtools import mcmc

suffix = 'run'; selection = 'not water'; checkpoint_interval = 10; n_states = 11; n_cycles = 5000


lambda_protocol = LambdaProtocol(functions='default')
reporter_file = 'reporter.nc'
reporter = MultiStateReporter(reporter_file, analysis_particle_indices = apo_htf.hybrid_topology.select(selection), checkpoint_interval = checkpoint_interval)
hss = HybridRepexSampler(mcmc_moves=mcmc.LangevinSplittingDynamicsMove(timestep= 4.0 * unit.femtoseconds,
                                                                      collision_rate=5.0 / unit.picosecond,
                                                                      n_steps=250,
                                                                      reassign_velocities=False,
                                                                      n_restart_attempts=20,
                                                                      splitting="V R R R O R R R V",
                                                                      constraint_tolerance=1e-06),
                                                                      hybrid_factory=apo_htf, online_analysis_interval=10)
hss.setup(n_states=n_states, temperature=300*unit.kelvin, storage_file = reporter, lambda_protocol = lambda_protocol, endstates=False)
hss.extend(n_cycles)
# Out:
# /home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/openmmtools/multistate/multistatereporter.py:116: UserWarning: Warning: The openmmtools.multistate API is experimental and may change in future releases
#   warnings.warn('Warning: The openmmtools.multistate API is experimental and may change in future releases')
# /home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/openmmtools/multistate/multistatesampler.py:145: UserWarning: Warning: The openmmtools.multistate API is experimental and may change in future releases
#   warnings.warn('Warning: The openmmtools.multistate API is experimental and may change in future releases')
# INFO:multistate:n_replicas not defined, setting to match n_states, 11
# Please cite the following:
#
#         Friedrichs MS, Eastman P, Vaidyanathan V, Houston M, LeGrand S, Beberg AL, Ensign DL, Bruns CM, and Pande VS. Accelerating molecular dynamic simulations on graphics processing unit. J. Comput. Chem. 30:864, 2009. DOI: 10.1002/jcc.21209
#         Eastman P and Pande VS. OpenMM: A hardware-independent framework for molecular simulations. Comput. Sci. Eng. 12:34, 2010. DOI: 10.1109/MCSE.2010.27
#         Eastman P and Pande VS. Efficient nonbonded interactions for molecular dynamics on a graphics processing unit. J. Comput. Chem. 31:1268, 2010. DOI: 10.1002/jcc.21413
#         Eastman P and Pande VS. Constant constraint matrix approximation: A robust, parallelizable constraint method for molecular simulations. J. Chem. Theor. Comput. 6:434, 2010. DOI: 10.1021/ct900463w
#         Chodera JD and Shirts MR. Replica exchange and expanded ensemble simulations as Gibbs multistate: Simple improvements for enhanced mixing. J. Chem. Phys., 135:194110, 2011. DOI:10.1063/1.3660669

# %% [markdown]
# # Test revised PointMutationExecutor

# %% [markdown]
# ### Solvent

# %%
from pkg_resources import resource_filename
from perses.app.relative_point_mutation_setup import PointMutationExecutor
# Out:
# INFO:numexpr.utils:Note: detected 72 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# INFO:numexpr.utils:Note: NumExpr detected 72 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=6)
#            2	LOAD_GLOBAL(arg=0, lineno=6)
#            4	LOAD_METHOD(arg=1, lineno=6)
#            6	LOAD_CONST(arg=1, lineno=6)
#            8	CALL_METHOD(arg=1, lineno=6)
#           10	STORE_FAST(arg=2, lineno=6)
#           12	LOAD_FAST(arg=0, lineno=7)
#           14	LOAD_CONST(arg=2, lineno=7)
#           16	BINARY_SUBSCR(arg=None, lineno=7)
#           18	LOAD_FAST(arg=1, lineno=7)
#           20	LOAD_CONST(arg=3, lineno=7)
#           22	BINARY_SUBSCR(arg=None, lineno=7)
#           24	BINARY_MULTIPLY(arg=None, lineno=7)
#           26	LOAD_FAST(arg=0, lineno=7)
#           28	LOAD_CONST(arg=3, lineno=7)
#           30	BINARY_SUBSCR(arg=None, lineno=7)
#           32	LOAD_FAST(arg=1, lineno=7)
#           34	LOAD_CONST(arg=2, lineno=7)
#           36	BINARY_SUBSCR(arg=None, lineno=7)
#           38	BINARY_MULTIPLY(arg=None, lineno=7)
#           40	BINARY_SUBTRACT(arg=None, lineno=7)
#           42	LOAD_FAST(arg=2, lineno=7)
#           44	LOAD_CONST(arg=4, lineno=7)
#           46	STORE_SUBSCR(arg=None, lineno=7)
#           48	LOAD_FAST(arg=0, lineno=8)
#           50	LOAD_CONST(arg=3, lineno=8)
#           52	BINARY_SUBSCR(arg=None, lineno=8)
#           54	LOAD_FAST(arg=1, lineno=8)
#           56	LOAD_CONST(arg=4, lineno=8)
#           58	BINARY_SUBSCR(arg=None, lineno=8)
#           60	BINARY_MULTIPLY(arg=None, lineno=8)
#           62	LOAD_FAST(arg=0, lineno=8)
#           64	LOAD_CONST(arg=4, lineno=8)
#           66	BINARY_SUBSCR(arg=None, lineno=8)
#           68	LOAD_FAST(arg=1, lineno=8)
#           70	LOAD_CONST(arg=3, lineno=8)
#           72	BINARY_SUBSCR(arg=None, lineno=8)
#           74	BINARY_MULTIPLY(arg=None, lineno=8)
#           76	BINARY_SUBTRACT(arg=None, lineno=8)
#           78	LOAD_FAST(arg=2, lineno=8)
#           80	LOAD_CONST(arg=2, lineno=8)
#           82	STORE_SUBSCR(arg=None, lineno=8)
#           84	LOAD_FAST(arg=0, lineno=9)
#           86	LOAD_CONST(arg=4, lineno=9)
#           88	BINARY_SUBSCR(arg=None, lineno=9)
#           90	LOAD_FAST(arg=1, lineno=9)
#           92	LOAD_CONST(arg=2, lineno=9)
#           94	BINARY_SUBSCR(arg=None, lineno=9)
#           96	BINARY_MULTIPLY(arg=None, lineno=9)
#           98	LOAD_FAST(arg=0, lineno=9)
#          100	LOAD_CONST(arg=2, lineno=9)
#          102	BINARY_SUBSCR(arg=None, lineno=9)
#          104	LOAD_FAST(arg=1, lineno=9)
#          106	LOAD_CONST(arg=4, lineno=9)
#          108	BINARY_SUBSCR(arg=None, lineno=9)
#          110	BINARY_MULTIPLY(arg=None, lineno=9)
#          112	BINARY_SUBTRACT(arg=None, lineno=9)
#          114	LOAD_FAST(arg=2, lineno=9)
#          116	LOAD_CONST(arg=3, lineno=9)
#          118	STORE_SUBSCR(arg=None, lineno=9)
#          120	LOAD_FAST(arg=2, lineno=10)
#          122	RETURN_VALUE(arg=None, lineno=10)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=6)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_GLOBAL(arg=0, lineno=6)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_METHOD(arg=1, lineno=6)
# DEBUG:numba.core.byteflow:stack ['$2load_global.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=LOAD_CONST(arg=1, lineno=6)
# DEBUG:numba.core.byteflow:stack ['$4load_method.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=CALL_METHOD(arg=1, lineno=6)
# DEBUG:numba.core.byteflow:stack ['$4load_method.1', '$const6.2']
# DEBUG:numba.core.byteflow:dispatch pc=10, inst=STORE_FAST(arg=2, lineno=6)
# DEBUG:numba.core.byteflow:stack ['$8call_method.3']
# DEBUG:numba.core.byteflow:dispatch pc=12, inst=LOAD_FAST(arg=0, lineno=7)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=14, inst=LOAD_CONST(arg=2, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$a12.4']
# DEBUG:numba.core.byteflow:dispatch pc=16, inst=BINARY_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$a12.4', '$const14.5']
# DEBUG:numba.core.byteflow:dispatch pc=18, inst=LOAD_FAST(arg=1, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$16binary_subscr.6']
# DEBUG:numba.core.byteflow:dispatch pc=20, inst=LOAD_CONST(arg=3, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$16binary_subscr.6', '$b18.7']
# DEBUG:numba.core.byteflow:dispatch pc=22, inst=BINARY_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$16binary_subscr.6', '$b18.7', '$const20.8']
# DEBUG:numba.core.byteflow:dispatch pc=24, inst=BINARY_MULTIPLY(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$16binary_subscr.6', '$22binary_subscr.9']
# DEBUG:numba.core.byteflow:dispatch pc=26, inst=LOAD_FAST(arg=0, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10']
# DEBUG:numba.core.byteflow:dispatch pc=28, inst=LOAD_CONST(arg=3, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$a26.11']
# DEBUG:numba.core.byteflow:dispatch pc=30, inst=BINARY_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$a26.11', '$const28.12']
# DEBUG:numba.core.byteflow:dispatch pc=32, inst=LOAD_FAST(arg=1, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$30binary_subscr.13']
# DEBUG:numba.core.byteflow:dispatch pc=34, inst=LOAD_CONST(arg=2, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$30binary_subscr.13', '$b32.14']
# DEBUG:numba.core.byteflow:dispatch pc=36, inst=BINARY_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$30binary_subscr.13', '$b32.14', '$const34.15']
# DEBUG:numba.core.byteflow:dispatch pc=38, inst=BINARY_MULTIPLY(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$30binary_subscr.13', '$36binary_subscr.16']
# DEBUG:numba.core.byteflow:dispatch pc=40, inst=BINARY_SUBTRACT(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$38binary_multiply.17']
# DEBUG:numba.core.byteflow:dispatch pc=42, inst=LOAD_FAST(arg=2, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$40binary_subtract.18']
# DEBUG:numba.core.byteflow:dispatch pc=44, inst=LOAD_CONST(arg=4, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$40binary_subtract.18', '$c42.19']
# DEBUG:numba.core.byteflow:dispatch pc=46, inst=STORE_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$40binary_subtract.18', '$c42.19', '$const44.20']
# DEBUG:numba.core.byteflow:dispatch pc=48, inst=LOAD_FAST(arg=0, lineno=8)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=50, inst=LOAD_CONST(arg=3, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$a48.21']
# DEBUG:numba.core.byteflow:dispatch pc=52, inst=BINARY_SUBSCR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$a48.21', '$const50.22']
# DEBUG:numba.core.byteflow:dispatch pc=54, inst=LOAD_FAST(arg=1, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$52binary_subscr.23']
# DEBUG:numba.core.byteflow:dispatch pc=56, inst=LOAD_CONST(arg=4, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$52binary_subscr.23', '$b54.24']
# DEBUG:numba.core.byteflow:dispatch pc=58, inst=BINARY_SUBSCR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$52binary_subscr.23', '$b54.24', '$const56.25']
# DEBUG:numba.core.byteflow:dispatch pc=60, inst=BINARY_MULTIPLY(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$52binary_subscr.23', '$58binary_subscr.26']
# DEBUG:numba.core.byteflow:dispatch pc=62, inst=LOAD_FAST(arg=0, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27']
# DEBUG:numba.core.byteflow:dispatch pc=64, inst=LOAD_CONST(arg=4, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$a62.28']
# DEBUG:numba.core.byteflow:dispatch pc=66, inst=BINARY_SUBSCR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$a62.28', '$const64.29']
# DEBUG:numba.core.byteflow:dispatch pc=68, inst=LOAD_FAST(arg=1, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$66binary_subscr.30']
# DEBUG:numba.core.byteflow:dispatch pc=70, inst=LOAD_CONST(arg=3, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$66binary_subscr.30', '$b68.31']
# DEBUG:numba.core.byteflow:dispatch pc=72, inst=BINARY_SUBSCR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$66binary_subscr.30', '$b68.31', '$const70.32']
# DEBUG:numba.core.byteflow:dispatch pc=74, inst=BINARY_MULTIPLY(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$66binary_subscr.30', '$72binary_subscr.33']
# DEBUG:numba.core.byteflow:dispatch pc=76, inst=BINARY_SUBTRACT(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$74binary_multiply.34']
# DEBUG:numba.core.byteflow:dispatch pc=78, inst=LOAD_FAST(arg=2, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$76binary_subtract.35']
# DEBUG:numba.core.byteflow:dispatch pc=80, inst=LOAD_CONST(arg=2, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$76binary_subtract.35', '$c78.36']
# DEBUG:numba.core.byteflow:dispatch pc=82, inst=STORE_SUBSCR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$76binary_subtract.35', '$c78.36', '$const80.37']
# DEBUG:numba.core.byteflow:dispatch pc=84, inst=LOAD_FAST(arg=0, lineno=9)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=86, inst=LOAD_CONST(arg=4, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$a84.38']
# DEBUG:numba.core.byteflow:dispatch pc=88, inst=BINARY_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$a84.38', '$const86.39']
# DEBUG:numba.core.byteflow:dispatch pc=90, inst=LOAD_FAST(arg=1, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$88binary_subscr.40']
# DEBUG:numba.core.byteflow:dispatch pc=92, inst=LOAD_CONST(arg=2, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$88binary_subscr.40', '$b90.41']
# DEBUG:numba.core.byteflow:dispatch pc=94, inst=BINARY_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$88binary_subscr.40', '$b90.41', '$const92.42']
# DEBUG:numba.core.byteflow:dispatch pc=96, inst=BINARY_MULTIPLY(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$88binary_subscr.40', '$94binary_subscr.43']
# DEBUG:numba.core.byteflow:dispatch pc=98, inst=LOAD_FAST(arg=0, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44']
# DEBUG:numba.core.byteflow:dispatch pc=100, inst=LOAD_CONST(arg=2, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$a98.45']
# DEBUG:numba.core.byteflow:dispatch pc=102, inst=BINARY_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$a98.45', '$const100.46']
# DEBUG:numba.core.byteflow:dispatch pc=104, inst=LOAD_FAST(arg=1, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$102binary_subscr.47']
# DEBUG:numba.core.byteflow:dispatch pc=106, inst=LOAD_CONST(arg=4, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$102binary_subscr.47', '$b104.48']
# DEBUG:numba.core.byteflow:dispatch pc=108, inst=BINARY_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$102binary_subscr.47', '$b104.48', '$const106.49']
# DEBUG:numba.core.byteflow:dispatch pc=110, inst=BINARY_MULTIPLY(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$102binary_subscr.47', '$108binary_subscr.50']
# DEBUG:numba.core.byteflow:dispatch pc=112, inst=BINARY_SUBTRACT(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$110binary_multiply.51']
# DEBUG:numba.core.byteflow:dispatch pc=114, inst=LOAD_FAST(arg=2, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$112binary_subtract.52']
# DEBUG:numba.core.byteflow:dispatch pc=116, inst=LOAD_CONST(arg=3, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$112binary_subtract.52', '$c114.53']
# DEBUG:numba.core.byteflow:dispatch pc=118, inst=STORE_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$112binary_subtract.52', '$c114.53', '$const116.54']
# DEBUG:numba.core.byteflow:dispatch pc=120, inst=LOAD_FAST(arg=2, lineno=10)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=122, inst=RETURN_VALUE(arg=None, lineno=10)
# DEBUG:numba.core.byteflow:stack ['$c120.55']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$2load_global.0'}), (4, {'item': '$2load_global.0', 'res': '$4load_method.1'}), (6, {'res': '$const6.2'}), (8, {'func': '$4load_method.1', 'args': ['$const6.2'], 'res': '$8call_method.3'}), (10, {'value': '$8call_method.3'}), (12, {'res': '$a12.4'}), (14, {'res': '$const14.5'}), (16, {'index': '$const14.5', 'target': '$a12.4', 'res': '$16binary_subscr.6'}), (18, {'res': '$b18.7'}), (20, {'res': '$const20.8'}), (22, {'index': '$const20.8', 'target': '$b18.7', 'res': '$22binary_subscr.9'}), (24, {'lhs': '$16binary_subscr.6', 'rhs': '$22binary_subscr.9', 'res': '$24binary_multiply.10'}), (26, {'res': '$a26.11'}), (28, {'res': '$const28.12'}), (30, {'index': '$const28.12', 'target': '$a26.11', 'res': '$30binary_subscr.13'}), (32, {'res': '$b32.14'}), (34, {'res': '$const34.15'}), (36, {'index': '$const34.15', 'target': '$b32.14', 'res': '$36binary_subscr.16'}), (38, {'lhs': '$30binary_subscr.13', 'rhs': '$36binary_subscr.16', 'res': '$38binary_multiply.17'}), (40, {'lhs': '$24binary_multiply.10', 'rhs': '$38binary_multiply.17', 'res': '$40binary_subtract.18'}), (42, {'res': '$c42.19'}), (44, {'res': '$const44.20'}), (46, {'target': '$c42.19', 'index': '$const44.20', 'value': '$40binary_subtract.18'}), (48, {'res': '$a48.21'}), (50, {'res': '$const50.22'}), (52, {'index': '$const50.22', 'target': '$a48.21', 'res': '$52binary_subscr.23'}), (54, {'res': '$b54.24'}), (56, {'res': '$const56.25'}), (58, {'index': '$const56.25', 'target': '$b54.24', 'res': '$58binary_subscr.26'}), (60, {'lhs': '$52binary_subscr.23', 'rhs': '$58binary_subscr.26', 'res': '$60binary_multiply.27'}), (62, {'res': '$a62.28'}), (64, {'res': '$const64.29'}), (66, {'index': '$const64.29', 'target': '$a62.28', 'res': '$66binary_subscr.30'}), (68, {'res': '$b68.31'}), (70, {'res': '$const70.32'}), (72, {'index': '$const70.32', 'target': '$b68.31', 'res': '$72binary_subscr.33'}), (74, {'lhs': '$66binary_subscr.30', 'rhs': '$72binary_subscr.33', 'res': '$74binary_multiply.34'}), (76, {'lhs': '$60binary_multiply.27', 'rhs': '$74binary_multiply.34', 'res': '$76binary_subtract.35'}), (78, {'res': '$c78.36'}), (80, {'res': '$const80.37'}), (82, {'target': '$c78.36', 'index': '$const80.37', 'value': '$76binary_subtract.35'}), (84, {'res': '$a84.38'}), (86, {'res': '$const86.39'}), (88, {'index': '$const86.39', 'target': '$a84.38', 'res': '$88binary_subscr.40'}), (90, {'res': '$b90.41'}), (92, {'res': '$const92.42'}), (94, {'index': '$const92.42', 'target': '$b90.41', 'res': '$94binary_subscr.43'}), (96, {'lhs': '$88binary_subscr.40', 'rhs': '$94binary_subscr.43', 'res': '$96binary_multiply.44'}), (98, {'res': '$a98.45'}), (100, {'res': '$const100.46'}), (102, {'index': '$const100.46', 'target': '$a98.45', 'res': '$102binary_subscr.47'}), (104, {'res': '$b104.48'}), (106, {'res': '$const106.49'}), (108, {'index': '$const106.49', 'target': '$b104.48', 'res': '$108binary_subscr.50'}), (110, {'lhs': '$102binary_subscr.47', 'rhs': '$108binary_subscr.50', 'res': '$110binary_multiply.51'}), (112, {'lhs': '$96binary_multiply.44', 'rhs': '$110binary_multiply.51', 'res': '$112binary_subtract.52'}), (114, {'res': '$c114.53'}), (116, {'res': '$const116.54'}), (118, {'target': '$c114.53', 'index': '$const116.54', 'value': '$112binary_subtract.52'}), (120, {'res': '$c120.55'}), (122, {'retval': '$c120.55', 'castval': '$122return_value.56'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     a = arg(0, name=a)                       ['a']
#     b = arg(1, name=b)                       ['b']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=zeros) ['$2load_global.0', '$4load_method.1']
#     $const6.2 = const(int, 3)                ['$const6.2']
#     $8call_method.3 = call $4load_method.1($const6.2, func=$4load_method.1, args=[Var($const6.2, coordinate_numba.py:6)], kws=(), vararg=None) ['$4load_method.1', '$8call_method.3', '$const6.2']
#     c = $8call_method.3                      ['$8call_method.3', 'c']
#     $const14.5 = const(int, 1)               ['$const14.5']
#     $16binary_subscr.6 = getitem(value=a, index=$const14.5) ['$16binary_subscr.6', '$const14.5', 'a']
#     $const20.8 = const(int, 2)               ['$const20.8']
#     $22binary_subscr.9 = getitem(value=b, index=$const20.8) ['$22binary_subscr.9', '$const20.8', 'b']
#     $24binary_multiply.10 = $16binary_subscr.6 * $22binary_subscr.9 ['$16binary_subscr.6', '$22binary_subscr.9', '$24binary_multiply.10']
#     $const28.12 = const(int, 2)              ['$const28.12']
#     $30binary_subscr.13 = getitem(value=a, index=$const28.12) ['$30binary_subscr.13', '$const28.12', 'a']
#     $const34.15 = const(int, 1)              ['$const34.15']
#     $36binary_subscr.16 = getitem(value=b, index=$const34.15) ['$36binary_subscr.16', '$const34.15', 'b']
#     $38binary_multiply.17 = $30binary_subscr.13 * $36binary_subscr.16 ['$30binary_subscr.13', '$36binary_subscr.16', '$38binary_multiply.17']
#     $40binary_subtract.18 = $24binary_multiply.10 - $38binary_multiply.17 ['$24binary_multiply.10', '$38binary_multiply.17', '$40binary_subtract.18']
#     $const44.20 = const(int, 0)              ['$const44.20']
#     c[$const44.20] = $40binary_subtract.18   ['$40binary_subtract.18', '$const44.20', 'c']
#     $const50.22 = const(int, 2)              ['$const50.22']
#     $52binary_subscr.23 = getitem(value=a, index=$const50.22) ['$52binary_subscr.23', '$const50.22', 'a']
#     $const56.25 = const(int, 0)              ['$const56.25']
#     $58binary_subscr.26 = getitem(value=b, index=$const56.25) ['$58binary_subscr.26', '$const56.25', 'b']
#     $60binary_multiply.27 = $52binary_subscr.23 * $58binary_subscr.26 ['$52binary_subscr.23', '$58binary_subscr.26', '$60binary_multiply.27']
#     $const64.29 = const(int, 0)              ['$const64.29']
#     $66binary_subscr.30 = getitem(value=a, index=$const64.29) ['$66binary_subscr.30', '$const64.29', 'a']
#     $const70.32 = const(int, 2)              ['$const70.32']
#     $72binary_subscr.33 = getitem(value=b, index=$const70.32) ['$72binary_subscr.33', '$const70.32', 'b']
#     $74binary_multiply.34 = $66binary_subscr.30 * $72binary_subscr.33 ['$66binary_subscr.30', '$72binary_subscr.33', '$74binary_multiply.34']
#     $76binary_subtract.35 = $60binary_multiply.27 - $74binary_multiply.34 ['$60binary_multiply.27', '$74binary_multiply.34', '$76binary_subtract.35']
#     $const80.37 = const(int, 1)              ['$const80.37']
#     c[$const80.37] = $76binary_subtract.35   ['$76binary_subtract.35', '$const80.37', 'c']
#     $const86.39 = const(int, 0)              ['$const86.39']
#     $88binary_subscr.40 = getitem(value=a, index=$const86.39) ['$88binary_subscr.40', '$const86.39', 'a']
#     $const92.42 = const(int, 1)              ['$const92.42']
#     $94binary_subscr.43 = getitem(value=b, index=$const92.42) ['$94binary_subscr.43', '$const92.42', 'b']
#     $96binary_multiply.44 = $88binary_subscr.40 * $94binary_subscr.43 ['$88binary_subscr.40', '$94binary_subscr.43', '$96binary_multiply.44']
#     $const100.46 = const(int, 1)             ['$const100.46']
#     $102binary_subscr.47 = getitem(value=a, index=$const100.46) ['$102binary_subscr.47', '$const100.46', 'a']
#     $const106.49 = const(int, 0)             ['$const106.49']
#     $108binary_subscr.50 = getitem(value=b, index=$const106.49) ['$108binary_subscr.50', '$const106.49', 'b']
#     $110binary_multiply.51 = $102binary_subscr.47 * $108binary_subscr.50 ['$102binary_subscr.47', '$108binary_subscr.50', '$110binary_multiply.51']
#     $112binary_subtract.52 = $96binary_multiply.44 - $110binary_multiply.51 ['$110binary_multiply.51', '$112binary_subtract.52', '$96binary_multiply.44']
#     $const116.54 = const(int, 2)             ['$const116.54']
#     c[$const116.54] = $112binary_subtract.52 ['$112binary_subtract.52', '$const116.54', 'c']
#     $122return_value.56 = cast(value=c)      ['$122return_value.56', 'c']
#     return $122return_value.56               ['$122return_value.56']
#
# DEBUG:numba.core.ssa:-----------------------------------BEFORE SSA-----------------------------------
# DEBUG:numba.core.ssa:label 0:
#     a = arg(0, name=a)                       ['a']
#     b = arg(1, name=b)                       ['b']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=zeros) ['$2load_global.0', '$4load_method.1']
#     $const6.2 = const(int, 3)                ['$const6.2']
#     $8call_method.3 = call $4load_method.1($const6.2, func=$4load_method.1, args=[Var($const6.2, coordinate_numba.py:6)], kws=(), vararg=None) ['$4load_method.1', '$8call_method.3', '$const6.2']
#     c = $8call_method.3                      ['$8call_method.3', 'c']
#     $const14.5 = const(int, 1)               ['$const14.5']
#     $16binary_subscr.6 = static_getitem(value=a, index=1, index_var=$const14.5) ['$16binary_subscr.6', '$const14.5', 'a']
#     $const20.8 = const(int, 2)               ['$const20.8']
#     $22binary_subscr.9 = static_getitem(value=b, index=2, index_var=$const20.8) ['$22binary_subscr.9', '$const20.8', 'b']
#     $24binary_multiply.10 = $16binary_subscr.6 * $22binary_subscr.9 ['$16binary_subscr.6', '$22binary_subscr.9', '$24binary_multiply.10']
#     $const28.12 = const(int, 2)              ['$const28.12']
#     $30binary_subscr.13 = static_getitem(value=a, index=2, index_var=$const28.12) ['$30binary_subscr.13', '$const28.12', 'a']
#     $const34.15 = const(int, 1)              ['$const34.15']
#     $36binary_subscr.16 = static_getitem(value=b, index=1, index_var=$const34.15) ['$36binary_subscr.16', '$const34.15', 'b']
#     $38binary_multiply.17 = $30binary_subscr.13 * $36binary_subscr.16 ['$30binary_subscr.13', '$36binary_subscr.16', '$38binary_multiply.17']
#     $40binary_subtract.18 = $24binary_multiply.10 - $38binary_multiply.17 ['$24binary_multiply.10', '$38binary_multiply.17', '$40binary_subtract.18']
#     $const44.20 = const(int, 0)              ['$const44.20']
#     c[0] = $40binary_subtract.18             ['$40binary_subtract.18', '$const44.20', 'c']
#     $const50.22 = const(int, 2)              ['$const50.22']
#     $52binary_subscr.23 = static_getitem(value=a, index=2, index_var=$const50.22) ['$52binary_subscr.23', '$const50.22', 'a']
#     $const56.25 = const(int, 0)              ['$const56.25']
#     $58binary_subscr.26 = static_getitem(value=b, index=0, index_var=$const56.25) ['$58binary_subscr.26', '$const56.25', 'b']
#     $60binary_multiply.27 = $52binary_subscr.23 * $58binary_subscr.26 ['$52binary_subscr.23', '$58binary_subscr.26', '$60binary_multiply.27']
#     $const64.29 = const(int, 0)              ['$const64.29']
#     $66binary_subscr.30 = static_getitem(value=a, index=0, index_var=$const64.29) ['$66binary_subscr.30', '$const64.29', 'a']
#     $const70.32 = const(int, 2)              ['$const70.32']
#     $72binary_subscr.33 = static_getitem(value=b, index=2, index_var=$const70.32) ['$72binary_subscr.33', '$const70.32', 'b']
#     $74binary_multiply.34 = $66binary_subscr.30 * $72binary_subscr.33 ['$66binary_subscr.30', '$72binary_subscr.33', '$74binary_multiply.34']
#     $76binary_subtract.35 = $60binary_multiply.27 - $74binary_multiply.34 ['$60binary_multiply.27', '$74binary_multiply.34', '$76binary_subtract.35']
#     $const80.37 = const(int, 1)              ['$const80.37']
#     c[1] = $76binary_subtract.35             ['$76binary_subtract.35', '$const80.37', 'c']
#     $const86.39 = const(int, 0)              ['$const86.39']
#     $88binary_subscr.40 = static_getitem(value=a, index=0, index_var=$const86.39) ['$88binary_subscr.40', '$const86.39', 'a']
#     $const92.42 = const(int, 1)              ['$const92.42']
#     $94binary_subscr.43 = static_getitem(value=b, index=1, index_var=$const92.42) ['$94binary_subscr.43', '$const92.42', 'b']
#     $96binary_multiply.44 = $88binary_subscr.40 * $94binary_subscr.43 ['$88binary_subscr.40', '$94binary_subscr.43', '$96binary_multiply.44']
#     $const100.46 = const(int, 1)             ['$const100.46']
#     $102binary_subscr.47 = static_getitem(value=a, index=1, index_var=$const100.46) ['$102binary_subscr.47', '$const100.46', 'a']
#     $const106.49 = const(int, 0)             ['$const106.49']
#     $108binary_subscr.50 = static_getitem(value=b, index=0, index_var=$const106.49) ['$108binary_subscr.50', '$const106.49', 'b']
#     $110binary_multiply.51 = $102binary_subscr.47 * $108binary_subscr.50 ['$102binary_subscr.47', '$108binary_subscr.50', '$110binary_multiply.51']
#     $112binary_subtract.52 = $96binary_multiply.44 - $110binary_multiply.51 ['$110binary_multiply.51', '$112binary_subtract.52', '$96binary_multiply.44']
#     $const116.54 = const(int, 2)             ['$const116.54']
#     c[2] = $112binary_subtract.52            ['$112binary_subtract.52', '$const116.54', 'c']
#     $122return_value.56 = cast(value=c)      ['$122return_value.56', 'c']
#     return $122return_value.56               ['$122return_value.56']
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b4cfdcb7518>
# DEBUG:numba.core.ssa:on stmt: a = arg(0, name=a)
# DEBUG:numba.core.ssa:on stmt: b = arg(1, name=b)
# DEBUG:numba.core.ssa:on stmt: $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $4load_method.1 = getattr(value=$2load_global.0, attr=zeros)
# DEBUG:numba.core.ssa:on stmt: $const6.2 = const(int, 3)
# DEBUG:numba.core.ssa:on stmt: $8call_method.3 = call $4load_method.1($const6.2, func=$4load_method.1, args=[Var($const6.2, coordinate_numba.py:6)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: c = $8call_method.3
# DEBUG:numba.core.ssa:on stmt: $const14.5 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $16binary_subscr.6 = static_getitem(value=a, index=1, index_var=$const14.5)
# DEBUG:numba.core.ssa:on stmt: $const20.8 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $22binary_subscr.9 = static_getitem(value=b, index=2, index_var=$const20.8)
# DEBUG:numba.core.ssa:on stmt: $24binary_multiply.10 = $16binary_subscr.6 * $22binary_subscr.9
# DEBUG:numba.core.ssa:on stmt: $const28.12 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $30binary_subscr.13 = static_getitem(value=a, index=2, index_var=$const28.12)
# DEBUG:numba.core.ssa:on stmt: $const34.15 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $36binary_subscr.16 = static_getitem(value=b, index=1, index_var=$const34.15)
# DEBUG:numba.core.ssa:on stmt: $38binary_multiply.17 = $30binary_subscr.13 * $36binary_subscr.16
# DEBUG:numba.core.ssa:on stmt: $40binary_subtract.18 = $24binary_multiply.10 - $38binary_multiply.17
# DEBUG:numba.core.ssa:on stmt: $const44.20 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: c[0] = $40binary_subtract.18
# DEBUG:numba.core.ssa:on stmt: $const50.22 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $52binary_subscr.23 = static_getitem(value=a, index=2, index_var=$const50.22)
# DEBUG:numba.core.ssa:on stmt: $const56.25 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $58binary_subscr.26 = static_getitem(value=b, index=0, index_var=$const56.25)
# DEBUG:numba.core.ssa:on stmt: $60binary_multiply.27 = $52binary_subscr.23 * $58binary_subscr.26
# DEBUG:numba.core.ssa:on stmt: $const64.29 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $66binary_subscr.30 = static_getitem(value=a, index=0, index_var=$const64.29)
# DEBUG:numba.core.ssa:on stmt: $const70.32 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $72binary_subscr.33 = static_getitem(value=b, index=2, index_var=$const70.32)
# DEBUG:numba.core.ssa:on stmt: $74binary_multiply.34 = $66binary_subscr.30 * $72binary_subscr.33
# DEBUG:numba.core.ssa:on stmt: $76binary_subtract.35 = $60binary_multiply.27 - $74binary_multiply.34
# DEBUG:numba.core.ssa:on stmt: $const80.37 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: c[1] = $76binary_subtract.35
# DEBUG:numba.core.ssa:on stmt: $const86.39 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $88binary_subscr.40 = static_getitem(value=a, index=0, index_var=$const86.39)
# DEBUG:numba.core.ssa:on stmt: $const92.42 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $94binary_subscr.43 = static_getitem(value=b, index=1, index_var=$const92.42)
# DEBUG:numba.core.ssa:on stmt: $96binary_multiply.44 = $88binary_subscr.40 * $94binary_subscr.43
# DEBUG:numba.core.ssa:on stmt: $const100.46 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $102binary_subscr.47 = static_getitem(value=a, index=1, index_var=$const100.46)
# DEBUG:numba.core.ssa:on stmt: $const106.49 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $108binary_subscr.50 = static_getitem(value=b, index=0, index_var=$const106.49)
# DEBUG:numba.core.ssa:on stmt: $110binary_multiply.51 = $102binary_subscr.47 * $108binary_subscr.50
# DEBUG:numba.core.ssa:on stmt: $112binary_subtract.52 = $96binary_multiply.44 - $110binary_multiply.51
# DEBUG:numba.core.ssa:on stmt: $const116.54 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: c[2] = $112binary_subtract.52
# DEBUG:numba.core.ssa:on stmt: $122return_value.56 = cast(value=c)
# DEBUG:numba.core.ssa:on stmt: return $122return_value.56
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$102binary_subscr.47': [<numba.core.ir.Assign object at 0x2b4cfdce2978>],
#              '$108binary_subscr.50': [<numba.core.ir.Assign object at 0x2b4cfdce29e8>],
#              '$110binary_multiply.51': [<numba.core.ir.Assign object at 0x2b4cfdce2160>],
#              '$112binary_subtract.52': [<numba.core.ir.Assign object at 0x2b4cfdce2240>],
#              '$122return_value.56': [<numba.core.ir.Assign object at 0x2b4cfdce25c0>],
#              '$16binary_subscr.6': [<numba.core.ir.Assign object at 0x2b4cfdccbbe0>],
#              '$22binary_subscr.9': [<numba.core.ir.Assign object at 0x2b4cfdccb320>],
#              '$24binary_multiply.10': [<numba.core.ir.Assign object at 0x2b4cfdccbe80>],
#              '$2load_global.0': [<numba.core.ir.Assign object at 0x2b4cfdccb588>],
#              '$30binary_subscr.13': [<numba.core.ir.Assign object at 0x2b4cfdce24e0>],
#              '$36binary_subscr.16': [<numba.core.ir.Assign object at 0x2b4cfdce2668>],
#              '$38binary_multiply.17': [<numba.core.ir.Assign object at 0x2b4cfdcda470>],
#              '$40binary_subtract.18': [<numba.core.ir.Assign object at 0x2b4cfdcda550>],
#              '$4load_method.1': [<numba.core.ir.Assign object at 0x2b4cfdccb668>],
#              '$52binary_subscr.23': [<numba.core.ir.Assign object at 0x2b4cfdce26d8>],
#              '$58binary_subscr.26': [<numba.core.ir.Assign object at 0x2b4cfdce2748>],
#              '$60binary_multiply.27': [<numba.core.ir.Assign object at 0x2b4cfdcdacf8>],
#              '$66binary_subscr.30': [<numba.core.ir.Assign object at 0x2b4cfdce27b8>],
#              '$72binary_subscr.33': [<numba.core.ir.Assign object at 0x2b4cfdce2828>],
#              '$74binary_multiply.34': [<numba.core.ir.Assign object at 0x2b4cfdcdd2e8>],
#              '$76binary_subtract.35': [<numba.core.ir.Assign object at 0x2b4cfdcdd3c8>],
#              '$88binary_subscr.40': [<numba.core.ir.Assign object at 0x2b4cfdce2898>],
#              '$8call_method.3': [<numba.core.ir.Assign object at 0x2b4cfdccb828>],
#              '$94binary_subscr.43': [<numba.core.ir.Assign object at 0x2b4cfdce2908>],
#              '$96binary_multiply.44': [<numba.core.ir.Assign object at 0x2b4cfdcddb70>],
#              '$const100.46': [<numba.core.ir.Assign object at 0x2b4cfdcddcf8>],
#              '$const106.49': [<numba.core.ir.Assign object at 0x2b4cfdcddf60>],
#              '$const116.54': [<numba.core.ir.Assign object at 0x2b4cfdce23c8>],
#              '$const14.5': [<numba.core.ir.Assign object at 0x2b4cfdccba58>],
#              '$const20.8': [<numba.core.ir.Assign object at 0x2b4cfdccbcc0>],
#              '$const28.12': [<numba.core.ir.Assign object at 0x2b4cfdcda048>],
#              '$const34.15': [<numba.core.ir.Assign object at 0x2b4cfdcda2b0>],
#              '$const44.20': [<numba.core.ir.Assign object at 0x2b4cfdcda6d8>],
#              '$const50.22': [<numba.core.ir.Assign object at 0x2b4cfdcda8d0>],
#              '$const56.25': [<numba.core.ir.Assign object at 0x2b4cfdcdab38>],
#              '$const6.2': [<numba.core.ir.Assign object at 0x2b4cfdccb748>],
#              '$const64.29': [<numba.core.ir.Assign object at 0x2b4cfdcdae80>],
#              '$const70.32': [<numba.core.ir.Assign object at 0x2b4cfdcdd128>],
#              '$const80.37': [<numba.core.ir.Assign object at 0x2b4cfdcdd550>],
#              '$const86.39': [<numba.core.ir.Assign object at 0x2b4cfdcdd748>],
#              '$const92.42': [<numba.core.ir.Assign object at 0x2b4cfdcdd9b0>],
#              'a': [<numba.core.ir.Assign object at 0x2b4cfdccb3c8>],
#              'b': [<numba.core.ir.Assign object at 0x2b4cfdccb470>],
#              'c': [<numba.core.ir.Assign object at 0x2b4cfdccb8d0>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     a = arg(0, name=a)                       ['a']
#     b = arg(1, name=b)                       ['b']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=zeros) ['$2load_global.0', '$4load_method.1']
#     $const6.2 = const(int, 3)                ['$const6.2']
#     $8call_method.3 = call $4load_method.1($const6.2, func=$4load_method.1, args=[Var($const6.2, coordinate_numba.py:6)], kws=(), vararg=None) ['$4load_method.1', '$8call_method.3', '$const6.2']
#     c = $8call_method.3                      ['$8call_method.3', 'c']
#     $const14.5 = const(int, 1)               ['$const14.5']
#     $16binary_subscr.6 = static_getitem(value=a, index=1, index_var=$const14.5) ['$16binary_subscr.6', '$const14.5', 'a']
#     $const20.8 = const(int, 2)               ['$const20.8']
#     $22binary_subscr.9 = static_getitem(value=b, index=2, index_var=$const20.8) ['$22binary_subscr.9', '$const20.8', 'b']
#     $24binary_multiply.10 = $16binary_subscr.6 * $22binary_subscr.9 ['$16binary_subscr.6', '$22binary_subscr.9', '$24binary_multiply.10']
#     $const28.12 = const(int, 2)              ['$const28.12']
#     $30binary_subscr.13 = static_getitem(value=a, index=2, index_var=$const28.12) ['$30binary_subscr.13', '$const28.12', 'a']
#     $const34.15 = const(int, 1)              ['$const34.15']
#     $36binary_subscr.16 = static_getitem(value=b, index=1, index_var=$const34.15) ['$36binary_subscr.16', '$const34.15', 'b']
#     $38binary_multiply.17 = $30binary_subscr.13 * $36binary_subscr.16 ['$30binary_subscr.13', '$36binary_subscr.16', '$38binary_multiply.17']
#     $40binary_subtract.18 = $24binary_multiply.10 - $38binary_multiply.17 ['$24binary_multiply.10', '$38binary_multiply.17', '$40binary_subtract.18']
#     $const44.20 = const(int, 0)              ['$const44.20']
#     c[0] = $40binary_subtract.18             ['$40binary_subtract.18', '$const44.20', 'c']
#     $const50.22 = const(int, 2)              ['$const50.22']
#     $52binary_subscr.23 = static_getitem(value=a, index=2, index_var=$const50.22) ['$52binary_subscr.23', '$const50.22', 'a']
#     $const56.25 = const(int, 0)              ['$const56.25']
#     $58binary_subscr.26 = static_getitem(value=b, index=0, index_var=$const56.25) ['$58binary_subscr.26', '$const56.25', 'b']
#     $60binary_multiply.27 = $52binary_subscr.23 * $58binary_subscr.26 ['$52binary_subscr.23', '$58binary_subscr.26', '$60binary_multiply.27']
#     $const64.29 = const(int, 0)              ['$const64.29']
#     $66binary_subscr.30 = static_getitem(value=a, index=0, index_var=$const64.29) ['$66binary_subscr.30', '$const64.29', 'a']
#     $const70.32 = const(int, 2)              ['$const70.32']
#     $72binary_subscr.33 = static_getitem(value=b, index=2, index_var=$const70.32) ['$72binary_subscr.33', '$const70.32', 'b']
#     $74binary_multiply.34 = $66binary_subscr.30 * $72binary_subscr.33 ['$66binary_subscr.30', '$72binary_subscr.33', '$74binary_multiply.34']
#     $76binary_subtract.35 = $60binary_multiply.27 - $74binary_multiply.34 ['$60binary_multiply.27', '$74binary_multiply.34', '$76binary_subtract.35']
#     $const80.37 = const(int, 1)              ['$const80.37']
#     c[1] = $76binary_subtract.35             ['$76binary_subtract.35', '$const80.37', 'c']
#     $const86.39 = const(int, 0)              ['$const86.39']
#     $88binary_subscr.40 = static_getitem(value=a, index=0, index_var=$const86.39) ['$88binary_subscr.40', '$const86.39', 'a']
#     $const92.42 = const(int, 1)              ['$const92.42']
#     $94binary_subscr.43 = static_getitem(value=b, index=1, index_var=$const92.42) ['$94binary_subscr.43', '$const92.42', 'b']
#     $96binary_multiply.44 = $88binary_subscr.40 * $94binary_subscr.43 ['$88binary_subscr.40', '$94binary_subscr.43', '$96binary_multiply.44']
#     $const100.46 = const(int, 1)             ['$const100.46']
#     $102binary_subscr.47 = static_getitem(value=a, index=1, index_var=$const100.46) ['$102binary_subscr.47', '$const100.46', 'a']
#     $const106.49 = const(int, 0)             ['$const106.49']
#     $108binary_subscr.50 = static_getitem(value=b, index=0, index_var=$const106.49) ['$108binary_subscr.50', '$const106.49', 'b']
#     $110binary_multiply.51 = $102binary_subscr.47 * $108binary_subscr.50 ['$102binary_subscr.47', '$108binary_subscr.50', '$110binary_multiply.51']
#     $112binary_subtract.52 = $96binary_multiply.44 - $110binary_multiply.51 ['$110binary_multiply.51', '$112binary_subtract.52', '$96binary_multiply.44']
#     $const116.54 = const(int, 2)             ['$const116.54']
#     c[2] = $112binary_subtract.52            ['$112binary_subtract.52', '$const116.54', 'c']
#     $122return_value.56 = cast(value=c)      ['$122return_value.56', 'c']
#     return $122return_value.56               ['$122return_value.56']
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=14)
#            2	LOAD_GLOBAL(arg=0, lineno=14)
#            4	LOAD_METHOD(arg=1, lineno=14)
#            6	LOAD_FAST(arg=0, lineno=14)
#            8	LOAD_FAST(arg=0, lineno=14)
#           10	CALL_METHOD(arg=2, lineno=14)
#           12	STORE_FAST(arg=1, lineno=14)
#           14	LOAD_GLOBAL(arg=0, lineno=15)
#           16	LOAD_METHOD(arg=2, lineno=15)
#           18	LOAD_FAST(arg=1, lineno=15)
#           20	CALL_METHOD(arg=1, lineno=15)
#           22	RETURN_VALUE(arg=None, lineno=15)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=14)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_GLOBAL(arg=0, lineno=14)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_METHOD(arg=1, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$2load_global.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=LOAD_FAST(arg=0, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$4load_method.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=LOAD_FAST(arg=0, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$4load_method.1', '$a6.2']
# DEBUG:numba.core.byteflow:dispatch pc=10, inst=CALL_METHOD(arg=2, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$4load_method.1', '$a6.2', '$a8.3']
# DEBUG:numba.core.byteflow:dispatch pc=12, inst=STORE_FAST(arg=1, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$10call_method.4']
# DEBUG:numba.core.byteflow:dispatch pc=14, inst=LOAD_GLOBAL(arg=0, lineno=15)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=16, inst=LOAD_METHOD(arg=2, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$14load_global.5']
# DEBUG:numba.core.byteflow:dispatch pc=18, inst=LOAD_FAST(arg=1, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$16load_method.6']
# DEBUG:numba.core.byteflow:dispatch pc=20, inst=CALL_METHOD(arg=1, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$16load_method.6', '$n_218.7']
# DEBUG:numba.core.byteflow:dispatch pc=22, inst=RETURN_VALUE(arg=None, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$20call_method.8']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$2load_global.0'}), (4, {'item': '$2load_global.0', 'res': '$4load_method.1'}), (6, {'res': '$a6.2'}), (8, {'res': '$a8.3'}), (10, {'func': '$4load_method.1', 'args': ['$a6.2', '$a8.3'], 'res': '$10call_method.4'}), (12, {'value': '$10call_method.4'}), (14, {'res': '$14load_global.5'}), (16, {'item': '$14load_global.5', 'res': '$16load_method.6'}), (18, {'res': '$n_218.7'}), (20, {'func': '$16load_method.6', 'args': ['$n_218.7'], 'res': '$20call_method.8'}), (22, {'retval': '$20call_method.8', 'castval': '$22return_value.9'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     a = arg(0, name=a)                       ['a']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=dot) ['$2load_global.0', '$4load_method.1']
#     $10call_method.4 = call $4load_method.1(a, a, func=$4load_method.1, args=[Var(a, coordinate_numba.py:14), Var(a, coordinate_numba.py:14)], kws=(), vararg=None) ['$10call_method.4', '$4load_method.1', 'a', 'a']
#     n_2 = $10call_method.4                   ['$10call_method.4', 'n_2']
#     $14load_global.5 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$14load_global.5']
#     $16load_method.6 = getattr(value=$14load_global.5, attr=sqrt) ['$14load_global.5', '$16load_method.6']
#     $20call_method.8 = call $16load_method.6(n_2, func=$16load_method.6, args=[Var(n_2, coordinate_numba.py:14)], kws=(), vararg=None) ['$16load_method.6', '$20call_method.8', 'n_2']
#     $22return_value.9 = cast(value=$20call_method.8) ['$20call_method.8', '$22return_value.9']
#     return $22return_value.9                 ['$22return_value.9']
#
# DEBUG:numba.core.ssa:-----------------------------------BEFORE SSA-----------------------------------
# DEBUG:numba.core.ssa:label 0:
#     a = arg(0, name=a)                       ['a']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=dot) ['$2load_global.0', '$4load_method.1']
#     $10call_method.4 = call $4load_method.1(a, a, func=$4load_method.1, args=[Var(a, coordinate_numba.py:14), Var(a, coordinate_numba.py:14)], kws=(), vararg=None) ['$10call_method.4', '$4load_method.1', 'a', 'a']
#     n_2 = $10call_method.4                   ['$10call_method.4', 'n_2']
#     $14load_global.5 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$14load_global.5']
#     $16load_method.6 = getattr(value=$14load_global.5, attr=sqrt) ['$14load_global.5', '$16load_method.6']
#     $20call_method.8 = call $16load_method.6(n_2, func=$16load_method.6, args=[Var(n_2, coordinate_numba.py:14)], kws=(), vararg=None) ['$16load_method.6', '$20call_method.8', 'n_2']
#     $22return_value.9 = cast(value=$20call_method.8) ['$20call_method.8', '$22return_value.9']
#     return $22return_value.9                 ['$22return_value.9']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b4cfdd59748>
# DEBUG:numba.core.ssa:on stmt: a = arg(0, name=a)
# DEBUG:numba.core.ssa:on stmt: $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $4load_method.1 = getattr(value=$2load_global.0, attr=dot)
# DEBUG:numba.core.ssa:on stmt: $10call_method.4 = call $4load_method.1(a, a, func=$4load_method.1, args=[Var(a, coordinate_numba.py:14), Var(a, coordinate_numba.py:14)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: n_2 = $10call_method.4
# DEBUG:numba.core.ssa:on stmt: $14load_global.5 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $16load_method.6 = getattr(value=$14load_global.5, attr=sqrt)
# DEBUG:numba.core.ssa:on stmt: $20call_method.8 = call $16load_method.6(n_2, func=$16load_method.6, args=[Var(n_2, coordinate_numba.py:14)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: $22return_value.9 = cast(value=$20call_method.8)
# DEBUG:numba.core.ssa:on stmt: return $22return_value.9
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$10call_method.4': [<numba.core.ir.Assign object at 0x2b4cfdd24b38>],
#              '$14load_global.5': [<numba.core.ir.Assign object at 0x2b4cfdd24940>],
#              '$16load_method.6': [<numba.core.ir.Assign object at 0x2b4cfdd247f0>],
#              '$20call_method.8': [<numba.core.ir.Assign object at 0x2b4cfdd24748>],
#              '$22return_value.9': [<numba.core.ir.Assign object at 0x2b4cfdd24438>],
#              '$2load_global.0': [<numba.core.ir.Assign object at 0x2b4cfdd24208>],
#              '$4load_method.1': [<numba.core.ir.Assign object at 0x2b4cfdd24358>],
#              'a': [<numba.core.ir.Assign object at 0x2b4cfdd24048>],
#              'n_2': [<numba.core.ir.Assign object at 0x2b4cfdd24a58>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     a = arg(0, name=a)                       ['a']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=dot) ['$2load_global.0', '$4load_method.1']
# ...
# DEBUG:numba.core.ssa:on stmt: angle_position_2 = arg(0, name=angle_position_2)
# DEBUG:numba.core.ssa:on stmt: torsion_position_1 = arg(1, name=torsion_position_1)
# DEBUG:numba.core.ssa:on stmt: $6binary_subtract.2 = angle_position_2 - torsion_position_1
# DEBUG:numba.core.ssa:on stmt: $8return_value.3 = cast(value=$6binary_subtract.2)
# DEBUG:numba.core.ssa:on stmt: return $8return_value.3
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$6binary_subtract.2': [<numba.core.ir.Assign object at 0x2b4cfe4314a8>],
#              '$8return_value.3': [<numba.core.ir.Assign object at 0x2b4cfe431048>],
#              'angle_position_2': [<numba.core.ir.Assign object at 0x2b4cfe431320>],
#              'torsion_position_1': [<numba.core.ir.Assign object at 0x2b4cfe4312e8>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     angle_position_2 = arg(0, name=angle_position_2) ['angle_position_2']
#     torsion_position_1 = arg(1, name=torsion_position_1) ['torsion_position_1']
#     $6binary_subtract.2 = angle_position_2 - torsion_position_1 ['$6binary_subtract.2', 'angle_position_2', 'torsion_position_1']
#     $8return_value.3 = cast(value=$6binary_subtract.2) ['$6binary_subtract.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=106)
#            2	LOAD_FAST(arg=1, lineno=106)
#            4	LOAD_FAST(arg=0, lineno=110)
#            6	BINARY_TRUE_DIVIDE(arg=None, lineno=110)
#            8	RETURN_VALUE(arg=None, lineno=110)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=106)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_FAST(arg=1, lineno=106)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_FAST(arg=0, lineno=110)
# DEBUG:numba.core.byteflow:stack ['$a_12.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=BINARY_TRUE_DIVIDE(arg=None, lineno=110)
# DEBUG:numba.core.byteflow:stack ['$a_12.0', '$_32call_function_12_14.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=RETURN_VALUE(arg=None, lineno=110)
# DEBUG:numba.core.byteflow:stack ['$6binary_true_divide.2']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$a_12.0'}), (4, {'res': '$_32call_function_12_14.1'}), (6, {'lhs': '$a_12.0', 'rhs': '$_32call_function_12_14.1', 'res': '$6binary_true_divide.2'}), (8, {'retval': '$6binary_true_divide.2', 'castval': '$8return_value.3'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     _32call_function_12_1 = arg(0, name=_32call_function_12_1) ['_32call_function_12_1']
#     a_1 = arg(1, name=a_1)                   ['a_1']
#     $6binary_true_divide.2 = a_1 / _32call_function_12_1 ['$6binary_true_divide.2', '_32call_function_12_1', 'a_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:-----------------------------------BEFORE SSA-----------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _32call_function_12_1 = arg(0, name=_32call_function_12_1) ['_32call_function_12_1']
#     a_1 = arg(1, name=a_1)                   ['a_1']
#     $6binary_true_divide.2 = a_1 / _32call_function_12_1 ['$6binary_true_divide.2', '_32call_function_12_1', 'a_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b4cfe0cdf60>
# DEBUG:numba.core.ssa:on stmt: _32call_function_12_1 = arg(0, name=_32call_function_12_1)
# DEBUG:numba.core.ssa:on stmt: a_1 = arg(1, name=a_1)
# DEBUG:numba.core.ssa:on stmt: $6binary_true_divide.2 = a_1 / _32call_function_12_1
# DEBUG:numba.core.ssa:on stmt: $8return_value.3 = cast(value=$6binary_true_divide.2)
# DEBUG:numba.core.ssa:on stmt: return $8return_value.3
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$6binary_true_divide.2': [<numba.core.ir.Assign object at 0x2b4cfe0bd390>],
#              '$8return_value.3': [<numba.core.ir.Assign object at 0x2b4cfe0bd470>],
#              '_32call_function_12_1': [<numba.core.ir.Assign object at 0x2b4cfe0bd0b8>],
#              'a_1': [<numba.core.ir.Assign object at 0x2b4cfe0bd160>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _32call_function_12_1 = arg(0, name=_32call_function_12_1) ['_32call_function_12_1']
#     a_1 = arg(1, name=a_1)                   ['a_1']
#     $6binary_true_divide.2 = a_1 / _32call_function_12_1 ['$6binary_true_divide.2', '_32call_function_12_1', 'a_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=107)
#            2	LOAD_FAST(arg=1, lineno=107)
#            4	LOAD_FAST(arg=0, lineno=111)
#            6	BINARY_TRUE_DIVIDE(arg=None, lineno=111)
#            8	RETURN_VALUE(arg=None, lineno=111)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=107)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_FAST(arg=1, lineno=107)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_FAST(arg=0, lineno=111)
# DEBUG:numba.core.byteflow:stack ['$b_12.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=BINARY_TRUE_DIVIDE(arg=None, lineno=111)
# DEBUG:numba.core.byteflow:stack ['$b_12.0', '$_44call_function_17_14.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=RETURN_VALUE(arg=None, lineno=111)
# DEBUG:numba.core.byteflow:stack ['$6binary_true_divide.2']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$b_12.0'}), (4, {'res': '$_44call_function_17_14.1'}), (6, {'lhs': '$b_12.0', 'rhs': '$_44call_function_17_14.1', 'res': '$6binary_true_divide.2'}), (8, {'retval': '$6binary_true_divide.2', 'castval': '$8return_value.3'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     _44call_function_17_1 = arg(0, name=_44call_function_17_1) ['_44call_function_17_1']
#     b_1 = arg(1, name=b_1)                   ['b_1']
#     $6binary_true_divide.2 = b_1 / _44call_function_17_1 ['$6binary_true_divide.2', '_44call_function_17_1', 'b_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:-----------------------------------BEFORE SSA-----------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _44call_function_17_1 = arg(0, name=_44call_function_17_1) ['_44call_function_17_1']
#     b_1 = arg(1, name=b_1)                   ['b_1']
#     $6binary_true_divide.2 = b_1 / _44call_function_17_1 ['$6binary_true_divide.2', '_44call_function_17_1', 'b_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b4cfe316048>
# DEBUG:numba.core.ssa:on stmt: _44call_function_17_1 = arg(0, name=_44call_function_17_1)
# DEBUG:numba.core.ssa:on stmt: b_1 = arg(1, name=b_1)
# DEBUG:numba.core.ssa:on stmt: $6binary_true_divide.2 = b_1 / _44call_function_17_1
# DEBUG:numba.core.ssa:on stmt: $8return_value.3 = cast(value=$6binary_true_divide.2)
# DEBUG:numba.core.ssa:on stmt: return $8return_value.3
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$6binary_true_divide.2': [<numba.core.ir.Assign object at 0x2b4cfe316400>],
#              '$8return_value.3': [<numba.core.ir.Assign object at 0x2b4cfe3165f8>],
#              '_44call_function_17_1': [<numba.core.ir.Assign object at 0x2b4cfe3164e0>],
#              'b_1': [<numba.core.ir.Assign object at 0x2b4cfe316780>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _44call_function_17_1 = arg(0, name=_44call_function_17_1) ['_44call_function_17_1']
#     b_1 = arg(1, name=b_1)                   ['b_1']
#     $6binary_true_divide.2 = b_1 / _44call_function_17_1 ['$6binary_true_divide.2', '_44call_function_17_1', 'b_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=109)
#            2	LOAD_FAST(arg=1, lineno=109)
#            4	LOAD_FAST(arg=0, lineno=112)
#            6	BINARY_TRUE_DIVIDE(arg=None, lineno=112)
#            8	RETURN_VALUE(arg=None, lineno=112)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=109)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_FAST(arg=1, lineno=109)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_FAST(arg=0, lineno=112)
# DEBUG:numba.core.byteflow:stack ['$c_12.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=BINARY_TRUE_DIVIDE(arg=None, lineno=112)
# DEBUG:numba.core.byteflow:stack ['$c_12.0', '$_56call_function_22_14.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=RETURN_VALUE(arg=None, lineno=112)
# DEBUG:numba.core.byteflow:stack ['$6binary_true_divide.2']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$c_12.0'}), (4, {'res': '$_56call_function_22_14.1'}), (6, {'lhs': '$c_12.0', 'rhs': '$_56call_function_22_14.1', 'res': '$6binary_true_divide.2'}), (8, {'retval': '$6binary_true_divide.2', 'castval': '$8return_value.3'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     _56call_function_22_1 = arg(0, name=_56call_function_22_1) ['_56call_function_22_1']
#     c_1 = arg(1, name=c_1)                   ['c_1']
#     $6binary_true_divide.2 = c_1 / _56call_function_22_1 ['$6binary_true_divide.2', '_56call_function_22_1', 'c_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:-----------------------------------BEFORE SSA-----------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _56call_function_22_1 = arg(0, name=_56call_function_22_1) ['_56call_function_22_1']
#     c_1 = arg(1, name=c_1)                   ['c_1']
#     $6binary_true_divide.2 = c_1 / _56call_function_22_1 ['$6binary_true_divide.2', '_56call_function_22_1', 'c_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b4cfe238f98>
# DEBUG:numba.core.ssa:on stmt: _56call_function_22_1 = arg(0, name=_56call_function_22_1)
# DEBUG:numba.core.ssa:on stmt: c_1 = arg(1, name=c_1)
# DEBUG:numba.core.ssa:on stmt: $6binary_true_divide.2 = c_1 / _56call_function_22_1
# DEBUG:numba.core.ssa:on stmt: $8return_value.3 = cast(value=$6binary_true_divide.2)
# DEBUG:numba.core.ssa:on stmt: return $8return_value.3
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$6binary_true_divide.2': [<numba.core.ir.Assign object at 0x2b4cfe8ac160>],
#              '$8return_value.3': [<numba.core.ir.Assign object at 0x2b4cfe8ac240>],
#              '_56call_function_22_1': [<numba.core.ir.Assign object at 0x2b4cfe8a5b00>],
#              'c_1': [<numba.core.ir.Assign object at 0x2b4cfe8a5a58>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _56call_function_22_1 = arg(0, name=_56call_function_22_1) ['_56call_function_22_1']
#     c_1 = arg(1, name=c_1)                   ['c_1']
#     $6binary_true_divide.2 = c_1 / _56call_function_22_1 ['$6binary_true_divide.2', '_56call_function_22_1', 'c_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# RDKit WARNING: [17:10:24] Enabling RDKit 2019.09.3 jupyter extensions

# %%
apm_delivery = PointMutationExecutor('../input/ala_vacuum.pdb', 
                         '1', 
                         '2', 
                         'VAL',
                        conduct_endstate_validation=True,
                        )
apo_htf = apm_delivery.get_apo_htf()
# Out:
# DEBUG:perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:[4, 4, 4, 4, 4, 4]
# WARNING:proposal_generator:	rank_degenerate_maps: 'NoneType' object has no attribute 'IsAromatic'
# INFO:proposal_generator:Maximum atom matched after hydrogen exceptions: 2
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 8
# INFO:geometry:Atom index proposal order is [14, 18, 21, 20, 17, 16, 15, 19]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 11 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 48 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 72 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 2096 in the reference Nonbonded force
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -16.061296701914923
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context new positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 8 new atoms
# INFO:geometry:	reduced angle potential = 0.0399254815817493.
# INFO:geometry:	reduced angle potential = 0.3991689514927569.
# INFO:geometry:	reduced angle potential = 0.028334349504930523.
# INFO:geometry:	reduced angle potential = 0.6729740938105145.
# INFO:geometry:	reduced angle potential = 0.7243231975184564.
# INFO:geometry:	reduced angle potential = 2.349731348925296.
# INFO:geometry:	reduced angle potential = 0.5445886282874882.
# INFO:geometry:	reduced angle potential = 0.8293967197122432.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce', 'MonteCarloBarostat']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 11 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 48 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 72 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 16.820920233259045
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: -37.54288421999399
# INFO:geometry:final reduced energy -20.72196187872715
# INFO:geometry:sum of energies: -20.72196398673494
# INFO:geometry:magnitude of difference in the energies: 2.1080077914348294e-06
# INFO:geometry:Final logp_proposal: 33.50998475415936
# added energy components: [('CustomBondForce', 3.9751261280910675), ('CustomAngleForce', 11.613791981643796), ('CustomTorsionForce', 5.7315662486449686), ('CustomBondForce', -58.86336857837382)]
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 2
# INFO:geometry:Atom index proposal order is [15, 11]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 2060 in the reference Nonbonded force
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -2.8903717578961645
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:setting atoms_with_positions context old positions
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:There are 2 new atoms
# INFO:geometry:	reduced angle potential = 1.1491328110690509.
# INFO:geometry:	reduced angle potential = 8.578546222633222e-06.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce', 'MonteCarloBarostat']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced potential before atom placement: 16.82092023325904
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# INFO:geometry:total reduced energy added from growth system: 9.132765379135986
# INFO:geometry:final reduced energy 25.953685947680075
# INFO:geometry:sum of energies: 25.953685612395027
# INFO:geometry:magnitude of difference in the energies: 3.3528504772561973e-07
# INFO:geometry:Final logp_proposal: 10.446313318626755
# added energy components: [('CustomBondForce', 0.0), ('CustomAngleForce', 1.5196339774707472), ('CustomTorsionForce', 0.0036836193671578284), ('CustomBondForce', 7.60944778229808)]
# INFO:relative:Beginning nonbonded method, total particle, barostat, and exceptions retrieval...
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce', 'MonteCarloBarostat'])
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce', 'MonteCarloBarostat'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 4
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:Added MonteCarloBarostat.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.7648, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.7648, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.7648), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:Adding bond force terms...
# INFO:relative:Adding angle force terms...
# INFO:relative:Adding torsion force terms...
# INFO:relative:Adding nonbonded force terms...
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b4d01889690> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is PME or Ewald
# INFO:relative:	_add_nonbonded_force_terms: 4 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 2 added to sterics_custom_nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.CustomNonbondedForce; proxy of <Swig Object of type 'OpenMM::CustomNonbondedForce *' at 0x2b4d018893f0> > added to hybrid system
# INFO:relative:Handling harmonic bonds...
# INFO:relative:	handle_harmonic_bonds: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_bonds: looping through new_system to add relevant terms...
# INFO:relative:Handling harmonic angles...
# INFO:relative:	handle_harmonic_angles: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_angles: looping through new_system to add relevant terms...
# INFO:relative:Handling torsion forces...
# INFO:relative:	handle_periodic_torsion_forces: looping through old_system to add relevant terms...
# INFO:relative:	handle_periodic_torsion_forces: looping through new_system to add relevant terms...
# INFO:relative:Handling nonbonded forces...
# INFO:relative:	handle_nonbonded: looping through all particles in hybrid...
# INFO:relative:	handle_nonbonded: Handling Interaction Groups...
# INFO:relative:	handle_nonbonded: Handling Hybrid Exceptions...
# INFO:relative:	handle_nonbonded: Handling Original Exceptions...
# INFO:relative:Handling unique_new/old interaction exceptions...
# INFO:relative:There are old or new system exceptions...proceeding.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 0.03336689198711389
# 			HarmonicAngleForce: 2.1347394429482724
# 			PeriodicTorsionForce: 16.176131477654224
# 			NonbondedForce: -1285.9024711046145
# 			AndersenThermostat: 0.0
# 			MonteCarloBarostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			CustomBondForce: 0.0333668919871139
# 			HarmonicBondForce: 3.9751261280909644
# 			CustomAngleForce: 0.6151054654774569
# 			HarmonicAngleForce: 13.133425959114717
# 			CustomTorsionForce: 0.0014372414311074064
# 			PeriodicTorsionForce: 21.9062598581807
# 			NonbondedForce: -1331.6467615296067
# 			CustomNonbondedForce: -13.119137718048535
# 			CustomBondForce: 0.0
# 			AndersenThermostat: 0.0
# 			MonteCarloBarostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			CustomBondForce: 0.0333668919871139
# 			HarmonicBondForce: 3.9751261280909644
# 			CustomAngleForce: 0.6151054654774569
# 			HarmonicAngleForce: 13.133425959114717
# 			CustomTorsionForce: 0.0014372414311074064
# 			PeriodicTorsionForce: 21.9062598581807
# 			NonbondedForce: -1298.6568515214237
# 			CustomNonbondedForce: 132.2597880985701
# 			CustomBondForce: 0.0
# 			AndersenThermostat: 0.0
# 			MonteCarloBarostat: 0.0
# conducting subsequent work with the following platform: CUDA
# 			HarmonicBondForce: 4.008493020078078
# 			HarmonicAngleForce: 12.228897447121359
# 			PeriodicTorsionForce: 21.904013486993396
# 			NonbondedForce: -1174.006460700367
# 			AndersenThermostat: 0.0
# 			MonteCarloBarostat: 0.0

# %% [markdown]
# ### Vacuum

# %%
from pkg_resources import resource_filename
from perses.app.relative_point_mutation_setup import PointMutationExecutor
import simtk.openmm.app as app
# Out:
# INFO:numexpr.utils:Note: detected 72 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# INFO:numexpr.utils:Note: NumExpr detected 72 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=6)
#            2	LOAD_GLOBAL(arg=0, lineno=6)
#            4	LOAD_METHOD(arg=1, lineno=6)
#            6	LOAD_CONST(arg=1, lineno=6)
#            8	CALL_METHOD(arg=1, lineno=6)
#           10	STORE_FAST(arg=2, lineno=6)
#           12	LOAD_FAST(arg=0, lineno=7)
#           14	LOAD_CONST(arg=2, lineno=7)
#           16	BINARY_SUBSCR(arg=None, lineno=7)
#           18	LOAD_FAST(arg=1, lineno=7)
#           20	LOAD_CONST(arg=3, lineno=7)
#           22	BINARY_SUBSCR(arg=None, lineno=7)
#           24	BINARY_MULTIPLY(arg=None, lineno=7)
#           26	LOAD_FAST(arg=0, lineno=7)
#           28	LOAD_CONST(arg=3, lineno=7)
#           30	BINARY_SUBSCR(arg=None, lineno=7)
#           32	LOAD_FAST(arg=1, lineno=7)
#           34	LOAD_CONST(arg=2, lineno=7)
#           36	BINARY_SUBSCR(arg=None, lineno=7)
#           38	BINARY_MULTIPLY(arg=None, lineno=7)
#           40	BINARY_SUBTRACT(arg=None, lineno=7)
#           42	LOAD_FAST(arg=2, lineno=7)
#           44	LOAD_CONST(arg=4, lineno=7)
#           46	STORE_SUBSCR(arg=None, lineno=7)
#           48	LOAD_FAST(arg=0, lineno=8)
#           50	LOAD_CONST(arg=3, lineno=8)
#           52	BINARY_SUBSCR(arg=None, lineno=8)
#           54	LOAD_FAST(arg=1, lineno=8)
#           56	LOAD_CONST(arg=4, lineno=8)
#           58	BINARY_SUBSCR(arg=None, lineno=8)
#           60	BINARY_MULTIPLY(arg=None, lineno=8)
#           62	LOAD_FAST(arg=0, lineno=8)
#           64	LOAD_CONST(arg=4, lineno=8)
#           66	BINARY_SUBSCR(arg=None, lineno=8)
#           68	LOAD_FAST(arg=1, lineno=8)
#           70	LOAD_CONST(arg=3, lineno=8)
#           72	BINARY_SUBSCR(arg=None, lineno=8)
#           74	BINARY_MULTIPLY(arg=None, lineno=8)
#           76	BINARY_SUBTRACT(arg=None, lineno=8)
#           78	LOAD_FAST(arg=2, lineno=8)
#           80	LOAD_CONST(arg=2, lineno=8)
#           82	STORE_SUBSCR(arg=None, lineno=8)
#           84	LOAD_FAST(arg=0, lineno=9)
#           86	LOAD_CONST(arg=4, lineno=9)
#           88	BINARY_SUBSCR(arg=None, lineno=9)
#           90	LOAD_FAST(arg=1, lineno=9)
#           92	LOAD_CONST(arg=2, lineno=9)
#           94	BINARY_SUBSCR(arg=None, lineno=9)
#           96	BINARY_MULTIPLY(arg=None, lineno=9)
#           98	LOAD_FAST(arg=0, lineno=9)
#          100	LOAD_CONST(arg=2, lineno=9)
#          102	BINARY_SUBSCR(arg=None, lineno=9)
#          104	LOAD_FAST(arg=1, lineno=9)
#          106	LOAD_CONST(arg=4, lineno=9)
#          108	BINARY_SUBSCR(arg=None, lineno=9)
#          110	BINARY_MULTIPLY(arg=None, lineno=9)
#          112	BINARY_SUBTRACT(arg=None, lineno=9)
#          114	LOAD_FAST(arg=2, lineno=9)
#          116	LOAD_CONST(arg=3, lineno=9)
#          118	STORE_SUBSCR(arg=None, lineno=9)
#          120	LOAD_FAST(arg=2, lineno=10)
#          122	RETURN_VALUE(arg=None, lineno=10)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=6)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_GLOBAL(arg=0, lineno=6)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_METHOD(arg=1, lineno=6)
# DEBUG:numba.core.byteflow:stack ['$2load_global.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=LOAD_CONST(arg=1, lineno=6)
# DEBUG:numba.core.byteflow:stack ['$4load_method.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=CALL_METHOD(arg=1, lineno=6)
# DEBUG:numba.core.byteflow:stack ['$4load_method.1', '$const6.2']
# DEBUG:numba.core.byteflow:dispatch pc=10, inst=STORE_FAST(arg=2, lineno=6)
# DEBUG:numba.core.byteflow:stack ['$8call_method.3']
# DEBUG:numba.core.byteflow:dispatch pc=12, inst=LOAD_FAST(arg=0, lineno=7)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=14, inst=LOAD_CONST(arg=2, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$a12.4']
# DEBUG:numba.core.byteflow:dispatch pc=16, inst=BINARY_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$a12.4', '$const14.5']
# DEBUG:numba.core.byteflow:dispatch pc=18, inst=LOAD_FAST(arg=1, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$16binary_subscr.6']
# DEBUG:numba.core.byteflow:dispatch pc=20, inst=LOAD_CONST(arg=3, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$16binary_subscr.6', '$b18.7']
# DEBUG:numba.core.byteflow:dispatch pc=22, inst=BINARY_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$16binary_subscr.6', '$b18.7', '$const20.8']
# DEBUG:numba.core.byteflow:dispatch pc=24, inst=BINARY_MULTIPLY(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$16binary_subscr.6', '$22binary_subscr.9']
# DEBUG:numba.core.byteflow:dispatch pc=26, inst=LOAD_FAST(arg=0, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10']
# DEBUG:numba.core.byteflow:dispatch pc=28, inst=LOAD_CONST(arg=3, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$a26.11']
# DEBUG:numba.core.byteflow:dispatch pc=30, inst=BINARY_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$a26.11', '$const28.12']
# DEBUG:numba.core.byteflow:dispatch pc=32, inst=LOAD_FAST(arg=1, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$30binary_subscr.13']
# DEBUG:numba.core.byteflow:dispatch pc=34, inst=LOAD_CONST(arg=2, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$30binary_subscr.13', '$b32.14']
# DEBUG:numba.core.byteflow:dispatch pc=36, inst=BINARY_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$30binary_subscr.13', '$b32.14', '$const34.15']
# DEBUG:numba.core.byteflow:dispatch pc=38, inst=BINARY_MULTIPLY(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$30binary_subscr.13', '$36binary_subscr.16']
# DEBUG:numba.core.byteflow:dispatch pc=40, inst=BINARY_SUBTRACT(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$38binary_multiply.17']
# DEBUG:numba.core.byteflow:dispatch pc=42, inst=LOAD_FAST(arg=2, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$40binary_subtract.18']
# DEBUG:numba.core.byteflow:dispatch pc=44, inst=LOAD_CONST(arg=4, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$40binary_subtract.18', '$c42.19']
# DEBUG:numba.core.byteflow:dispatch pc=46, inst=STORE_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$40binary_subtract.18', '$c42.19', '$const44.20']
# DEBUG:numba.core.byteflow:dispatch pc=48, inst=LOAD_FAST(arg=0, lineno=8)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=50, inst=LOAD_CONST(arg=3, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$a48.21']
# DEBUG:numba.core.byteflow:dispatch pc=52, inst=BINARY_SUBSCR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$a48.21', '$const50.22']
# DEBUG:numba.core.byteflow:dispatch pc=54, inst=LOAD_FAST(arg=1, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$52binary_subscr.23']
# DEBUG:numba.core.byteflow:dispatch pc=56, inst=LOAD_CONST(arg=4, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$52binary_subscr.23', '$b54.24']
# DEBUG:numba.core.byteflow:dispatch pc=58, inst=BINARY_SUBSCR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$52binary_subscr.23', '$b54.24', '$const56.25']
# DEBUG:numba.core.byteflow:dispatch pc=60, inst=BINARY_MULTIPLY(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$52binary_subscr.23', '$58binary_subscr.26']
# DEBUG:numba.core.byteflow:dispatch pc=62, inst=LOAD_FAST(arg=0, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27']
# DEBUG:numba.core.byteflow:dispatch pc=64, inst=LOAD_CONST(arg=4, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$a62.28']
# DEBUG:numba.core.byteflow:dispatch pc=66, inst=BINARY_SUBSCR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$a62.28', '$const64.29']
# DEBUG:numba.core.byteflow:dispatch pc=68, inst=LOAD_FAST(arg=1, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$66binary_subscr.30']
# DEBUG:numba.core.byteflow:dispatch pc=70, inst=LOAD_CONST(arg=3, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$66binary_subscr.30', '$b68.31']
# DEBUG:numba.core.byteflow:dispatch pc=72, inst=BINARY_SUBSCR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$66binary_subscr.30', '$b68.31', '$const70.32']
# DEBUG:numba.core.byteflow:dispatch pc=74, inst=BINARY_MULTIPLY(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$66binary_subscr.30', '$72binary_subscr.33']
# DEBUG:numba.core.byteflow:dispatch pc=76, inst=BINARY_SUBTRACT(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$74binary_multiply.34']
# DEBUG:numba.core.byteflow:dispatch pc=78, inst=LOAD_FAST(arg=2, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$76binary_subtract.35']
# DEBUG:numba.core.byteflow:dispatch pc=80, inst=LOAD_CONST(arg=2, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$76binary_subtract.35', '$c78.36']
# DEBUG:numba.core.byteflow:dispatch pc=82, inst=STORE_SUBSCR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$76binary_subtract.35', '$c78.36', '$const80.37']
# DEBUG:numba.core.byteflow:dispatch pc=84, inst=LOAD_FAST(arg=0, lineno=9)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=86, inst=LOAD_CONST(arg=4, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$a84.38']
# DEBUG:numba.core.byteflow:dispatch pc=88, inst=BINARY_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$a84.38', '$const86.39']
# DEBUG:numba.core.byteflow:dispatch pc=90, inst=LOAD_FAST(arg=1, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$88binary_subscr.40']
# DEBUG:numba.core.byteflow:dispatch pc=92, inst=LOAD_CONST(arg=2, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$88binary_subscr.40', '$b90.41']
# DEBUG:numba.core.byteflow:dispatch pc=94, inst=BINARY_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$88binary_subscr.40', '$b90.41', '$const92.42']
# DEBUG:numba.core.byteflow:dispatch pc=96, inst=BINARY_MULTIPLY(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$88binary_subscr.40', '$94binary_subscr.43']
# DEBUG:numba.core.byteflow:dispatch pc=98, inst=LOAD_FAST(arg=0, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44']
# DEBUG:numba.core.byteflow:dispatch pc=100, inst=LOAD_CONST(arg=2, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$a98.45']
# DEBUG:numba.core.byteflow:dispatch pc=102, inst=BINARY_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$a98.45', '$const100.46']
# DEBUG:numba.core.byteflow:dispatch pc=104, inst=LOAD_FAST(arg=1, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$102binary_subscr.47']
# DEBUG:numba.core.byteflow:dispatch pc=106, inst=LOAD_CONST(arg=4, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$102binary_subscr.47', '$b104.48']
# DEBUG:numba.core.byteflow:dispatch pc=108, inst=BINARY_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$102binary_subscr.47', '$b104.48', '$const106.49']
# DEBUG:numba.core.byteflow:dispatch pc=110, inst=BINARY_MULTIPLY(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$102binary_subscr.47', '$108binary_subscr.50']
# DEBUG:numba.core.byteflow:dispatch pc=112, inst=BINARY_SUBTRACT(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$110binary_multiply.51']
# DEBUG:numba.core.byteflow:dispatch pc=114, inst=LOAD_FAST(arg=2, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$112binary_subtract.52']
# DEBUG:numba.core.byteflow:dispatch pc=116, inst=LOAD_CONST(arg=3, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$112binary_subtract.52', '$c114.53']
# DEBUG:numba.core.byteflow:dispatch pc=118, inst=STORE_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$112binary_subtract.52', '$c114.53', '$const116.54']
# DEBUG:numba.core.byteflow:dispatch pc=120, inst=LOAD_FAST(arg=2, lineno=10)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=122, inst=RETURN_VALUE(arg=None, lineno=10)
# DEBUG:numba.core.byteflow:stack ['$c120.55']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$2load_global.0'}), (4, {'item': '$2load_global.0', 'res': '$4load_method.1'}), (6, {'res': '$const6.2'}), (8, {'func': '$4load_method.1', 'args': ['$const6.2'], 'res': '$8call_method.3'}), (10, {'value': '$8call_method.3'}), (12, {'res': '$a12.4'}), (14, {'res': '$const14.5'}), (16, {'index': '$const14.5', 'target': '$a12.4', 'res': '$16binary_subscr.6'}), (18, {'res': '$b18.7'}), (20, {'res': '$const20.8'}), (22, {'index': '$const20.8', 'target': '$b18.7', 'res': '$22binary_subscr.9'}), (24, {'lhs': '$16binary_subscr.6', 'rhs': '$22binary_subscr.9', 'res': '$24binary_multiply.10'}), (26, {'res': '$a26.11'}), (28, {'res': '$const28.12'}), (30, {'index': '$const28.12', 'target': '$a26.11', 'res': '$30binary_subscr.13'}), (32, {'res': '$b32.14'}), (34, {'res': '$const34.15'}), (36, {'index': '$const34.15', 'target': '$b32.14', 'res': '$36binary_subscr.16'}), (38, {'lhs': '$30binary_subscr.13', 'rhs': '$36binary_subscr.16', 'res': '$38binary_multiply.17'}), (40, {'lhs': '$24binary_multiply.10', 'rhs': '$38binary_multiply.17', 'res': '$40binary_subtract.18'}), (42, {'res': '$c42.19'}), (44, {'res': '$const44.20'}), (46, {'target': '$c42.19', 'index': '$const44.20', 'value': '$40binary_subtract.18'}), (48, {'res': '$a48.21'}), (50, {'res': '$const50.22'}), (52, {'index': '$const50.22', 'target': '$a48.21', 'res': '$52binary_subscr.23'}), (54, {'res': '$b54.24'}), (56, {'res': '$const56.25'}), (58, {'index': '$const56.25', 'target': '$b54.24', 'res': '$58binary_subscr.26'}), (60, {'lhs': '$52binary_subscr.23', 'rhs': '$58binary_subscr.26', 'res': '$60binary_multiply.27'}), (62, {'res': '$a62.28'}), (64, {'res': '$const64.29'}), (66, {'index': '$const64.29', 'target': '$a62.28', 'res': '$66binary_subscr.30'}), (68, {'res': '$b68.31'}), (70, {'res': '$const70.32'}), (72, {'index': '$const70.32', 'target': '$b68.31', 'res': '$72binary_subscr.33'}), (74, {'lhs': '$66binary_subscr.30', 'rhs': '$72binary_subscr.33', 'res': '$74binary_multiply.34'}), (76, {'lhs': '$60binary_multiply.27', 'rhs': '$74binary_multiply.34', 'res': '$76binary_subtract.35'}), (78, {'res': '$c78.36'}), (80, {'res': '$const80.37'}), (82, {'target': '$c78.36', 'index': '$const80.37', 'value': '$76binary_subtract.35'}), (84, {'res': '$a84.38'}), (86, {'res': '$const86.39'}), (88, {'index': '$const86.39', 'target': '$a84.38', 'res': '$88binary_subscr.40'}), (90, {'res': '$b90.41'}), (92, {'res': '$const92.42'}), (94, {'index': '$const92.42', 'target': '$b90.41', 'res': '$94binary_subscr.43'}), (96, {'lhs': '$88binary_subscr.40', 'rhs': '$94binary_subscr.43', 'res': '$96binary_multiply.44'}), (98, {'res': '$a98.45'}), (100, {'res': '$const100.46'}), (102, {'index': '$const100.46', 'target': '$a98.45', 'res': '$102binary_subscr.47'}), (104, {'res': '$b104.48'}), (106, {'res': '$const106.49'}), (108, {'index': '$const106.49', 'target': '$b104.48', 'res': '$108binary_subscr.50'}), (110, {'lhs': '$102binary_subscr.47', 'rhs': '$108binary_subscr.50', 'res': '$110binary_multiply.51'}), (112, {'lhs': '$96binary_multiply.44', 'rhs': '$110binary_multiply.51', 'res': '$112binary_subtract.52'}), (114, {'res': '$c114.53'}), (116, {'res': '$const116.54'}), (118, {'target': '$c114.53', 'index': '$const116.54', 'value': '$112binary_subtract.52'}), (120, {'res': '$c120.55'}), (122, {'retval': '$c120.55', 'castval': '$122return_value.56'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     a = arg(0, name=a)                       ['a']
#     b = arg(1, name=b)                       ['b']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=zeros) ['$2load_global.0', '$4load_method.1']
#     $const6.2 = const(int, 3)                ['$const6.2']
#     $8call_method.3 = call $4load_method.1($const6.2, func=$4load_method.1, args=[Var($const6.2, coordinate_numba.py:6)], kws=(), vararg=None) ['$4load_method.1', '$8call_method.3', '$const6.2']
#     c = $8call_method.3                      ['$8call_method.3', 'c']
#     $const14.5 = const(int, 1)               ['$const14.5']
#     $16binary_subscr.6 = getitem(value=a, index=$const14.5) ['$16binary_subscr.6', '$const14.5', 'a']
#     $const20.8 = const(int, 2)               ['$const20.8']
#     $22binary_subscr.9 = getitem(value=b, index=$const20.8) ['$22binary_subscr.9', '$const20.8', 'b']
#     $24binary_multiply.10 = $16binary_subscr.6 * $22binary_subscr.9 ['$16binary_subscr.6', '$22binary_subscr.9', '$24binary_multiply.10']
#     $const28.12 = const(int, 2)              ['$const28.12']
#     $30binary_subscr.13 = getitem(value=a, index=$const28.12) ['$30binary_subscr.13', '$const28.12', 'a']
#     $const34.15 = const(int, 1)              ['$const34.15']
#     $36binary_subscr.16 = getitem(value=b, index=$const34.15) ['$36binary_subscr.16', '$const34.15', 'b']
#     $38binary_multiply.17 = $30binary_subscr.13 * $36binary_subscr.16 ['$30binary_subscr.13', '$36binary_subscr.16', '$38binary_multiply.17']
#     $40binary_subtract.18 = $24binary_multiply.10 - $38binary_multiply.17 ['$24binary_multiply.10', '$38binary_multiply.17', '$40binary_subtract.18']
#     $const44.20 = const(int, 0)              ['$const44.20']
#     c[$const44.20] = $40binary_subtract.18   ['$40binary_subtract.18', '$const44.20', 'c']
#     $const50.22 = const(int, 2)              ['$const50.22']
#     $52binary_subscr.23 = getitem(value=a, index=$const50.22) ['$52binary_subscr.23', '$const50.22', 'a']
#     $const56.25 = const(int, 0)              ['$const56.25']
#     $58binary_subscr.26 = getitem(value=b, index=$const56.25) ['$58binary_subscr.26', '$const56.25', 'b']
#     $60binary_multiply.27 = $52binary_subscr.23 * $58binary_subscr.26 ['$52binary_subscr.23', '$58binary_subscr.26', '$60binary_multiply.27']
#     $const64.29 = const(int, 0)              ['$const64.29']
#     $66binary_subscr.30 = getitem(value=a, index=$const64.29) ['$66binary_subscr.30', '$const64.29', 'a']
#     $const70.32 = const(int, 2)              ['$const70.32']
#     $72binary_subscr.33 = getitem(value=b, index=$const70.32) ['$72binary_subscr.33', '$const70.32', 'b']
#     $74binary_multiply.34 = $66binary_subscr.30 * $72binary_subscr.33 ['$66binary_subscr.30', '$72binary_subscr.33', '$74binary_multiply.34']
#     $76binary_subtract.35 = $60binary_multiply.27 - $74binary_multiply.34 ['$60binary_multiply.27', '$74binary_multiply.34', '$76binary_subtract.35']
#     $const80.37 = const(int, 1)              ['$const80.37']
#     c[$const80.37] = $76binary_subtract.35   ['$76binary_subtract.35', '$const80.37', 'c']
#     $const86.39 = const(int, 0)              ['$const86.39']
#     $88binary_subscr.40 = getitem(value=a, index=$const86.39) ['$88binary_subscr.40', '$const86.39', 'a']
#     $const92.42 = const(int, 1)              ['$const92.42']
#     $94binary_subscr.43 = getitem(value=b, index=$const92.42) ['$94binary_subscr.43', '$const92.42', 'b']
#     $96binary_multiply.44 = $88binary_subscr.40 * $94binary_subscr.43 ['$88binary_subscr.40', '$94binary_subscr.43', '$96binary_multiply.44']
#     $const100.46 = const(int, 1)             ['$const100.46']
#     $102binary_subscr.47 = getitem(value=a, index=$const100.46) ['$102binary_subscr.47', '$const100.46', 'a']
#     $const106.49 = const(int, 0)             ['$const106.49']
#     $108binary_subscr.50 = getitem(value=b, index=$const106.49) ['$108binary_subscr.50', '$const106.49', 'b']
#     $110binary_multiply.51 = $102binary_subscr.47 * $108binary_subscr.50 ['$102binary_subscr.47', '$108binary_subscr.50', '$110binary_multiply.51']
#     $112binary_subtract.52 = $96binary_multiply.44 - $110binary_multiply.51 ['$110binary_multiply.51', '$112binary_subtract.52', '$96binary_multiply.44']
#     $const116.54 = const(int, 2)             ['$const116.54']
#     c[$const116.54] = $112binary_subtract.52 ['$112binary_subtract.52', '$const116.54', 'c']
#     $122return_value.56 = cast(value=c)      ['$122return_value.56', 'c']
#     return $122return_value.56               ['$122return_value.56']
#
# DEBUG:numba.core.ssa:-----------------------------------BEFORE SSA-----------------------------------
# DEBUG:numba.core.ssa:label 0:
#     a = arg(0, name=a)                       ['a']
#     b = arg(1, name=b)                       ['b']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=zeros) ['$2load_global.0', '$4load_method.1']
#     $const6.2 = const(int, 3)                ['$const6.2']
#     $8call_method.3 = call $4load_method.1($const6.2, func=$4load_method.1, args=[Var($const6.2, coordinate_numba.py:6)], kws=(), vararg=None) ['$4load_method.1', '$8call_method.3', '$const6.2']
#     c = $8call_method.3                      ['$8call_method.3', 'c']
#     $const14.5 = const(int, 1)               ['$const14.5']
#     $16binary_subscr.6 = static_getitem(value=a, index=1, index_var=$const14.5) ['$16binary_subscr.6', '$const14.5', 'a']
#     $const20.8 = const(int, 2)               ['$const20.8']
#     $22binary_subscr.9 = static_getitem(value=b, index=2, index_var=$const20.8) ['$22binary_subscr.9', '$const20.8', 'b']
#     $24binary_multiply.10 = $16binary_subscr.6 * $22binary_subscr.9 ['$16binary_subscr.6', '$22binary_subscr.9', '$24binary_multiply.10']
#     $const28.12 = const(int, 2)              ['$const28.12']
#     $30binary_subscr.13 = static_getitem(value=a, index=2, index_var=$const28.12) ['$30binary_subscr.13', '$const28.12', 'a']
#     $const34.15 = const(int, 1)              ['$const34.15']
#     $36binary_subscr.16 = static_getitem(value=b, index=1, index_var=$const34.15) ['$36binary_subscr.16', '$const34.15', 'b']
#     $38binary_multiply.17 = $30binary_subscr.13 * $36binary_subscr.16 ['$30binary_subscr.13', '$36binary_subscr.16', '$38binary_multiply.17']
#     $40binary_subtract.18 = $24binary_multiply.10 - $38binary_multiply.17 ['$24binary_multiply.10', '$38binary_multiply.17', '$40binary_subtract.18']
#     $const44.20 = const(int, 0)              ['$const44.20']
#     c[0] = $40binary_subtract.18             ['$40binary_subtract.18', '$const44.20', 'c']
#     $const50.22 = const(int, 2)              ['$const50.22']
#     $52binary_subscr.23 = static_getitem(value=a, index=2, index_var=$const50.22) ['$52binary_subscr.23', '$const50.22', 'a']
#     $const56.25 = const(int, 0)              ['$const56.25']
#     $58binary_subscr.26 = static_getitem(value=b, index=0, index_var=$const56.25) ['$58binary_subscr.26', '$const56.25', 'b']
#     $60binary_multiply.27 = $52binary_subscr.23 * $58binary_subscr.26 ['$52binary_subscr.23', '$58binary_subscr.26', '$60binary_multiply.27']
#     $const64.29 = const(int, 0)              ['$const64.29']
#     $66binary_subscr.30 = static_getitem(value=a, index=0, index_var=$const64.29) ['$66binary_subscr.30', '$const64.29', 'a']
#     $const70.32 = const(int, 2)              ['$const70.32']
#     $72binary_subscr.33 = static_getitem(value=b, index=2, index_var=$const70.32) ['$72binary_subscr.33', '$const70.32', 'b']
#     $74binary_multiply.34 = $66binary_subscr.30 * $72binary_subscr.33 ['$66binary_subscr.30', '$72binary_subscr.33', '$74binary_multiply.34']
#     $76binary_subtract.35 = $60binary_multiply.27 - $74binary_multiply.34 ['$60binary_multiply.27', '$74binary_multiply.34', '$76binary_subtract.35']
#     $const80.37 = const(int, 1)              ['$const80.37']
#     c[1] = $76binary_subtract.35             ['$76binary_subtract.35', '$const80.37', 'c']
#     $const86.39 = const(int, 0)              ['$const86.39']
#     $88binary_subscr.40 = static_getitem(value=a, index=0, index_var=$const86.39) ['$88binary_subscr.40', '$const86.39', 'a']
#     $const92.42 = const(int, 1)              ['$const92.42']
#     $94binary_subscr.43 = static_getitem(value=b, index=1, index_var=$const92.42) ['$94binary_subscr.43', '$const92.42', 'b']
#     $96binary_multiply.44 = $88binary_subscr.40 * $94binary_subscr.43 ['$88binary_subscr.40', '$94binary_subscr.43', '$96binary_multiply.44']
#     $const100.46 = const(int, 1)             ['$const100.46']
#     $102binary_subscr.47 = static_getitem(value=a, index=1, index_var=$const100.46) ['$102binary_subscr.47', '$const100.46', 'a']
#     $const106.49 = const(int, 0)             ['$const106.49']
#     $108binary_subscr.50 = static_getitem(value=b, index=0, index_var=$const106.49) ['$108binary_subscr.50', '$const106.49', 'b']
#     $110binary_multiply.51 = $102binary_subscr.47 * $108binary_subscr.50 ['$102binary_subscr.47', '$108binary_subscr.50', '$110binary_multiply.51']
#     $112binary_subtract.52 = $96binary_multiply.44 - $110binary_multiply.51 ['$110binary_multiply.51', '$112binary_subtract.52', '$96binary_multiply.44']
#     $const116.54 = const(int, 2)             ['$const116.54']
#     c[2] = $112binary_subtract.52            ['$112binary_subtract.52', '$const116.54', 'c']
#     $122return_value.56 = cast(value=c)      ['$122return_value.56', 'c']
#     return $122return_value.56               ['$122return_value.56']
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b7cd16f4ef0>
# DEBUG:numba.core.ssa:on stmt: a = arg(0, name=a)
# DEBUG:numba.core.ssa:on stmt: b = arg(1, name=b)
# DEBUG:numba.core.ssa:on stmt: $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $4load_method.1 = getattr(value=$2load_global.0, attr=zeros)
# DEBUG:numba.core.ssa:on stmt: $const6.2 = const(int, 3)
# DEBUG:numba.core.ssa:on stmt: $8call_method.3 = call $4load_method.1($const6.2, func=$4load_method.1, args=[Var($const6.2, coordinate_numba.py:6)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: c = $8call_method.3
# DEBUG:numba.core.ssa:on stmt: $const14.5 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $16binary_subscr.6 = static_getitem(value=a, index=1, index_var=$const14.5)
# DEBUG:numba.core.ssa:on stmt: $const20.8 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $22binary_subscr.9 = static_getitem(value=b, index=2, index_var=$const20.8)
# DEBUG:numba.core.ssa:on stmt: $24binary_multiply.10 = $16binary_subscr.6 * $22binary_subscr.9
# DEBUG:numba.core.ssa:on stmt: $const28.12 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $30binary_subscr.13 = static_getitem(value=a, index=2, index_var=$const28.12)
# DEBUG:numba.core.ssa:on stmt: $const34.15 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $36binary_subscr.16 = static_getitem(value=b, index=1, index_var=$const34.15)
# DEBUG:numba.core.ssa:on stmt: $38binary_multiply.17 = $30binary_subscr.13 * $36binary_subscr.16
# DEBUG:numba.core.ssa:on stmt: $40binary_subtract.18 = $24binary_multiply.10 - $38binary_multiply.17
# DEBUG:numba.core.ssa:on stmt: $const44.20 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: c[0] = $40binary_subtract.18
# DEBUG:numba.core.ssa:on stmt: $const50.22 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $52binary_subscr.23 = static_getitem(value=a, index=2, index_var=$const50.22)
# DEBUG:numba.core.ssa:on stmt: $const56.25 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $58binary_subscr.26 = static_getitem(value=b, index=0, index_var=$const56.25)
# DEBUG:numba.core.ssa:on stmt: $60binary_multiply.27 = $52binary_subscr.23 * $58binary_subscr.26
# DEBUG:numba.core.ssa:on stmt: $const64.29 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $66binary_subscr.30 = static_getitem(value=a, index=0, index_var=$const64.29)
# DEBUG:numba.core.ssa:on stmt: $const70.32 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $72binary_subscr.33 = static_getitem(value=b, index=2, index_var=$const70.32)
# DEBUG:numba.core.ssa:on stmt: $74binary_multiply.34 = $66binary_subscr.30 * $72binary_subscr.33
# DEBUG:numba.core.ssa:on stmt: $76binary_subtract.35 = $60binary_multiply.27 - $74binary_multiply.34
# DEBUG:numba.core.ssa:on stmt: $const80.37 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: c[1] = $76binary_subtract.35
# DEBUG:numba.core.ssa:on stmt: $const86.39 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $88binary_subscr.40 = static_getitem(value=a, index=0, index_var=$const86.39)
# DEBUG:numba.core.ssa:on stmt: $const92.42 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $94binary_subscr.43 = static_getitem(value=b, index=1, index_var=$const92.42)
# DEBUG:numba.core.ssa:on stmt: $96binary_multiply.44 = $88binary_subscr.40 * $94binary_subscr.43
# DEBUG:numba.core.ssa:on stmt: $const100.46 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $102binary_subscr.47 = static_getitem(value=a, index=1, index_var=$const100.46)
# DEBUG:numba.core.ssa:on stmt: $const106.49 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $108binary_subscr.50 = static_getitem(value=b, index=0, index_var=$const106.49)
# DEBUG:numba.core.ssa:on stmt: $110binary_multiply.51 = $102binary_subscr.47 * $108binary_subscr.50
# DEBUG:numba.core.ssa:on stmt: $112binary_subtract.52 = $96binary_multiply.44 - $110binary_multiply.51
# DEBUG:numba.core.ssa:on stmt: $const116.54 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: c[2] = $112binary_subtract.52
# DEBUG:numba.core.ssa:on stmt: $122return_value.56 = cast(value=c)
# DEBUG:numba.core.ssa:on stmt: return $122return_value.56
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$102binary_subscr.47': [<numba.core.ir.Assign object at 0x2b7cd174a860>],
#              '$108binary_subscr.50': [<numba.core.ir.Assign object at 0x2b7cd174a8d0>],
#              '$110binary_multiply.51': [<numba.core.ir.Assign object at 0x2b7cd174a0b8>],
#              '$112binary_subtract.52': [<numba.core.ir.Assign object at 0x2b7cd174a198>],
#              '$122return_value.56': [<numba.core.ir.Assign object at 0x2b7cd174a4e0>],
#              '$16binary_subscr.6': [<numba.core.ir.Assign object at 0x2b7cd17368d0>],
#              '$22binary_subscr.9': [<numba.core.ir.Assign object at 0x2b7cd1736e80>],
#              '$24binary_multiply.10': [<numba.core.ir.Assign object at 0x2b7cd1736dd8>],
#              '$2load_global.0': [<numba.core.ir.Assign object at 0x2b7cd17364e0>],
#              '$30binary_subscr.13': [<numba.core.ir.Assign object at 0x2b7cd174a240>],
#              '$36binary_subscr.16': [<numba.core.ir.Assign object at 0x2b7cd174a550>],
#              '$38binary_multiply.17': [<numba.core.ir.Assign object at 0x2b7cd17423c8>],
#              '$40binary_subtract.18': [<numba.core.ir.Assign object at 0x2b7cd17424a8>],
#              '$4load_method.1': [<numba.core.ir.Assign object at 0x2b7cd17365c0>],
#              '$52binary_subscr.23': [<numba.core.ir.Assign object at 0x2b7cd174a5c0>],
#              '$58binary_subscr.26': [<numba.core.ir.Assign object at 0x2b7cd174a630>],
#              '$60binary_multiply.27': [<numba.core.ir.Assign object at 0x2b7cd1742c50>],
#              '$66binary_subscr.30': [<numba.core.ir.Assign object at 0x2b7cd174a6a0>],
#              '$72binary_subscr.33': [<numba.core.ir.Assign object at 0x2b7cd174a710>],
#              '$74binary_multiply.34': [<numba.core.ir.Assign object at 0x2b7cd1745240>],
#              '$76binary_subtract.35': [<numba.core.ir.Assign object at 0x2b7cd1745320>],
#              '$88binary_subscr.40': [<numba.core.ir.Assign object at 0x2b7cd174a780>],
#              '$8call_method.3': [<numba.core.ir.Assign object at 0x2b7cd1736780>],
#              '$94binary_subscr.43': [<numba.core.ir.Assign object at 0x2b7cd174a7f0>],
#              '$96binary_multiply.44': [<numba.core.ir.Assign object at 0x2b7cd1745ac8>],
#              '$const100.46': [<numba.core.ir.Assign object at 0x2b7cd1745c50>],
#              '$const106.49': [<numba.core.ir.Assign object at 0x2b7cd1745eb8>],
#              '$const116.54': [<numba.core.ir.Assign object at 0x2b7cd174a320>],
#              '$const14.5': [<numba.core.ir.Assign object at 0x2b7cd17369b0>],
#              '$const20.8': [<numba.core.ir.Assign object at 0x2b7cd1736c18>],
#              '$const28.12': [<numba.core.ir.Assign object at 0x2b7cd1736f60>],
#              '$const34.15': [<numba.core.ir.Assign object at 0x2b7cd1742208>],
#              '$const44.20': [<numba.core.ir.Assign object at 0x2b7cd1742630>],
#              '$const50.22': [<numba.core.ir.Assign object at 0x2b7cd1742828>],
#              '$const56.25': [<numba.core.ir.Assign object at 0x2b7cd1742a90>],
#              '$const6.2': [<numba.core.ir.Assign object at 0x2b7cd17366a0>],
#              '$const64.29': [<numba.core.ir.Assign object at 0x2b7cd1742dd8>],
#              '$const70.32': [<numba.core.ir.Assign object at 0x2b7cd1745080>],
#              '$const80.37': [<numba.core.ir.Assign object at 0x2b7cd17454a8>],
#              '$const86.39': [<numba.core.ir.Assign object at 0x2b7cd17456a0>],
#              '$const92.42': [<numba.core.ir.Assign object at 0x2b7cd1745908>],
#              'a': [<numba.core.ir.Assign object at 0x2b7cd1736320>],
#              'b': [<numba.core.ir.Assign object at 0x2b7cd17363c8>],
#              'c': [<numba.core.ir.Assign object at 0x2b7cd1736828>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     a = arg(0, name=a)                       ['a']
#     b = arg(1, name=b)                       ['b']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=zeros) ['$2load_global.0', '$4load_method.1']
#     $const6.2 = const(int, 3)                ['$const6.2']
#     $8call_method.3 = call $4load_method.1($const6.2, func=$4load_method.1, args=[Var($const6.2, coordinate_numba.py:6)], kws=(), vararg=None) ['$4load_method.1', '$8call_method.3', '$const6.2']
#     c = $8call_method.3                      ['$8call_method.3', 'c']
#     $const14.5 = const(int, 1)               ['$const14.5']
#     $16binary_subscr.6 = static_getitem(value=a, index=1, index_var=$const14.5) ['$16binary_subscr.6', '$const14.5', 'a']
#     $const20.8 = const(int, 2)               ['$const20.8']
#     $22binary_subscr.9 = static_getitem(value=b, index=2, index_var=$const20.8) ['$22binary_subscr.9', '$const20.8', 'b']
#     $24binary_multiply.10 = $16binary_subscr.6 * $22binary_subscr.9 ['$16binary_subscr.6', '$22binary_subscr.9', '$24binary_multiply.10']
#     $const28.12 = const(int, 2)              ['$const28.12']
#     $30binary_subscr.13 = static_getitem(value=a, index=2, index_var=$const28.12) ['$30binary_subscr.13', '$const28.12', 'a']
#     $const34.15 = const(int, 1)              ['$const34.15']
#     $36binary_subscr.16 = static_getitem(value=b, index=1, index_var=$const34.15) ['$36binary_subscr.16', '$const34.15', 'b']
#     $38binary_multiply.17 = $30binary_subscr.13 * $36binary_subscr.16 ['$30binary_subscr.13', '$36binary_subscr.16', '$38binary_multiply.17']
#     $40binary_subtract.18 = $24binary_multiply.10 - $38binary_multiply.17 ['$24binary_multiply.10', '$38binary_multiply.17', '$40binary_subtract.18']
#     $const44.20 = const(int, 0)              ['$const44.20']
#     c[0] = $40binary_subtract.18             ['$40binary_subtract.18', '$const44.20', 'c']
#     $const50.22 = const(int, 2)              ['$const50.22']
#     $52binary_subscr.23 = static_getitem(value=a, index=2, index_var=$const50.22) ['$52binary_subscr.23', '$const50.22', 'a']
#     $const56.25 = const(int, 0)              ['$const56.25']
#     $58binary_subscr.26 = static_getitem(value=b, index=0, index_var=$const56.25) ['$58binary_subscr.26', '$const56.25', 'b']
#     $60binary_multiply.27 = $52binary_subscr.23 * $58binary_subscr.26 ['$52binary_subscr.23', '$58binary_subscr.26', '$60binary_multiply.27']
#     $const64.29 = const(int, 0)              ['$const64.29']
#     $66binary_subscr.30 = static_getitem(value=a, index=0, index_var=$const64.29) ['$66binary_subscr.30', '$const64.29', 'a']
#     $const70.32 = const(int, 2)              ['$const70.32']
#     $72binary_subscr.33 = static_getitem(value=b, index=2, index_var=$const70.32) ['$72binary_subscr.33', '$const70.32', 'b']
#     $74binary_multiply.34 = $66binary_subscr.30 * $72binary_subscr.33 ['$66binary_subscr.30', '$72binary_subscr.33', '$74binary_multiply.34']
#     $76binary_subtract.35 = $60binary_multiply.27 - $74binary_multiply.34 ['$60binary_multiply.27', '$74binary_multiply.34', '$76binary_subtract.35']
#     $const80.37 = const(int, 1)              ['$const80.37']
#     c[1] = $76binary_subtract.35             ['$76binary_subtract.35', '$const80.37', 'c']
#     $const86.39 = const(int, 0)              ['$const86.39']
#     $88binary_subscr.40 = static_getitem(value=a, index=0, index_var=$const86.39) ['$88binary_subscr.40', '$const86.39', 'a']
#     $const92.42 = const(int, 1)              ['$const92.42']
#     $94binary_subscr.43 = static_getitem(value=b, index=1, index_var=$const92.42) ['$94binary_subscr.43', '$const92.42', 'b']
#     $96binary_multiply.44 = $88binary_subscr.40 * $94binary_subscr.43 ['$88binary_subscr.40', '$94binary_subscr.43', '$96binary_multiply.44']
#     $const100.46 = const(int, 1)             ['$const100.46']
#     $102binary_subscr.47 = static_getitem(value=a, index=1, index_var=$const100.46) ['$102binary_subscr.47', '$const100.46', 'a']
#     $const106.49 = const(int, 0)             ['$const106.49']
#     $108binary_subscr.50 = static_getitem(value=b, index=0, index_var=$const106.49) ['$108binary_subscr.50', '$const106.49', 'b']
#     $110binary_multiply.51 = $102binary_subscr.47 * $108binary_subscr.50 ['$102binary_subscr.47', '$108binary_subscr.50', '$110binary_multiply.51']
#     $112binary_subtract.52 = $96binary_multiply.44 - $110binary_multiply.51 ['$110binary_multiply.51', '$112binary_subtract.52', '$96binary_multiply.44']
#     $const116.54 = const(int, 2)             ['$const116.54']
#     c[2] = $112binary_subtract.52            ['$112binary_subtract.52', '$const116.54', 'c']
#     $122return_value.56 = cast(value=c)      ['$122return_value.56', 'c']
#     return $122return_value.56               ['$122return_value.56']
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=14)
#            2	LOAD_GLOBAL(arg=0, lineno=14)
#            4	LOAD_METHOD(arg=1, lineno=14)
#            6	LOAD_FAST(arg=0, lineno=14)
#            8	LOAD_FAST(arg=0, lineno=14)
#           10	CALL_METHOD(arg=2, lineno=14)
#           12	STORE_FAST(arg=1, lineno=14)
#           14	LOAD_GLOBAL(arg=0, lineno=15)
#           16	LOAD_METHOD(arg=2, lineno=15)
#           18	LOAD_FAST(arg=1, lineno=15)
#           20	CALL_METHOD(arg=1, lineno=15)
#           22	RETURN_VALUE(arg=None, lineno=15)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=14)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_GLOBAL(arg=0, lineno=14)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_METHOD(arg=1, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$2load_global.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=LOAD_FAST(arg=0, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$4load_method.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=LOAD_FAST(arg=0, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$4load_method.1', '$a6.2']
# DEBUG:numba.core.byteflow:dispatch pc=10, inst=CALL_METHOD(arg=2, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$4load_method.1', '$a6.2', '$a8.3']
# DEBUG:numba.core.byteflow:dispatch pc=12, inst=STORE_FAST(arg=1, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$10call_method.4']
# DEBUG:numba.core.byteflow:dispatch pc=14, inst=LOAD_GLOBAL(arg=0, lineno=15)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=16, inst=LOAD_METHOD(arg=2, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$14load_global.5']
# DEBUG:numba.core.byteflow:dispatch pc=18, inst=LOAD_FAST(arg=1, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$16load_method.6']
# DEBUG:numba.core.byteflow:dispatch pc=20, inst=CALL_METHOD(arg=1, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$16load_method.6', '$n_218.7']
# DEBUG:numba.core.byteflow:dispatch pc=22, inst=RETURN_VALUE(arg=None, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$20call_method.8']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$2load_global.0'}), (4, {'item': '$2load_global.0', 'res': '$4load_method.1'}), (6, {'res': '$a6.2'}), (8, {'res': '$a8.3'}), (10, {'func': '$4load_method.1', 'args': ['$a6.2', '$a8.3'], 'res': '$10call_method.4'}), (12, {'value': '$10call_method.4'}), (14, {'res': '$14load_global.5'}), (16, {'item': '$14load_global.5', 'res': '$16load_method.6'}), (18, {'res': '$n_218.7'}), (20, {'func': '$16load_method.6', 'args': ['$n_218.7'], 'res': '$20call_method.8'}), (22, {'retval': '$20call_method.8', 'castval': '$22return_value.9'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     a = arg(0, name=a)                       ['a']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=dot) ['$2load_global.0', '$4load_method.1']
#     $10call_method.4 = call $4load_method.1(a, a, func=$4load_method.1, args=[Var(a, coordinate_numba.py:14), Var(a, coordinate_numba.py:14)], kws=(), vararg=None) ['$10call_method.4', '$4load_method.1', 'a', 'a']
#     n_2 = $10call_method.4                   ['$10call_method.4', 'n_2']
#     $14load_global.5 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$14load_global.5']
#     $16load_method.6 = getattr(value=$14load_global.5, attr=sqrt) ['$14load_global.5', '$16load_method.6']
#     $20call_method.8 = call $16load_method.6(n_2, func=$16load_method.6, args=[Var(n_2, coordinate_numba.py:14)], kws=(), vararg=None) ['$16load_method.6', '$20call_method.8', 'n_2']
#     $22return_value.9 = cast(value=$20call_method.8) ['$20call_method.8', '$22return_value.9']
#     return $22return_value.9                 ['$22return_value.9']
#
# DEBUG:numba.core.ssa:-----------------------------------BEFORE SSA-----------------------------------
# DEBUG:numba.core.ssa:label 0:
#     a = arg(0, name=a)                       ['a']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=dot) ['$2load_global.0', '$4load_method.1']
#     $10call_method.4 = call $4load_method.1(a, a, func=$4load_method.1, args=[Var(a, coordinate_numba.py:14), Var(a, coordinate_numba.py:14)], kws=(), vararg=None) ['$10call_method.4', '$4load_method.1', 'a', 'a']
#     n_2 = $10call_method.4                   ['$10call_method.4', 'n_2']
#     $14load_global.5 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$14load_global.5']
#     $16load_method.6 = getattr(value=$14load_global.5, attr=sqrt) ['$14load_global.5', '$16load_method.6']
#     $20call_method.8 = call $16load_method.6(n_2, func=$16load_method.6, args=[Var(n_2, coordinate_numba.py:14)], kws=(), vararg=None) ['$16load_method.6', '$20call_method.8', 'n_2']
#     $22return_value.9 = cast(value=$20call_method.8) ['$20call_method.8', '$22return_value.9']
#     return $22return_value.9                 ['$22return_value.9']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b7cd174af98>
# DEBUG:numba.core.ssa:on stmt: a = arg(0, name=a)
# DEBUG:numba.core.ssa:on stmt: $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $4load_method.1 = getattr(value=$2load_global.0, attr=dot)
# DEBUG:numba.core.ssa:on stmt: $10call_method.4 = call $4load_method.1(a, a, func=$4load_method.1, args=[Var(a, coordinate_numba.py:14), Var(a, coordinate_numba.py:14)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: n_2 = $10call_method.4
# DEBUG:numba.core.ssa:on stmt: $14load_global.5 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $16load_method.6 = getattr(value=$14load_global.5, attr=sqrt)
# DEBUG:numba.core.ssa:on stmt: $20call_method.8 = call $16load_method.6(n_2, func=$16load_method.6, args=[Var(n_2, coordinate_numba.py:14)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: $22return_value.9 = cast(value=$20call_method.8)
# DEBUG:numba.core.ssa:on stmt: return $22return_value.9
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$10call_method.4': [<numba.core.ir.Assign object at 0x2b7cd17bfa20>],
#              '$14load_global.5': [<numba.core.ir.Assign object at 0x2b7cd17bfba8>],
#              '$16load_method.6': [<numba.core.ir.Assign object at 0x2b7cd17bfc88>],
#              '$20call_method.8': [<numba.core.ir.Assign object at 0x2b7cd17bff28>],
#              '$22return_value.9': [<numba.core.ir.Assign object at 0x2b7cd17bf518>],
#              '$2load_global.0': [<numba.core.ir.Assign object at 0x2b7cd17bf710>],
#              '$4load_method.1': [<numba.core.ir.Assign object at 0x2b7cd17bf7f0>],
#              'a': [<numba.core.ir.Assign object at 0x2b7cd17bf5f8>],
#              'n_2': [<numba.core.ir.Assign object at 0x2b7cd17bfac8>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     a = arg(0, name=a)                       ['a']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=dot) ['$2load_global.0', '$4load_method.1']
# ...
# DEBUG:numba.core.ssa:on stmt: angle_position_2 = arg(0, name=angle_position_2)
# DEBUG:numba.core.ssa:on stmt: torsion_position_1 = arg(1, name=torsion_position_1)
# DEBUG:numba.core.ssa:on stmt: $6binary_subtract.2 = angle_position_2 - torsion_position_1
# DEBUG:numba.core.ssa:on stmt: $8return_value.3 = cast(value=$6binary_subtract.2)
# DEBUG:numba.core.ssa:on stmt: return $8return_value.3
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$6binary_subtract.2': [<numba.core.ir.Assign object at 0x2b7cd1f6f3c8>],
#              '$8return_value.3': [<numba.core.ir.Assign object at 0x2b7cd1f6f470>],
#              'angle_position_2': [<numba.core.ir.Assign object at 0x2b7cd1f6f0b8>],
#              'torsion_position_1': [<numba.core.ir.Assign object at 0x2b7cd1f6f160>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     angle_position_2 = arg(0, name=angle_position_2) ['angle_position_2']
#     torsion_position_1 = arg(1, name=torsion_position_1) ['torsion_position_1']
#     $6binary_subtract.2 = angle_position_2 - torsion_position_1 ['$6binary_subtract.2', 'angle_position_2', 'torsion_position_1']
#     $8return_value.3 = cast(value=$6binary_subtract.2) ['$6binary_subtract.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=106)
#            2	LOAD_FAST(arg=1, lineno=106)
#            4	LOAD_FAST(arg=0, lineno=110)
#            6	BINARY_TRUE_DIVIDE(arg=None, lineno=110)
#            8	RETURN_VALUE(arg=None, lineno=110)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=106)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_FAST(arg=1, lineno=106)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_FAST(arg=0, lineno=110)
# DEBUG:numba.core.byteflow:stack ['$a_12.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=BINARY_TRUE_DIVIDE(arg=None, lineno=110)
# DEBUG:numba.core.byteflow:stack ['$a_12.0', '$_32call_function_12_14.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=RETURN_VALUE(arg=None, lineno=110)
# DEBUG:numba.core.byteflow:stack ['$6binary_true_divide.2']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$a_12.0'}), (4, {'res': '$_32call_function_12_14.1'}), (6, {'lhs': '$a_12.0', 'rhs': '$_32call_function_12_14.1', 'res': '$6binary_true_divide.2'}), (8, {'retval': '$6binary_true_divide.2', 'castval': '$8return_value.3'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     _32call_function_12_1 = arg(0, name=_32call_function_12_1) ['_32call_function_12_1']
#     a_1 = arg(1, name=a_1)                   ['a_1']
#     $6binary_true_divide.2 = a_1 / _32call_function_12_1 ['$6binary_true_divide.2', '_32call_function_12_1', 'a_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:-----------------------------------BEFORE SSA-----------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _32call_function_12_1 = arg(0, name=_32call_function_12_1) ['_32call_function_12_1']
#     a_1 = arg(1, name=a_1)                   ['a_1']
#     $6binary_true_divide.2 = a_1 / _32call_function_12_1 ['$6binary_true_divide.2', '_32call_function_12_1', 'a_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b7cd1837e80>
# DEBUG:numba.core.ssa:on stmt: _32call_function_12_1 = arg(0, name=_32call_function_12_1)
# DEBUG:numba.core.ssa:on stmt: a_1 = arg(1, name=a_1)
# DEBUG:numba.core.ssa:on stmt: $6binary_true_divide.2 = a_1 / _32call_function_12_1
# DEBUG:numba.core.ssa:on stmt: $8return_value.3 = cast(value=$6binary_true_divide.2)
# DEBUG:numba.core.ssa:on stmt: return $8return_value.3
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$6binary_true_divide.2': [<numba.core.ir.Assign object at 0x2b7cd18379e8>],
#              '$8return_value.3': [<numba.core.ir.Assign object at 0x2b7cd1837a90>],
#              '_32call_function_12_1': [<numba.core.ir.Assign object at 0x2b7cd18376d8>],
#              'a_1': [<numba.core.ir.Assign object at 0x2b7cd1837780>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _32call_function_12_1 = arg(0, name=_32call_function_12_1) ['_32call_function_12_1']
#     a_1 = arg(1, name=a_1)                   ['a_1']
#     $6binary_true_divide.2 = a_1 / _32call_function_12_1 ['$6binary_true_divide.2', '_32call_function_12_1', 'a_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=107)
#            2	LOAD_FAST(arg=1, lineno=107)
#            4	LOAD_FAST(arg=0, lineno=111)
#            6	BINARY_TRUE_DIVIDE(arg=None, lineno=111)
#            8	RETURN_VALUE(arg=None, lineno=111)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=107)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_FAST(arg=1, lineno=107)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_FAST(arg=0, lineno=111)
# DEBUG:numba.core.byteflow:stack ['$b_12.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=BINARY_TRUE_DIVIDE(arg=None, lineno=111)
# DEBUG:numba.core.byteflow:stack ['$b_12.0', '$_44call_function_17_14.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=RETURN_VALUE(arg=None, lineno=111)
# DEBUG:numba.core.byteflow:stack ['$6binary_true_divide.2']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$b_12.0'}), (4, {'res': '$_44call_function_17_14.1'}), (6, {'lhs': '$b_12.0', 'rhs': '$_44call_function_17_14.1', 'res': '$6binary_true_divide.2'}), (8, {'retval': '$6binary_true_divide.2', 'castval': '$8return_value.3'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     _44call_function_17_1 = arg(0, name=_44call_function_17_1) ['_44call_function_17_1']
#     b_1 = arg(1, name=b_1)                   ['b_1']
#     $6binary_true_divide.2 = b_1 / _44call_function_17_1 ['$6binary_true_divide.2', '_44call_function_17_1', 'b_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:-----------------------------------BEFORE SSA-----------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _44call_function_17_1 = arg(0, name=_44call_function_17_1) ['_44call_function_17_1']
#     b_1 = arg(1, name=b_1)                   ['b_1']
#     $6binary_true_divide.2 = b_1 / _44call_function_17_1 ['$6binary_true_divide.2', '_44call_function_17_1', 'b_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b7cd1dcad68>
# DEBUG:numba.core.ssa:on stmt: _44call_function_17_1 = arg(0, name=_44call_function_17_1)
# DEBUG:numba.core.ssa:on stmt: b_1 = arg(1, name=b_1)
# DEBUG:numba.core.ssa:on stmt: $6binary_true_divide.2 = b_1 / _44call_function_17_1
# DEBUG:numba.core.ssa:on stmt: $8return_value.3 = cast(value=$6binary_true_divide.2)
# DEBUG:numba.core.ssa:on stmt: return $8return_value.3
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$6binary_true_divide.2': [<numba.core.ir.Assign object at 0x2b7cd1dcaba8>],
#              '$8return_value.3': [<numba.core.ir.Assign object at 0x2b7cd1dcac50>],
#              '_44call_function_17_1': [<numba.core.ir.Assign object at 0x2b7cd1dca898>],
#              'b_1': [<numba.core.ir.Assign object at 0x2b7cd1dca940>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _44call_function_17_1 = arg(0, name=_44call_function_17_1) ['_44call_function_17_1']
#     b_1 = arg(1, name=b_1)                   ['b_1']
#     $6binary_true_divide.2 = b_1 / _44call_function_17_1 ['$6binary_true_divide.2', '_44call_function_17_1', 'b_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=109)
#            2	LOAD_FAST(arg=1, lineno=109)
#            4	LOAD_FAST(arg=0, lineno=112)
#            6	BINARY_TRUE_DIVIDE(arg=None, lineno=112)
#            8	RETURN_VALUE(arg=None, lineno=112)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=109)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_FAST(arg=1, lineno=109)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_FAST(arg=0, lineno=112)
# DEBUG:numba.core.byteflow:stack ['$c_12.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=BINARY_TRUE_DIVIDE(arg=None, lineno=112)
# DEBUG:numba.core.byteflow:stack ['$c_12.0', '$_56call_function_22_14.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=RETURN_VALUE(arg=None, lineno=112)
# DEBUG:numba.core.byteflow:stack ['$6binary_true_divide.2']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$c_12.0'}), (4, {'res': '$_56call_function_22_14.1'}), (6, {'lhs': '$c_12.0', 'rhs': '$_56call_function_22_14.1', 'res': '$6binary_true_divide.2'}), (8, {'retval': '$6binary_true_divide.2', 'castval': '$8return_value.3'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     _56call_function_22_1 = arg(0, name=_56call_function_22_1) ['_56call_function_22_1']
#     c_1 = arg(1, name=c_1)                   ['c_1']
#     $6binary_true_divide.2 = c_1 / _56call_function_22_1 ['$6binary_true_divide.2', '_56call_function_22_1', 'c_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:-----------------------------------BEFORE SSA-----------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _56call_function_22_1 = arg(0, name=_56call_function_22_1) ['_56call_function_22_1']
#     c_1 = arg(1, name=c_1)                   ['c_1']
#     $6binary_true_divide.2 = c_1 / _56call_function_22_1 ['$6binary_true_divide.2', '_56call_function_22_1', 'c_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b7cd1ee1cc0>
# DEBUG:numba.core.ssa:on stmt: _56call_function_22_1 = arg(0, name=_56call_function_22_1)
# DEBUG:numba.core.ssa:on stmt: c_1 = arg(1, name=c_1)
# DEBUG:numba.core.ssa:on stmt: $6binary_true_divide.2 = c_1 / _56call_function_22_1
# DEBUG:numba.core.ssa:on stmt: $8return_value.3 = cast(value=$6binary_true_divide.2)
# DEBUG:numba.core.ssa:on stmt: return $8return_value.3
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$6binary_true_divide.2': [<numba.core.ir.Assign object at 0x2b7cd1eec470>],
#              '$8return_value.3': [<numba.core.ir.Assign object at 0x2b7cd1eec518>],
#              '_56call_function_22_1': [<numba.core.ir.Assign object at 0x2b7cd1eec160>],
#              'c_1': [<numba.core.ir.Assign object at 0x2b7cd1eec208>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _56call_function_22_1 = arg(0, name=_56call_function_22_1) ['_56call_function_22_1']
#     c_1 = arg(1, name=c_1)                   ['c_1']
#     $6binary_true_divide.2 = c_1 / _56call_function_22_1 ['$6binary_true_divide.2', '_56call_function_22_1', 'c_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# RDKit WARNING: [13:37:33] Enabling RDKit 2019.09.3 jupyter extensions

# %%
apm_delivery = PointMutationExecutor('../input/ala_vacuum.pdb', 
                         '1', 
                         '2', 
                         'VAL',
                        phase='vacuum',
                        barostat=None,
                        periodic_forcefield_kwargs=None, 
                        nonperiodic_forcefield_kwargs={'nonbondedMethod': app.NoCutoff}
                        )
apo_htf = apm_delivery.get_apo_htf()
# Out:
# 2020-06-01 13:40:47,231:(94.40s):perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11
# 2020-06-01 13:40:47,246:(0.01s):proposal_generator:	Conducting polymer point mutation proposal...
# 2020-06-01 13:40:47,257:(0.01s):proposal_generator:[4, 4, 4, 4, 4, 4]
# 2020-06-01 13:40:47,260:(0.00s):proposal_generator:	rank_degenerate_maps: 'NoneType' object has no attribute 'IsAromatic'
# 2020-06-01 13:40:47,263:(0.00s):proposal_generator:Maximum atom matched after hydrogen exceptions: 2
# 2020-06-01 13:40:47,281:(0.02s):geometry:propose: performing forward proposal
# 2020-06-01 13:40:47,284:(0.00s):geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# 2020-06-01 13:40:47,286:(0.00s):geometry:Conducting forward proposal...
# 2020-06-01 13:40:47,289:(0.00s):geometry:Computing proposal order with NetworkX...
# 2020-06-01 13:40:47,294:(0.01s):geometry:number of atoms to be placed: 8
# 2020-06-01 13:40:47,297:(0.00s):geometry:Atom index proposal order is [14, 18, 19, 16, 20, 17, 21, 15]
# 2020-06-01 13:40:47,299:(0.00s):geometry:omitted_bonds: []
# 2020-06-01 13:40:47,302:(0.00s):geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# 2020-06-01 13:40:47,320:(0.02s):geometry:creating growth system...
# 2020-06-01 13:40:47,328:(0.01s):geometry:	creating bond force...
# 2020-06-01 13:40:47,331:(0.00s):geometry:	there are 11 bonds in reference force.
# 2020-06-01 13:40:47,334:(0.00s):geometry:	creating angle force...
# 2020-06-01 13:40:47,336:(0.00s):geometry:	there are 48 angles in reference force.
# 2020-06-01 13:40:47,342:(0.01s):geometry:	creating torsion force...
# 2020-06-01 13:40:47,344:(0.00s):geometry:	creating extra torsions force...
# 2020-06-01 13:40:47,347:(0.00s):geometry:	there are 72 torsions in reference force.
# 2020-06-01 13:40:47,354:(0.01s):geometry:	creating nonbonded force...
# 2020-06-01 13:40:47,357:(0.00s):geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# 2020-06-01 13:40:47,359:(0.00s):geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# 2020-06-01 13:40:47,362:(0.00s):geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# 2020-06-01 13:40:47,364:(0.00s):geometry:		there are 134 in the reference Nonbonded force
# 2020-06-01 13:40:47,379:(0.01s):geometry:Neglected angle terms : []
# 2020-06-01 13:40:47,381:(0.00s):geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# 2020-06-01 13:40:47,384:(0.00s):geometry:extra torsions: {}
# 2020-06-01 13:40:47,386:(0.00s):geometry:neglected angle terms include []
# 2020-06-01 13:40:47,389:(0.00s):geometry:log probability choice of torsions and atom order: -16.061296701914923
# 2020-06-01 13:40:47,392:(0.00s):geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# 2020-06-01 13:40:48,023:(0.63s):geometry:setting atoms_with_positions context new positions
# conducting subsequent work with the following platform: CUDA
# 2020-06-01 13:40:48,563:(0.54s):geometry:There are 8 new atoms
# 2020-06-01 13:40:48,570:(0.01s):geometry:	reduced angle potential = 0.0407752800482258.
# 2020-06-01 13:40:48,696:(0.13s):geometry:	reduced angle potential = 0.04944835780520963.
# 2020-06-01 13:40:48,817:(0.12s):geometry:	reduced angle potential = 0.04677096785714798.
# 2020-06-01 13:40:48,937:(0.12s):geometry:	reduced angle potential = 0.1552786173074734.
# 2020-06-01 13:40:49,058:(0.12s):geometry:	reduced angle potential = 0.3529251674562445.
# 2020-06-01 13:40:49,178:(0.12s):geometry:	reduced angle potential = 1.8370270100270991.
# 2020-06-01 13:40:49,299:(0.12s):geometry:	reduced angle potential = 0.233568867494854.
# 2020-06-01 13:40:49,421:(0.12s):geometry:	reduced angle potential = 0.04567782929077883.
# 2020-06-01 13:40:49,543:(0.12s):geometry:	beginning construction of no_nonbonded final system...
# 2020-06-01 13:40:49,547:(0.00s):geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# 2020-06-01 13:40:49,557:(0.01s):geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# 2020-06-01 13:40:49,560:(0.00s):geometry:	there are 11 bond forces in the no-nonbonded final system
# 2020-06-01 13:40:49,562:(0.00s):geometry:	there are 48 angle forces in the no-nonbonded final system
# 2020-06-01 13:40:49,565:(0.00s):geometry:	there are 72 torsion forces in the no-nonbonded final system
# 2020-06-01 13:40:49,568:(0.00s):geometry:forward final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# 2020-06-01 13:40:50,912:(1.34s):geometry:total reduced potential before atom placement: 16.820920233259045
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# 2020-06-01 13:40:52,639:(1.73s):geometry:total reduced energy added from growth system: -41.6387218233892
# 2020-06-01 13:40:52,643:(0.00s):geometry:final reduced energy -24.817798488654184
# 2020-06-01 13:40:52,646:(0.00s):geometry:sum of energies: -24.817801590130152
# 2020-06-01 13:40:52,648:(0.00s):geometry:magnitude of difference in the energies: 3.1014759684921955e-06
# 2020-06-01 13:40:52,651:(0.00s):geometry:Final logp_proposal: 38.6347128438049
# added energy components: [('CustomBondForce', 0.1907890418646498), ('CustomAngleForce', 8.16441875347046), ('CustomTorsionForce', 7.5583683171625555), ('CustomBondForce', -57.55229793588686)]
# 2020-06-01 13:40:52,922:(0.27s):geometry:logp_reverse: performing reverse proposal
# 2020-06-01 13:40:52,926:(0.00s):geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# 2020-06-01 13:40:52,928:(0.00s):geometry:Conducting forward proposal...
# 2020-06-01 13:40:52,931:(0.00s):geometry:Computing proposal order with NetworkX...
# 2020-06-01 13:40:52,935:(0.00s):geometry:number of atoms to be placed: 2
# 2020-06-01 13:40:52,938:(0.00s):geometry:Atom index proposal order is [11, 15]
# 2020-06-01 13:40:52,940:(0.00s):geometry:omitted_bonds: []
# 2020-06-01 13:40:52,943:(0.00s):geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# 2020-06-01 13:40:52,958:(0.01s):geometry:creating growth system...
# 2020-06-01 13:40:52,964:(0.01s):geometry:	creating bond force...
# 2020-06-01 13:40:52,967:(0.00s):geometry:	there are 9 bonds in reference force.
# 2020-06-01 13:40:52,970:(0.00s):geometry:	creating angle force...
# 2020-06-01 13:40:52,972:(0.00s):geometry:	there are 36 angles in reference force.
# 2020-06-01 13:40:52,976:(0.00s):geometry:	creating torsion force...
# 2020-06-01 13:40:52,979:(0.00s):geometry:	creating extra torsions force...
# 2020-06-01 13:40:52,981:(0.00s):geometry:	there are 42 torsions in reference force.
# 2020-06-01 13:40:52,985:(0.00s):geometry:	creating nonbonded force...
# 2020-06-01 13:40:52,988:(0.00s):geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# 2020-06-01 13:40:52,990:(0.00s):geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# 2020-06-01 13:40:52,993:(0.00s):geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# 2020-06-01 13:40:52,995:(0.00s):geometry:		there are 98 in the reference Nonbonded force
# 2020-06-01 13:40:53,005:(0.01s):geometry:Neglected angle terms : []
# 2020-06-01 13:40:53,007:(0.00s):geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# 2020-06-01 13:40:53,010:(0.00s):geometry:extra torsions: {}
# 2020-06-01 13:40:53,012:(0.00s):geometry:neglected angle terms include []
# 2020-06-01 13:40:53,015:(0.00s):geometry:log probability choice of torsions and atom order: -2.8903717578961645
# 2020-06-01 13:40:53,017:(0.00s):geometry:creating platform, integrators, and contexts; setting growth parameter
# conducting subsequent work with the following platform: CUDA
# 2020-06-01 13:40:53,625:(0.61s):geometry:setting atoms_with_positions context old positions
# conducting subsequent work with the following platform: CUDA
# 2020-06-01 13:40:54,150:(0.53s):geometry:There are 2 new atoms
# 2020-06-01 13:40:54,155:(0.00s):geometry:	reduced angle potential = 8.578546222633222e-06.
# 2020-06-01 13:40:54,279:(0.12s):geometry:	reduced angle potential = 1.1491328110690509.
# 2020-06-01 13:40:54,403:(0.12s):geometry:	beginning construction of no_nonbonded final system...
# 2020-06-01 13:40:54,406:(0.00s):geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# 2020-06-01 13:40:54,415:(0.01s):geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# 2020-06-01 13:40:54,418:(0.00s):geometry:	there are 9 bond forces in the no-nonbonded final system
# 2020-06-01 13:40:54,421:(0.00s):geometry:	there are 36 angle forces in the no-nonbonded final system
# 2020-06-01 13:40:54,423:(0.00s):geometry:	there are 42 torsion forces in the no-nonbonded final system
# 2020-06-01 13:40:54,426:(0.00s):geometry:reverse final system defined with 0 neglected angles.
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# 2020-06-01 13:40:55,763:(1.34s):geometry:total reduced potential before atom placement: 16.82092023325904
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# conducting subsequent work with the following platform: CUDA
# 2020-06-01 13:40:57,436:(1.67s):geometry:total reduced energy added from growth system: 9.132765379135986
# 2020-06-01 13:40:57,439:(0.00s):geometry:final reduced energy 25.953685947680015
# 2020-06-01 13:40:57,442:(0.00s):geometry:sum of energies: 25.953685612395027
# 2020-06-01 13:40:57,444:(0.00s):geometry:magnitude of difference in the energies: 3.352849873294872e-07
# 2020-06-01 13:40:57,447:(0.00s):geometry:Final logp_proposal: 9.797851547049408
# added energy components: [('CustomBondForce', 0.0), ('CustomAngleForce', 1.5196339774707472), ('CustomTorsionForce', 0.0036836193671578284), ('CustomBondForce', 7.60944778229808)]
# 2020-06-01 13:40:57,708:(0.26s):relative:Beginning nonbonded method, total particle, barostat, and exceptions retrieval...
# 2020-06-01 13:40:57,720:(0.01s):relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# 2020-06-01 13:40:57,722:(0.00s):relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# 2020-06-01 13:40:57,725:(0.00s):relative:No unknown forces.
# 2020-06-01 13:40:57,727:(0.00s):relative:Nonbonded method to be used (i.e. from old system): 0
# 2020-06-01 13:40:57,730:(0.00s):relative:Adding and mapping old atoms to hybrid system...
# 2020-06-01 13:40:57,732:(0.00s):relative:Adding and mapping new atoms to hybrid system...
# 2020-06-01 13:40:57,735:(0.00s):relative:No MonteCarloBarostat added.
# 2020-06-01 13:40:57,738:(0.00s):relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# 2020-06-01 13:40:57,741:(0.00s):relative:Determined atom classes.
# 2020-06-01 13:40:57,743:(0.00s):relative:Generating old system exceptions dict...
# 2020-06-01 13:40:57,746:(0.00s):relative:Generating new system exceptions dict...
# 2020-06-01 13:40:57,751:(0.00s):relative:Handling constraints...
# 2020-06-01 13:40:57,754:(0.00s):relative:Handling virtual sites...
# 2020-06-01 13:40:57,756:(0.00s):relative:	_handle_virtual_sites: numVirtualSites: 0
# 2020-06-01 13:40:57,757:(0.00s):relative:Adding bond force terms...
# 2020-06-01 13:40:57,758:(0.00s):relative:Adding angle force terms...
# 2020-06-01 13:40:57,762:(0.00s):relative:Adding torsion force terms...
# 2020-06-01 13:40:57,763:(0.00s):relative:Adding nonbonded force terms...
# 2020-06-01 13:40:57,764:(0.00s):relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b7cd4d99a80> > added to hybrid system
# 2020-06-01 13:40:57,765:(0.00s):relative:	_add_nonbonded_force_terms: nonbonded_method is NoCutoff
# 2020-06-01 13:40:57,766:(0.00s):relative:	_add_nonbonded_force_terms: 0 added to standard nonbonded force
# 2020-06-01 13:40:57,767:(0.00s):relative:	_add_nonbonded_force_terms: 0 added to sterics_custom_nonbonded force
# 2020-06-01 13:40:57,768:(0.00s):relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.CustomNonbondedForce; proxy of <Swig Object of type 'OpenMM::CustomNonbondedForce *' at 0x2b7cd4d99ba0> > added to hybrid system
# 2020-06-01 13:40:57,769:(0.00s):relative:Handling harmonic bonds...
# 2020-06-01 13:40:57,770:(0.00s):relative:	handle_harmonic_bonds: looping through old_system to add relevant terms...
# 2020-06-01 13:40:57,774:(0.00s):relative:	handle_harmonic_bonds: looping through new_system to add relevant terms...
# 2020-06-01 13:40:57,788:(0.01s):relative:Handling harmonic angles...
# 2020-06-01 13:40:57,789:(0.00s):relative:	handle_harmonic_angles: looping through old_system to add relevant terms...
# 2020-06-01 13:40:57,802:(0.01s):relative:	handle_harmonic_angles: looping through new_system to add relevant terms...
# 2020-06-01 13:40:57,811:(0.01s):relative:Handling torsion forces...
# 2020-06-01 13:40:57,812:(0.00s):relative:	handle_periodic_torsion_forces: looping through old_system to add relevant terms...
# 2020-06-01 13:40:57,814:(0.00s):relative:	handle_periodic_torsion_forces: looping through new_system to add relevant terms...
# 2020-06-01 13:40:57,820:(0.01s):relative:Handling nonbonded forces...
# 2020-06-01 13:40:57,827:(0.01s):relative:	handle_nonbonded: looping through all particles in hybrid...
# 2020-06-01 13:40:57,836:(0.01s):relative:	handle_nonbonded: Handling Interaction Groups...
# 2020-06-01 13:40:57,842:(0.01s):relative:	handle_nonbonded: Handling Hybrid Exceptions...
# 2020-06-01 13:40:57,846:(0.00s):relative:	handle_nonbonded: Handling Original Exceptions...
# 2020-06-01 13:40:57,947:(0.10s):relative:Handling unique_new/old interaction exceptions...
# 2020-06-01 13:40:57,950:(0.00s):relative:There are old or new system exceptions...proceeding.

# %%
import logging
import datetime

# Set up logger
class TimeFilter(logging.Filter):
    def filter(self, record):
        try:
            last = self.last
        except AttributeError:
            last = record.relativeCreated
        delta = datetime.datetime.fromtimestamp(record.relativeCreated/1000.0) - datetime.datetime.fromtimestamp(last/1000.0)
        record.relative = '{0:.2f}'.format(delta.seconds + delta.microseconds/1000000.0)
        self.last = record.relativeCreated
        return True
fmt = logging.Formatter(fmt="%(asctime)s:(%(relative)ss):%(name)s:%(message)s")
logging.basicConfig(
    format='%(asctime)s %(levelname)-8s %(message)s',
    level=logging.DEBUG,
    datefmt='%Y-%m-%d %H:%M:%S')
_logger = logging.getLogger()
_logger.setLevel(logging.DEBUG)
[hndl.addFilter(TimeFilter()) for hndl in _logger.handlers]
[hndl.setFormatter(fmt) for hndl in _logger.handlers]
# Out:
# [None]

# %%
# Now we can build the hybrid repex samplers
from perses.annihilation.lambda_protocol import LambdaProtocol
from openmmtools.multistate import MultiStateReporter
from perses.samplers.multistate import HybridRepexSampler
from openmmtools import mcmc
import simtk.unit as unit


suffix = 'run'; selection = 'not water'; checkpoint_interval = 10; n_states = 11; n_cycles = 5000


lambda_protocol = LambdaProtocol(functions='default')
reporter_file = 'reporter.nc'
reporter = MultiStateReporter(reporter_file, analysis_particle_indices = apo_htf.hybrid_topology.select(selection), checkpoint_interval = checkpoint_interval)
hss = HybridRepexSampler(mcmc_moves=mcmc.LangevinSplittingDynamicsMove(timestep= 4.0 * unit.femtoseconds,
                                                                      collision_rate=5.0 / unit.picosecond,
                                                                      n_steps=250,
                                                                      reassign_velocities=False,
                                                                      n_restart_attempts=20,
                                                                      splitting="V R R R O R R R V",
                                                                      constraint_tolerance=1e-06),
                                                                      hybrid_factory=apo_htf, online_analysis_interval=10)
hss.setup(n_states=n_states, temperature=300*unit.kelvin, storage_file = reporter, lambda_protocol = lambda_protocol, endstates=False)
hss.extend(n_cycles)
# Out:
# 2020-06-01 13:41:32,979:(0.00s):openmmtools.multistate.multistatereporter:Initial checkpoint file automatically chosen as reporter_checkpoint.nc
# 2020-06-01 13:41:33,033:(0.05s):multistate:n_replicas not defined, setting to match n_states, 11
# 2020-06-01 13:41:43,071:(10.04s):mpiplus.mpiplus:Cannot find MPI environment. MPI disabled.
# 2020-06-01 13:41:43,075:(0.00s):mpiplus.mpiplus:Single node: executing <bound method MultiStateReporter.storage_exists of <openmmtools.multistate.multistatereporter.MultiStateReporter object at 0x2b7cd51367b8>>
# 2020-06-01 13:41:43,083:(0.01s):mpiplus.mpiplus:Single node: executing <function ReplicaExchangeSampler._display_citations at 0x2b7cc4f14d08>
# 2020-06-01 13:41:43,085:(0.00s):mpiplus.mpiplus:Single node: executing <function MultiStateSampler._display_citations at 0x2b7cc4ed1268>
# 2020-06-01 13:41:43,088:(0.00s):mpiplus.mpiplus:Single node: executing <function MultiStateSampler._initialize_reporter at 0x2b7cc4ed1510>
# 2020-06-01 13:41:43,126:(0.04s):openmmtools.multistate.multistatereporter:Serialized state thermodynamic_states/0 is  6586B | 6.432KB | 0.006MB
# 2020-06-01 13:41:43,152:(0.03s):openmmtools.utils:Storing thermodynamic states took    0.040s
# 2020-06-01 13:41:43,155:(0.00s):openmmtools.multistate.multistatesampler:Storing general ReplicaExchange options...
# 2020-06-01 13:41:43,163:(0.01s):mpiplus.mpiplus:Single node: executing <function MultiStateSampler._report_iteration at 0x2b7cc4ed1620>
# 2020-06-01 13:41:43,166:(0.00s):mpiplus.mpiplus:Single node: executing <function MultiStateSampler._report_iteration_items at 0x2b7cc4ed18c8>
# 2020-06-01 13:41:43,182:(0.02s):openmmtools.utils:Storing sampler states took    0.013s
# 2020-06-01 13:41:43,211:(0.03s):openmmtools.utils:Writing iteration information to storage took    0.045s
# Please cite the following:
#
#         Friedrichs MS, Eastman P, Vaidyanathan V, Houston M, LeGrand S, Beberg AL, Ensign DL, Bruns CM, and Pande VS. Accelerating molecular dynamic simulations on graphics processing unit. J. Comput. Chem. 30:864, 2009. DOI: 10.1002/jcc.21209
#         Eastman P and Pande VS. OpenMM: A hardware-independent framework for molecular simulations. Comput. Sci. Eng. 12:34, 2010. DOI: 10.1109/MCSE.2010.27
#         Eastman P and Pande VS. Efficient nonbonded interactions for molecular dynamics on a graphics processing unit. J. Comput. Chem. 31:1268, 2010. DOI: 10.1002/jcc.21413
#         Eastman P and Pande VS. Constant constraint matrix approximation: A robust, parallelizable constraint method for molecular simulations. J. Chem. Theor. Comput. 6:434, 2010. DOI: 10.1021/ct900463w
#         Chodera JD and Shirts MR. Replica exchange and expanded ensemble simulations as Gibbs multistate: Simple improvements for enhanced mixing. J. Chem. Phys., 135:194110, 2011. DOI:10.1063/1.3660669
# 2020-06-01 13:41:43,306:(0.09s):mpiplus.mpiplus:Single node: executing <bound method MultiStateSampler._store_options of <instance of HybridRepexSampler>>
# 2020-06-01 13:41:43,308:(0.00s):openmmtools.multistate.multistatesampler:Storing general ReplicaExchange options...
# 2020-06-01 13:41:43,313:(0.00s):mpiplus.mpiplus:Running _compute_replica_energies serially.
# 2020-06-01 13:41:43,813:(0.50s):openmmtools.utils:Computing energy matrix took    0.501s
# 2020-06-01 13:41:43,817:(0.00s):mpiplus.mpiplus:Single node: executing <bound method MultiStateReporter.write_energies of <openmmtools.multistate.multistatereporter.MultiStateReporter object at 0x2b7cd51367b8>>
# 2020-06-01 13:41:43,821:(0.00s):openmmtools.multistate.multistatesampler:********************************************************************************
# 2020-06-01 13:41:43,824:(0.00s):openmmtools.multistate.multistatesampler:Iteration 1/5000
# 2020-06-01 13:41:43,827:(0.00s):openmmtools.multistate.multistatesampler:********************************************************************************
# 2020-06-01 13:41:43,829:(0.00s):mpiplus.mpiplus:Single node: executing <function ReplicaExchangeSampler._mix_replicas at 0x2b7cc4f149d8>
# 2020-06-01 13:41:43,832:(0.00s):openmmtools.multistate.replicaexchange:Mixing replicas...
# 2020-06-01 13:41:43,866:(0.03s):openmmtools.utils:Mixing of replicas took    0.032s
# 2020-06-01 13:41:43,869:(0.00s):openmmtools.multistate.replicaexchange:Accepted 14478/29282 attempted swaps (49.4%)
# 2020-06-01 13:41:43,872:(0.00s):openmmtools.multistate.multistatesampler:Propagating all replicas...
# 2020-06-01 13:41:43,874:(0.00s):mpiplus.mpiplus:Running _propagate_replica serially.
# 2020-06-01 13:41:46,727:(2.85s):mpiplus.mpiplus:Running _get_replica_move_statistics serially.
# 2020-06-01 13:41:46,731:(0.00s):openmmtools.utils:Propagating all replicas took    2.860s
# 2020-06-01 13:41:46,734:(0.00s):mpiplus.mpiplus:Running _compute_replica_energies serially.
# 2020-06-01 13:41:46,842:(0.11s):openmmtools.utils:Computing energy matrix took    0.108s
# 2020-06-01 13:41:46,845:(0.00s):mpiplus.mpiplus:Single node: executing <function MultiStateSampler._report_iteration at 0x2b7cc4ed1620>
# 2020-06-01 13:41:46,848:(0.00s):mpiplus.mpiplus:Single node: executing <function MultiStateSampler._report_iteration_items at 0x2b7cc4ed18c8>
# 2020-06-01 13:41:46,851:(0.00s):openmmtools.multistate.multistatereporter:Iteration 1 not on the Checkpoint Interval of 10. Sampler State not written.
# 2020-06-01 13:41:46,858:(0.01s):openmmtools.utils:Storing sampler states took    0.007s
# 2020-06-01 13:41:46,875:(0.02s):openmmtools.utils:Writing iteration information to storage took    0.026s
# 2020-06-01 13:41:46,878:(0.00s):openmmtools.multistate.multistatesampler:Not enough iterations for online analysis (self.online_analysis_minimum_iterations = 200)
# 2020-06-01 13:41:46,880:(0.00s):mpiplus.mpiplus:Single node: executing <function MultiStateSampler._online_analysis at 0x2b7cc4ed4400>
# 2020-06-01 13:41:46,885:(0.01s):openmmtools.multistate.multistatereporter:Creating new NetCDF variable f_k with parameters: {'dtype': dtype('float64'), 'dims': ('dim_size11',), 'chunksizes': (11,)}
# 2020-06-01 13:41:46,889:(0.00s):openmmtools.multistate.multistatereporter:Creating new NetCDF variable free_energy with parameters: {'dtype': <class 'numpy.float64'>, 'dims': ('dim_size2',), 'chunksizes': (2,)}
# 2020-06-01 13:41:46,893:(0.00s):openmmtools.multistate.multistatereporter:Creating new NetCDF variable f_k_history with parameters: {'dtype': dtype('float64'), 'dims': ('iteration', 'dim_size11'), 'chunksizes': (1, 11)}
# 2020-06-01 13:41:46,896:(0.00s):openmmtools.multistate.multistatereporter:Creating new NetCDF variable free_energy_history with parameters: {'dtype': <class 'numpy.float64'>, 'dims': ('iteration', 'dim_size2'), 'chunksizes': (1, 2)}
# 2020-06-01 13:41:46,900:(0.00s):openmmtools.multistate.multistatesampler:*** ONLINE analysis free energies:
# 2020-06-01 13:41:46,903:(0.00s):openmmtools.multistate.multistatesampler:        -0.0    -0.5    -0.7    -0.4    -0.6    -1.7     0.3     0.3     0.3     0.3     0.3
# 2020-06-01 13:41:46,905:(0.00s):openmmtools.utils:Computing online free energy estimate took    0.022s
# 2020-06-01 13:41:46,908:(0.00s):openmmtools.multistate.multistatesampler:Iteration took 3.079s.
# 2020-06-01 13:41:46,911:(0.00s):openmmtools.multistate.multistatesampler:Estimated completion in 4:17:09.650326, at Mon Jun  1 17:58:56 2020 (consuming total wall clock time 4:17:12.736874).
# 2020-06-01 13:41:46,913:(0.00s):openmmtools.multistate.multistatesampler:********************************************************************************
# 2020-06-01 13:41:46,916:(0.00s):openmmtools.multistate.multistatesampler:Iteration 2/5000
# 2020-06-01 13:41:46,918:(0.00s):openmmtools.multistate.multistatesampler:********************************************************************************
# 2020-06-01 13:41:46,921:(0.00s):mpiplus.mpiplus:Single node: executing <function ReplicaExchangeSampler._mix_replicas at 0x2b7cc4f149d8>
# 2020-06-01 13:41:46,924:(0.00s):openmmtools.multistate.replicaexchange:Mixing replicas...
# 2020-06-01 13:41:46,926:(0.00s):openmmtools.utils:Mixing of replicas took    0.001s
# 2020-06-01 13:41:46,929:(0.00s):openmmtools.multistate.replicaexchange:Accepted 12048/29282 attempted swaps (41.1%)
# 2020-06-01 13:41:46,930:(0.00s):openmmtools.multistate.multistatesampler:Propagating all replicas...
# 2020-06-01 13:41:46,931:(0.00s):mpiplus.mpiplus:Running _propagate_replica serially.
# 2020-06-01 13:41:48,020:(1.09s):mpiplus.mpiplus:Running _get_replica_move_statistics serially.
# 2020-06-01 13:41:48,024:(0.00s):openmmtools.utils:Propagating all replicas took    1.094s
# 2020-06-01 13:41:48,026:(0.00s):mpiplus.mpiplus:Running _compute_replica_energies serially.
# 2020-06-01 13:41:48,124:(0.10s):openmmtools.utils:Computing energy matrix took    0.097s
# 2020-06-01 13:41:48,127:(0.00s):mpiplus.mpiplus:Single node: executing <function MultiStateSampler._report_iteration at 0x2b7cc4ed1620>
# 2020-06-01 13:41:48,130:(0.00s):mpiplus.mpiplus:Single node: executing <function MultiStateSampler._report_iteration_items at 0x2b7cc4ed18c8>
# 2020-06-01 13:41:48,132:(0.00s):openmmtools.multistate.multistatereporter:Iteration 2 not on the Checkpoint Interval of 10. Sampler State not written.
# 2020-06-01 13:41:48,139:(0.01s):openmmtools.utils:Storing sampler states took    0.007s
# 2020-06-01 13:41:48,156:(0.02s):openmmtools.utils:Writing iteration information to storage took    0.026s
# 2020-06-01 13:41:48,158:(0.00s):openmmtools.multistate.multistatesampler:Not enough iterations for online analysis (self.online_analysis_minimum_iterations = 200)
# 2020-06-01 13:41:48,161:(0.00s):mpiplus.mpiplus:Single node: executing <function MultiStateSampler._online_analysis at 0x2b7cc4ed4400>
# 2020-06-01 13:41:48,167:(0.01s):openmmtools.multistate.multistatesampler:*** ONLINE analysis free energies:
# 2020-06-01 13:41:48,170:(0.00s):openmmtools.multistate.multistatesampler:        -0.0    -0.7    -1.0    -0.7    -1.2    -3.2     0.4     0.4     0.4     0.4     0.4
# 2020-06-01 13:41:48,172:(0.00s):openmmtools.utils:Computing online free energy estimate took    0.008s
# 2020-06-01 13:41:48,175:(0.00s):openmmtools.multistate.multistatesampler:Iteration took 1.254s.
# 2020-06-01 13:41:48,177:(0.00s):openmmtools.multistate.multistatesampler:Estimated completion in 3:01:18.730706, at Mon Jun  1 16:43:06 2020 (consuming total wall clock time 3:01:23.083940).
# 2020-06-01 13:41:48,180:(0.00s):openmmtools.multistate.multistatesampler:********************************************************************************
# 2020-06-01 13:41:48,183:(0.00s):openmmtools.multistate.multistatesampler:Iteration 3/5000
# 2020-06-01 13:41:48,185:(0.00s):openmmtools.multistate.multistatesampler:********************************************************************************
# 2020-06-01 13:41:48,188:(0.00s):mpiplus.mpiplus:Single node: executing <function ReplicaExchangeSampler._mix_replicas at 0x2b7cc4f149d8>
# 2020-06-01 13:41:48,190:(0.00s):openmmtools.multistate.replicaexchange:Mixing replicas...
# 2020-06-01 13:41:48,194:(0.00s):openmmtools.utils:Mixing of replicas took    0.001s
# 2020-06-01 13:41:48,197:(0.00s):openmmtools.multistate.replicaexchange:Accepted 13790/29282 attempted swaps (47.1%)
# 2020-06-01 13:41:48,198:(0.00s):openmmtools.multistate.multistatesampler:Propagating all replicas...
# 2020-06-01 13:41:48,199:(0.00s):mpiplus.mpiplus:Running _propagate_replica serially.
# 2020-06-01 13:41:49,281:(1.08s):mpiplus.mpiplus:Running _get_replica_move_statistics serially.
# 2020-06-01 13:41:49,285:(0.00s):openmmtools.utils:Propagating all replicas took    1.087s
# 2020-06-01 13:41:49,288:(0.00s):mpiplus.mpiplus:Running _compute_replica_energies serially.
# 2020-06-01 13:41:49,389:(0.10s):openmmtools.utils:Computing energy matrix took    0.101s
# 2020-06-01 13:41:49,392:(0.00s):mpiplus.mpiplus:Single node: executing <function MultiStateSampler._report_iteration at 0x2b7cc4ed1620>
# 2020-06-01 13:41:49,394:(0.00s):mpiplus.mpiplus:Single node: executing <function MultiStateSampler._report_iteration_items at 0x2b7cc4ed18c8>
# 2020-06-01 13:41:49,397:(0.00s):openmmtools.multistate.multistatereporter:Iteration 3 not on the Checkpoint Interval of 10. Sampler State not written.
# 2020-06-01 13:41:49,404:(0.01s):openmmtools.utils:Storing sampler states took    0.007s
# 2020-06-01 13:41:49,432:(0.03s):openmmtools.utils:Writing iteration information to storage took    0.037s
# 2020-06-01 13:41:49,435:(0.00s):openmmtools.multistate.multistatesampler:Not enough iterations for online analysis (self.online_analysis_minimum_iterations = 200)
# 2020-06-01 13:41:49,437:(0.00s):mpiplus.mpiplus:Single node: executing <function MultiStateSampler._online_analysis at 0x2b7cc4ed4400>
# 2020-06-01 13:41:49,444:(0.01s):openmmtools.multistate.multistatesampler:*** ONLINE analysis free energies:
# 2020-06-01 13:41:49,446:(0.00s):openmmtools.multistate.multistatesampler:        -0.0    -0.9    -1.5    -1.0    -1.4    -3.8     0.5     0.5     0.5     0.5     0.5
# 2020-06-01 13:41:49,449:(0.00s):openmmtools.utils:Computing online free energy estimate took    0.009s
# 2020-06-01 13:41:49,451:(0.00s):openmmtools.multistate.multistatesampler:Iteration took 1.264s.
# 2020-06-01 13:41:49,454:(0.00s):openmmtools.multistate.multistatesampler:Estimated completion in 2:36:17.335785, at Mon Jun  1 16:18:06 2020 (consuming total wall clock time 2:36:22.965565).
# 2020-06-01 13:41:49,457:(0.00s):openmmtools.multistate.multistatesampler:********************************************************************************
# 2020-06-01 13:41:49,459:(0.00s):openmmtools.multistate.multistatesampler:Iteration 4/5000
# 2020-06-01 13:41:49,462:(0.00s):openmmtools.multistate.multistatesampler:********************************************************************************
# 2020-06-01 13:41:49,464:(0.00s):mpiplus.mpiplus:Single node: executing <function ReplicaExchangeSampler._mix_replicas at 0x2b7cc4f149d8>
# 2020-06-01 13:41:49,467:(0.00s):openmmtools.multistate.replicaexchange:Mixing replicas...
# 2020-06-01 13:41:49,471:(0.00s):openmmtools.utils:Mixing of replicas took    0.001s
# 2020-06-01 13:41:49,473:(0.00s):openmmtools.multistate.replicaexchange:Accepted 13252/29282 attempted swaps (45.3%)
# 2020-06-01 13:41:49,474:(0.00s):openmmtools.multistate.multistatesampler:Propagating all replicas...
# 2020-06-01 13:41:49,475:(0.00s):mpiplus.mpiplus:Running _propagate_replica serially.
# --------------------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-10-00272a68b708> in <module>
#      22                                                                       hybrid_factory=apo_htf, online_analysis_interval=10)
#      23 hss.setup(n_states=n_states, temperature=300*unit.kelvin, storage_file = reporter, lambda_protocol = lambda_protocol, endstates=False)
# ---> 24 hss.extend(n_cycles)
#
# ~/miniconda3/envs/perses-sims/lib/python3.7/site-packages/openmmtools/multistate/multistatesampler.py in extend(self, n_iterations)
#     727             # This MUST be assigned to a property or the storage won't be updated.
#     728             self.number_of_iterations = self._iteration + n_iterations
# --> 729         self.run(n_iterations)
#     730
#     731     def __repr__(self):
#
# ~/miniconda3/envs/perses-sims/lib/python3.7/site-packages/openmmtools/multistate/multistatesampler.py in run(self, n_iterations)
#     680
#     681             # Propagate replicas.
# --> 682             self._propagate_replicas()
#     683
#     684             # Compute energies of all replicas at all states
#
# ~/miniconda3/envs/perses-sims/lib/python3.7/site-packages/openmmtools/utils.py in _wrapper(*args, **kwargs)
#      85         def _wrapper(*args, **kwargs):
#      86             with time_it(task_name):
# ---> 87                 return func(*args, **kwargs)
#      88         return _wrapper
#      89     return _with_timer
#
# ~/miniconda3/envs/perses-sims/lib/python3.7/site-packages/openmmtools/multistate/multistatesampler.py in _propagate_replicas(self)
#    1196         # for propagation and computation of the energy matrix entries.
#    1197         propagated_states, replica_ids = mpiplus.distribute(self._propagate_replica, range(self.n_replicas),
# -> 1198                                                         send_results_to=0)
#    1199
#    1200         # Update all sampler states. For non-0 nodes, this will update only the
#
# ~/miniconda3/envs/perses-sims/lib/python3.7/site-packages/mpiplus/mpiplus.py in distribute(task, distributed_args, send_results_to, propagate_exceptions_to, sync_nodes, group_size, *other_args, **kwargs)
#     510     if get_mpicomm() is None:
#     511         logger.debug('Running {} serially.'.format(task.__name__))
# --> 512         all_results = [task(job_args, *other_args, **kwargs) for job_args in distributed_args]
#     513         if send_results_to == 'all':
#     514             return all_results
#
# ~/miniconda3/envs/perses-sims/lib/python3.7/site-packages/mpiplus/mpiplus.py in <listcomp>(.0)
#     510     if get_mpicomm() is None:
#     511         logger.debug('Running {} serially.'.format(task.__name__))
# --> 512         all_results = [task(job_args, *other_args, **kwargs) for job_args in distributed_args]
#     513         if send_results_to == 'all':
#     514             return all_results
#
# ~/miniconda3/envs/perses-sims/lib/python3.7/site-packages/openmmtools/multistate/multistatesampler.py in _propagate_replica(self, replica_id)
#    1224         # Apply MCMC move.
#    1225         try:
# -> 1226             mcmc_move.apply(thermodynamic_state, sampler_state)
#    1227         except mcmc.IntegratorMoveError as e:
#    1228             # Save NaNnig context and MCMove before aborting.
#
# ~/miniconda3/envs/perses-sims/lib/python3.7/site-packages/openmmtools/mcmc.py in apply(self, thermodynamic_state, sampler_state)
#    1112         """
#    1113         # Explicitly implemented just to have more specific docstring.
# -> 1114         super(LangevinDynamicsMove, self).apply(thermodynamic_state, sampler_state)
#    1115
#    1116     def __getstate__(self):
#
# ~/miniconda3/envs/perses-sims/lib/python3.7/site-packages/openmmtools/mcmc.py in apply(self, thermodynamic_state, sampler_state)
#     672                 # Run dynamics.
#     673                 timer.start("{}: step({})".format(move_name, self.n_steps))
# --> 674                 integrator.step(self.n_steps)
#     675             except Exception:
#     676                 # Catches particle positions becoming nan during integration.
#
# ~/miniconda3/envs/perses-sims/lib/python3.7/site-packages/simtk/openmm/openmm.py in step(self, steps)
#    2723             the number of time steps to take
#    2724         """
# -> 2725         return _openmm.CustomIntegrator_step(self, steps)
#    2726
#    2727
#
# KeyboardInterrupt:
