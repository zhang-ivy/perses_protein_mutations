# %% [markdown]
# JDC: This is odd: If I integrate the protocol work outside of the CustomIntegrator, I don't see the energy grow when I am just changing lambda_alchemical_bonds_{old|new} at the same time

# %% [markdown]
# Script: /home/chodera/equilibrated_restraint_experiments/281/test_langevin.py

# %%
import openmm
from openmm import unit

prefix = '/home/chodera/equilibrated_restraint_experiments/281/'

def read(filename):
    print(f'Reading {filename}...')
    with open(filename, 'r') as infile:
        return openmm.XmlSerializer.deserialize(infile.read())
    
def test(lambda_param=None):
    
    system = read(f'{prefix}281_apo_system.xml')
    state = read(f'{prefix}281_apo_state.xml')

    forces = { force.getName() : force for (index, force) in enumerate(system.getForces()) }
    cvforce = forces['CustomCVForce']

    platform = openmm.Platform.getPlatformByName('CUDA')
    platform.setPropertyDefaultValue('Precision', 'mixed')
    platform.setPropertyDefaultValue('DeterministicForces', 'true')
    
    print("************K_RMSD != 0************")
    print('Creating context...')
    
    temperature = 300 * unit.kelvin
    collision_rate = 1.0 / unit.picoseconds
    timestep = 4.0 * unit.femtoseconds
    kT = unit.AVOGADRO_CONSTANT_NA * unit.BOLTZMANN_CONSTANT_kB * temperature
    integrator = openmm.LangevinIntegrator(temperature, collision_rate, timestep)
    context = openmm.Context(system, integrator, platform)
    context.setState(state)

    print('Integrating...')
#     nsteps_total = 250000
#     nsteps = 5000
    nsteps = 25000
    lambda_ = 0.0
    keywords = ['bonds', 'angles', 'torsions', 'sterics', 'sterics_exceptions', 'electrostatics',
                 'electrostatics_exceptions']
    for keyword in keywords:
        context.setParameter(f'lambda_alchemical_{keyword}_old', 1.0 - lambda_)
        context.setParameter(f'lambda_alchemical_{keyword}_new', lambda_)
    protocol_work = 0.0
    error = 0.0
    nsteps_per_report = 1000
    for step in range(nsteps):
#         lambda_ = step / nsteps_total
        lambda_ = step / nsteps

        Uold = context.getState(getEnergy=True).getPotentialEnergy() / kT

        for keyword in keywords:
            context.setParameter(f'lambda_alchemical_{keyword}_old', 1.0 - lambda_)
            context.setParameter(f'lambda_alchemical_{keyword}_new', lambda_)
#         context.setParameter('lambda_alchemical_bonds_old', 1.0 - lambda_)
#         context.setParameter('lambda_alchemical_bonds_new', lambda_)

        Unew = context.getState(getEnergy=True).getPotentialEnergy() / kT

        protocol_work += (Unew - Uold)
        time = context.getTime()
        cvs = cvforce.getCollectiveVariableValues(context)
        rmsd = cvs[0]

        if step % nsteps_per_report == 0:
            print(f'step {step:10.0f} : time {time/unit.nanoseconds:10.3f} ns | lambda {lambda_:16.12f} | protocol_work = {protocol_work:12.3f} | RMSD = {rmsd:12.5f} nm')

        integrator.step(1)

    del context, integrator
    
    print("************K_RMSD == 0************")
    print('Creating context...')

    integrator = openmm.LangevinIntegrator(temperature, collision_rate, timestep)
    
    context = openmm.Context(system, integrator, platform)
    context.setState(state)
    
    print(f'Setting K_RMSD to 0')
    context.setParameter('K_RMSD', 0.0)

    print('Integrating...')
#     nsteps_total = 250000
#     nsteps = 5000
    nsteps = 25000
    lambda_ = 0.0
    keywords = ['bonds', 'angles', 'torsions', 'sterics', 'sterics_exceptions', 'electrostatics',
                 'electrostatics_exceptions']
    for keyword in keywords:
        context.setParameter(f'lambda_alchemical_{keyword}_old', 1.0 - lambda_)
        context.setParameter(f'lambda_alchemical_{keyword}_new', lambda_)
    protocol_work = 0.0
    error = 0.0
    nsteps_per_report = 1000
    
    for step in range(nsteps):
#         lambda_ = step / nsteps_total
        lambda_ = step / nsteps
        
        Uold = context.getState(getEnergy=True).getPotentialEnergy() / kT

        for keyword in keywords:
            context.setParameter(f'lambda_alchemical_{keyword}_old', 1.0 - lambda_)
            context.setParameter(f'lambda_alchemical_{keyword}_new', lambda_)

        Unew = context.getState(getEnergy=True).getPotentialEnergy() / kT

        protocol_work += (Unew - Uold)
        time = context.getTime()
        cvs = cvforce.getCollectiveVariableValues(context)
        rmsd = cvs[0]

        if step % nsteps_per_report == 0:
            print(f'step {step:10.0f} : time {time/unit.nanoseconds:10.3f} ns | lambda {lambda_:16.12f} | protocol_work = {protocol_work:12.3f} | RMSD = {rmsd:12.5f} nm')

        integrator.step(1)

    del context, integrator

# %% [markdown]
# ## Run neq changing all lambas

# %%
test()
# Out:
# Reading /home/chodera/equilibrated_restraint_experiments/281/281_apo_system.xml...
# Reading /home/chodera/equilibrated_restraint_experiments/281/281_apo_state.xml...
# ************K_RMSD != 0************
# Creating context...
# Integrating...
# step          0 : time      0.000 ns | lambda   0.000000000000 | protocol_work =       -0.000 | RMSD =      0.00026 nm
# step       1000 : time      0.004 ns | lambda   0.040000000000 | protocol_work =       -2.654 | RMSD =      0.06041 nm
# step       2000 : time      0.008 ns | lambda   0.080000000000 | protocol_work =       -3.130 | RMSD =      0.07256 nm
# step       3000 : time      0.012 ns | lambda   0.120000000000 | protocol_work =       -3.132 | RMSD =      0.08532 nm
# step       4000 : time      0.016 ns | lambda   0.160000000000 | protocol_work =       -2.692 | RMSD =      0.10073 nm
# step       5000 : time      0.020 ns | lambda   0.200000000000 | protocol_work =       -2.195 | RMSD =      0.10423 nm
# step       6000 : time      0.024 ns | lambda   0.240000000000 | protocol_work =       -2.354 | RMSD =      0.10356 nm
# step       7000 : time      0.028 ns | lambda   0.280000000000 | protocol_work =       -2.384 | RMSD =      0.09825 nm
# step       8000 : time      0.032 ns | lambda   0.320000000000 | protocol_work =       -2.235 | RMSD =      0.10506 nm
# step       9000 : time      0.036 ns | lambda   0.360000000000 | protocol_work =       -1.020 | RMSD =      0.09944 nm
# step      10000 : time      0.040 ns | lambda   0.400000000000 | protocol_work =       -0.037 | RMSD =      0.10584 nm
# step      11000 : time      0.044 ns | lambda   0.440000000000 | protocol_work =        0.727 | RMSD =      0.11652 nm
# step      12000 : time      0.048 ns | lambda   0.480000000000 | protocol_work =        1.672 | RMSD =      0.12730 nm
# step      13000 : time      0.052 ns | lambda   0.520000000000 | protocol_work =        2.831 | RMSD =      0.12169 nm
# step      14000 : time      0.056 ns | lambda   0.560000000000 | protocol_work =        3.722 | RMSD =      0.11827 nm
# step      15000 : time      0.060 ns | lambda   0.600000000000 | protocol_work =        4.274 | RMSD =      0.12346 nm
# step      16000 : time      0.064 ns | lambda   0.640000000000 | protocol_work =        5.158 | RMSD =      0.12125 nm
# step      17000 : time      0.068 ns | lambda   0.680000000000 | protocol_work =        5.964 | RMSD =      0.12831 nm
# step      18000 : time      0.072 ns | lambda   0.720000000000 | protocol_work =        6.575 | RMSD =      0.13735 nm
# step      19000 : time      0.076 ns | lambda   0.760000000000 | protocol_work =        7.359 | RMSD =      0.13255 nm
# step      20000 : time      0.080 ns | lambda   0.800000000000 | protocol_work =        7.648 | RMSD =      0.13785 nm
# step      21000 : time      0.084 ns | lambda   0.840000000000 | protocol_work =        7.616 | RMSD =      0.13234 nm
# step      22000 : time      0.088 ns | lambda   0.880000000000 | protocol_work =        7.913 | RMSD =      0.13350 nm
# step      23000 : time      0.092 ns | lambda   0.920000000000 | protocol_work =        7.779 | RMSD =      0.13804 nm
# step      24000 : time      0.096 ns | lambda   0.960000000000 | protocol_work =        7.474 | RMSD =      0.14250 nm
# ************K_RMSD == 0************
# Creating context...
# Setting K_RMSD to 0
# Integrating...
# step          0 : time      0.000 ns | lambda   0.000000000000 | protocol_work =        0.000 | RMSD =      0.00026 nm
# step       1000 : time      0.004 ns | lambda   0.040000000000 | protocol_work =       -2.771 | RMSD =      0.06342 nm
# step       2000 : time      0.008 ns | lambda   0.080000000000 | protocol_work =       -3.321 | RMSD =      0.07609 nm
# step       3000 : time      0.012 ns | lambda   0.120000000000 | protocol_work =       -3.329 | RMSD =      0.08865 nm
# step       4000 : time      0.016 ns | lambda   0.160000000000 | protocol_work =       -2.855 | RMSD =      0.09234 nm
# step       5000 : time      0.020 ns | lambda   0.200000000000 | protocol_work =       -2.392 | RMSD =      0.08637 nm
# step       6000 : time      0.024 ns | lambda   0.240000000000 | protocol_work =       -1.758 | RMSD =      0.09599 nm
# step       7000 : time      0.028 ns | lambda   0.280000000000 | protocol_work =       -0.637 | RMSD =      0.10350 nm
# step       8000 : time      0.032 ns | lambda   0.320000000000 | protocol_work =       -0.118 | RMSD =      0.10336 nm
# step       9000 : time      0.036 ns | lambda   0.360000000000 | protocol_work =        0.092 | RMSD =      0.10851 nm
# step      10000 : time      0.040 ns | lambda   0.400000000000 | protocol_work =        0.630 | RMSD =      0.10842 nm
# step      11000 : time      0.044 ns | lambda   0.440000000000 | protocol_work =        1.594 | RMSD =      0.10006 nm
# step      12000 : time      0.048 ns | lambda   0.480000000000 | protocol_work =        2.958 | RMSD =      0.09557 nm
# step      13000 : time      0.052 ns | lambda   0.520000000000 | protocol_work =        4.324 | RMSD =      0.09043 nm
# step      14000 : time      0.056 ns | lambda   0.560000000000 | protocol_work =        5.128 | RMSD =      0.09643 nm
# step      15000 : time      0.060 ns | lambda   0.600000000000 | protocol_work =        5.770 | RMSD =      0.10697 nm
# step      16000 : time      0.064 ns | lambda   0.640000000000 | protocol_work =        6.372 | RMSD =      0.11448 nm
# step      17000 : time      0.068 ns | lambda   0.680000000000 | protocol_work =        6.933 | RMSD =      0.10611 nm
# step      18000 : time      0.072 ns | lambda   0.720000000000 | protocol_work =        7.844 | RMSD =      0.11210 nm
# step      19000 : time      0.076 ns | lambda   0.760000000000 | protocol_work =        8.610 | RMSD =      0.11992 nm
# step      20000 : time      0.080 ns | lambda   0.800000000000 | protocol_work =        8.855 | RMSD =      0.11156 nm
# step      21000 : time      0.084 ns | lambda   0.840000000000 | protocol_work =        9.004 | RMSD =      0.10248 nm
# step      22000 : time      0.088 ns | lambda   0.880000000000 | protocol_work =        8.942 | RMSD =      0.10912 nm
# step      23000 : time      0.092 ns | lambda   0.920000000000 | protocol_work =        8.695 | RMSD =      0.10566 nm
# step      24000 : time      0.096 ns | lambda   0.960000000000 | protocol_work =        8.325 | RMSD =      0.11101 nm
